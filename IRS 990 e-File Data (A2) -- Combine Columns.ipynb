# %% [markdown]
# # Notes
# - In future runs remove these variables from *binarize_cols*
#     - *F9_12_PC_ACCTG_METHOD_OTHER*
#     - *F9_00_HD_EXEMPT_STATUS_501C*

# %% [markdown]
# # Overview
# This notebook needs to be updated to take into account the new way of creating the *ReturnHeader* variables. Namely, I have updated the concordance file to include additional *ReturnHeader* variables. I have also changed the MongoDB name to be not, for example, 'ReturnHeader.TaxYear' but instead 'ReturnHeader'. In notebook 'A1' I flatten the *ReturnHeader* column and then I will do the combining and renaming. So, I need to make sure the new variables work, and also modify the code below for the following variables:
#
#     'ReturnHeader.TaxYear': 1, 'ReturnHeader.TaxYr': 1,
#     'ReturnHeader.TaxPeriodEndDate': 1, 'ReturnHeader.TaxPeriodEndDt': 1,

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
#http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 250)

# %% [markdown]
# #### Set working directory

# %%
#cd '/Users/gsaxton/Dropbox/990 e-file data'

# %%
pwd
# Out:
# 'C:\\Users\\Gregory\\IRS 990 Control Variables'

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# # Read in Concordance File
# We are going to read in two codebooks. First, there is the 'concordance' file. Specifically, before re-arranging and renaming variables, we will read in the relevant section from the *master concordance* file, and then use this file to identify the relevant 'compensation' variables. In a following notebook, we will be using the *new_variable_name* field as our variable name.

# %%
concordance = pd.read_excel('concordance_VERIFIED.xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# # of columns: 15
# # of observations: 388
#                                    xpath project     variable_name_new  \
# 0  /Return/ReturnHeader/TaxPeriodEndDate     NaN  F9_00_HD_TAX_PER_END
# 1    /Return/ReturnHeader/TaxPeriodEndDt     NaN  F9_00_HD_TAX_PER_END
#
#    # of Characters (newly named) variable name notes  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
#
#                        PARSING NOTES OTHER NOTES          description  \
# 0  Will be nested under ReturnHeader         NaN  Tax period end date
# 1  Will be nested under ReturnHeader         NaN  Tax period end date
#
#   location_code part data_type_xsd BINARIZE      MongoDB_Name sub_key  \
# 0        HEADER   HD      DateType      NaN  TaxPeriodEndDate     NaN
# 1        HEADER   HD      DateType      NaN    TaxPeriodEndDt     NaN
#
#   sub_sub_key
# 0         NaN
# 1         NaN

# %%
concordance['data_type_xsd'].value_counts().sum()
# Out:
# 372

# %%
concordance[concordance['data_type_xsd'].isnull()][['variable_name_new', 'description']]
# Out:
#                     variable_name_new                            description
# 4           F9_00_HD_BUILD_TIME_STAMP  Build time stamp - IRS internal field
# 11                          TaxPeriod                                    NaN
# 290   F9_09_PC_FEES_FOR_SVCE_MGMT_TOT                                    NaN
# 291   F9_09_PC_FEES_FOR_SVCE_MGMT_TOT                                    NaN
# 292   F9_09_PC_FEES_FOR_SVCE_LEGL_TOT                                    NaN
# 293   F9_09_PC_FEES_FOR_SVCE_LEGL_TOT                                    NaN
# 294   F9_09_PC_FEES_FOR_SVCE_ACCT_TOT                                    NaN
# 295   F9_09_PC_FEES_FOR_SVCE_ACCT_TOT                                    NaN
# 296   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT                                    NaN
# 297   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT                                    NaN
# 298     F9_09_PC_FEES_FOR_SVCE_FR_TOT                                    NaN
# 299     F9_09_PC_FEES_FOR_SVCE_FR_TOT                                    NaN
# 300  F9_09_PC_FEES_FOR_SVCE_INVST_TOT                                    NaN
# 301  F9_09_PC_FEES_FOR_SVCE_INVST_TOT                                    NaN
# 302    F9_09_PC_FEES_FOR_SVCE_OTH_TOT                                    NaN
# 303    F9_09_PC_FEES_FOR_SVCE_OTH_TOT                                    NaN
# 378                               NaN                                    NaN

# %%
concordance['data_type_xsd'].value_counts()
# Out:
# USAmountType            167
# BooleanType              72
# CheckboxType             48
# USAmountNNType           39
# IntegerNNType             8
# CountType                 8
# StateType                 6
# DateType                  4
# YearType                  4
# LineExplanationType       4
# TextType                  2
# PersonNameType            2
# CountryType               2
# StringType                2
# ShortExplanationType      2
# TimestampType             2
# Name: data_type_xsd, dtype: int64

# %%
concordance[concordance['data_type_xsd']=='BooleanType'][:1]
# Out:
#                                                  xpath project  \
# 26  /Return/ReturnData/IRS990/GroupReturnForAffiliates     NaN
#
#         variable_name_new  # of Characters (newly named) variable name notes  \
# 26  F9_00_HD_GROUP_RETURN                            NaN                 NaN
#
#    PARSING NOTES OTHER NOTES  \
# 26           NaN         NaN
#
#                                                description  \
# 26  Indicates this form is a group return for subordinates
#
#                  location_code     part data_type_xsd  BINARIZE  \
# 26  F990-PC-PART-00-SECTION-HA  PART-00   BooleanType  binarize
#
#                 MongoDB_Name sub_key sub_sub_key
# 26  GroupReturnForAffiliates     NaN         NaN

# %%
concordance[concordance['data_type_xsd']=='CheckboxType'][:1]
# Out:
#                                       xpath project     variable_name_new  \
# 14  /Return/ReturnData/IRS990/AddressChange     NaN  F9_00_HD_ADDR_CHANGE
#
#     # of Characters (newly named) variable name notes PARSING NOTES  \
# 14                           20.0                 NaN           NaN
#
#    OTHER NOTES                                description  \
# 14         NaN  Indicates this form has an address change
#
#                 location_code     part data_type_xsd  BINARIZE   MongoDB_Name  \
# 14  F990-PC-PART-00-SECTION-B  PART-00  CheckboxType  binarize  AddressChange
#
#    sub_key sub_sub_key
# 14     NaN         NaN

# %% [markdown]
# # Read 990 DB into PANDAS
# - In previous round there were 1,547,828 observations; in Feb. 2020 there were 1,727,056 observations; in Nov. 2020 there are 1,895,016 observations
# - I also switched to using the *.pkl* file

# %%
#df = pd.read_csv('all filings - all control variables.csv', low_memory=False)
#print('# of columns:', len(df.columns))
#print('# of observations:', len(df))
#df[:2]

# %%
# %%time
df = pd.read_pickle('all filings nov. 2020 - all control variables.pkl.gz', compression='gzip')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:2]
# Out:
# # of columns: 324
# # of observations: 1895016
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod        EIN  \
# 0  93493313013011    201012  232705170
# 1  93493313013111    201106  581805618
#
#                                                                                                                                                                                                                                                 ReturnHeader  \
# 0  {'@binaryAttachmentCount': '0', 'Timestamp': '2011-11-09T06:41:09-06:00', 'TaxPeriodEndDate': '2010-12-31', 'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'CONCANNON MILLER & CO PC'}, 'PreparerFirmUSAddress': {'AddressLine1': ...
# 1  {'@binaryAttachmentCount': '0', 'Timestamp': '2011-11-09T07:32:06-08:00', 'TaxPeriodEndDate': '2011-06-30', 'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'MADDOX & ASSOCIATES APC'}, 'PreparerFirmUSAddress': {'AddressLine1': '...
#
#   AddressChange NameOfPrincipalOfficerPerson GrossReceipts  \
# 0             X                MICHAEL ANTON       1473903
# 1           NaN                          NaN        266420
#
#   GroupReturnForAffiliates Organization501c3 WebSite  \
# 0                        0                 X     N/A
# 1                    false                 X     N/A
#
#   TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 0                             X          1992                 PA
# 1                             X          1993                 WY
#
#                                                                                                                     ActivityOrMissionDescription  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
# 1                            19                          13                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
# 1                NaN             0                            NaN
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
# 1                          NaN                              0
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
# 1                         222839                  265592
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
# 1                      1425                         828                   NaN
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
# 1                       0                224264                  266420
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
# 1                            NaN                       0
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
# 1                            NaN                       0                71405
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
# 1                  82955                           NaN                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
# 1                           0                189785                   222550
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
# 1                 261190                   305505
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
# 1                        -36926                 -39085        1455332
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
# 1        1433342               17482               34577
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
# 1                    1437850                    1398765
#
#   ProfessionalFundraising FundraisingActivities Gaming  \
# 0                       0                     0      0
# 1                   false                 false  false
#
#   NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 0                            10                             10
# 1                            19                             13
#
#   FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 0                            0                            0
# 1                         true                         true
#
#   ChangesToOrganizingDocs MaterialDiversionOrMisuse MembersOrStockholders  \
# 0                       0                         0                     0
# 1                   false                     false                 false
#
#   ElectionOfBoardMembers DecisionsSubjectToApproval MinutesOfGoverningBody  \
# 0                      0                          0                      1
# 1                   true                       true                   true
#
#   MinutesOfCommittees OfficerMailingAddress LocalChapters  \
# 0                   1                     0             0
# 1                true                 false         false
#
#   Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 0                              1                        1
# 1                           true                     true
#
#   AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 0                              1                            1
# 1                           true                         true
#
#   WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 0                   0                       0                      0
# 1               false                   false                   true
#
#   CompensationProcessOther InvestmentInJointVenture  \
# 0                        0                        0
# 1                     true                    false
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0                   [PA, NJ, DE]           X                          X
# 1                            NaN           X                        NaN
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
# 1                        NaN                        1180355
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
# 1                 411648                       0          true
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
# 1            true                        false                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
# 1                   NaN                  0                 0
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
# 1                                                              {'TotalRevenueColumn': '266420', 'RelatedOrExemptFunctionIncome': '266420'}
#
#                               FeesForServicesLegal  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
# 1                                   {'Total': '0'}
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
# 1    {'Total': '7500', 'ManagementAndGeneral': '7500'}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
# 1          {'Total': '305505', 'ProgramServices': '276405', 'ManagementAndGeneral': '29100', 'Fundraising': '0'}
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 0  {'BOY': '332660', 'EOY': '270700'}                      256845
# 1                        {'EOY': '0'}                     2187206
#
#   LandBldgEquipmentAccumDeprec                           TotalAssets  \
# 0                        86228  {'BOY': '1925215', 'EOY': '2440859'}
# 1                       904332  {'BOY': '1455332', 'EOY': '1433342'}
#
#                     OtherLiabilities FollowSFAS117  \
# 0  {'BOY': '51640', 'EOY': '240077'}             X
# 1    {'BOY': '9203', 'EOY': '11349'}             X
#
#   ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 0                        89152                         X
# 1                       -39085                         X
#
#   AccountantCompileOrReview FSAudited AuditCommittee  \
# 0                         0         1              1
# 1                     false      true           true
#
#   FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 0                         0                   NaN                  NaN
# 1                      true                 false                 1736
#
#   PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 0                       NaN                      NaN
# 1                     false                    false
#
#   TotalProgramServiceRevenue CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                        NaN                          NaN                NaN
# 1                     265592               {'Total': '0'}     {'Total': '0'}
#
#                             OtherSalariesAndWages PensionPlanContributions  \
# 0                                             NaN                      NaN
# 1  {'Total': '59440', 'ProgramServices': '59440'}           {'Total': '0'}
#
#                             OtherEmployeeBenefits  \
# 0                                             NaN
# 1  {'Total': '17714', 'ProgramServices': '17714'}
#
#                                    PayrollTaxes  \
# 0                                           NaN
# 1  {'Total': '5801', 'ProgramServices': '5801'}
#
#                              FeesForServicesManagement  \
# 0                                                  NaN
# 1  {'Total': '21600', 'ManagementAndGeneral': '21600'}
#
#   FeesForServicesLobbying FeesForServicesProfFundraising  \
# 0                     NaN                            NaN
# 1          {'Total': '0'}                 {'Total': '0'}
#
#   FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 0                           NaN                  NaN
# 1                {'Total': '0'}       {'Total': '0'}
#
#            CashNonInterestBearing  MortNotesPyblSecuredInvestProp  \
# 0                             NaN                             NaN
# 1  {'BOY': '250', 'EOY': '22261'}  {'BOY': '6219', 'EOY': '7035'}
#
#   FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 0                        NaN                        NaN
# 1                       true                        NaN
#
#   MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 0                    NaN                      NaN          NaN
# 1                    NaN                      NaN          NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0               NaN                            NaN                  NaN
# 1               NaN                            NaN                  NaN
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                          NaN                       NaN                NaN
# 1                          NaN                       NaN                NaN
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0              NaN                     NaN                   NaN
# 1              NaN                     NaN                   NaN
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0             NaN                NaN                          NaN
# 1             NaN                NaN                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0           NaN            NaN               NaN                  NaN
# 1           NaN            NaN               NaN                  NaN
#
#   NoncashContributions OwnWebsite UnsecuredNotesLoansPayable  \
# 0                  NaN        NaN                        NaN
# 1                  NaN        NaN                        NaN
#
#   TypeOfOrganizationOther Organization501c TypeOfOrganizationTrust  \
# 0                     NaN              NaN                     NaN
# 1                     NaN              NaN                     NaN
#
#   TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 0                           NaN                  NaN           NaN
# 1                           NaN                  NaN           NaN
#
#   TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 0                       NaN              NaN                      NaN
# 1                       NaN              NaN                      NaN
#
#   SpecialConditionDescription Organization4947a1  \
# 0                         NaN                NaN
# 1                         NaN                NaN
#
#   ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
#
#   ReconcilationDonatedServices ReconcilationInvestExpenses PrincipalOfficerNm  \
# 0                          NaN                         NaN                NaN
# 1                          NaN                         NaN                NaN
#
#   GrossReceiptsAmt GroupReturnForAffiliatesInd Organization501c3Ind  \
# 0              NaN                         NaN                  NaN
# 1              NaN                         NaN                  NaN
#
#   TypeOfOrganizationCorpInd FormationYr LegalDomicileStateCd  \
# 0                       NaN         NaN                  NaN
# 1                       NaN         NaN                  NaN
#
#   ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                   NaN                           NaN
# 1                   NaN                           NaN
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                         NaN              NaN              NaN
# 1                         NaN              NaN              NaN
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                      NaN                        NaN                   NaN
# 1                      NaN                        NaN                   NaN
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0               NaN               NaN                       NaN
# 1               NaN               NaN                       NaN
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                        NaN                          NaN                NaN
# 1                        NaN                          NaN                NaN
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0                NaN                       NaN               NaN
# 1                NaN                       NaN               NaN
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0               NaN                    NaN                           NaN
# 1               NaN                    NaN                           NaN
#
#   NetAssetsOrFundBalancesEOYAmt ProfessionalFundraisingInd  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
#
#   FundraisingActivitiesInd GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 0                      NaN                 NaN                           NaN
# 1                      NaN                 NaN                           NaN
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                        NaN                    NaN                       NaN
# 1                        NaN                    NaN                       NaN
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                    NaN                      NaN              NaN
# 1                    NaN                      NaN              NaN
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                    NaN                        NaN                       NaN
# 1                    NaN                        NaN                       NaN
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                          NaN               NaN            NaN
# 1                          NaN               NaN            NaN
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
#
#   TotalRevenueGrp FeesForServicesAccountingGrp TotalFunctionalExpensesGrp  \
# 0             NaN                          NaN                        NaN
# 1             NaN                          NaN                        NaN
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                       NaN            NaN                        NaN
# 1                       NaN            NaN                        NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                       NaN                          NaN          NaN
# 1                       NaN                          NaN          NaN
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                          NaN               NaN                NaN
# 1                          NaN               NaN                NaN
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                        NaN                   NaN               NaN
# 1                        NaN                   NaN               NaN
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0               NaN                       NaN                        NaN
# 1               NaN                       NaN                        NaN
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                          NaN                        NaN                NaN
# 1                          NaN                        NaN                NaN
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0                NaN                       NaN                    NaN
# 1                NaN                       NaN                    NaN
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                            NaN                       NaN            NaN
# 1                            NaN                       NaN            NaN
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt CompCurrentOfcrDirectorsGrp  \
# 0                      NaN                NaN                         NaN
# 1                      NaN                NaN                         NaN
#
#   OtherSalariesAndWagesGrp PensionPlanContributionsGrp  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
#
#   OtherEmployeeBenefitsGrp PayrollTaxesGrp FeesForServicesOtherGrp  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
#
#   SavingsAndTempCashInvstGrp LandBldgEquipCostOrOtherBssAmt  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   LandBldgEquipAccumDeprecAmt MortgNotesPyblScrdInvstPropGrp  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
#
#   OtherLiabilitiesGrp OrganizationFollowsSFAS117Ind  \
# 0                 NaN                           NaN
# 1                 NaN                           NaN
#
#   NetUnrlzdGainsLossesInvstAmt AuditCommitteeInd AllAffiliatesIncludedInd  \
# 0                          NaN               NaN                      NaN
# 1                          NaN               NaN                      NaN
#
#   CompDisqualPersonsGrp FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
# 1                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
#
#   TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                           NaN                          NaN             NaN
# 1                           NaN                          NaN             NaN
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0              NaN                         NaN                     NaN
# 1              NaN                         NaN                     NaN
#
#   OwnWebsiteInd DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0           NaN                           NaN                    NaN
# 1           NaN                           NaN                    NaN
#
#   TypeOfOrganizationTrustInd FinalReturnInd ContractTerminationInd  \
# 0                        NaN            NaN                    NaN
# 1                        NaN            NaN                    NaN
#
#   GroupExemptionNum FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0               NaN                   NaN                        NaN
# 1               NaN                   NaN                        NaN
#
#   OtherOrganizationDsc TypeOfOrganizationAssocInd InitialReturnInd  \
# 0                  NaN                        NaN              NaN
# 1                  NaN                        NaN              NaN
#
#   GamingGrossIncomeAmt GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 0                  NaN                     NaN                        NaN
# 1                  NaN                     NaN                        NaN
#
#   InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 0                  NaN                 NaN                        NaN
# 1                  NaN                 NaN                        NaN
#
#   AmendedReturnInd SpecialConditionDesc fiscal_year
# 0              NaN                  NaN        2010
# 1              NaN                  NaN        2011

# %%
df[-2:]
# Out:
#                                     OrganizationName  \
# 1895014  COMMUNICATION WORKERS OF AMERICA LOCAL 6201
# 1895015                                          NaN
#
#                                                                          URL  \
# 1895014  https://s3.amazonaws.com/irs-form-990/202022309349303577_public.xml
# 1895015                                                                  NaN
#
#                     DLN TaxPeriod        EIN  \
# 1895014  93493230035770    201909  750817126
# 1895015             NaN       NaN        NaN
#
#                                                                                                                                                                                                                                                       ReturnHeader  \
# 1895014  {'@binaryAttachmentCnt': '0', 'ReturnTs': '2020-08-17T17:18:05-07:00', 'TaxPeriodEndDt': '2019-09-30', 'PreparerFirmGrp': {'PreparerFirmEIN': '274601790', 'PreparerFirmName': {'BusinessNameLine1Txt': 'Daryl C Soward CPA'}, 'PreparerUSAddress': {'...
# 1895015  {'@binaryAttachmentCnt': '0', 'ReturnTs': '2019-11-15T10:29:26-06:00', 'TaxPeriodEndDt': '2018-12-31', 'PreparerFirmGrp': {'PreparerFirmEIN': '770051130', 'PreparerFirmName': {'BusinessNameLine1Txt': 'ABBOTT STRINGHAM & LYNCH'}, 'PreparerUSAddres...
#
#         AddressChange NameOfPrincipalOfficerPerson GrossReceipts  \
# 1895014           NaN                          NaN           NaN
# 1895015           NaN                          NaN           NaN
#
#         GroupReturnForAffiliates Organization501c3 WebSite  \
# 1895014                      NaN               NaN     NaN
# 1895015                      NaN               NaN     NaN
#
#         TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 1895014                           NaN           NaN                NaN
# 1895015                           NaN           NaN                NaN
#
#         ActivityOrMissionDescription NbrVotingMembersGoverningBody  \
# 1895014                          NaN                           NaN
# 1895015                          NaN                           NaN
#
#         NbrIndependentVotingMembers TotalNbrEmployees TotalNbrVolunteers  \
# 1895014                         NaN               NaN                NaN
# 1895015                         NaN               NaN                NaN
#
#         TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 1895014           NaN                            NaN
# 1895015           NaN                            NaN
#
#         ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 1895014                          NaN                            NaN
# 1895015                          NaN                            NaN
#
#         ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 1895014                            NaN                     NaN
# 1895015                            NaN                     NaN
#
#         InvestmentIncomePriorYear InvestmentIncomeCurrentYear  \
# 1895014                       NaN                         NaN
# 1895015                       NaN                         NaN
#
#         OtherRevenuePriorYear OtherRevenueCurrentYear TotalRevenuePriorYear  \
# 1895014                   NaN                     NaN                   NaN
# 1895015                   NaN                     NaN                   NaN
#
#         TotalRevenueCurrentYear GrantsAndSimilarAmntsPriorYear  \
# 1895014                     NaN                            NaN
# 1895015                     NaN                            NaN
#
#         GrantsAndSimilarAmntsCY BenefitsPaidToMembersPriorYear  \
# 1895014                     NaN                            NaN
# 1895015                     NaN                            NaN
#
#         BenefitsPaidToMembersCY SalariesEtcPriorYear SalariesEtcCurrentYear  \
# 1895014                     NaN                  NaN                    NaN
# 1895015                     NaN                  NaN                    NaN
#
#         TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 1895014                           NaN                    NaN
# 1895015                           NaN                    NaN
#
#         TotalFundrsngExpCurrentYear OtherExpensePriorYear  \
# 1895014                         NaN                   NaN
# 1895015                         NaN                   NaN
#
#         OtherExpensesCurrentYear TotalExpensesPriorYear  \
# 1895014                      NaN                    NaN
# 1895015                      NaN                    NaN
#
#         TotalExpensesCurrentYear RevenuesLessExpensesPriorYear  \
# 1895014                      NaN                           NaN
# 1895015                      NaN                           NaN
#
#         RevenuesLessExpensesCY TotalAssetsBOY TotalAssetsEOY  \
# 1895014                    NaN            NaN            NaN
# 1895015                    NaN            NaN            NaN
#
#         TotalLiabilitiesBOY TotalLiabilitiesEOY NetAssetsOrFundBalancesBOY  \
# 1895014                 NaN                 NaN                        NaN
# 1895015                 NaN                 NaN                        NaN
#
#         NetAssetsOrFundBalancesEOY ProfessionalFundraising  \
# 1895014                        NaN                     NaN
# 1895015                        NaN                     NaN
#
#         FundraisingActivities Gaming NbrVotingGoverningBodyMembers  \
# 1895014                   NaN    NaN                           NaN
# 1895015                   NaN    NaN                           NaN
#
#         NumberIndependentVotingMembers FamilyOrBusinessRelationship  \
# 1895014                            NaN                          NaN
# 1895015                            NaN                          NaN
#
#         DelegationOfManagementDuties ChangesToOrganizingDocs  \
# 1895014                          NaN                     NaN
# 1895015                          NaN                     NaN
#
#         MaterialDiversionOrMisuse MembersOrStockholders  \
# 1895014                       NaN                   NaN
# 1895015                       NaN                   NaN
#
#         ElectionOfBoardMembers DecisionsSubjectToApproval  \
# 1895014                    NaN                        NaN
# 1895015                    NaN                        NaN
#
#         MinutesOfGoverningBody MinutesOfCommittees OfficerMailingAddress  \
# 1895014                    NaN                 NaN                   NaN
# 1895015                    NaN                 NaN                   NaN
#
#         LocalChapters Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 1895014           NaN                            NaN                      NaN
# 1895015           NaN                            NaN                      NaN
#
#         AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 1895014                            NaN                          NaN
# 1895015                            NaN                          NaN
#
#         WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 1895014                 NaN                     NaN                    NaN
# 1895015                 NaN                     NaN                    NaN
#
#         CompensationProcessOther InvestmentInJointVenture  \
# 1895014                      NaN                      NaN
# 1895015                      NaN                      NaN
#
#         StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 1895014                            NaN         NaN                        NaN
# 1895015                            NaN         NaN                        NaN
#
#         TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 1895014                        NaN                            NaN
# 1895015                        NaN                            NaN
#
#         TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 1895014                    NaN                     NaN           NaN
# 1895015                    NaN                     NaN           NaN
#
#         TotalCompGT150K CompensationFromOtherSources  \
# 1895014             NaN                          NaN
# 1895015             NaN                          NaN
#
#         NumberOfContractorsGT100K AllOtherContributions TotalContributions  \
# 1895014                       NaN                   NaN                NaN
# 1895015                       NaN                   NaN                NaN
#
#         TotalOtherRevenue TotalRevenue FeesForServicesLegal  \
# 1895014               NaN          NaN                  NaN
# 1895015               NaN          NaN                  NaN
#
#         FeesForServicesAccounting TotalFunctionalExpenses  \
# 1895014                       NaN                     NaN
# 1895015                       NaN                     NaN
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 1895014                           NaN                         NaN
# 1895015                           NaN                         NaN
#
#         LandBldgEquipmentAccumDeprec TotalAssets OtherLiabilities  \
# 1895014                          NaN         NaN              NaN
# 1895015                          NaN         NaN              NaN
#
#         FollowSFAS117 ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 1895014           NaN                          NaN                       NaN
# 1895015           NaN                          NaN                       NaN
#
#         AccountantCompileOrReview FSAudited AuditCommittee  \
# 1895014                       NaN       NaN            NaN
# 1895015                       NaN       NaN            NaN
#
#         FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 1895014                       NaN                   NaN                  NaN
# 1895015                       NaN                   NaN                  NaN
#
#         PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 1895014                       NaN                      NaN
# 1895015                       NaN                      NaN
#
#         TotalProgramServiceRevenue CompCurrentOfficersDirectors  \
# 1895014                        NaN                          NaN
# 1895015                        NaN                          NaN
#
#         CompDisqualPersons OtherSalariesAndWages PensionPlanContributions  \
# 1895014                NaN                   NaN                      NaN
# 1895015                NaN                   NaN                      NaN
#
#         OtherEmployeeBenefits PayrollTaxes FeesForServicesManagement  \
# 1895014                   NaN          NaN                       NaN
# 1895015                   NaN          NaN                       NaN
#
#         FeesForServicesLobbying FeesForServicesProfFundraising  \
# 1895014                     NaN              {'TotalAmt': '0'}
# 1895015                     NaN                            NaN
#
#         FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 1895014                           NaN                  NaN
# 1895015                           NaN                  NaN
#
#         CashNonInterestBearing MortNotesPyblSecuredInvestProp  \
# 1895014                    NaN                            NaN
# 1895015                    NaN                            NaN
#
#         FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 1895014                        NaN                        NaN
# 1895015                        NaN                        NaN
#
#         MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 1895014                    NaN                      NaN          NaN
# 1895015                    NaN                      NaN          NaN
#
#         FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 1895014               NaN                            NaN                  NaN
# 1895015               NaN                            NaN                  NaN
#
#         GrossIncomeFundraisingEvents FundraisingDirectExpenses  \
# 1895014                          NaN                       NaN
# 1895015                          NaN                       NaN
#
#         FederatedCampaigns GovernmentGrants MethodOfAccountingOther  \
# 1895014                NaN              NaN                     NaN
# 1895015                NaN              NaN                     NaN
#
#         GrossSalesOfInventory CostOfGoodsSold DoNotFollowSFAS117  \
# 1895014                   NaN             NaN                NaN
# 1895015                   NaN             NaN                NaN
#
#         RetainedEarningsEndowmentEtc InitialReturn MembershipDues  \
# 1895014                          NaN           NaN            NaN
# 1895015                          NaN           NaN            NaN
#
#         GrossIncomeGaming GamingDirectExpenses NoncashContributions  \
# 1895014               NaN                  NaN                  NaN
# 1895015               NaN                  NaN                  NaN
#
#         OwnWebsite UnsecuredNotesLoansPayable TypeOfOrganizationOther  \
# 1895014        NaN                        NaN                     NaN
# 1895015        NaN                        NaN                     NaN
#
#         Organization501c TypeOfOrganizationTrust  \
# 1895014              NaN                     NaN
# 1895015              NaN                     NaN
#
#         TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 1895014                           NaN                  NaN           NaN
# 1895015                           NaN                  NaN           NaN
#
#         TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 1895014                       NaN              NaN                      NaN
# 1895015                       NaN              NaN                      NaN
#
#         SpecialConditionDescription Organization4947a1  \
# 1895014                         NaN                NaN
# 1895015                         NaN                NaN
#
#         ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 1895014                            NaN                          NaN
# 1895015                            NaN                          NaN
#
#         ReconcilationDonatedServices ReconcilationInvestExpenses  \
# 1895014                          NaN                         NaN
# 1895015                          NaN                         NaN
#
#         PrincipalOfficerNm GrossReceiptsAmt GroupReturnForAffiliatesInd  \
# 1895014                NaN           496889                       false
# 1895015          JOHN MORA             1075                           0
#
#         Organization501c3Ind TypeOfOrganizationCorpInd FormationYr  \
# 1895014                  NaN                       NaN         NaN
# 1895015                    X                         X        2006
#
#         LegalDomicileStateCd  \
# 1895014                   TX
# 1895015                   CA
#
#                                                                    ActivityOrMissionDesc  \
# 1895014  Local Labor Union Representing Members of the Communication Workers of America.
# 1895015                           OPERATING YOUTH SPORTS PROGRAMS FOR THE PUBLIC BENEFIT
#
#         VotingMembersGoverningBodyCnt VotingMembersIndependentCnt  \
# 1895014                             4                           0
# 1895015                             3                           0
#
#         TotalEmployeeCnt TotalGrossUBIAmt CYContributionsGrantsAmt  \
# 1895014               41                0                   474396
# 1895015                0                0                        0
#
#         CYProgramServiceRevenueAmt CYInvestmentIncomeAmt CYOtherRevenueAmt  \
# 1895014                          0                 20351              2142
# 1895015                       1075                     0                 0
#
#         CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 1895014            496889                         0
# 1895015              1075                         0
#
#         CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 1895014                          0                       296767
# 1895015                          0                            0
#
#         CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt  \
# 1895014                          0                            0
# 1895015                          0                            0
#
#         CYOtherExpensesAmt CYTotalExpensesAmt CYRevenuesLessExpensesAmt  \
# 1895014             246540             543307                    -46418
# 1895015              10378              10378                     -9303
#
#         TotalAssetsBOYAmt TotalAssetsEOYAmt TotalLiabilitiesEOYAmt  \
# 1895014           3167749           3121837                    817
# 1895015             32567             23264                      0
#
#         NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 1895014                       3167438                       3121020
# 1895015                         32567                         23264
#
#         ProfessionalFundraisingInd FundraisingActivitiesInd  \
# 1895014                      false                    false
# 1895015                          0                        0
#
#         GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 1895014               false                             4
# 1895015                   0                             3
#
#         IndependentVotingMemberCnt FamilyOrBusinessRlnInd  \
# 1895014                          0                  false
# 1895015                          0                      0
#
#         DelegationOfMgmtDutiesInd ChangeToOrgDocumentsInd  \
# 1895014                     false                   false
# 1895015                         0                       0
#
#         MaterialDiversionOrMisuseInd MembersOrStockholdersInd  \
# 1895014                        false                     true
# 1895015                            0                        0
#
#         ElectionOfBoardMembersInd DecisionsSubjectToApprovaInd  \
# 1895014                      true                         true
# 1895015                         0                            0
#
#         MinutesOfGoverningBodyInd MinutesOfCommitteesInd  \
# 1895014                      true                   true
# 1895015                         1                      1
#
#         OfficerMailingAddressInd LocalChaptersInd  \
# 1895014                    false            false
# 1895015                        0                0
#
#         Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 1895014                        false                       false
# 1895015                            0                           1
#
#         WhistleblowerPolicyInd DocumentRetentionPolicyInd  \
# 1895014                  false                      false
# 1895015                      1                          1
#
#         CompensationProcessCEOInd CompensationProcessOtherInd  \
# 1895014                     false                       false
# 1895015                         0                           0
#
#         InvestmentInJointVentureInd StatesWhereCopyOfReturnIsFldCd  \
# 1895014                       false                            NaN
# 1895015                           0                             CA
#
#         NoListedPersonsCompensatedInd FormerOfcrEmployeesListedInd  \
# 1895014                           NaN                        false
# 1895015                             X                            0
#
#         TotalCompGreaterThan150KInd CompensationFromOtherSrcsInd  \
# 1895014                       false                        false
# 1895015                           0                            0
#
#         MembershipDuesAmt FundraisingAmt AllOtherContributionsAmt  \
# 1895014            474396            NaN                      NaN
# 1895015               NaN            NaN                      NaN
#
#         TotalContributionsAmt OtherRevenueTotalAmt  \
# 1895014                474396                 2142
# 1895015                   NaN                  NaN
#
#                                                                                                                             TotalRevenueGrp  \
# 1895014                                                        {'TotalRevenueColumnAmt': '496889', 'RelatedOrExemptFuncIncomeAmt': '22493'}
# 1895015  {'TotalRevenueColumnAmt': '1075', 'RelatedOrExemptFuncIncomeAmt': '1075', 'UnrelatedBusinessRevenueAmt': '0', 'ExclusionAmt': '0'}
#
#                                     FeesForServicesAccountingGrp  \
# 1895014  {'TotalAmt': '5913', 'ManagementAndGeneralAmt': '5913'}
# 1895015                                                      NaN
#
#                                                                                                  TotalFunctionalExpensesGrp  \
# 1895014  {'TotalAmt': '543307', 'ProgramServicesAmt': '123662', 'ManagementAndGeneralAmt': '419645', 'FundraisingAmt': '0'}
# 1895015       {'TotalAmt': '10378', 'ProgramServicesAmt': '8649', 'ManagementAndGeneralAmt': '1729', 'FundraisingAmt': '0'}
#
#                        CashNonInterestBearingGrp  \
# 1895014  {'BOYAmt': '140194', 'EOYAmt': '98702'}
# 1895015     {'BOYAmt': '6630', 'EOYAmt': '4245'}
#
#                                      TotalAssetsGrp  \
# 1895014  {'BOYAmt': '3167749', 'EOYAmt': '3121837'}
# 1895015      {'BOYAmt': '32567', 'EOYAmt': '23264'}
#
#         OrgDoesNotFollowSFAS117Ind RtnEarnEndowmentIncmOthFndsGrp  \
# 1895014                        NaN                            NaN
# 1895015                        NaN                            NaN
#
#         ReconcilationRevenueExpnssAmt MethodOfAccountingCashInd  \
# 1895014                        -46418                         X
# 1895015                         -9303                         X
#
#         AccountantCompileOrReviewInd FSAuditedInd  \
# 1895014                        false         true
# 1895015                            0            0
#
#         FederalGrantAuditRequiredInd         WebsiteAddressTxt  \
# 1895014                        false           www.cwa6201.org
# 1895015                            0  WWW.PLAYFLAGFOOTBALL.COM
#
#         TotalVolunteersCnt NetUnrelatedBusTxblIncmAmt  \
# 1895014                NaN                        NaN
# 1895015                300                          0
#
#         PYContributionsGrantsAmt PYProgramServiceRevenueAmt  \
# 1895014                   503335                        NaN
# 1895015                        0                        250
#
#         PYInvestmentIncomeAmt PYOtherRevenueAmt PYTotalRevenueAmt  \
# 1895014                  6322             10145            519802
# 1895015                     0                 0               250
#
#         PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 1895014                       NaN                        NaN
# 1895015                         0                          0
#
#         PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt  \
# 1895014                       308373                        NaN
# 1895015                            0                          0
#
#         PYOtherExpensesAmt PYTotalExpensesAmt PYRevenuesLessExpensesAmt  \
# 1895014             243420             551793                    -31991
# 1895015               8092               8092                     -7842
#
#         TotalLiabilitiesBOYAmt AnnualDisclosureCoveredPrsnInd  \
# 1895014                    311                          false
# 1895015                      0                              1
#
#         RegularMonitoringEnfrcInd UponRequestInd  \
# 1895014                     false            NaN
# 1895015                         1              X
#
#         TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 1895014                        192892                         NaN
# 1895015                             0                           0
#
#         TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 1895014                       NaN                           0
# 1895015                         0                           0
#
#         CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 1895014                            0                 NaN
# 1895015                            0                 NaN
#
#         TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 1895014                             0                       NaN
# 1895015                          1075                       NaN
#
#         ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 1895014                          NaN                          NaN
# 1895015                          NaN                          NaN
#
#         GrossSalesOfInventoryAmt CostOfGoodsSoldAmt  \
# 1895014                      NaN                NaN
# 1895015                      NaN                NaN
#
#                                                                         CompCurrentOfcrDirectorsGrp  \
# 1895014  {'TotalAmt': '192892', 'ProgramServicesAmt': '86983', 'ManagementAndGeneralAmt': '105909'}
# 1895015                                                                                         NaN
#
#                                                                         OtherSalariesAndWagesGrp  \
# 1895014  {'TotalAmt': '73967', 'ProgramServicesAmt': '4086', 'ManagementAndGeneralAmt': '69881'}
# 1895015                                                                                      NaN
#
#                                      PensionPlanContributionsGrp  \
# 1895014  {'TotalAmt': '4654', 'ManagementAndGeneralAmt': '4654'}
# 1895015                                                      NaN
#
#                                         OtherEmployeeBenefitsGrp  \
# 1895014  {'TotalAmt': '1608', 'ManagementAndGeneralAmt': '1608'}
# 1895015                                                      NaN
#
#                                                                                  PayrollTaxesGrp  \
# 1895014  {'TotalAmt': '23646', 'ProgramServicesAmt': '8078', 'ManagementAndGeneralAmt': '15568'}
# 1895015                                                                                      NaN
#
#         FeesForServicesOtherGrp                  SavingsAndTempCashInvstGrp  \
# 1895014       {'TotalAmt': '0'}  {'BOYAmt': '2006329', 'EOYAmt': '2041045'}
# 1895015                     NaN                                         NaN
#
#         LandBldgEquipCostOrOtherBssAmt LandBldgEquipAccumDeprecAmt  \
# 1895014                        1607660                      625570
# 1895015                         215130                      196111
#
#         MortgNotesPyblScrdInvstPropGrp                 OtherLiabilitiesGrp  \
# 1895014                            NaN  {'BOYAmt': '311', 'EOYAmt': '817'}
# 1895015                            NaN                                 NaN
#
#         OrganizationFollowsSFAS117Ind NetUnrlzdGainsLossesInvstAmt  \
# 1895014                             X                          NaN
# 1895015                             X                          NaN
#
#         AuditCommitteeInd AllAffiliatesIncludedInd CompDisqualPersonsGrp  \
# 1895014             false                    false     {'TotalAmt': '0'}
# 1895015               NaN                      NaN                   NaN
#
#         FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 1895014            {'TotalAmt': '0'}       {'TotalAmt': '0'}
# 1895015                          NaN                     NaN
#
#         FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 1895014          {'TotalAmt': '0'}            {'TotalAmt': '0'}
# 1895015                        NaN                          NaN
#
#         MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 1895014                          NaN                     NaN
# 1895015                          NaN                     NaN
#
#         TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 1895014                         NaN                           NaN
# 1895015                         NaN                           NaN
#
#         UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 1895014                           NaN                       NaN
# 1895015                           NaN                       NaN
#
#         FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd  \
# 1895014                           NaN                          NaN
# 1895015                           NaN                          NaN
#
#         OtherWebsiteInd AddressChangeInd WrittenPolicyOrProcedureInd  \
# 1895014             NaN              NaN                         NaN
# 1895015             NaN              NaN                         NaN
#
#         RelatedOrganizationsAmt OwnWebsiteInd DonatedServicesAndUseFcltsAmt  \
# 1895014                     NaN           NaN                           NaN
# 1895015                     NaN           NaN                           NaN
#
#         LegalDomicileCountryCd TypeOfOrganizationTrustInd FinalReturnInd  \
# 1895014                    NaN                        NaN            NaN
# 1895015                    NaN                        NaN            NaN
#
#         ContractTerminationInd GroupExemptionNum FederatedCampaignsAmt  \
# 1895014                    NaN               NaN                   NaN
# 1895015                    NaN               NaN                   NaN
#
#         TypeOfOrganizationOtherInd OtherOrganizationDsc  \
# 1895014                        NaN                  NaN
# 1895015                        NaN                  NaN
#
#         TypeOfOrganizationAssocInd InitialReturnInd GamingGrossIncomeAmt  \
# 1895014                          X              NaN                  NaN
# 1895015                        NaN              NaN                  NaN
#
#         GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 1895014                     NaN                        NaN
# 1895015                     NaN                        NaN
#
#         InvestmentExpenseAmt                              Organization501cInd  \
# 1895014                  NaN  {'@organization501cTypeTxt': '5', '#text': 'X'}
# 1895015                  NaN                                              NaN
#
#         Organization4947a1NotPFInd AmendedReturnInd SpecialConditionDesc  \
# 1895014                        NaN              NaN                  NaN
# 1895015                        NaN              NaN                  NaN
#
#         fiscal_year
# 1895014        2019
# 1895015         NaN

# %% [markdown]
# ### Create and save list of EINs for BMF File
# In previous round I believe there were only 296,334 EINs (though that may have only been for valid BMF EINs.

# %%
ein_list = df['EIN'].tolist()
print(len(ein_list))
print(len(set(ein_list)))
ein_list = list(set(ein_list))
print(len(ein_list))
# Out:
# 1895016
# 336695
# 336695

# %%
import json
with open('ein_list.json', 'w') as fp:
    json.dump(ein_list, fp)

# %% [markdown]
# <br> Add BMF variables in the following notebook:
# *IRS 990 e-File Data -- CONTROL VARIABLES (A4) -- Merge in BMF Data (NTEE, MSA, etc) - uses 'combine_first' Combine Columns (Python 3.6).ipynb*

# %% [markdown]
# ### Collapse

# %%
def agg_funcs(x):
    names = {
        #'name': x['variable_name_new'].head(1).values[0],
        'original_names':  list(set(x['MongoDB_Name'].tolist())),
        'data_type_xsd': x['data_type_xsd'].head(1).values[0]
        }
    #THE FOLLOWING SHORTCUT WORKS BUT CHANGES THE ORDER OF THE COLUMNS
    #return pd.Series(names, index = list(names.keys()))
    return pd.Series(names, index=['original_names', 'data_type_xsd'])
new_variables_df = concordance[:].groupby(['variable_name_new']).apply(agg_funcs)
new_variables_df = new_variables_df.reset_index()
print('# of variables:', len(new_variables_df))
new_variables_df[:5]
# Out:
# # of variables: 193
#                variable_name_new  \
# 0           F9_00_HD_ADDR_CHANGE
# 1        F9_00_HD_AMENDED_RETURN
# 2      F9_00_HD_BUILD_TIME_STAMP
# 3      F9_00_HD_CTRY_OF_DOMICILE
# 4  F9_00_HD_EXEMPT_STATUS_4847A1
#
#                                      original_names data_type_xsd
# 0                 [AddressChange, AddressChangeInd]  CheckboxType
# 1                 [AmendedReturn, AmendedReturnInd]  CheckboxType
# 2                                         [BuildTS]           NaN
# 3    [CountryLegalDomicile, LegalDomicileCountryCd]   CountryType
# 4  [Organization4947a1NotPFInd, Organization4947a1]  CheckboxType

# %%
new_variables_df['len'] = new_variables_df['original_names'].apply(lambda x: len(x))
print(new_variables_df['len'].value_counts(), '\n')
new_variables_df[:4]
# Out:
# 2    189
# 1      4
# Name: len, dtype: int64
#            variable_name_new                                  original_names  \
# 0       F9_00_HD_ADDR_CHANGE               [AddressChange, AddressChangeInd]
# 1    F9_00_HD_AMENDED_RETURN               [AmendedReturn, AmendedReturnInd]
# 2  F9_00_HD_BUILD_TIME_STAMP                                       [BuildTS]
# 3  F9_00_HD_CTRY_OF_DOMICILE  [CountryLegalDomicile, LegalDomicileCountryCd]
#
#   data_type_xsd  len
# 0  CheckboxType    2
# 1  CheckboxType    2
# 2           NaN    1
# 3   CountryType    2

# %% [markdown]
# ## Flatten *ReturnHeader* column
#
# ### 2/14/2020 --  THIS IS A NEW APPROACH --> FLATTEN THEN REMOVE NON-USED COLUMNS
#
# ###  BE SURE TO FOLLOW THROUGH WITH CHANGES TO THE FOLLOWING VARIABLES IN SUBSEQUENT NOTEBOOKS:
#     'ReturnHeader.TaxYear': 1, 'ReturnHeader.TaxYr': 1,
#     'ReturnHeader.TaxPeriodEndDate': 1, 'ReturnHeader.TaxPeriodEndDt': 1,

# %%
print(df.columns.tolist()[-5:])
# Out:
# ['Organization501cInd', 'Organization4947a1NotPFInd', 'AmendedReturnInd', 'SpecialConditionDesc', 'fiscal_year']

# %%
# %%time
print("Number of columns:", len(df.columns))
df = pd.concat([df.drop(['ReturnHeader'], axis=1), df['ReturnHeader'].apply(pd.Series)], axis=1)
print("Number of columns:", len(df.columns))
df[:2]
# Out:
# Number of columns: 324
# Number of columns: 346
# Wall time: 15min 46s
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod        EIN AddressChange  \
# 0  93493313013011    201012  232705170             X
# 1  93493313013111    201106  581805618           NaN
#
#   NameOfPrincipalOfficerPerson GrossReceipts GroupReturnForAffiliates  \
# 0                MICHAEL ANTON       1473903                        0
# 1                          NaN        266420                    false
#
#   Organization501c3 WebSite TypeOfOrganizationCorporation YearFormation  \
# 0                 X     N/A                             X          1992
# 1                 X     N/A                             X          1993
#
#   StateLegalDomicile  \
# 0                 PA
# 1                 WY
#
#                                                                                                                     ActivityOrMissionDescription  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
# 1                            19                          13                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
# 1                NaN             0                            NaN
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
# 1                          NaN                              0
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
# 1                         222839                  265592
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
# 1                      1425                         828                   NaN
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
# 1                       0                224264                  266420
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
# 1                            NaN                       0
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
# 1                            NaN                       0                71405
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
# 1                  82955                           NaN                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
# 1                           0                189785                   222550
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
# 1                 261190                   305505
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
# 1                        -36926                 -39085        1455332
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
# 1        1433342               17482               34577
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
# 1                    1437850                    1398765
#
#   ProfessionalFundraising FundraisingActivities Gaming  \
# 0                       0                     0      0
# 1                   false                 false  false
#
#   NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 0                            10                             10
# 1                            19                             13
#
#   FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 0                            0                            0
# 1                         true                         true
#
#   ChangesToOrganizingDocs MaterialDiversionOrMisuse MembersOrStockholders  \
# 0                       0                         0                     0
# 1                   false                     false                 false
#
#   ElectionOfBoardMembers DecisionsSubjectToApproval MinutesOfGoverningBody  \
# 0                      0                          0                      1
# 1                   true                       true                   true
#
#   MinutesOfCommittees OfficerMailingAddress LocalChapters  \
# 0                   1                     0             0
# 1                true                 false         false
#
#   Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 0                              1                        1
# 1                           true                     true
#
#   AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 0                              1                            1
# 1                           true                         true
#
#   WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 0                   0                       0                      0
# 1               false                   false                   true
#
#   CompensationProcessOther InvestmentInJointVenture  \
# 0                        0                        0
# 1                     true                    false
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0                   [PA, NJ, DE]           X                          X
# 1                            NaN           X                        NaN
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
# 1                        NaN                        1180355
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
# 1                 411648                       0          true
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
# 1            true                        false                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
# 1                   NaN                  0                 0
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
# 1                                                              {'TotalRevenueColumn': '266420', 'RelatedOrExemptFunctionIncome': '266420'}
#
#                               FeesForServicesLegal  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
# 1                                   {'Total': '0'}
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
# 1    {'Total': '7500', 'ManagementAndGeneral': '7500'}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
# 1          {'Total': '305505', 'ProgramServices': '276405', 'ManagementAndGeneral': '29100', 'Fundraising': '0'}
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 0  {'BOY': '332660', 'EOY': '270700'}                      256845
# 1                        {'EOY': '0'}                     2187206
#
#   LandBldgEquipmentAccumDeprec                           TotalAssets  \
# 0                        86228  {'BOY': '1925215', 'EOY': '2440859'}
# 1                       904332  {'BOY': '1455332', 'EOY': '1433342'}
#
#                     OtherLiabilities FollowSFAS117  \
# 0  {'BOY': '51640', 'EOY': '240077'}             X
# 1    {'BOY': '9203', 'EOY': '11349'}             X
#
#   ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 0                        89152                         X
# 1                       -39085                         X
#
#   AccountantCompileOrReview FSAudited AuditCommittee  \
# 0                         0         1              1
# 1                     false      true           true
#
#   FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 0                         0                   NaN                  NaN
# 1                      true                 false                 1736
#
#   PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 0                       NaN                      NaN
# 1                     false                    false
#
#   TotalProgramServiceRevenue CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                        NaN                          NaN                NaN
# 1                     265592               {'Total': '0'}     {'Total': '0'}
#
#                             OtherSalariesAndWages PensionPlanContributions  \
# 0                                             NaN                      NaN
# 1  {'Total': '59440', 'ProgramServices': '59440'}           {'Total': '0'}
#
#                             OtherEmployeeBenefits  \
# 0                                             NaN
# 1  {'Total': '17714', 'ProgramServices': '17714'}
#
#                                    PayrollTaxes  \
# 0                                           NaN
# 1  {'Total': '5801', 'ProgramServices': '5801'}
#
#                              FeesForServicesManagement  \
# 0                                                  NaN
# 1  {'Total': '21600', 'ManagementAndGeneral': '21600'}
#
#   FeesForServicesLobbying F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 0                     NaN                           NaN
# 1          {'Total': '0'}                {'Total': '0'}
#
#   FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 0                           NaN                  NaN
# 1                {'Total': '0'}       {'Total': '0'}
#
#            CashNonInterestBearing  MortNotesPyblSecuredInvestProp  \
# 0                             NaN                             NaN
# 1  {'BOY': '250', 'EOY': '22261'}  {'BOY': '6219', 'EOY': '7035'}
#
#   FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 0                        NaN                        NaN
# 1                       true                        NaN
#
#   MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 0                    NaN                      NaN          NaN
# 1                    NaN                      NaN          NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0               NaN                            NaN                  NaN
# 1               NaN                            NaN                  NaN
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                          NaN                       NaN                NaN
# 1                          NaN                       NaN                NaN
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0              NaN                     NaN                   NaN
# 1              NaN                     NaN                   NaN
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0             NaN                NaN                          NaN
# 1             NaN                NaN                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0           NaN            NaN               NaN                  NaN
# 1           NaN            NaN               NaN                  NaN
#
#   NoncashContributions OwnWebsite UnsecuredNotesLoansPayable  \
# 0                  NaN        NaN                        NaN
# 1                  NaN        NaN                        NaN
#
#   TypeOfOrganizationOther Organization501c TypeOfOrganizationTrust  \
# 0                     NaN              NaN                     NaN
# 1                     NaN              NaN                     NaN
#
#   TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 0                           NaN                  NaN           NaN
# 1                           NaN                  NaN           NaN
#
#   TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 0                       NaN              NaN                      NaN
# 1                       NaN              NaN                      NaN
#
#   SpecialConditionDescription Organization4947a1  \
# 0                         NaN                NaN
# 1                         NaN                NaN
#
#   ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
#
#   ReconcilationDonatedServices ReconcilationInvestExpenses PrincipalOfficerNm  \
# 0                          NaN                         NaN                NaN
# 1                          NaN                         NaN                NaN
#
#   GrossReceiptsAmt GroupReturnForAffiliatesInd Organization501c3Ind  \
# 0              NaN                         NaN                  NaN
# 1              NaN                         NaN                  NaN
#
#   TypeOfOrganizationCorpInd FormationYr LegalDomicileStateCd  \
# 0                       NaN         NaN                  NaN
# 1                       NaN         NaN                  NaN
#
#   ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                   NaN                           NaN
# 1                   NaN                           NaN
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                         NaN              NaN              NaN
# 1                         NaN              NaN              NaN
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                      NaN                        NaN                   NaN
# 1                      NaN                        NaN                   NaN
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0               NaN               NaN                       NaN
# 1               NaN               NaN                       NaN
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                        NaN                          NaN                NaN
# 1                        NaN                          NaN                NaN
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0                NaN                       NaN               NaN
# 1                NaN                       NaN               NaN
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0               NaN                    NaN                           NaN
# 1               NaN                    NaN                           NaN
#
#   NetAssetsOrFundBalancesEOYAmt ProfessionalFundraisingInd  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
#
#   FundraisingActivitiesInd GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 0                      NaN                 NaN                           NaN
# 1                      NaN                 NaN                           NaN
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                        NaN                    NaN                       NaN
# 1                        NaN                    NaN                       NaN
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                    NaN                      NaN              NaN
# 1                    NaN                      NaN              NaN
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                    NaN                        NaN                       NaN
# 1                    NaN                        NaN                       NaN
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                          NaN               NaN            NaN
# 1                          NaN               NaN            NaN
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
#
#   TotalRevenueGrp FeesForServicesAccountingGrp TotalFunctionalExpensesGrp  \
# 0             NaN                          NaN                        NaN
# 1             NaN                          NaN                        NaN
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                       NaN            NaN                        NaN
# 1                       NaN            NaN                        NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                       NaN                          NaN          NaN
# 1                       NaN                          NaN          NaN
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                          NaN               NaN                NaN
# 1                          NaN               NaN                NaN
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                        NaN                   NaN               NaN
# 1                        NaN                   NaN               NaN
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0               NaN                       NaN                        NaN
# 1               NaN                       NaN                        NaN
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                          NaN                        NaN                NaN
# 1                          NaN                        NaN                NaN
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0                NaN                       NaN                    NaN
# 1                NaN                       NaN                    NaN
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                            NaN                       NaN            NaN
# 1                            NaN                       NaN            NaN
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                          NaN                 NaN
# 1                          NaN                 NaN
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt CompCurrentOfcrDirectorsGrp  \
# 0                      NaN                NaN                         NaN
# 1                      NaN                NaN                         NaN
#
#   OtherSalariesAndWagesGrp PensionPlanContributionsGrp  \
# 0                      NaN                         NaN
# 1                      NaN                         NaN
#
#   OtherEmployeeBenefitsGrp PayrollTaxesGrp FeesForServicesOtherGrp  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
#
#   SavingsAndTempCashInvstGrp LandBldgEquipCostOrOtherBssAmt  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   LandBldgEquipAccumDeprecAmt MortgNotesPyblScrdInvstPropGrp  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
#
#   OtherLiabilitiesGrp OrganizationFollowsSFAS117Ind  \
# 0                 NaN                           NaN
# 1                 NaN                           NaN
#
#   NetUnrlzdGainsLossesInvstAmt AuditCommitteeInd AllAffiliatesIncludedInd  \
# 0                          NaN               NaN                      NaN
# 1                          NaN               NaN                      NaN
#
#   CompDisqualPersonsGrp FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
# 1                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
#
#   TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                           NaN                          NaN             NaN
# 1                           NaN                          NaN             NaN
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0              NaN                         NaN                     NaN
# 1              NaN                         NaN                     NaN
#
#   OwnWebsiteInd DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0           NaN                           NaN                    NaN
# 1           NaN                           NaN                    NaN
#
#   TypeOfOrganizationTrustInd FinalReturnInd ContractTerminationInd  \
# 0                        NaN            NaN                    NaN
# 1                        NaN            NaN                    NaN
#
#   GroupExemptionNum FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0               NaN                   NaN                        NaN
# 1               NaN                   NaN                        NaN
#
#   OtherOrganizationDsc TypeOfOrganizationAssocInd InitialReturnInd  \
# 0                  NaN                        NaN              NaN
# 1                  NaN                        NaN              NaN
#
#   GamingGrossIncomeAmt GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 0                  NaN                     NaN                        NaN
# 1                  NaN                     NaN                        NaN
#
#   InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 0                  NaN                 NaN                        NaN
# 1                  NaN                 NaN                        NaN
#
#   AmendedReturnInd SpecialConditionDesc fiscal_year @binaryAttachmentCount  \
# 0              NaN                  NaN        2010                      0
# 1              NaN                  NaN        2011                      0
#
#                    Timestamp TaxPeriodEndDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31
# 1  2011-11-09T07:32:06-08:00       2011-06-30
#
#                                                                                                                                                                                                                     PreparerFirm  \
# 0  {'PreparerFirmBusinessName': {'BusinessNameLine1': 'CONCANNON MILLER & CO PC'}, 'PreparerFirmUSAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY SUITE 30', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '180172285'}}
# 1             {'PreparerFirmBusinessName': {'BusinessNameLine1': 'MADDOX & ASSOCIATES APC'}, 'PreparerFirmUSAddress': {'AddressLine1': '5627 BANKERS AVE BLDG 2', 'City': 'BATON ROUGE', 'State': 'LA', 'ZIPCode': '708082610'}}
#
#   ReturnType TaxPeriodBeginDate  \
# 0        990         2010-01-01
# 1        990         2010-07-01
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
# 1  {'EIN': '581805618', 'Name': {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}, 'NameControl': 'TORR', 'Phone': '7033415000', 'USAddress': {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA'...
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#                                                 Preparer TaxYear  \
# 0  {'Name': 'E BARRY HETZEL CPA', 'Phone': '6104335501'}    2010
# 1     {'Name': 'WILLIAM B BEALE', 'Phone': '2259263360'}    2010
#
#                 BuildTS DisasterRelief @binaryAttachmentCnt ReturnTs  \
# 0  2016-02-24 21:20:13Z            NaN                  NaN      NaN
# 1  2016-02-24 21:20:13Z            NaN                  NaN      NaN
#
#   TaxPeriodEndDt PreparerFirmGrp ReturnTypeCd TaxPeriodBeginDt  \
# 0            NaN             NaN          NaN              NaN
# 1            NaN             NaN          NaN              NaN
#
#   BusinessOfficerGrp PreparerPersonGrp TaxYr DisasterReliefTxt  \
# 0                NaN               NaN   NaN               NaN
# 1                NaN               NaN   NaN               NaN
#
#   FilingSecurityInformation
# 0                       NaN
# 1                       NaN

# %%
print(df.columns.tolist()[-23:])
# Out:
# ['@binaryAttachmentCount', 'Timestamp', 'TaxPeriodEndDate', 'PreparerFirm', 'ReturnType', 'TaxPeriodBeginDate', 'Filer', 'Officer', 'Preparer', 'TaxYear', 'BuildTS', 'DisasterRelief', '@binaryAttachmentCnt', 'ReturnTs', 'TaxPeriodEndDt', 'PreparerFirmGrp', 'ReturnTypeCd', 'TaxPeriodBeginDt', 'BusinessOfficerGrp', 'PreparerPersonGrp', 'TaxYr', 'DisasterReliefTxt', 'FilingSecurityInformation']

# %%
set(df.columns.tolist()[-23:]) - set(['@binaryAttachmentCount', 'PreparerFirm', 'ReturnType', 'TaxPeriodBeginDate', 'Preparer', 
             'DisasterRelief', '@binaryAttachmentCnt', 'PreparerFirmGrp', 'ReturnTypeCd', 'TaxPeriodBeginDt', 
             'PreparerPersonGrp', 'DisasterReliefTxt', 'FilingSecurityInformation'])
# Out:
# {'BuildTS',
#  'BusinessOfficerGrp',
#  'Filer',
#  'Officer',
#  'ReturnTs',
#  'TaxPeriodEndDate',
#  'TaxPeriodEndDt',
#  'TaxYear',
#  'TaxYr',
#  'Timestamp'}

# %%
# %%time 
#print([c for c in df.columns.tolist() if c not in mongo_cols])
omit_cols = ['@binaryAttachmentCount', 'PreparerFirm', 'ReturnType', 'TaxPeriodBeginDate', 'Preparer', 
             'DisasterRelief', '@binaryAttachmentCnt', 'PreparerFirmGrp', 'ReturnTypeCd', 'TaxPeriodBeginDt', 
             'PreparerPersonGrp', 'DisasterReliefTxt', 'FilingSecurityInformation']
print('omit_cols:', len(omit_cols))
print("Number of columns:", len(df.columns))
df = df[[c for c in df.columns.tolist() if c not in omit_cols]]
print(len(df))
print("Number of columns:", len(df.columns))
df[:1]
# Out:
# omit_cols: 13
# 346
# 1895016
# 333
# Wall time: 57.7 s
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod        EIN AddressChange  \
# 0  93493313013011    201012  232705170             X
#
#   NameOfPrincipalOfficerPerson GrossReceipts GroupReturnForAffiliates  \
# 0                MICHAEL ANTON       1473903                        0
#
#   Organization501c3 WebSite TypeOfOrganizationCorporation YearFormation  \
# 0                 X     N/A                             X          1992
#
#   StateLegalDomicile  \
# 0                 PA
#
#                                                                ActivityOrMissionDescription  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
#
#   ProfessionalFundraising FundraisingActivities Gaming  \
# 0                       0                     0      0
#
#   NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 0                            10                             10
#
#   FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 0                            0                            0
#
#   ChangesToOrganizingDocs MaterialDiversionOrMisuse MembersOrStockholders  \
# 0                       0                         0                     0
#
#   ElectionOfBoardMembers DecisionsSubjectToApproval MinutesOfGoverningBody  \
# 0                      0                          0                      1
#
#   MinutesOfCommittees OfficerMailingAddress LocalChapters  \
# 0                   1                     0             0
#
#   Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 0                              1                        1
#
#   AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 0                              1                            1
#
#   WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 0                   0                       0                      0
#
#   CompensationProcessOther InvestmentInJointVenture  \
# 0                        0                        0
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0                   [PA, NJ, DE]           X                          X
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
#
#                               FeesForServicesLegal  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 0  {'BOY': '332660', 'EOY': '270700'}                      256845
#
#   LandBldgEquipmentAccumDeprec                           TotalAssets  \
# 0                        86228  {'BOY': '1925215', 'EOY': '2440859'}
#
#                     OtherLiabilities FollowSFAS117  \
# 0  {'BOY': '51640', 'EOY': '240077'}             X
#
#   ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 0                        89152                         X
#
#   AccountantCompileOrReview FSAudited AuditCommittee  \
# 0                         0         1              1
#
#   FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 0                         0                   NaN                  NaN
#
#   PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 0                       NaN                      NaN
#
#   TotalProgramServiceRevenue CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                        NaN                          NaN                NaN
#
#   OtherSalariesAndWages PensionPlanContributions OtherEmployeeBenefits  \
# 0                   NaN                      NaN                   NaN
#
#   PayrollTaxes FeesForServicesManagement FeesForServicesLobbying  \
# 0          NaN                       NaN                     NaN
#
#   F9_09_PC_FEES_FOR_SVCE_FR_TOT FeesForServicesInvstMgmntFees  \
# 0                           NaN                           NaN
#
#   FeesForServicesOther CashNonInterestBearing MortNotesPyblSecuredInvestProp  \
# 0                  NaN                    NaN                            NaN
#
#   FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 0                        NaN                        NaN
#
#   MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 0                    NaN                      NaN          NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0               NaN                            NaN                  NaN
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                          NaN                       NaN                NaN
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0              NaN                     NaN                   NaN
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0             NaN                NaN                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0           NaN            NaN               NaN                  NaN
#
#   NoncashContributions OwnWebsite UnsecuredNotesLoansPayable  \
# 0                  NaN        NaN                        NaN
#
#   TypeOfOrganizationOther Organization501c TypeOfOrganizationTrust  \
# 0                     NaN              NaN                     NaN
#
#   TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 0                           NaN                  NaN           NaN
#
#   TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 0                       NaN              NaN                      NaN
#
#   SpecialConditionDescription Organization4947a1  \
# 0                         NaN                NaN
#
#   ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 0                            NaN                          NaN
#
#   ReconcilationDonatedServices ReconcilationInvestExpenses PrincipalOfficerNm  \
# 0                          NaN                         NaN                NaN
#
#   GrossReceiptsAmt GroupReturnForAffiliatesInd Organization501c3Ind  \
# 0              NaN                         NaN                  NaN
#
#   TypeOfOrganizationCorpInd FormationYr LegalDomicileStateCd  \
# 0                       NaN         NaN                  NaN
#
#   ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                   NaN                           NaN
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                         NaN              NaN              NaN
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                      NaN                        NaN                   NaN
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0               NaN               NaN                       NaN
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                        NaN                          NaN
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                        NaN                          NaN                NaN
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0                NaN                       NaN               NaN
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0               NaN                    NaN                           NaN
#
#   NetAssetsOrFundBalancesEOYAmt ProfessionalFundraisingInd  \
# 0                           NaN                        NaN
#
#   FundraisingActivitiesInd GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 0                      NaN                 NaN                           NaN
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                        NaN                    NaN                       NaN
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                     NaN                          NaN
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                      NaN                       NaN
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                          NaN                       NaN
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                    NaN                      NaN              NaN
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                          NaN                         NaN
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                    NaN                        NaN                       NaN
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                         NaN                         NaN
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                            NaN                           NaN
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                          NaN                         NaN
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                          NaN               NaN            NaN
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                      NaN                   NaN                  NaN
#
#   TotalRevenueGrp FeesForServicesAccountingGrp TotalFunctionalExpensesGrp  \
# 0             NaN                          NaN                        NaN
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                       NaN            NaN                        NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                            NaN                           NaN
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                       NaN                          NaN          NaN
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                          NaN               NaN                NaN
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                        NaN                      NaN
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                        NaN                   NaN               NaN
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0               NaN                       NaN                        NaN
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                          NaN                        NaN                NaN
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0                NaN                       NaN                    NaN
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                            NaN                       NaN            NaN
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                           NaN                         NaN
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                       NaN                         NaN
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                          NaN                 NaN
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                           NaN                       NaN
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                          NaN                          NaN
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt CompCurrentOfcrDirectorsGrp  \
# 0                      NaN                NaN                         NaN
#
#   OtherSalariesAndWagesGrp PensionPlanContributionsGrp  \
# 0                      NaN                         NaN
#
#   OtherEmployeeBenefitsGrp PayrollTaxesGrp FeesForServicesOtherGrp  \
# 0                      NaN             NaN                     NaN
#
#   SavingsAndTempCashInvstGrp LandBldgEquipCostOrOtherBssAmt  \
# 0                        NaN                            NaN
#
#   LandBldgEquipAccumDeprecAmt MortgNotesPyblScrdInvstPropGrp  \
# 0                         NaN                            NaN
#
#   OtherLiabilitiesGrp OrganizationFollowsSFAS117Ind  \
# 0                 NaN                           NaN
#
#   NetUnrlzdGainsLossesInvstAmt AuditCommitteeInd AllAffiliatesIncludedInd  \
# 0                          NaN               NaN                      NaN
#
#   CompDisqualPersonsGrp FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 0                        NaN                          NaN
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 0                          NaN                     NaN
#
#   TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 0                         NaN                           NaN
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                           NaN                       NaN
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                           NaN                          NaN             NaN
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0              NaN                         NaN                     NaN
#
#   OwnWebsiteInd DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0           NaN                           NaN                    NaN
#
#   TypeOfOrganizationTrustInd FinalReturnInd ContractTerminationInd  \
# 0                        NaN            NaN                    NaN
#
#   GroupExemptionNum FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0               NaN                   NaN                        NaN
#
#   OtherOrganizationDsc TypeOfOrganizationAssocInd InitialReturnInd  \
# 0                  NaN                        NaN              NaN
#
#   GamingGrossIncomeAmt GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 0                  NaN                     NaN                        NaN
#
#   InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 0                  NaN                 NaN                        NaN
#
#   AmendedReturnInd SpecialConditionDesc fiscal_year  \
# 0              NaN                  NaN        2010
#
#                    Timestamp TaxPeriodEndDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   TaxYear               BuildTS ReturnTs TaxPeriodEndDt BusinessOfficerGrp  \
# 0    2010  2016-02-24 21:20:13Z      NaN            NaN                NaN
#
#   TaxYr
# 0   NaN

# %% [markdown]
# #### Save DF

# %%
# %%time
df.to_pickle('all filings nov. 2020 - all control variables (renamed).pkl.gz', compression='gzip')
# Out:
# Wall time: 28min 49s

# %% [markdown]
# ### Process the two *ReturnHeader* variables separately
# - This is the *old* way of doing it.

# %%
#new_variables_df[new_variables_df['variable_name_new'].isin(['F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR'])]
# Out:
#        variable_name_new  \
# 15  F9_00_HD_TAX_PER_END
# 16     F9_00_HD_TAX_YEAR
#
#                                                   original_names  \
# 15  [ReturnHeader.TaxPeriodEndDt, ReturnHeader.TaxPeriodEndDate]
# 16                    [ReturnHeader.TaxYear, ReturnHeader.TaxYr]
#
#    data_type_xsd  len
# 15      DateType    2
# 16      YearType    2

# %%
#df.sample(1)
# Out:
#      AccountantCompileOrReview ActivityOrMissionDescription AddressChange  \
# 3393                       NaN                          NaN           NaN
#
#      AllAffiliatesIncluded AllOtherContributions AmendedReturn  \
# 3393                   NaN                   NaN           NaN
#
#      AnnualDisclosureCoveredPersons AuditCommittee BenefitsPaidToMembersCY  \
# 3393                            NaN            NaN                     NaN
#
#      BenefitsPaidToMembersPriorYear CashNonInterestBearing  \
# 3393                            NaN                    NaN
#
#      ChangesToOrganizingDocs CntrbtnsRprtdFundraisingEvents  \
# 3393                     NaN                            NaN
#
#      CompCurrentOfficersDirectors CompDisqualPersons  \
# 3393                          NaN                NaN
#
#      CompensationFromOtherSources CompensationProcessCEO  \
# 3393                          NaN                    NaN
#
#      CompensationProcessOther ConflictOfInterestPolicy  \
# 3393                      NaN                      NaN
#
#      ContributionsGrantsCurrentYear ContributionsGrantsPriorYear  \
# 3393                            NaN                          NaN
#
#      CostOfGoodsSold CountryLegalDomicile             DLN  \
# 3393             NaN                  NaN  93493267001399
#
#      DecisionsSubjectToApproval DelegationOfManagementDuties  \
# 3393                        NaN                          NaN
#
#      DoNotFollowSFAS117 DocumentRetentionPolicy        EIN  \
# 3393                NaN                     NaN  930846286
#
#      ElectionOfBoardMembers FSAudited FamilyOrBusinessRelationship  \
# 3393                    NaN       NaN                          NaN
#
#      FederalGrantAuditPerformed FederalGrantAuditRequired FederatedCampaigns  \
# 3393                        NaN                       NaN                NaN
#
#      FeesForServicesAccounting FeesForServicesInvstMgmntFees  \
# 3393                       NaN                           NaN
#
#      FeesForServicesLegal FeesForServicesLobbying FeesForServicesManagement  \
# 3393                  NaN                     NaN                       NaN
#
#      FeesForServicesOther F9_09_PC_FEES_FOR_SVCE_FR_TOT FollowSFAS117  \
# 3393                  NaN             {'TotalAmt': '0'}           NaN
#
#      Form990ProvidedToGoverningBody FormersListed FundraisingDirectExpenses  \
# 3393                            NaN           NaN                       NaN
#
#      FundraisingEvents GamingDirectExpenses GovernmentGrants  \
# 3393               NaN                  NaN              NaN
#
#      GrantsAndSimilarAmntsCY GrantsAndSimilarAmntsPriorYear  \
# 3393                     NaN                            NaN
#
#      GrossIncomeFundraisingEvents GrossIncomeGaming GrossReceipts  \
# 3393                          NaN               NaN           NaN
#
#      GrossSalesOfInventory GroupExemptionNumber GroupReturnForAffiliates  \
# 3393                   NaN                  NaN                      NaN
#
#      InitialReturn InvestmentInJointVenture InvestmentIncomeCurrentYear  \
# 3393           NaN                      NaN                         NaN
#
#      InvestmentIncomePriorYear LandBldgEquipmentAccumDeprec  \
# 3393                       NaN                          NaN
#
#      LandBuildingsEquipmentBasis LoansFromOfficersDirectors LocalChapters  \
# 3393                         NaN                        NaN           NaN
#
#      MaterialDiversionOrMisuse MembersOrStockholders MembershipDues  \
# 3393                       NaN                   NaN            NaN
#
#      MethodOfAccountingAccrual MethodOfAccountingCash MethodOfAccountingOther  \
# 3393                       NaN                    NaN                     NaN
#
#      MinutesOfCommittees MinutesOfGoverningBody  \
# 3393                 NaN                    NaN
#
#      MortNotesPyblSecuredInvestProp NameOfPrincipalOfficerPerson  \
# 3393                            NaN                          NaN
#
#      NbrIndependentVotingMembers NbrVotingGoverningBodyMembers  \
# 3393                         NaN                           NaN
#
#      NbrVotingMembersGoverningBody NetAssetsOrFundBalancesBOY  \
# 3393                           NaN                        NaN
#
#      NetAssetsOrFundBalancesEOY NetUnrelatedBusinessTxblIncome  \
# 3393                        NaN                            NaN
#
#      NoListedPersonsCompensated NoncashContributions  \
# 3393                        NaN                  NaN
#
#      NumberIndependentVotingMembers NumberIndividualsGT100K  \
# 3393                            NaN                     NaN
#
#      NumberOfContractorsGT100K OfficerMailingAddress Organization4947a1  \
# 3393                       NaN                   NaN                NaN
#
#      Organization501c Organization501c3  \
# 3393              NaN               NaN
#
#                              OrganizationName OtherEmployeeBenefits  \
# 3393  ST PAUL PAROCHIAL SCHOOL ENDOWMENT FUND                   NaN
#
#      OtherExpensePriorYear OtherExpensesCurrentYear OtherLiabilities  \
# 3393                   NaN                      NaN              NaN
#
#      OtherRevenueCurrentYear OtherRevenuePriorYear OtherSalariesAndWages  \
# 3393                     NaN                   NaN                   NaN
#
#      OtherWebsite OwnWebsite PayrollTaxes PensionPlanContributions  \
# 3393          NaN        NaN          NaN                      NaN
#
#      PoliciesReferenceChapters ProgramServiceRevenueCY  \
# 3393                       NaN                     NaN
#
#      ProgramServiceRevenuePriorYear ReconcilationRevenueExpenses  \
# 3393                            NaN                          NaN
#
#      RegularMonitoringEnforcement RelatedOrganizations  \
# 3393                          NaN                  NaN
#
#      RetainedEarningsEndowmentEtc  \
# 3393                          NaN
#
#                                            ReturnHeader  \
# 3393  {'TaxPeriodEndDt': '2019-06-30', 'TaxYr': '2018'}
#
#      RevenuesLessExpensesCY RevenuesLessExpensesPriorYear  \
# 3393                    NaN                           NaN
#
#      SalariesEtcCurrentYear SalariesEtcPriorYear  \
# 3393                    NaN                  NaN
#
#      SavingsAndTempCashInvestments SpecialConditionDescription  \
# 3393                           NaN                         NaN
#
#      StateLegalDomicile StatesWhereCopyOfReturnIsFiled  \
# 3393                NaN                            NaN
#
#      TaxExemptBondLiabilities TaxPeriod TerminatedReturn  \
# 3393                      NaN    201906              NaN
#
#      TerminationOrContraction TotalAssets TotalAssetsBOY TotalAssetsEOY  \
# 3393                      NaN         NaN            NaN            NaN
#
#      TotalCompGT150K TotalContributions TotalExpensesCurrentYear  \
# 3393             NaN                NaN                      NaN
#
#      TotalExpensesPriorYear TotalFunctionalExpenses  \
# 3393                    NaN                     NaN
#
#      TotalFundrsngExpCurrentYear TotalGrossUBI TotalLiabilitiesBOY  \
# 3393                         NaN           NaN                 NaN
#
#      TotalLiabilitiesEOY TotalNbrEmployees TotalNbrVolunteers  \
# 3393                 NaN               NaN                NaN
#
#      TotalOtherCompensation TotalOtherRevenue TotalProfFundrsngExpCY  \
# 3393                    NaN               NaN                    NaN
#
#      TotalProfFundrsngExpPriorYear TotalProgramServiceRevenue  \
# 3393                           NaN                        NaN
#
#      TotalReportableCompFrmRltdOrgs TotalReportableCompFromOrg TotalRevenue  \
# 3393                            NaN                        NaN          NaN
#
#      TotalRevenueCurrentYear TotalRevenuePriorYear TypeOfOrgOtherDescription  \
# 3393                     NaN                   NaN                       NaN
#
#      TypeOfOrganizationAssociation TypeOfOrganizationCorporation  \
# 3393                           NaN                           NaN
#
#      TypeOfOrganizationOther TypeOfOrganizationTrust  \
# 3393                     NaN                     NaN
#
#                                                                       URL  \
# 3393  https://s3.amazonaws.com/irs-form-990/201942679349300139_public.xml
#
#      UnsecuredNotesLoansPayable UponRequest WebSite WhistleblowerPolicy  \
# 3393                        NaN         NaN     NaN                 NaN
#
#      WrittenPolicyOrProcedure YearFormation ReconcilationDonatedServices  \
# 3393                      NaN           NaN                          NaN
#
#      ReconcilationInvestExpenses ReconcilationPriorAdjustment  \
# 3393                         NaN                          NaN
#
#      ReconciliationUnrealizedInvest AccountantCompileOrReviewInd  \
# 3393                            NaN                        false
#
#                                        ActivityOrMissionDesc AddressChangeInd  \
# 3393  SUPPORTING ORGANIZATION FOR ST. PAUL PAROCHIAL SCHOOL.              NaN
#
#      AllAffiliatesIncludedInd AllOtherContributionsAmt AmendedReturnInd  \
# 3393                    false                    14140              NaN
#
#      AnnualDisclosureCoveredPrsnInd AuditCommitteeInd  \
# 3393                          false               NaN
#
#      CYBenefitsPaidToMembersAmt CYContributionsGrantsAmt  \
# 3393                          0                    14140
#
#      CYGrantsAndSimilarPaidAmt CYInvestmentIncomeAmt CYOtherExpensesAmt  \
# 3393                     24403                 33397               9690
#
#      CYOtherRevenueAmt CYProgramServiceRevenueAmt CYRevenuesLessExpensesAmt  \
# 3393                 0                       2450                     15894
#
#      CYSalariesCompEmpBnftPaidAmt CYTotalExpensesAmt  \
# 3393                            0              34093
#
#      CYTotalFundraisingExpenseAmt CYTotalProfFndrsngExpnsAmt  \
# 3393                            0                          0
#
#      CYTotalRevenueAmt           CashNonInterestBearingGrp  \
# 3393             49987  {'BOYAmt': '107', 'EOYAmt': '284'}
#
#      ChangeToOrgDocumentsInd CntrctRcvdGreaterThan100KCnt  \
# 3393                   false                            0
#
#      CompCurrentOfcrDirectorsGrp CompDisqualPersonsGrp  \
# 3393           {'TotalAmt': '0'}     {'TotalAmt': '0'}
#
#      CompensationFromOtherSrcsInd CompensationProcessCEOInd  \
# 3393                        false                     false
#
#      CompensationProcessOtherInd ConflictOfInterestPolicyInd  \
# 3393                       false                       false
#
#      ContractTerminationInd ContriRptFundraisingEventAmt CostOfGoodsSoldAmt  \
# 3393                    NaN                          NaN                NaN
#
#      DecisionsSubjectToApprovaInd DelegationOfMgmtDutiesInd  \
# 3393                        false                     false
#
#      DocumentRetentionPolicyInd DonatedServicesAndUseFcltsAmt  \
# 3393                      false                           NaN
#
#      ElectionOfBoardMembersInd FSAuditedInd FamilyOrBusinessRlnInd  \
# 3393                     false        false                  false
#
#      FederalGrantAuditPerformedInd FederalGrantAuditRequiredInd  \
# 3393                           NaN                        false
#
#      FederatedCampaignsAmt  \
# 3393                   NaN
#
#                             FeesForServicesAccountingGrp  \
# 3393  {'TotalAmt': '1345', 'ProgramServicesAmt': '1345'}
#
#      FeesForServicesLegalGrp FeesForServicesLobbyingGrp  \
# 3393       {'TotalAmt': '0'}          {'TotalAmt': '0'}
#
#      FeesForServicesManagementGrp FeesForServicesOtherGrp  \
# 3393            {'TotalAmt': '0'}       {'TotalAmt': '0'}
#
#                             FeesForSrvcInvstMgmntFeesGrp FinalReturnInd  \
# 3393  {'TotalAmt': '5838', 'ProgramServicesAmt': '5838'}            NaN
#
#      Form990ProvidedToGvrnBodyInd FormationYr FormerOfcrEmployeesListedInd  \
# 3393                        false         NaN                        false
#
#      FundraisingAmt FundraisingDirectExpensesAmt FundraisingGrossIncomeAmt  \
# 3393            NaN                          NaN                       NaN
#
#      GamingDirectExpensesAmt GamingGrossIncomeAmt  \
# 3393                     NaN                  NaN
#
#      GoverningBodyVotingMembersCnt GovernmentGrantsAmt GrossReceiptsAmt  \
# 3393                            13                 NaN           232935
#
#      GrossSalesOfInventoryAmt GroupExemptionNum GroupReturnForAffiliatesInd  \
# 3393                      NaN               NaN                       false
#
#      IndependentVotingMemberCnt IndivRcvdGreaterThan100KCnt InitialReturnInd  \
# 3393                          0                           0              NaN
#
#      InvestmentExpenseAmt InvestmentInJointVentureInd  \
# 3393                  NaN                       false
#
#      LandBldgEquipAccumDeprecAmt LandBldgEquipCostOrOtherBssAmt  \
# 3393                         NaN                            NaN
#
#      LegalDomicileCountryCd LegalDomicileStateCd  \
# 3393                    NaN                  NaN
#
#      LoansFromOfficersDirectorsGrp LocalChaptersInd  \
# 3393                           NaN            false
#
#      MaterialDiversionOrMisuseInd MembersOrStockholdersInd MembershipDuesAmt  \
# 3393                        false                    false               NaN
#
#      MethodOfAccountingAccrualInd MethodOfAccountingCashInd  \
# 3393                          NaN                         X
#
#      MethodOfAccountingOtherInd MinutesOfCommitteesInd  \
# 3393                        NaN                  false
#
#      MinutesOfGoverningBodyInd MortgNotesPyblScrdInvstPropGrp  \
# 3393                     false                            NaN
#
#      NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 3393                        578679                        594573
#
#      NetUnrelatedBusTxblIncmAmt NetUnrlzdGainsLossesInvstAmt  \
# 3393                        NaN                          NaN
#
#      NoListedPersonsCompensatedInd NoncashContributionsAmt  \
# 3393                             X                     NaN
#
#      OfficerMailingAddressInd OrgDoesNotFollowSFAS117Ind  \
# 3393                    false                        NaN
#
#      Organization4947a1NotPFInd Organization501c3Ind Organization501cInd  \
# 3393                        NaN                    X                 NaN
#
#      OrganizationFollowsSFAS117Ind OtherEmployeeBenefitsGrp  \
# 3393                             X        {'TotalAmt': '0'}
#
#      OtherLiabilitiesGrp OtherOrganizationDsc OtherRevenueTotalAmt  \
# 3393                 NaN                  NaN                    0
#
#      OtherSalariesAndWagesGrp OtherWebsiteInd OwnWebsiteInd  \
# 3393        {'TotalAmt': '0'}             NaN           NaN
#
#      PYBenefitsPaidToMembersAmt PYContributionsGrantsAmt  \
# 3393                        NaN                    24634
#
#      PYGrantsAndSimilarPaidAmt PYInvestmentIncomeAmt PYOtherExpensesAmt  \
# 3393                     27521                 28259               9430
#
#      PYOtherRevenueAmt PYProgramServiceRevenueAmt PYRevenuesLessExpensesAmt  \
# 3393               NaN                       2775                     18717
#
#      PYSalariesCompEmpBnftPaidAmt PYTotalExpensesAmt  \
# 3393                          NaN              36951
#
#      PYTotalProfFndrsngExpnsAmt PYTotalRevenueAmt    PayrollTaxesGrp  \
# 3393                        NaN             55668  {'TotalAmt': '0'}
#
#      PensionPlanContributionsGrp PoliciesReferenceChaptersInd  \
# 3393           {'TotalAmt': '0'}                          NaN
#
#      PrincipalOfficerNm PriorPeriodAdjustmentsAmt  \
# 3393                NaN                       NaN
#
#      ReconcilationRevenueExpnssAmt RegularMonitoringEnfrcInd  \
# 3393                         15894                     false
#
#      RelatedOrganizationsAmt RtnEarnEndowmentIncmOthFndsGrp  \
# 3393                     NaN                            NaN
#
#                   SavingsAndTempCashInvstGrp SpecialConditionDesc  \
# 3393  {'BOYAmt': '83504', 'EOYAmt': '43131'}                  NaN
#
#      StatesWhereCopyOfReturnIsFldCd TaxExemptBondLiabilitiesGrp  \
# 3393                            NaN                         NaN
#
#      TotReportableCompRltdOrgAmt TotalAssetsBOYAmt TotalAssetsEOYAmt  \
# 3393                         NaN            578679            594573
#
#                                 TotalAssetsGrp TotalCompGreaterThan150KInd  \
# 3393  {'BOYAmt': '578679', 'EOYAmt': '594573'}                       false
#
#      TotalContributionsAmt TotalEmployeeCnt  \
# 3393                 14140                0
#
#                                                                                        TotalFunctionalExpensesGrp  \
# 3393  {'TotalAmt': '34093', 'ProgramServicesAmt': '34093', 'ManagementAndGeneralAmt': '0', 'FundraisingAmt': '0'}
#
#      TotalGrossUBIAmt TotalLiabilitiesBOYAmt TotalLiabilitiesEOYAmt  \
# 3393                0                    NaN                      0
#
#      TotalOtherCompensationAmt TotalProgramServiceRevenueAmt  \
# 3393                       NaN                          2450
#
#      TotalReportableCompFromOrgAmt  \
# 3393                           NaN
#
#                                                                                           TotalRevenueGrp  \
# 3393  {'TotalRevenueColumnAmt': '49987', 'RelatedOrExemptFuncIncomeAmt': '7849', 'ExclusionAmt': '27998'}
#
#      TotalVolunteersCnt TypeOfOrganizationAssocInd TypeOfOrganizationCorpInd  \
# 3393                NaN                        NaN                       NaN
#
#      TypeOfOrganizationOtherInd TypeOfOrganizationTrustInd  \
# 3393                        NaN                        NaN
#
#      UnsecuredNotesLoansPayableGrp UponRequestInd  \
# 3393                           NaN            NaN
#
#      VotingMembersGoverningBodyCnt VotingMembersIndependentCnt  \
# 3393                            13                           0
#
#      WebsiteAddressTxt WhistleblowerPolicyInd WrittenPolicyOrProcedureInd  \
# 3393               N/A                  false                         NaN
#
#      fiscal_year
# 3393        2019

# %% [markdown]
# <br>*ast* only needed if reading in CSV file

# %%
#from ast import literal_eval
#import ast
#for index, row in df[:2].iterrows():
#    print(row['ReturnHeader'])
#    print(type(row['ReturnHeader']))
#    #USE FOLLOWING CODE IF I AM IMPORTING CSV
#    #print(type(ast.literal_eval(row['ReturnHeader']))) 
#    #print(ast.literal_eval(row['ReturnHeader'])['Total'], '\n')
# Out:
# {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}
# <class 'dict'>
# {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}
# <class 'dict'>

# %% [markdown]
# #### Extended 'lambda' function
# https://stackoverflow.com/questions/48872234/using-apply-in-pandas-lambda-functions-with-multiple-if-statements?noredirect=1&lq=1

# %% [markdown]
# ##### Version if reading in *.csv file

# %%
"""
def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in ast.literal_eval(x).keys():
        return ast.literal_eval(x)[key1]
    elif key2 in ast.literal_eval(x).keys():
        return ast.literal_eval(x)[key2]
    else:
        return np.nan
"""

# %% [markdown]
# ##### Version if reading in *.pkl file

# %%
"""def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    elif key2 in x.keys():
        return x[key2]
    else:
        return np.nan
"""

# %%
#import timeit
#start_time = timeit.default_timer()
#df['F9_00_HD_TAX_PER_END'] = df['ReturnHeader'][:].apply(func, key1='TaxPeriodEndDt', key2='TaxPeriodEndDate')
##df['F9_09_PC_FEES_FOR_SVCE_MGMT_TOT2'] = df['ReturnHeader'].astype('float')
#elapsed = timeit.default_timer() - start_time
#print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.2046476249999993

# %%
#import timeit
#start_time = timeit.default_timer()
#df['F9_00_HD_TAX_YEAR'] = df['ReturnHeader'][:].apply(func, key1='TaxYr', key2='TaxYear')
##df['F9_09_PC_FEES_FOR_SVCE_MGMT_TOT2'] = df['ReturnHeader'].astype('float')
#elapsed = timeit.default_timer() - start_time
#print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.19795467166666944

# %% [markdown]
# ### Handle variables with only 1 original name
# NOTE:
# - Per *IRS 990 e-File Data -- Control Variables (4) -- Fees-for-Services Variables  - Extract from MongoDB and Process -- Part I (Python 3.6).ipynb*, it looks like there is no *FeesForServicesProfFundraisingGrp*
#     - Instead, as seen in the concordance file, *FeesForServicesProfFundraising* has both a 'Total' and a 'TotalAmt' key, which suggests this is the only key that did not change names

# %%
new_variables_df[new_variables_df['len']!=2]
# Out:
#                  variable_name_new                    original_names  \
# 2        F9_00_HD_BUILD_TIME_STAMP                         [BuildTS]
# 7          F9_00_HD_FILER_STATE_US                           [Filer]
# 137  F9_09_PC_FEES_FOR_SVCE_FR_TOT  [FeesForServicesProfFundraising]
# 192                      TaxPeriod                       [TaxPeriod]
#
#     data_type_xsd  len
# 2             NaN    1
# 7       StateType    1
# 137           NaN    1
# 192           NaN    1

# %% [markdown]
# #### Rename *FeesForServicesProfFundraising*
# Note that *describe* and *value_counts* won't work yet because some values are dictionaries

# %%
# %%time
df.rename(columns = {'FeesForServicesProfFundraising':'F9_09_PC_FEES_FOR_SVCE_FR_TOT'}, inplace = True)
#df['F9_09_PC_FEES_FOR_SVCE_FR_TOT'].describe()
#df['F9_09_PC_FEES_FOR_SVCE_FR_TOT'].value_counts()[:5]
# Out:
# Wall time: 27.6 s

# %% [markdown]
# #### Rename *BuildTS*

# %%
# %%time
df.rename(columns = {'BuildTS':'F9_00_HD_BUILD_TIME_STAMP'}, inplace = True)
# Out:
# Wall time: 11 s

# %%
df[['F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'F9_00_HD_BUILD_TIME_STAMP', 'Filer', 'TaxPeriod']].sample(5)
# Out:
#                             F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 1017228                                 {'TotalAmt': '0'}
# 1031402  {'TotalAmt': '31250', 'FundraisingAmt': '31250'}
# 382975                                                NaN
# 492695   {'TotalAmt': '44056', 'FundraisingAmt': '44056'}
# 901684                                                NaN
#
#         F9_00_HD_BUILD_TIME_STAMP  \
# 1017228      2017-02-10 21:41:12Z
# 1031402      2017-02-10 21:41:12Z
# 382975       2016-02-25 16:41:14Z
# 492695       2015-11-30 17:44:51Z
# 901684       2016-09-27 15:27:22Z
#
#                                                                                                                                                                                                                                                              Filer  \
# 1017228  {'EIN': '742158707', 'BusinessName': {'BusinessNameLine1Txt': 'NATIONAL ANIMAL CARE & CONTROL', 'BusinessNameLine2Txt': 'ASSOCIATION'}, 'BusinessNameControlTxt': 'NATI', 'PhoneNum': '9137681319', 'USAddress': {'AddressLine1Txt': '515 RUSSELL AVE'...
# 1031402  {'EIN': '030342594', 'BusinessName': {'BusinessNameLine1Txt': 'LAKE CHAMPLAIN COMMUNITY SAILING', 'BusinessNameLine2Txt': 'CENTER INC'}, 'BusinessNameControlTxt': 'LAKE', 'PhoneNum': '8028642499', 'USAddress': {'AddressLine1Txt': 'PO BOX 64818', ...
# 382975   {'EIN': '203345087', 'Name': {'BusinessNameLine1': 'LIONS EYE BANK OF NEW JERSEY INC'}, 'NameControl': 'LION', 'Phone': '7323823060', 'USAddress': {'AddressLine1': '77 BRANT AVE', 'AddressLine2': 'ROOM/SUITE 100', 'City': 'CLARK', 'State': 'NJ', ...
# 492695   {'EIN': '581735540', 'BusinessName': {'BusinessNameLine1': 'WICHITA HABITAT FOR HUMANITY INC'}, 'BusinessNameControlTxt': 'WICH', 'PhoneNum': '3162690755', 'USAddress': {'AddressLine1': '130 E MURDOCK NO 102', 'City': 'WICHITA', 'State': 'KS', 'Z...
# 901684   {'EIN': '232028533', 'BusinessName': {'BusinessNameLine1Txt': 'COVINGTON CHURCH OF CHRIST'}, 'BusinessNameControlTxt': 'COVI', 'PhoneNum': '5706595629', 'USAddress': {'AddressLine1Txt': '2225 N WILLIAMSON ROAD PO BOX 185', 'CityNm': 'COVINGTON', ...
#
#         TaxPeriod
# 1017228    201512
# 1031402    201512
# 382975     201206
# 492695     201312
# 901684     201512

# %%
#years = pd.DataFrame(df['F9_00_HD_TAX_YEAR'].value_counts())
years = pd.DataFrame(df['fiscal_year'].value_counts())
years.index.name = 'year'
years = years.reset_index()
years = years.sort_values('year')
years
# Out:
#     year  fiscal_year
# 9   2010        98185
# 7   2011       139300
# 6   2012       170761
# 5   2013       190710
# 4   2014       210538
# 3   2015       228000
# 2   2016       240291
# 0   2017       251118
# 1   2018       250237
# 8   2019       113354
# 10  2020         2520
# 11  2108            1

# %% [markdown]
# <br>
# NOTE: I am not dropping *fiscal_year* yet -- it is different from *F9_00_HD_TAX_YEAR* (*fiscal_year* is the 'year' part of the variable *TaxPeriod*, which is the year-month of *F9_00_HD_TAX_PER_END*
#
# So, the first three below -- *fiscal_year*,  *TaxPeriod*, and *F9_00_HD_TAX_PER_END* -- are all based off the same date, which is the *END* of the tax period, while *F9_00_HD_TAX_YEAR* reflects the year in which the tax period *BEGINS*.

# %%
df[['fiscal_year',  'TaxPeriod', 'F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR']].sample(25)
# Out:
#         fiscal_year TaxPeriod F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR
# 1858761        2019    201906           2019-06-30              2018
# 1256596        2016    201612           2016-12-31              2016
# 226064         2012    201203           2012-03-31              2011
# 1732876        2019    201906           2019-06-30              2018
# 740754         2014    201406           2014-06-30              2013
# 1437744        2017    201712           2017-12-31              2017
# 181793         2011    201112           2011-12-31              2011
# 718120         2014    201412           2014-12-31              2014
# 1735409        2018    201812           2018-12-31              2018
# 248050         2011    201112           2011-12-31              2011
# 1759965        2019    201904           2019-04-30              2018
# 5620           2010    201012           2010-12-31              2010
# 838025         2015    201506           2015-06-30              2014
# 295731         2012    201208           2012-08-31              2011
# 647820         2014    201406           2014-06-30              2013
# 1685275        2019    201906           2019-06-30              2018
# 1478201        2017    201712           2017-12-31              2017
# 1325972        2017    201706           2017-06-30              2016
# 856550         2014    201412           2014-12-31              2014
# 1485425        2017    201712           2017-12-31              2017
# 513989         2013    201309           2013-09-30              2012
# 963848         2015    201512           2015-12-31              2015
# 1734192        2018    201812           2018-12-31              2018
# 17623          2010    201008           2010-08-31              2009
# 409243         2011    201112           2011-12-31              2011

# %%
#df = df.drop('fiscal_year', 1)

# %%
df[['fiscal_year', 'F9_00_HD_TAX_YEAR']].describe().T
# Out:
#                      count unique   top    freq
# fiscal_year        1895015     12  2017  251118
# F9_00_HD_TAX_YEAR  1895016     11  2017  252085

# %%
[c for c in df.columns.tolist() if 'tax' in c.lower()]
# Out:
# ['TaxPeriod',
#  'F9_00_HD_TAX_PER_END',
#  'F9_00_HD_TAX_YEAR',
#  'F9_09_PC_PAYROLL_TAX_FUNDRAISE',
#  'F9_09_PC_PAYROLL_TAX_MGMT',
#  'F9_09_PC_PAYROLL_TAX_PROG_SVCE',
#  'F9_09_PC_PAYROLL_TAX_TOTAL']

# %% [markdown]
# <br>Drop *ReturnHeader*

# %%
#df = df.drop('ReturnHeader', 1)

# %% [markdown]
# <br>Drop the two variables from *new_variables_df*

# %%
#print(len(new_variables_df))
#new_variables_df = new_variables_df[~new_variables_df['variable_name_new'].isin(['F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR'])]
#print(len(new_variables_df))
# Out:
# 185
# 183

# %%
df[:1]
# Out:
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod        EIN AddressChange  \
# 0  93493313013011    201012  232705170             X
#
#   NameOfPrincipalOfficerPerson GrossReceipts GroupReturnForAffiliates  \
# 0                MICHAEL ANTON       1473903                        0
#
#   Organization501c3 WebSite TypeOfOrganizationCorporation YearFormation  \
# 0                 X     N/A                             X          1992
#
#   StateLegalDomicile  \
# 0                 PA
#
#                                                                ActivityOrMissionDescription  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
#
#   ProfessionalFundraising FundraisingActivities Gaming  \
# 0                       0                     0      0
#
#   NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 0                            10                             10
#
#   FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 0                            0                            0
#
#   ChangesToOrganizingDocs MaterialDiversionOrMisuse MembersOrStockholders  \
# 0                       0                         0                     0
#
#   ElectionOfBoardMembers DecisionsSubjectToApproval MinutesOfGoverningBody  \
# 0                      0                          0                      1
#
#   MinutesOfCommittees OfficerMailingAddress LocalChapters  \
# 0                   1                     0             0
#
#   Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 0                              1                        1
#
#   AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 0                              1                            1
#
#   WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 0                   0                       0                      0
#
#   CompensationProcessOther InvestmentInJointVenture  \
# 0                        0                        0
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0                   [PA, NJ, DE]           X                          X
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
#
#                               FeesForServicesLegal  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 0  {'BOY': '332660', 'EOY': '270700'}                      256845
#
#   LandBldgEquipmentAccumDeprec                           TotalAssets  \
# 0                        86228  {'BOY': '1925215', 'EOY': '2440859'}
#
#                     OtherLiabilities FollowSFAS117  \
# 0  {'BOY': '51640', 'EOY': '240077'}             X
#
#   ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 0                        89152                         X
#
#   AccountantCompileOrReview FSAudited AuditCommittee  \
# 0                         0         1              1
#
#   FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 0                         0                   NaN                  NaN
#
#   PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 0                       NaN                      NaN
#
#   TotalProgramServiceRevenue CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                        NaN                          NaN                NaN
#
#   OtherSalariesAndWages PensionPlanContributions OtherEmployeeBenefits  \
# 0                   NaN                      NaN                   NaN
#
#   PayrollTaxes FeesForServicesManagement FeesForServicesLobbying  \
# 0          NaN                       NaN                     NaN
#
#   F9_09_PC_FEES_FOR_SVCE_FR_TOT FeesForServicesInvstMgmntFees  \
# 0                           NaN                           NaN
#
#   FeesForServicesOther CashNonInterestBearing MortNotesPyblSecuredInvestProp  \
# 0                  NaN                    NaN                            NaN
#
#   FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 0                        NaN                        NaN
#
#   MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 0                    NaN                      NaN          NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0               NaN                            NaN                  NaN
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                          NaN                       NaN                NaN
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0              NaN                     NaN                   NaN
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0             NaN                NaN                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0           NaN            NaN               NaN                  NaN
#
#   NoncashContributions OwnWebsite UnsecuredNotesLoansPayable  \
# 0                  NaN        NaN                        NaN
#
#   TypeOfOrganizationOther Organization501c TypeOfOrganizationTrust  \
# 0                     NaN              NaN                     NaN
#
#   TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 0                           NaN                  NaN           NaN
#
#   TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 0                       NaN              NaN                      NaN
#
#   SpecialConditionDescription Organization4947a1  \
# 0                         NaN                NaN
#
#   ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 0                            NaN                          NaN
#
#   ReconcilationDonatedServices ReconcilationInvestExpenses PrincipalOfficerNm  \
# 0                          NaN                         NaN                NaN
#
#   GrossReceiptsAmt GroupReturnForAffiliatesInd Organization501c3Ind  \
# 0              NaN                         NaN                  NaN
#
#   TypeOfOrganizationCorpInd FormationYr LegalDomicileStateCd  \
# 0                       NaN         NaN                  NaN
#
#   ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                   NaN                           NaN
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                         NaN              NaN              NaN
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                      NaN                        NaN                   NaN
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0               NaN               NaN                       NaN
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                        NaN                          NaN
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                        NaN                          NaN                NaN
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0                NaN                       NaN               NaN
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0               NaN                    NaN                           NaN
#
#   NetAssetsOrFundBalancesEOYAmt ProfessionalFundraisingInd  \
# 0                           NaN                        NaN
#
#   FundraisingActivitiesInd GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 0                      NaN                 NaN                           NaN
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                        NaN                    NaN                       NaN
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                     NaN                          NaN
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                      NaN                       NaN
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                          NaN                       NaN
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                    NaN                      NaN              NaN
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                          NaN                         NaN
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                    NaN                        NaN                       NaN
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                         NaN                         NaN
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                            NaN                           NaN
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                          NaN                         NaN
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                          NaN               NaN            NaN
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                      NaN                   NaN                  NaN
#
#   TotalRevenueGrp FeesForServicesAccountingGrp TotalFunctionalExpensesGrp  \
# 0             NaN                          NaN                        NaN
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                       NaN            NaN                        NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                            NaN                           NaN
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                       NaN                          NaN          NaN
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                          NaN               NaN                NaN
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                        NaN                      NaN
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                        NaN                   NaN               NaN
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0               NaN                       NaN                        NaN
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                          NaN                        NaN                NaN
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0                NaN                       NaN                    NaN
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                            NaN                       NaN            NaN
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                           NaN                         NaN
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                       NaN                         NaN
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                          NaN                 NaN
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                           NaN                       NaN
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                          NaN                          NaN
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt CompCurrentOfcrDirectorsGrp  \
# 0                      NaN                NaN                         NaN
#
#   OtherSalariesAndWagesGrp PensionPlanContributionsGrp  \
# 0                      NaN                         NaN
#
#   OtherEmployeeBenefitsGrp PayrollTaxesGrp FeesForServicesOtherGrp  \
# 0                      NaN             NaN                     NaN
#
#   SavingsAndTempCashInvstGrp LandBldgEquipCostOrOtherBssAmt  \
# 0                        NaN                            NaN
#
#   LandBldgEquipAccumDeprecAmt MortgNotesPyblScrdInvstPropGrp  \
# 0                         NaN                            NaN
#
#   OtherLiabilitiesGrp OrganizationFollowsSFAS117Ind  \
# 0                 NaN                           NaN
#
#   NetUnrlzdGainsLossesInvstAmt AuditCommitteeInd AllAffiliatesIncludedInd  \
# 0                          NaN               NaN                      NaN
#
#   CompDisqualPersonsGrp FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 0                        NaN                          NaN
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 0                          NaN                     NaN
#
#   TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 0                         NaN                           NaN
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                           NaN                       NaN
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                           NaN                          NaN             NaN
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0              NaN                         NaN                     NaN
#
#   OwnWebsiteInd DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0           NaN                           NaN                    NaN
#
#   TypeOfOrganizationTrustInd FinalReturnInd ContractTerminationInd  \
# 0                        NaN            NaN                    NaN
#
#   GroupExemptionNum FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0               NaN                   NaN                        NaN
#
#   OtherOrganizationDsc TypeOfOrganizationAssocInd InitialReturnInd  \
# 0                  NaN                        NaN              NaN
#
#   GamingGrossIncomeAmt GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 0                  NaN                     NaN                        NaN
#
#   InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 0                  NaN                 NaN                        NaN
#
#   AmendedReturnInd SpecialConditionDesc fiscal_year  \
# 0              NaN                  NaN        2010
#
#                    Timestamp TaxPeriodEndDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   TaxYear F9_00_HD_BUILD_TIME_STAMP ReturnTs TaxPeriodEndDt  \
# 0    2010      2016-02-24 21:20:13Z      NaN            NaN
#
#   BusinessOfficerGrp TaxYr
# 0                NaN   NaN

# %% [markdown]
# ##### Save DF

# %%
#import timeit
#start_time = timeit.default_timer()
#df.to_pickle('all filings - with 185 newly named control variables.pkl')
#elapsed = timeit.default_timer() - start_time
#print('# of minutes: ', elapsed/60)

# %%
"""
import timeit
start_time = timeit.default_timer()
df = pd.read_pickle('all filings - with 185 newly named control variables.pkl')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60) 
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:2]
"""
# Out:
# # of minutes:  1.9289162200000003
# # of columns: 318
# # of observations: 1727056
#   AccountantCompileOrReview  \
# 0                         0
# 1                     false
#
#                                                                                                                     ActivityOrMissionDescription  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   AddressChange AllAffiliatesIncluded AllOtherContributions AmendedReturn  \
# 0             X                   NaN               1439340           NaN
# 1           NaN                 false                   NaN           NaN
#
#   AnnualDisclosureCoveredPersons AuditCommittee BenefitsPaidToMembersCY  \
# 0                              1              1                       0
# 1                           true           true                       0
#
#   BenefitsPaidToMembersPriorYear          CashNonInterestBearing  \
# 0                              0                             NaN
# 1                            NaN  {'BOY': '250', 'EOY': '22261'}
#
#   ChangesToOrganizingDocs CntrbtnsRprtdFundraisingEvents  \
# 0                       0                            NaN
# 1                   false                            NaN
#
#   CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                          NaN                NaN
# 1               {'Total': '0'}     {'Total': '0'}
#
#   CompensationFromOtherSources CompensationProcessCEO  \
# 0                            0                      0
# 1                        false                   true
#
#   CompensationProcessOther ConflictOfInterestPolicy  \
# 0                        0                        1
# 1                     true                     true
#
#   ContributionsGrantsCurrentYear ContributionsGrantsPriorYear CostOfGoodsSold  \
# 0                        1439340                      1044925             NaN
# 1                              0                          NaN             NaN
#
#   CountryLegalDomicile             DLN DecisionsSubjectToApproval  \
# 0                  NaN  93493313013011                          0
# 1                  NaN  93493313013111                       true
#
#   DelegationOfManagementDuties DoNotFollowSFAS117 DocumentRetentionPolicy  \
# 0                            0                NaN                       0
# 1                         true                NaN                   false
#
#          EIN ElectionOfBoardMembers FSAudited FamilyOrBusinessRelationship  \
# 0  232705170                      0         1                            0
# 1  581805618                   true      true                         true
#
#   FederalGrantAuditPerformed FederalGrantAuditRequired FederatedCampaigns  \
# 0                        NaN                         0                NaN
# 1                       true                      true                NaN
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
# 1    {'Total': '7500', 'ManagementAndGeneral': '7500'}
#
#   FeesForServicesInvstMgmntFees  \
# 0                           NaN
# 1                {'Total': '0'}
#
#                               FeesForServicesLegal FeesForServicesLobbying  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}                     NaN
# 1                                   {'Total': '0'}          {'Total': '0'}
#
#                              FeesForServicesManagement FeesForServicesOther  \
# 0                                                  NaN                  NaN
# 1  {'Total': '21600', 'ManagementAndGeneral': '21600'}       {'Total': '0'}
#
#   F9_09_PC_FEES_FOR_SVCE_FR_TOT FollowSFAS117 Form990ProvidedToGoverningBody  \
# 0                           NaN             X                              1
# 1                {'Total': '0'}             X                           true
#
#   FormersListed FundraisingDirectExpenses FundraisingEvents  \
# 0             0                       NaN               NaN
# 1          true                       NaN               NaN
#
#   GamingDirectExpenses GovernmentGrants GrantsAndSimilarAmntsCY  \
# 0                  NaN              NaN                  925000
# 1                  NaN              NaN                       0
#
#   GrantsAndSimilarAmntsPriorYear GrossIncomeFundraisingEvents  \
# 0                         638637                          NaN
# 1                            NaN                          NaN
#
#   GrossIncomeGaming GrossReceipts GrossSalesOfInventory GroupExemptionNumber  \
# 0               NaN       1473903                   NaN                  NaN
# 1               NaN        266420                   NaN                 1736
#
#   GroupReturnForAffiliates InitialReturn InvestmentInJointVenture  \
# 0                        0           NaN                        0
# 1                    false           NaN                    false
#
#   InvestmentIncomeCurrentYear InvestmentIncomePriorYear  \
# 0                       33563                     30447
# 1                         828                      1425
#
#   LandBldgEquipmentAccumDeprec LandBuildingsEquipmentBasis  \
# 0                        86228                      256845
# 1                       904332                     2187206
#
#   LoansFromOfficersDirectors LocalChapters MaterialDiversionOrMisuse  \
# 0                        NaN             0                         0
# 1                        NaN         false                     false
#
#   MembersOrStockholders MembershipDues MethodOfAccountingAccrual  \
# 0                     0            NaN                         X
# 1                 false            NaN                         X
#
#   MethodOfAccountingCash MethodOfAccountingOther MinutesOfCommittees  \
# 0                    NaN                     NaN                   1
# 1                    NaN                     NaN                true
#
#   MinutesOfGoverningBody  MortNotesPyblSecuredInvestProp  \
# 0                      1                             NaN
# 1                   true  {'BOY': '6219', 'EOY': '7035'}
#
#   NameOfPrincipalOfficerPerson NbrIndependentVotingMembers  \
# 0                MICHAEL ANTON                          10
# 1                          NaN                          13
#
#   NbrVotingGoverningBodyMembers NbrVotingMembersGoverningBody  \
# 0                            10                            10
# 1                            19                            19
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
# 1                    1437850                    1398765
#
#   NetUnrelatedBusinessTxblIncome NoListedPersonsCompensated  \
# 0                              0                          X
# 1                            NaN                        NaN
#
#   NoncashContributions NumberIndependentVotingMembers NumberIndividualsGT100K  \
# 0                  NaN                             10                       0
# 1                  NaN                             13                       0
#
#   NumberOfContractorsGT100K OfficerMailingAddress Organization4947a1  \
# 0                         0                     0                NaN
# 1                         0                 false                NaN
#
#   Organization501c Organization501c3  \
# 0              NaN                 X
# 1              NaN                 X
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                             OtherEmployeeBenefits OtherExpensePriorYear  \
# 0                                             NaN                243131
# 1  {'Total': '17714', 'ProgramServices': '17714'}                189785
#
#   OtherExpensesCurrentYear                   OtherLiabilities  \
# 0                   459751  {'BOY': '51640', 'EOY': '240077'}
# 1                   222550    {'BOY': '9203', 'EOY': '11349'}
#
#   OtherRevenueCurrentYear OtherRevenuePriorYear  \
# 0                    1000                     0
# 1                       0                   NaN
#
#                             OtherSalariesAndWages OtherWebsite OwnWebsite  \
# 0                                             NaN          NaN        NaN
# 1  {'Total': '59440', 'ProgramServices': '59440'}          NaN        NaN
#
#                                    PayrollTaxes PensionPlanContributions  \
# 0                                           NaN                      NaN
# 1  {'Total': '5801', 'ProgramServices': '5801'}           {'Total': '0'}
#
#   PoliciesReferenceChapters ProgramServiceRevenueCY  \
# 0                       NaN                       0
# 1                     false                  265592
#
#   ProgramServiceRevenuePriorYear ReconcilationRevenueExpenses  \
# 0                              0                        89152
# 1                         222839                       -39085
#
#   RegularMonitoringEnforcement RelatedOrganizations  \
# 0                            1                  NaN
# 1                         true                  NaN
#
#   RetainedEarningsEndowmentEtc RevenuesLessExpensesCY  \
# 0                          NaN                  89152
# 1                          NaN                 -39085
#
#   RevenuesLessExpensesPriorYear SalariesEtcCurrentYear SalariesEtcPriorYear  \
# 0                        193604                      0                    0
# 1                        -36926                  82955                71405
#
#         SavingsAndTempCashInvestments SpecialConditionDescription  \
# 0  {'BOY': '332660', 'EOY': '270700'}                         NaN
# 1                        {'EOY': '0'}                         NaN
#
#   StateLegalDomicile StatesWhereCopyOfReturnIsFiled TaxExemptBondLiabilities  \
# 0                 PA                   [PA, NJ, DE]                      NaN
# 1                 WY                            NaN                      NaN
#
#   TaxPeriod TerminatedReturn TerminationOrContraction  \
# 0    201012              NaN                      NaN
# 1    201106              NaN                      NaN
#
#                             TotalAssets TotalAssetsBOY TotalAssetsEOY  \
# 0  {'BOY': '1925215', 'EOY': '2440859'}        1925215        2440859
# 1  {'BOY': '1455332', 'EOY': '1433342'}        1455332        1433342
#
#   TotalCompGT150K TotalContributions TotalExpensesCurrentYear  \
# 0               0            1439340                  1384751
# 1            true                  0                   305505
#
#   TotalExpensesPriorYear  \
# 0                 881768
# 1                 261190
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
# 1          {'Total': '305505', 'ProgramServices': '276405', 'ManagementAndGeneral': '29100', 'Fundraising': '0'}
#
#   TotalFundrsngExpCurrentYear TotalGrossUBI TotalLiabilitiesBOY  \
# 0                      195892             0              171810
# 1                           0             0               17482
#
#   TotalLiabilitiesEOY TotalNbrEmployees TotalNbrVolunteers  \
# 0              450430                 0                  0
# 1               34577                 0                NaN
#
#   TotalOtherCompensation TotalOtherRevenue TotalProfFundrsngExpCY  \
# 0                      0              1000                      0
# 1                 411648                 0                      0
#
#   TotalProfFundrsngExpPriorYear TotalProgramServiceRevenue  \
# 0                             0                        NaN
# 1                           NaN                     265592
#
#   TotalReportableCompFrmRltdOrgs TotalReportableCompFromOrg  \
# 0                              0                          0
# 1                        1180355                        NaN
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
# 1                                                              {'TotalRevenueColumn': '266420', 'RelatedOrExemptFunctionIncome': '266420'}
#
#   TotalRevenueCurrentYear TotalRevenuePriorYear TypeOfOrgOtherDescription  \
# 0                 1473903               1075372                       NaN
# 1                  266420                224264                       NaN
#
#   TypeOfOrganizationAssociation TypeOfOrganizationCorporation  \
# 0                           NaN                             X
# 1                           NaN                             X
#
#   TypeOfOrganizationOther TypeOfOrganizationTrust  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#   UnsecuredNotesLoansPayable UponRequest WebSite WhistleblowerPolicy  \
# 0                        NaN           X     N/A                   0
# 1                        NaN           X     N/A               false
#
#   WrittenPolicyOrProcedure YearFormation ReconcilationDonatedServices  \
# 0                      NaN          1992                          NaN
# 1                    false          1993                          NaN
#
#   ReconcilationInvestExpenses ReconcilationPriorAdjustment  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
#
#   ReconciliationUnrealizedInvest AccountantCompileOrReviewInd  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
#
#   ActivityOrMissionDesc AddressChangeInd AllAffiliatesIncludedInd  \
# 0                   NaN              NaN                      NaN
# 1                   NaN              NaN                      NaN
#
#   AllOtherContributionsAmt AmendedReturnInd AnnualDisclosureCoveredPrsnInd  \
# 0                      NaN              NaN                            NaN
# 1                      NaN              NaN                            NaN
#
#   AuditCommitteeInd CYBenefitsPaidToMembersAmt CYContributionsGrantsAmt  \
# 0               NaN                        NaN                      NaN
# 1               NaN                        NaN                      NaN
#
#   CYGrantsAndSimilarPaidAmt CYInvestmentIncomeAmt CYOtherExpensesAmt  \
# 0                       NaN                   NaN                NaN
# 1                       NaN                   NaN                NaN
#
#   CYOtherRevenueAmt CYProgramServiceRevenueAmt CYRevenuesLessExpensesAmt  \
# 0               NaN                        NaN                       NaN
# 1               NaN                        NaN                       NaN
#
#   CYSalariesCompEmpBnftPaidAmt CYTotalExpensesAmt  \
# 0                          NaN                NaN
# 1                          NaN                NaN
#
#   CYTotalFundraisingExpenseAmt CYTotalProfFndrsngExpnsAmt CYTotalRevenueAmt  \
# 0                          NaN                        NaN               NaN
# 1                          NaN                        NaN               NaN
#
#   CashNonInterestBearingGrp ChangeToOrgDocumentsInd  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
#
#   CntrctRcvdGreaterThan100KCnt CompCurrentOfcrDirectorsGrp  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
#
#   CompDisqualPersonsGrp CompensationFromOtherSrcsInd  \
# 0                   NaN                          NaN
# 1                   NaN                          NaN
#
#   CompensationProcessCEOInd CompensationProcessOtherInd  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
#
#   ConflictOfInterestPolicyInd ContractTerminationInd  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
#
#   ContriRptFundraisingEventAmt CostOfGoodsSoldAmt  \
# 0                          NaN                NaN
# 1                          NaN                NaN
#
#   DecisionsSubjectToApprovaInd DelegationOfMgmtDutiesInd  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
#
#   DocumentRetentionPolicyInd DonatedServicesAndUseFcltsAmt  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
#
#   ElectionOfBoardMembersInd FSAuditedInd FamilyOrBusinessRlnInd  \
# 0                       NaN          NaN                    NaN
# 1                       NaN          NaN                    NaN
#
#   FederalGrantAuditPerformedInd FederalGrantAuditRequiredInd  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
#
#   FederatedCampaignsAmt FeesForServicesAccountingGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
# 1                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForServicesManagementGrp  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#   FeesForServicesOtherGrp FeesForSrvcInvstMgmntFeesGrp FinalReturnInd  \
# 0                     NaN                          NaN            NaN
# 1                     NaN                          NaN            NaN
#
#   Form990ProvidedToGvrnBodyInd FormationYr FormerOfcrEmployeesListedInd  \
# 0                          NaN         NaN                          NaN
# 1                          NaN         NaN                          NaN
#
#   FundraisingAmt FundraisingDirectExpensesAmt FundraisingGrossIncomeAmt  \
# 0            NaN                          NaN                       NaN
# 1            NaN                          NaN                       NaN
#
#   GamingDirectExpensesAmt GamingGrossIncomeAmt GoverningBodyVotingMembersCnt  \
# 0                     NaN                  NaN                           NaN
# 1                     NaN                  NaN                           NaN
#
#   GovernmentGrantsAmt GrossReceiptsAmt GrossSalesOfInventoryAmt  \
# 0                 NaN              NaN                      NaN
# 1                 NaN              NaN                      NaN
#
#   GroupExemptionNum GroupReturnForAffiliatesInd IndependentVotingMemberCnt  \
# 0               NaN                         NaN                        NaN
# 1               NaN                         NaN                        NaN
#
#   IndivRcvdGreaterThan100KCnt InitialReturnInd InvestmentExpenseAmt  \
# 0                         NaN              NaN                  NaN
# 1                         NaN              NaN                  NaN
#
#   InvestmentInJointVentureInd LandBldgEquipAccumDeprecAmt  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
#
#   LandBldgEquipCostOrOtherBssAmt LegalDomicileCountryCd LegalDomicileStateCd  \
# 0                            NaN                    NaN                  NaN
# 1                            NaN                    NaN                  NaN
#
#   LoansFromOfficersDirectorsGrp LocalChaptersInd MaterialDiversionOrMisuseInd  \
# 0                           NaN              NaN                          NaN
# 1                           NaN              NaN                          NaN
#
#   MembersOrStockholdersInd MembershipDuesAmt MethodOfAccountingAccrualInd  \
# 0                      NaN               NaN                          NaN
# 1                      NaN               NaN                          NaN
#
#   MethodOfAccountingCashInd MethodOfAccountingOtherInd MinutesOfCommitteesInd  \
# 0                       NaN                        NaN                    NaN
# 1                       NaN                        NaN                    NaN
#
#   MinutesOfGoverningBodyInd MortgNotesPyblScrdInvstPropGrp  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
#
#   NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
#
#   NetUnrelatedBusTxblIncmAmt NetUnrlzdGainsLossesInvstAmt  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
#
#   NoListedPersonsCompensatedInd NoncashContributionsAmt  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
#
#   OfficerMailingAddressInd OrgDoesNotFollowSFAS117Ind  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
#
#   Organization4947a1NotPFInd Organization501c3Ind Organization501cInd  \
# 0                        NaN                  NaN                 NaN
# 1                        NaN                  NaN                 NaN
#
#   OrganizationFollowsSFAS117Ind OtherEmployeeBenefitsGrp OtherLiabilitiesGrp  \
# 0                           NaN                      NaN                 NaN
# 1                           NaN                      NaN                 NaN
#
#   OtherOrganizationDsc OtherRevenueTotalAmt OtherSalariesAndWagesGrp  \
# 0                  NaN                  NaN                      NaN
# 1                  NaN                  NaN                      NaN
#
#   OtherWebsiteInd OwnWebsiteInd PYBenefitsPaidToMembersAmt  \
# 0             NaN           NaN                        NaN
# 1             NaN           NaN                        NaN
#
#   PYContributionsGrantsAmt PYGrantsAndSimilarPaidAmt PYInvestmentIncomeAmt  \
# 0                      NaN                       NaN                   NaN
# 1                      NaN                       NaN                   NaN
#
#   PYOtherExpensesAmt PYOtherRevenueAmt PYProgramServiceRevenueAmt  \
# 0                NaN               NaN                        NaN
# 1                NaN               NaN                        NaN
#
#   PYRevenuesLessExpensesAmt PYSalariesCompEmpBnftPaidAmt PYTotalExpensesAmt  \
# 0                       NaN                          NaN                NaN
# 1                       NaN                          NaN                NaN
#
#   PYTotalProfFndrsngExpnsAmt PYTotalRevenueAmt PayrollTaxesGrp  \
# 0                        NaN               NaN             NaN
# 1                        NaN               NaN             NaN
#
#   PensionPlanContributionsGrp PoliciesReferenceChaptersInd PrincipalOfficerNm  \
# 0                         NaN                          NaN                NaN
# 1                         NaN                          NaN                NaN
#
#   PriorPeriodAdjustmentsAmt ReconcilationRevenueExpnssAmt  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
#
#   RegularMonitoringEnfrcInd RelatedOrganizationsAmt  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp SavingsAndTempCashInvstGrp  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
#
#   SpecialConditionDesc StatesWhereCopyOfReturnIsFldCd  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
#
#   TaxExemptBondLiabilitiesGrp TotReportableCompRltdOrgAmt TotalAssetsBOYAmt  \
# 0                         NaN                         NaN               NaN
# 1                         NaN                         NaN               NaN
#
#   TotalAssetsEOYAmt TotalAssetsGrp TotalCompGreaterThan150KInd  \
# 0               NaN            NaN                         NaN
# 1               NaN            NaN                         NaN
#
#   TotalContributionsAmt TotalEmployeeCnt TotalFunctionalExpensesGrp  \
# 0                   NaN              NaN                        NaN
# 1                   NaN              NaN                        NaN
#
#   TotalGrossUBIAmt TotalLiabilitiesBOYAmt TotalLiabilitiesEOYAmt  \
# 0              NaN                    NaN                    NaN
# 1              NaN                    NaN                    NaN
#
#   TotalOtherCompensationAmt TotalProgramServiceRevenueAmt  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
#
#   TotalReportableCompFromOrgAmt TotalRevenueGrp TotalVolunteersCnt  \
# 0                           NaN             NaN                NaN
# 1                           NaN             NaN                NaN
#
#   TypeOfOrganizationAssocInd TypeOfOrganizationCorpInd  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
#
#   TypeOfOrganizationOtherInd TypeOfOrganizationTrustInd  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
#
#   UnsecuredNotesLoansPayableGrp UponRequestInd VotingMembersGoverningBodyCnt  \
# 0                           NaN            NaN                           NaN
# 1                           NaN            NaN                           NaN
#
#   VotingMembersIndependentCnt WebsiteAddressTxt WhistleblowerPolicyInd  \
# 0                         NaN               NaN                    NaN
# 1                         NaN               NaN                    NaN
#
#   WrittenPolicyOrProcedureInd F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR
# 0                         NaN           2010-12-31              2010
# 1                         NaN           2011-06-30              2010

# %% [markdown]
# # Combine all columns where *len*==2

# %% [markdown]
# ### Define Function to combine columns
# In Python we can thus create a series of functions that can be used as shortcuts. First we'll create a function called 'combine' that will combine two variables. It takes as *inputs* four things: our dataset/dataframe (*df*), the name we'd like for our new variable (*newvar*), the name of the first variable to combine (*var1*), and the name of the second variable to combine (*var2*).

# %%
def combine(df, newvar, var1, var2):
    df[newvar] = np.where(df[var1].notnull(), df[var1], df[var2])
    #print(df[newvar].value_counts().head(), '\n')
    #print('# of missing observations:', len(df[df[newvar].isnull()]))
    #print('# of valid observations:', len(df[df[newvar].notnull()]), '\n')  
    #return df.sample(5)[[newvar, var1, var2, 'DLN']] 
    #print(df[[newvar, var1, var2, 'ObjectId']][:5], '\n\n\n')

# %% [markdown]
# #### Do initial check to ensure that no row has values in both columns

# %%
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    #print(row['variable_name_new'])
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    print('\t\t', len(df[df[row['original_names'][0]].notnull()]))
    print('\t\t', len(df[df[row['original_names'][1]].notnull()]))
    #print(len(df[(df[row['original_names'][0]].isnull()) & (df[row['original_names'][1]].isnull())]), '\n\n')      
    print('OK IF ZERO:', len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n\n')
# Out:
# F9_00_HD_ADDR_CHANGE AddressChange AddressChangeInd
# 		 19701
# 		 54825
# OK IF ZERO: 0
#
#
# F9_00_HD_AMENDED_RETURN AmendedReturn AmendedReturnInd
# 		 4675
# 		 11967
# OK IF ZERO: 0
#
#
# F9_00_HD_CTRY_OF_DOMICILE CountryLegalDomicile LegalDomicileCountryCd
# 		 272
# 		 749
# OK IF ZERO: 0
#
#
# F9_00_HD_EXEMPT_STATUS_4847A1 Organization4947a1NotPFInd Organization4947a1
# 		 777
# 		 737
# OK IF ZERO: 0
#
#
# F9_00_HD_EXEMPT_STATUS_501C Organization501cInd Organization501c
# 		 340575
# 		 145796
# OK IF ZERO: 0
#
#
# F9_00_HD_EXEMPT_STATUS_501C3 Organization501c3 Organization501c3Ind
# 		 348990
# 		 1058141
# OK IF ZERO: 0
#
#
# F9_00_HD_FINAL_RETURN FinalReturnInd TerminatedReturn
# 		 8044
# 		 2079
# OK IF ZERO: 0
#
#
# F9_00_HD_GROSS_EXEMPT_NUM GroupExemptionNum GroupExemptionNumber
# 		 46460
# 		 19031
# OK IF ZERO: 0
#
#
# F9_00_HD_GROSS_RCPT GrossReceiptsAmt GrossReceipts
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_00_HD_GROUP_RETURN GroupReturnForAffiliates GroupReturnForAffiliatesInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_00_HD_INCLUDES_SUBORD_ORGS AllAffiliatesIncluded AllAffiliatesIncludedInd
# 		 80876
# 		 217028
# OK IF ZERO: 0
#
#
# F9_00_HD_INITIAL_RETURN InitialReturn InitialReturnInd
# 		 4084
# 		 14029
# OK IF ZERO: 0
#
#
# F9_00_HD_PRIN_OFF_NAME PrincipalOfficerNm NameOfPrincipalOfficerPerson
# 		 1184570
# 		 406689
# OK IF ZERO: 0
#
#
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_00_HD_SPECIAL_CONDITION_DESC SpecialConditionDesc SpecialConditionDescription
# 		 693
# 		 108
# OK IF ZERO: 0
#
#
# F9_00_HD_STATE_OF_DOMICILE LegalDomicileStateCd StateLegalDomicile
# 		 1325175
# 		 462503
# OK IF ZERO: 0
#
#
# F9_00_HD_TAX_PER_END TaxPeriodEndDate TaxPeriodEndDt
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_00_HD_TAX_YEAR TaxYr TaxYear
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_00_HD_TIME_STAMP ReturnTs Timestamp
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_00_HD_TYPE_ORG_ASSOCIATION TypeOfOrganizationAssocInd TypeOfOrganizationAssociation
# 		 62585
# 		 20984
# OK IF ZERO: 0
#
#
# F9_00_HD_TYPE_ORG_CORP TypeOfOrganizationCorpInd TypeOfOrganizationCorporation
# 		 1235703
# 		 431278
# OK IF ZERO: 0
#
#
# F9_00_HD_TYPE_ORG_OTHER TypeOfOrganizationOther TypeOfOrganizationOtherInd
# 		 12719
# 		 33227
# OK IF ZERO: 0
#
#
# F9_00_HD_TYPE_ORG_OTHER_DESC TypeOfOrgOtherDescription OtherOrganizationDsc
# 		 9451
# 		 24637
# OK IF ZERO: 0
#
#
# F9_00_HD_TYPE_ORG_TRUST TypeOfOrganizationTrustInd TypeOfOrganizationTrust
# 		 43401
# 		 17516
# OK IF ZERO: 0
#
#
# F9_00_HD_WEBSITE WebSite WebsiteAddressTxt
# 		 448254
# 		 1249670
# OK IF ZERO: 0
#
#
# F9_00_HD_YEAR_FORMED FormationYr YearFormation
# 		 1296656
# 		 451282
# OK IF ZERO: 0
#
#
# F9_01_PC_BEN_PAID_MEMB_PRIOR PYBenefitsPaidToMembersAmt BenefitsPaidToMembersPriorYear
# 		 641805
# 		 240192
# OK IF ZERO: 0
#
#
# F9_01_PC_CONTR_GRANTS_CURR CYContributionsGrantsAmt ContributionsGrantsCurrentYear
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_CONTR_GRANTS_PRIOR PYContributionsGrantsAmt ContributionsGrantsPriorYear
# 		 1209458
# 		 426544
# OK IF ZERO: 0
#
#
# F9_01_PC_GRANTS_PRIOR PYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsPriorYear
# 		 790806
# 		 286427
# OK IF ZERO: 0
#
#
# F9_01_PC_INDEP_VOTING_MEMB VotingMembersIndependentCnt NbrIndependentVotingMembers
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_INVEST_INCOME_PRIOR InvestmentIncomePriorYear PYInvestmentIncomeAmt
# 		 432814
# 		 1162076
# OK IF ZERO: 0
#
#
# F9_01_PC_NET_ASSETS_BOY NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesBOY
# 		 1380223
# 		 490971
# OK IF ZERO: 0
#
#
# F9_01_PC_OTHER_EXPENSE_PRIOR OtherExpensePriorYear PYOtherExpensesAmt
# 		 477970
# 		 1350489
# OK IF ZERO: 0
#
#
# F9_01_PC_OTHER_REV_PRIOR PYOtherRevenueAmt OtherRevenuePriorYear
# 		 1044293
# 		 380767
# OK IF ZERO: 0
#
#
# F9_01_PC_PROF_FUNDRISING_EXP_CURR CYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpCY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_PROF_FUNDRISING_EXP_PRIOR PYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpPriorYear
# 		 630707
# 		 237172
# OK IF ZERO: 0
#
#
# F9_01_PC_PROG_SERVICE_REV_PRIOR PYProgramServiceRevenueAmt ProgramServiceRevenuePriorYear
# 		 1097368
# 		 401429
# OK IF ZERO: 0
#
#
# F9_01_PC_REV_LESS_EXP_CURR CYRevenuesLessExpensesAmt RevenuesLessExpensesCY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_REV_LESS_EXP_PRIOR RevenuesLessExpensesPriorYear PYRevenuesLessExpensesAmt
# 		 480043
# 		 1356034
# OK IF ZERO: 0
#
#
# F9_01_PC_TERMINATION_CONTRACTION ContractTerminationInd TerminationOrContraction
# 		 10956
# 		 2574
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_ASSETS_EOY TotalAssetsEOYAmt TotalAssetsEOY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_EXP_PRIOR TotalExpensesPriorYear PYTotalExpensesAmt
# 		 479573
# 		 1354842
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_FNDR_EXP_CURR CYTotalFundraisingExpenseAmt TotalFundrsngExpCurrentYear
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_INDIV_EMPLOYED TotalNbrEmployees TotalEmployeeCnt
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_INDIV_VOLUNTEERS TotalVolunteersCnt TotalNbrVolunteers
# 		 1023751
# 		 371109
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_LIABILITIES_EOY TotalLiabilitiesEOYAmt TotalLiabilitiesEOY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_REVENUE_PRIOR TotalRevenuePriorYear PYTotalRevenueAmt
# 		 480796
# 		 1357343
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_UBI_GROSS TotalGrossUBIAmt TotalGrossUBI
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PC_TOT_UBI_NET NetUnrelatedBusTxblIncmAmt NetUnrelatedBusinessTxblIncome
# 		 734926
# 		 270738
# OK IF ZERO: 0
#
#
# F9_01_PC_VOTING_MEMB_GOV_BODY NbrVotingMembersGoverningBody VotingMembersGoverningBodyCnt
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_01_PZ_BEN_PAID_TO_MEMB_CURR CYBenefitsPaidToMembersAmt BenefitsPaidToMembersCY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_GRANTS_PAID_CURR CYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsCY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_INVEST_INCOME_CURR CYInvestmentIncomeAmt InvestmentIncomeCurrentYear
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_NAFB_EOY NetAssetsOrFundBalancesEOYAmt NetAssetsOrFundBalancesEOY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_ORGANIZATIONAL_MISSION ActivityOrMissionDescription ActivityOrMissionDesc
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_01_PZ_OTHER_EXPENSE_CURR OtherExpensesCurrentYear CYOtherExpensesAmt
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_01_PZ_OTHER_REV_CURR CYOtherRevenueAmt OtherRevenueCurrentYear
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_PROG_SERVICE_REV_CURR CYProgramServiceRevenueAmt ProgramServiceRevenueCY
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_SALARIES_CURR CYSalariesCompEmpBnftPaidAmt SalariesEtcCurrentYear
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_SALARIES_PRIOR SalariesEtcPriorYear PYSalariesCompEmpBnftPaidAmt
# 		 409428
# 		 1120515
# OK IF ZERO: 0
#
#
# F9_01_PZ_TOT_ASSETS_BOY TotalAssetsBOYAmt TotalAssetsBOY
# 		 1381588
# 		 491593
# OK IF ZERO: 0
#
#
# F9_01_PZ_TOT_EXP_CURR CYTotalExpensesAmt TotalExpensesCurrentYear
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_01_PZ_TOT_LIAB_BOY TotalLiabilitiesBOY TotalLiabilitiesBOYAmt
# 		 432290
# 		 1176416
# OK IF ZERO: 0
#
#
# F9_01_PZ_TOT_REV_CURR TotalRevenueCurrentYear CYTotalRevenueAmt
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_04_PC_FR_EVENT_INC_GT_15K FundraisingActivities FundraisingActivitiesInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_04_PC_GAMING_INC_GT_15K Gaming GamingActivitiesInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_04_PC_PROF_FR_EXP_GT_15K ProfessionalFundraisingInd ProfessionalFundraising
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_990_PROVIDED_GOV_BODY Form990ProvidedToGvrnBodyInd Form990ProvidedToGoverningBody
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_ANNUAL_DISC_COVRD_PERS AnnualDisclosureCoveredPersons AnnualDisclosureCoveredPrsnInd
# 		 353844
# 		 972424
# OK IF ZERO: 0
#
#
# F9_06_PC_CEO_COMPENSTN_PROCESS CompensationProcessCEOInd CompensationProcessCEO
# 		 1393132
# 		 491106
# OK IF ZERO: 0
#
#
# F9_06_PC_CHANGES_ORGANIZING_DOCS ChangesToOrganizingDocs ChangeToOrgDocumentsInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_CONFLICT_OF_INTEREST ConflictOfInterestPolicy ConflictOfInterestPolicyInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_DECISIONS_SUBJ_APPROVAL DecisionsSubjectToApprovaInd DecisionsSubjectToApproval
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_DELEGATION_MGT_DUTIES DelegationOfManagementDuties DelegationOfMgmtDutiesInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_DELEGATION_OF_MGT DelegationOfManagementDuties DelegationOfMgmtDutiesInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_DOCUMENT_RET_POLICY DocumentRetentionPolicy DocumentRetentionPolicyInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_ELECTION_BOARD_MEMBERS ElectionOfBoardMembersInd ElectionOfBoardMembers
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_FAMILY_OR_BUSINESS_REL FamilyOrBusinessRelationship FamilyOrBusinessRlnInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_FORM_AVAIL_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# 		 88817
# 		 29051
# OK IF ZERO: 0
#
#
# F9_06_PC_FORM_UPON_REQUEST UponRequest UponRequestInd
# 		 457550
# 		 1267577
# OK IF ZERO: 0
#
#
# F9_06_PC_JOINT_VENTURE_INVESTMNT InvestmentInJointVentureInd InvestmentInJointVenture
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_JOINT_VENTURE_POLICY WrittenPolicyOrProcedure WrittenPolicyOrProcedureInd
# 		 62690
# 		 37200
# OK IF ZERO: 0
#
#
# F9_06_PC_LOCAL_CHAPTERS LocalChaptersInd LocalChapters
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_MATERIAL_DIVERSION MaterialDiversionOrMisuseInd MaterialDiversionOrMisuse
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_MEMBERS_OR_STOCKHOLDERS MembersOrStockholders MembersOrStockholdersInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_MINUTES_COMMITTEES MinutesOfCommittees MinutesOfCommitteesInd
# 		 492801
# 		 1395675
# OK IF ZERO: 0
#
#
# F9_06_PC_MINUTES_GOVERNING_BODY MinutesOfGoverningBodyInd MinutesOfGoverningBody
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_MONITORING_OF_COI_POLICY RegularMonitoringEnfrcInd RegularMonitoringEnforcement
# 		 972331
# 		 353004
# OK IF ZERO: 0
#
#
# F9_06_PC_NUM_IND_VOTING_MEMBERS NumberIndependentVotingMembers IndependentVotingMemberCnt
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_06_PC_NUM_VOTING_GOV_MEMBERS GoverningBodyVotingMembersCnt NbrVotingGoverningBodyMembers
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_OFFICER_MAILING_ADDRESS OfficerMailingAddressInd OfficerMailingAddress
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_06_PC_OTHER_COMPENSTN_PROCESS CompensationProcessOther CompensationProcessOtherInd
# 		 490186
# 		 1391978
# OK IF ZERO: 0
#
#
# F9_06_PC_OTHER_WEBSITE OtherWebsite OtherWebsiteInd
# 		 73172
# 		 178440
# OK IF ZERO: 0
#
#
# F9_06_PC_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# 		 88817
# 		 29051
# OK IF ZERO: 0
#
#
# F9_06_PC_POLICIES_GOVERN_CHAPTER PoliciesReferenceChaptersInd PoliciesReferenceChapters
# 		 74209
# 		 76643
# OK IF ZERO: 0
#
#
# F9_06_PC_STATES_WHERE_RET_FILED StatesWhereCopyOfReturnIsFiled StatesWhereCopyOfReturnIsFldCd
# 		 260142
# 		 706990
# OK IF ZERO: 0
#
#
# F9_06_PC_WHISTLEBLOWER_POLICY WhistleblowerPolicy WhistleblowerPolicyInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_07_PC_COMPENSATION_OTHER_SRCE CompensationFromOtherSources CompensationFromOtherSrcsInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_07_PC_FORMER_OFFICER_LISTED FormerOfcrEmployeesListedInd FormersListed
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_07_PC_NO_LISTED_PERS_COMPENSD NoListedPersonsCompensated NoListedPersonsCompensatedInd
# 		 190833
# 		 614373
# OK IF ZERO: 0
#
#
# F9_07_PC_NUM_CONTRCTRS_GRTR_100K NumberOfContractorsGT100K CntrctRcvdGreaterThan100KCnt
# 		 333535
# 		 857046
# OK IF ZERO: 0
#
#
# F9_07_PC_NUM_INDS_GREATER_100K NumberIndividualsGT100K IndivRcvdGreaterThan100KCnt
# 		 364003
# 		 979110
# OK IF ZERO: 0
#
#
# F9_07_PC_TOTAL_COMP_GRTR_150K TotalCompGT150K TotalCompGreaterThan150KInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_07_PC_TOT_OTHER_COMPENSATION TotalOtherCompensation TotalOtherCompensationAmt
# 		 313261
# 		 841970
# OK IF ZERO: 0
#
#
# F9_07_PC_TOT_REPRT_COMP_FROM_ORG TotalReportableCompFromOrgAmt TotalReportableCompFromOrg
# 		 1036522
# 		 381105
# OK IF ZERO: 0
#
#
# F9_07_PC_TOT_REPRT_COMP_RLTD_ORG TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs
# 		 765562
# 		 283814
# OK IF ZERO: 0
#
#
# F9_08_PC_ALL_OTHER_CONTRIBUTIONS AllOtherContributions AllOtherContributionsAmt
# 		 321002
# 		 931273
# OK IF ZERO: 0
#
#
# F9_08_PC_CONTS_REPRTD_FNDRAISNG CntrbtnsRprtdFundraisingEvents ContriRptFundraisingEventAmt
# 		 80330
# 		 234879
# OK IF ZERO: 0
#
#
# F9_08_PC_COST_OF_GOODS_SOLD CostOfGoodsSoldAmt CostOfGoodsSold
# 		 195812
# 		 62410
# OK IF ZERO: 0
#
#
# F9_08_PC_FEDERATED_CAMPAIGNS FederatedCampaignsAmt FederatedCampaigns
# 		 91747
# 		 35866
# OK IF ZERO: 0
#
#
# F9_08_PC_FUNDRAISING_DIRECT_EXP FundraisingDirectExpenses FundraisingDirectExpensesAmt
# 		 128348
# 		 389505
# OK IF ZERO: 0
#
#
# F9_08_PC_FUNDRAISING_EVENTS FundraisingEvents FundraisingAmt
# 		 88484
# 		 245486
# OK IF ZERO: 0
#
#
# F9_08_PC_FUNDRAISING_GROSS_INC GrossIncomeFundraisingEvents FundraisingGrossIncomeAmt
# 		 134188
# 		 403996
# OK IF ZERO: 0
#
#
# F9_08_PC_GAMING_DIRECT_EXPENSES GamingDirectExpenses GamingDirectExpensesAmt
# 		 19808
# 		 85594
# OK IF ZERO: 0
#
#
# F9_08_PC_GAMING_GROSS_INCOME GamingGrossIncomeAmt GrossIncomeGaming
# 		 89416
# 		 21295
# OK IF ZERO: 0
#
#
# F9_08_PC_GOVERNMENT_GRANTS GovernmentGrants GovernmentGrantsAmt
# 		 149035
# 		 377089
# OK IF ZERO: 0
#
#
# F9_08_PC_GROSS_SALES_INVENTORY GrossSalesOfInventoryAmt GrossSalesOfInventory
# 		 206043
# 		 66512
# OK IF ZERO: 0
#
#
# F9_08_PC_MEMBERSHIP_DUES MembershipDuesAmt MembershipDues
# 		 250298
# 		 82094
# OK IF ZERO: 0
#
#
# F9_08_PC_NONCASH_CONTRIBUTIONS NoncashContributions NoncashContributionsAmt
# 		 82267
# 		 228002
# OK IF ZERO: 0
#
#
# F9_08_PC_PROGRAM_SVCE_REV_TOTAL TotalProgramServiceRevenue TotalProgramServiceRevenueAmt
# 		 380503
# 		 1037055
# OK IF ZERO: 0
#
#
# F9_08_PC_RELATED_ORGANIZATIONS RelatedOrganizationsAmt RelatedOrganizations
# 		 90291
# 		 36414
# OK IF ZERO: 0
#
#
# F9_08_PC_TOTAL_CONTRIBUTIONS TotalContributionsAmt TotalContributions
# 		 1163744
# 		 409883
# OK IF ZERO: 0
#
#
# F9_08_PC_TOTAL_OTHER_REVENUE TotalOtherRevenue OtherRevenueTotalAmt
# 		 275402
# 		 724083
# OK IF ZERO: 0
#
#
# F9_08_PC_TOTAL_PROG_SVCE_REVENUE TotalProgramServiceRevenue TotalProgramServiceRevenueAmt
# 		 380503
# 		 1037055
# OK IF ZERO: 0
#
#
# F9_08_PC_TOTAL_REVENUE TotalRevenueGrp TotalRevenue
# 		 1399493
# 		 495523
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_DISQUAL_FUNDRAISE CompDisqualPersonsGrp CompDisqualPersons
# 		 358275
# 		 136571
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_DISQUAL_MGMT CompDisqualPersonsGrp CompDisqualPersons
# 		 358275
# 		 136571
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_DISQUAL_PROG_SVCE CompDisqualPersonsGrp CompDisqualPersons
# 		 358275
# 		 136571
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_DISQUAL_TOTAL CompDisqualPersonsGrp CompDisqualPersons
# 		 358275
# 		 136571
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_OFFICERS_FUNDRAISE CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 		 303702
# 		 812839
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_OFFICERS_MGMT CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 		 303702
# 		 812839
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_OFFICERS_PROG_SVCE CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 		 303702
# 		 812839
# OK IF ZERO: 0
#
#
# F9_09_PC_COMP_OFFICERS_TOTAL CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 		 303702
# 		 812839
# OK IF ZERO: 0
#
#
# F9_09_PC_FEES_FOR_SVCE_ACCT_TOT FeesForServicesAccounting FeesForServicesAccountingGrp
# 		 408639
# 		 1144010
# OK IF ZERO: 0
#
#
# F9_09_PC_FEES_FOR_SVCE_INVST_TOT FeesForSrvcInvstMgmntFeesGrp FeesForServicesInvstMgmntFees
# 		 468361
# 		 170269
# OK IF ZERO: 0
#
#
# F9_09_PC_FEES_FOR_SVCE_LEGL_TOT FeesForServicesLegalGrp FeesForServicesLegal
# 		 677130
# 		 256406
# OK IF ZERO: 0
#
#
# F9_09_PC_FEES_FOR_SVCE_LOBB_TOT FeesForServicesLobbyingGrp FeesForServicesLobbying
# 		 364525
# 		 138714
# OK IF ZERO: 0
#
#
# F9_09_PC_FEES_FOR_SVCE_MGMT_TOT FeesForServicesManagement FeesForServicesManagementGrp
# 		 179599
# 		 487344
# OK IF ZERO: 0
#
#
# F9_09_PC_FEES_FOR_SVCE_OTH_TOT FeesForServicesOtherGrp FeesForServicesOther
# 		 830322
# 		 295254
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_EMP_BEN_FUNDRAISE OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 		 791514
# 		 309420
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_EMP_BEN_MGMT OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 		 791514
# 		 309420
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_EMP_BEN_PROG_SVCE OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 		 791514
# 		 309420
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_EMP_BEN_TOTAL OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 		 791514
# 		 309420
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_SALARY_FUNDRAISE OtherSalariesAndWagesGrp OtherSalariesAndWages
# 		 989244
# 		 367248
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_SALARY_MGMT OtherSalariesAndWagesGrp OtherSalariesAndWages
# 		 989244
# 		 367248
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_SALARY_PROG_SVCE OtherSalariesAndWagesGrp OtherSalariesAndWages
# 		 989244
# 		 367248
# OK IF ZERO: 0
#
#
# F9_09_PC_OTHER_SALARY_TOTAL OtherSalariesAndWagesGrp OtherSalariesAndWages
# 		 989244
# 		 367248
# OK IF ZERO: 0
#
#
# F9_09_PC_PAYROLL_TAX_FUNDRAISE PayrollTaxes PayrollTaxesGrp
# 		 360420
# 		 979744
# OK IF ZERO: 0
#
#
# F9_09_PC_PAYROLL_TAX_MGMT PayrollTaxes PayrollTaxesGrp
# 		 360420
# 		 979744
# OK IF ZERO: 0
#
#
# F9_09_PC_PAYROLL_TAX_PROG_SVCE PayrollTaxes PayrollTaxesGrp
# 		 360420
# 		 979744
# OK IF ZERO: 0
#
#
# F9_09_PC_PAYROLL_TAX_TOTAL PayrollTaxes PayrollTaxesGrp
# 		 360420
# 		 979744
# OK IF ZERO: 0
#
#
# F9_09_PC_PENSION_CONT_FUNDRAISE PensionPlanContributionsGrp PensionPlanContributions
# 		 585076
# 		 230090
# OK IF ZERO: 0
#
#
# F9_09_PC_PENSION_CONT_MGMT PensionPlanContributionsGrp PensionPlanContributions
# 		 585076
# 		 230090
# OK IF ZERO: 0
#
#
# F9_09_PC_PENSION_CONT_PROG_SVCE PensionPlanContributionsGrp PensionPlanContributions
# 		 585076
# 		 230090
# OK IF ZERO: 0
#
#
# F9_09_PC_PENSION_CONT_TOTAL PensionPlanContributionsGrp PensionPlanContributions
# 		 585076
# 		 230090
# OK IF ZERO: 0
#
#
# F9_09_PC_TOTAL_FUNC_EXPENSES TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_09_PC_TOTAL_FUNDRAISE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_09_PC_TOTAL_MGMT_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_09_PC_TOTAL_PROG_SVCE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_10_PC_BOND_LIABILITIES_EOY TaxExemptBondLiabilities TaxExemptBondLiabilitiesGrp
# 		 40626
# 		 98737
# OK IF ZERO: 0
#
#
# F9_10_PC_CASH_NON_INTEREST_BOY CashNonInterestBearing CashNonInterestBearingGrp
# 		 447004
# 		 1290669
# OK IF ZERO: 0
#
#
# F9_10_PC_CASH_NON_INTEREST_EOY CashNonInterestBearing CashNonInterestBearingGrp
# 		 447004
# 		 1290669
# OK IF ZERO: 0
#
#
# F9_10_PC_LAND_BLDG_EQPMT LandBldgEquipCostOrOtherBssAmt LandBuildingsEquipmentBasis
# 		 1023986
# 		 380115
# OK IF ZERO: 0
#
#
# F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN LandBldgEquipAccumDeprecAmt LandBldgEquipmentAccumDeprec
# 		 980893
# 		 365067
# OK IF ZERO: 0
#
#
# F9_10_PC_LOANS_FROM_OFFICERS_EOY LoansFromOfficersDirectors LoansFromOfficersDirectorsGrp
# 		 35004
# 		 109694
# OK IF ZERO: 0
#
#
# F9_10_PC_ORG_FOLLOWS_SFAS117 OrganizationFollowsSFAS117Ind FollowSFAS117
# 		 1045027
# 		 382727
# OK IF ZERO: 0
#
#
# F9_10_PC_ORG_NOT_FOLLOW_SFAS117 DoNotFollowSFAS117 OrgDoesNotFollowSFAS117Ind
# 		 111282
# 		 315410
# OK IF ZERO: 0
#
#
# F9_10_PC_OTHER_LIABILITIES_EOY OtherLiabilities OtherLiabilitiesGrp
# 		 234246
# 		 597476
# OK IF ZERO: 0
#
#
# F9_10_PC_RET_EARNINGS_ENDWMT_EOY RtnEarnEndowmentIncmOthFndsGrp RetainedEarningsEndowmentEtc
# 		 310903
# 		 106044
# OK IF ZERO: 0
#
#
# F9_10_PC_SAVINGS_TEMP_INVEST_BOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# 		 347150
# 		 920403
# OK IF ZERO: 0
#
#
# F9_10_PC_SAVINGS_TEMP_INVEST_EOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# 		 347150
# 		 920403
# OK IF ZERO: 0
#
#
# F9_10_PC_SECURED_MORTGAGES_EOY MortNotesPyblSecuredInvestProp MortgNotesPyblScrdInvstPropGrp
# 		 142239
# 		 353857
# OK IF ZERO: 0
#
#
# F9_10_PC_UNSECURED_NOTES_BOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# 		 49454
# 		 150179
# OK IF ZERO: 0
#
#
# F9_10_PC_UNSECURED_NOTES_EOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# 		 49454
# 		 150179
# OK IF ZERO: 0
#
#
# F9_10_PZ_TOTAL_ASSETS_EOY TotalAssets TotalAssetsGrp
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_11_PC_RECNCLTN_DONATED_SVCES DonatedServicesAndUseFcltsAmt ReconcilationDonatedServices
# 		 45428
# 		 5828
# OK IF ZERO: 0
#
#
# F9_11_PC_RECNCLTN_INVSTMNT_EXP ReconcilationInvestExpenses InvestmentExpenseAmt
# 		 4377
# 		 36255
# OK IF ZERO: 0
#
#
# F9_11_PC_RECNCLTN_PRIOR_PER_ADJ ReconcilationPriorAdjustment PriorPeriodAdjustmentsAmt
# 		 14237
# 		 127121
# OK IF ZERO: 0
#
#
# F9_11_PC_RECNCLTN_REV_LESS_EXP ReconcilationRevenueExpnssAmt ReconcilationRevenueExpenses
# 		 1399493
# 		 462213
# OK IF ZERO: 0
#
#
# F9_11_PC_RECNCLTN_UNRLZD_GAIN ReconciliationUnrealizedInvest NetUnrlzdGainsLossesInvstAmt
# 		 44815
# 		 356914
# OK IF ZERO: 0
#
#
# F9_12_PC_ACCNT_COMPILE_OR_REVIEW AccountantCompileOrReview AccountantCompileOrReviewInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0
#
#
# F9_12_PC_ACCTG_METHOD_ACCRUAL MethodOfAccountingAccrualInd MethodOfAccountingAccrual
# 		 912887
# 		 351058
# OK IF ZERO: 0
#
#
# F9_12_PC_ACCTG_METHOD_CASH MethodOfAccountingCash MethodOfAccountingCashInd
# 		 135180
# 		 456766
# OK IF ZERO: 0
#
#
# F9_12_PC_ACCTG_METHOD_OTHER MethodOfAccountingOtherInd MethodOfAccountingOther
# 		 29840
# 		 9285
# OK IF ZERO: 0
#
#
# F9_12_PC_AUDIT_COMMITTEE AuditCommittee AuditCommitteeInd
# 		 340746
# 		 783107
# OK IF ZERO: 0
#
#
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD FederalGrantAuditPerformedInd FederalGrantAuditPerformed
# 		 127450
# 		 107038
# OK IF ZERO: 0
#
#
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd FederalGrantAuditRequired
# 		 1261948
# 		 456373
# OK IF ZERO: 0
#
#
# F9_12_PC_FINCL_STMTS_AUDITED FSAudited FSAuditedInd
# 		 495523
# 		 1399493
# OK IF ZERO: 0

# %% [markdown]
# ##### Check *F9_07_PC_TOT_REPRT_COMP_RLTD_ORG*

# %% [markdown]
# <br>First run of code below showed problem with variable *F9_07_PC_TOT_REPRT_COMP_RLTD_ORG*
#
# But now it seems to be OK.

# %%
#for index, row in new_variables_df[new_variables_df['variable_name_new']=='F9_07_PC_TOT_REPRT_COMP_RLTD_ORG'].iterrows():
#    #print(row['variable_name_new'])
#    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
#    print('\t\t', len(df[df[row['original_names'][0]].notnull()]))
#    print('\t\t', len(df[df[row['original_names'][1]].notnull()]))
#    #print(len(df[(df[row['original_names'][0]].isnull()) & (df[row['original_names'][1]].isnull())]), '\n\n')      
#    print('OK IF ZERO:', len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n\n')
# Out:
# F9_07_PC_TOT_REPRT_COMP_RLTD_ORG TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs
# 		 663252
# 		 283814
# OK IF ZERO: 0

# %%
#['variable_name_new']=='F9_07_PC_TOT_REPRT_COMP_RLTD_ORG']
# Out:
#                     variable_name_new  \
# 101  F9_07_PC_TOT_REPRT_COMP_RLTD_ORG
#
#                                                     original_names  \
# 101  [TotReportableCompRltdOrgAmt, TotalReportableCompFrmRltdOrgs]
#
#     data_type_xsd  len
# 101  USAmountType    2

# %%
#df[['TotalReportableCompFrmRltdOrgs']].sample(1)
# Out:
#      TotalReportableCompFrmRltdOrgs
# 2962                            NaN

# %%
#df[['TotReportableCompRltdOrgAmt']].sample(5)
# Out:
#      TotReportableCompRltdOrgAmt
# 8508                         NaN
# 7210                         NaN
# 7076                           0
# 133                          NaN
# 9717                         NaN

# %%
#df[['TotReportableCompRltdOrgAmt', 'TotalReportableCompFrmRltdOrgs', 'F9_07_PC_TOT_REPRT_COMP_RLTD_ORG']].sample(5)
# Out:
#      TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs  \
# 2567                         NaN                            NaN
# 9645                      110000                            NaN
# 7353                       48000                            NaN
# 7365                         NaN                              0
# 6520                         NaN                            NaN
#
#      F9_07_PC_TOT_REPRT_COMP_RLTD_ORG
# 2567                              NaN
# 9645                           110000
# 7353                            48000
# 7365                                0
# 6520                              NaN

# %%
#print(len(df[df['TotalReportableCompFrmRltdOrgs'].notnull()]))
#print(len(df[df['TotalReportableCompFrmRltdOrgs'].isnull()]))
# Out:
# 283814
# 1443242

# %%
print(len(df[df['TotReportableCompRltdOrgAmt'].notnull()]))
print(len(df[df['TotReportableCompRltdOrgAmt'].isnull()]))
# Out:
# 765562
# 1129454

# %% [markdown]
# ### Combine

# %%
combo_fails = []
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    try:
        combine(df, row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    except:
        print('\n\n\n\n\n***********issue with variable: ', row['variable_name_new'])
        combo_fails.append(row['variable_name_new'])

print(combo_fails)
# Out:
# F9_00_HD_ADDR_CHANGE AddressChange AddressChangeInd
# F9_00_HD_AMENDED_RETURN AmendedReturn AmendedReturnInd
# F9_00_HD_CTRY_OF_DOMICILE CountryLegalDomicile LegalDomicileCountryCd
# F9_00_HD_EXEMPT_STATUS_4847A1 Organization4947a1NotPFInd Organization4947a1
# F9_00_HD_EXEMPT_STATUS_501C Organization501cInd Organization501c
# F9_00_HD_EXEMPT_STATUS_501C3 Organization501c3 Organization501c3Ind
# F9_00_HD_FINAL_RETURN FinalReturnInd TerminatedReturn
# F9_00_HD_GROSS_EXEMPT_NUM GroupExemptionNum GroupExemptionNumber
# F9_00_HD_GROSS_RCPT GrossReceiptsAmt GrossReceipts
# F9_00_HD_GROUP_RETURN GroupReturnForAffiliates GroupReturnForAffiliatesInd
# F9_00_HD_INCLUDES_SUBORD_ORGS AllAffiliatesIncluded AllAffiliatesIncludedInd
# F9_00_HD_INITIAL_RETURN InitialReturn InitialReturnInd
# F9_00_HD_PRIN_OFF_NAME PrincipalOfficerNm NameOfPrincipalOfficerPerson
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# F9_00_HD_SPECIAL_CONDITION_DESC SpecialConditionDesc SpecialConditionDescription
# F9_00_HD_STATE_OF_DOMICILE LegalDomicileStateCd StateLegalDomicile
# F9_00_HD_TAX_PER_END TaxPeriodEndDate TaxPeriodEndDt
# F9_00_HD_TAX_YEAR TaxYr TaxYear
# F9_00_HD_TIME_STAMP ReturnTs Timestamp
# F9_00_HD_TYPE_ORG_ASSOCIATION TypeOfOrganizationAssocInd TypeOfOrganizationAssociation
# F9_00_HD_TYPE_ORG_CORP TypeOfOrganizationCorpInd TypeOfOrganizationCorporation
# F9_00_HD_TYPE_ORG_OTHER TypeOfOrganizationOther TypeOfOrganizationOtherInd
# F9_00_HD_TYPE_ORG_OTHER_DESC TypeOfOrgOtherDescription OtherOrganizationDsc
# F9_00_HD_TYPE_ORG_TRUST TypeOfOrganizationTrustInd TypeOfOrganizationTrust
# F9_00_HD_WEBSITE WebSite WebsiteAddressTxt
# F9_00_HD_YEAR_FORMED FormationYr YearFormation
# F9_01_PC_BEN_PAID_MEMB_PRIOR PYBenefitsPaidToMembersAmt BenefitsPaidToMembersPriorYear
# F9_01_PC_CONTR_GRANTS_CURR CYContributionsGrantsAmt ContributionsGrantsCurrentYear
# F9_01_PC_CONTR_GRANTS_PRIOR PYContributionsGrantsAmt ContributionsGrantsPriorYear
# F9_01_PC_GRANTS_PRIOR PYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsPriorYear
# F9_01_PC_INDEP_VOTING_MEMB VotingMembersIndependentCnt NbrIndependentVotingMembers
# F9_01_PC_INVEST_INCOME_PRIOR InvestmentIncomePriorYear PYInvestmentIncomeAmt
# F9_01_PC_NET_ASSETS_BOY NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesBOY
# F9_01_PC_OTHER_EXPENSE_PRIOR OtherExpensePriorYear PYOtherExpensesAmt
# F9_01_PC_OTHER_REV_PRIOR PYOtherRevenueAmt OtherRevenuePriorYear
# F9_01_PC_PROF_FUNDRISING_EXP_CURR CYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpCY
# F9_01_PC_PROF_FUNDRISING_EXP_PRIOR PYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpPriorYear
# F9_01_PC_PROG_SERVICE_REV_PRIOR PYProgramServiceRevenueAmt ProgramServiceRevenuePriorYear
# F9_01_PC_REV_LESS_EXP_CURR CYRevenuesLessExpensesAmt RevenuesLessExpensesCY
# F9_01_PC_REV_LESS_EXP_PRIOR RevenuesLessExpensesPriorYear PYRevenuesLessExpensesAmt
# F9_01_PC_TERMINATION_CONTRACTION ContractTerminationInd TerminationOrContraction
# F9_01_PC_TOT_ASSETS_EOY TotalAssetsEOYAmt TotalAssetsEOY
# F9_01_PC_TOT_EXP_PRIOR TotalExpensesPriorYear PYTotalExpensesAmt
# F9_01_PC_TOT_FNDR_EXP_CURR CYTotalFundraisingExpenseAmt TotalFundrsngExpCurrentYear
# F9_01_PC_TOT_INDIV_EMPLOYED TotalNbrEmployees TotalEmployeeCnt
# F9_01_PC_TOT_INDIV_VOLUNTEERS TotalVolunteersCnt TotalNbrVolunteers
# F9_01_PC_TOT_LIABILITIES_EOY TotalLiabilitiesEOYAmt TotalLiabilitiesEOY
# F9_01_PC_TOT_REVENUE_PRIOR TotalRevenuePriorYear PYTotalRevenueAmt
# F9_01_PC_TOT_UBI_GROSS TotalGrossUBIAmt TotalGrossUBI
# F9_01_PC_TOT_UBI_NET NetUnrelatedBusTxblIncmAmt NetUnrelatedBusinessTxblIncome
# F9_01_PC_VOTING_MEMB_GOV_BODY NbrVotingMembersGoverningBody VotingMembersGoverningBodyCnt
# F9_01_PZ_BEN_PAID_TO_MEMB_CURR CYBenefitsPaidToMembersAmt BenefitsPaidToMembersCY
# F9_01_PZ_GRANTS_PAID_CURR CYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsCY
# F9_01_PZ_INVEST_INCOME_CURR CYInvestmentIncomeAmt InvestmentIncomeCurrentYear
# F9_01_PZ_NAFB_EOY NetAssetsOrFundBalancesEOYAmt NetAssetsOrFundBalancesEOY
# F9_01_PZ_ORGANIZATIONAL_MISSION ActivityOrMissionDescription ActivityOrMissionDesc
# F9_01_PZ_OTHER_EXPENSE_CURR OtherExpensesCurrentYear CYOtherExpensesAmt
# F9_01_PZ_OTHER_REV_CURR CYOtherRevenueAmt OtherRevenueCurrentYear
# F9_01_PZ_PROG_SERVICE_REV_CURR CYProgramServiceRevenueAmt ProgramServiceRevenueCY
# F9_01_PZ_SALARIES_CURR CYSalariesCompEmpBnftPaidAmt SalariesEtcCurrentYear
# F9_01_PZ_SALARIES_PRIOR SalariesEtcPriorYear PYSalariesCompEmpBnftPaidAmt
# F9_01_PZ_TOT_ASSETS_BOY TotalAssetsBOYAmt TotalAssetsBOY
# F9_01_PZ_TOT_EXP_CURR CYTotalExpensesAmt TotalExpensesCurrentYear
# F9_01_PZ_TOT_LIAB_BOY TotalLiabilitiesBOY TotalLiabilitiesBOYAmt
# F9_01_PZ_TOT_REV_CURR TotalRevenueCurrentYear CYTotalRevenueAmt
# F9_04_PC_FR_EVENT_INC_GT_15K FundraisingActivities FundraisingActivitiesInd
# F9_04_PC_GAMING_INC_GT_15K Gaming GamingActivitiesInd
# F9_04_PC_PROF_FR_EXP_GT_15K ProfessionalFundraisingInd ProfessionalFundraising
# F9_06_PC_990_PROVIDED_GOV_BODY Form990ProvidedToGvrnBodyInd Form990ProvidedToGoverningBody
# F9_06_PC_ANNUAL_DISC_COVRD_PERS AnnualDisclosureCoveredPersons AnnualDisclosureCoveredPrsnInd
# F9_06_PC_CEO_COMPENSTN_PROCESS CompensationProcessCEOInd CompensationProcessCEO
# F9_06_PC_CHANGES_ORGANIZING_DOCS ChangesToOrganizingDocs ChangeToOrgDocumentsInd
# F9_06_PC_CONFLICT_OF_INTEREST ConflictOfInterestPolicy ConflictOfInterestPolicyInd
# F9_06_PC_DECISIONS_SUBJ_APPROVAL DecisionsSubjectToApprovaInd DecisionsSubjectToApproval
# F9_06_PC_DELEGATION_MGT_DUTIES DelegationOfManagementDuties DelegationOfMgmtDutiesInd
# F9_06_PC_DELEGATION_OF_MGT DelegationOfManagementDuties DelegationOfMgmtDutiesInd
# F9_06_PC_DOCUMENT_RET_POLICY DocumentRetentionPolicy DocumentRetentionPolicyInd
# F9_06_PC_ELECTION_BOARD_MEMBERS ElectionOfBoardMembersInd ElectionOfBoardMembers
# F9_06_PC_FAMILY_OR_BUSINESS_REL FamilyOrBusinessRelationship FamilyOrBusinessRlnInd
# F9_06_PC_FORM_AVAIL_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# F9_06_PC_FORM_UPON_REQUEST UponRequest UponRequestInd
# F9_06_PC_JOINT_VENTURE_INVESTMNT InvestmentInJointVentureInd InvestmentInJointVenture
# F9_06_PC_JOINT_VENTURE_POLICY WrittenPolicyOrProcedure WrittenPolicyOrProcedureInd
# F9_06_PC_LOCAL_CHAPTERS LocalChaptersInd LocalChapters
# F9_06_PC_MATERIAL_DIVERSION MaterialDiversionOrMisuseInd MaterialDiversionOrMisuse
# F9_06_PC_MEMBERS_OR_STOCKHOLDERS MembersOrStockholders MembersOrStockholdersInd
# F9_06_PC_MINUTES_COMMITTEES MinutesOfCommittees MinutesOfCommitteesInd
# F9_06_PC_MINUTES_GOVERNING_BODY MinutesOfGoverningBodyInd MinutesOfGoverningBody
# F9_06_PC_MONITORING_OF_COI_POLICY RegularMonitoringEnfrcInd RegularMonitoringEnforcement
# F9_06_PC_NUM_IND_VOTING_MEMBERS NumberIndependentVotingMembers IndependentVotingMemberCnt
# F9_06_PC_NUM_VOTING_GOV_MEMBERS GoverningBodyVotingMembersCnt NbrVotingGoverningBodyMembers
# F9_06_PC_OFFICER_MAILING_ADDRESS OfficerMailingAddressInd OfficerMailingAddress
# F9_06_PC_OTHER_COMPENSTN_PROCESS CompensationProcessOther CompensationProcessOtherInd
# F9_06_PC_OTHER_WEBSITE OtherWebsite OtherWebsiteInd
# F9_06_PC_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# F9_06_PC_POLICIES_GOVERN_CHAPTER PoliciesReferenceChaptersInd PoliciesReferenceChapters
# F9_06_PC_STATES_WHERE_RET_FILED StatesWhereCopyOfReturnIsFiled StatesWhereCopyOfReturnIsFldCd
# F9_06_PC_WHISTLEBLOWER_POLICY WhistleblowerPolicy WhistleblowerPolicyInd
# F9_07_PC_COMPENSATION_OTHER_SRCE CompensationFromOtherSources CompensationFromOtherSrcsInd
# F9_07_PC_FORMER_OFFICER_LISTED FormerOfcrEmployeesListedInd FormersListed
# F9_07_PC_NO_LISTED_PERS_COMPENSD NoListedPersonsCompensated NoListedPersonsCompensatedInd
# F9_07_PC_NUM_CONTRCTRS_GRTR_100K NumberOfContractorsGT100K CntrctRcvdGreaterThan100KCnt
# F9_07_PC_NUM_INDS_GREATER_100K NumberIndividualsGT100K IndivRcvdGreaterThan100KCnt
# F9_07_PC_TOTAL_COMP_GRTR_150K TotalCompGT150K TotalCompGreaterThan150KInd
# F9_07_PC_TOT_OTHER_COMPENSATION TotalOtherCompensation TotalOtherCompensationAmt
# F9_07_PC_TOT_REPRT_COMP_FROM_ORG TotalReportableCompFromOrgAmt TotalReportableCompFromOrg
# F9_07_PC_TOT_REPRT_COMP_RLTD_ORG TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs
# F9_08_PC_ALL_OTHER_CONTRIBUTIONS AllOtherContributions AllOtherContributionsAmt
# F9_08_PC_CONTS_REPRTD_FNDRAISNG CntrbtnsRprtdFundraisingEvents ContriRptFundraisingEventAmt
# F9_08_PC_COST_OF_GOODS_SOLD CostOfGoodsSoldAmt CostOfGoodsSold
# F9_08_PC_FEDERATED_CAMPAIGNS FederatedCampaignsAmt FederatedCampaigns
# F9_08_PC_FUNDRAISING_DIRECT_EXP FundraisingDirectExpenses FundraisingDirectExpensesAmt
# F9_08_PC_FUNDRAISING_EVENTS FundraisingEvents FundraisingAmt
# F9_08_PC_FUNDRAISING_GROSS_INC GrossIncomeFundraisingEvents FundraisingGrossIncomeAmt
# F9_08_PC_GAMING_DIRECT_EXPENSES GamingDirectExpenses GamingDirectExpensesAmt
# F9_08_PC_GAMING_GROSS_INCOME GamingGrossIncomeAmt GrossIncomeGaming
# F9_08_PC_GOVERNMENT_GRANTS GovernmentGrants GovernmentGrantsAmt
# F9_08_PC_GROSS_SALES_INVENTORY GrossSalesOfInventoryAmt GrossSalesOfInventory
# F9_08_PC_MEMBERSHIP_DUES MembershipDuesAmt MembershipDues
# F9_08_PC_NONCASH_CONTRIBUTIONS NoncashContributions NoncashContributionsAmt
# F9_08_PC_PROGRAM_SVCE_REV_TOTAL TotalProgramServiceRevenue TotalProgramServiceRevenueAmt
# F9_08_PC_RELATED_ORGANIZATIONS RelatedOrganizationsAmt RelatedOrganizations
# F9_08_PC_TOTAL_CONTRIBUTIONS TotalContributionsAmt TotalContributions
# F9_08_PC_TOTAL_OTHER_REVENUE TotalOtherRevenue OtherRevenueTotalAmt
# F9_08_PC_TOTAL_PROG_SVCE_REVENUE TotalProgramServiceRevenue TotalProgramServiceRevenueAmt
# F9_08_PC_TOTAL_REVENUE TotalRevenueGrp TotalRevenue
# F9_09_PC_COMP_DISQUAL_FUNDRAISE CompDisqualPersonsGrp CompDisqualPersons
# F9_09_PC_COMP_DISQUAL_MGMT CompDisqualPersonsGrp CompDisqualPersons
# F9_09_PC_COMP_DISQUAL_PROG_SVCE CompDisqualPersonsGrp CompDisqualPersons
# F9_09_PC_COMP_DISQUAL_TOTAL CompDisqualPersonsGrp CompDisqualPersons
# F9_09_PC_COMP_OFFICERS_FUNDRAISE CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# F9_09_PC_COMP_OFFICERS_MGMT CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# F9_09_PC_COMP_OFFICERS_PROG_SVCE CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# F9_09_PC_COMP_OFFICERS_TOTAL CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# F9_09_PC_FEES_FOR_SVCE_ACCT_TOT FeesForServicesAccounting FeesForServicesAccountingGrp
# F9_09_PC_FEES_FOR_SVCE_INVST_TOT FeesForSrvcInvstMgmntFeesGrp FeesForServicesInvstMgmntFees
# F9_09_PC_FEES_FOR_SVCE_LEGL_TOT FeesForServicesLegalGrp FeesForServicesLegal
# F9_09_PC_FEES_FOR_SVCE_LOBB_TOT FeesForServicesLobbyingGrp FeesForServicesLobbying
# F9_09_PC_FEES_FOR_SVCE_MGMT_TOT FeesForServicesManagement FeesForServicesManagementGrp
# F9_09_PC_FEES_FOR_SVCE_OTH_TOT FeesForServicesOtherGrp FeesForServicesOther
# F9_09_PC_OTHER_EMP_BEN_FUNDRAISE OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# F9_09_PC_OTHER_EMP_BEN_MGMT OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# F9_09_PC_OTHER_EMP_BEN_PROG_SVCE OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# F9_09_PC_OTHER_EMP_BEN_TOTAL OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# F9_09_PC_OTHER_SALARY_FUNDRAISE OtherSalariesAndWagesGrp OtherSalariesAndWages
# F9_09_PC_OTHER_SALARY_MGMT OtherSalariesAndWagesGrp OtherSalariesAndWages
# F9_09_PC_OTHER_SALARY_PROG_SVCE OtherSalariesAndWagesGrp OtherSalariesAndWages
# F9_09_PC_OTHER_SALARY_TOTAL OtherSalariesAndWagesGrp OtherSalariesAndWages
# F9_09_PC_PAYROLL_TAX_FUNDRAISE PayrollTaxes PayrollTaxesGrp
# F9_09_PC_PAYROLL_TAX_MGMT PayrollTaxes PayrollTaxesGrp
# F9_09_PC_PAYROLL_TAX_PROG_SVCE PayrollTaxes PayrollTaxesGrp
# F9_09_PC_PAYROLL_TAX_TOTAL PayrollTaxes PayrollTaxesGrp
# F9_09_PC_PENSION_CONT_FUNDRAISE PensionPlanContributionsGrp PensionPlanContributions
# F9_09_PC_PENSION_CONT_MGMT PensionPlanContributionsGrp PensionPlanContributions
# F9_09_PC_PENSION_CONT_PROG_SVCE PensionPlanContributionsGrp PensionPlanContributions
# F9_09_PC_PENSION_CONT_TOTAL PensionPlanContributionsGrp PensionPlanContributions
# F9_09_PC_TOTAL_FUNC_EXPENSES TotalFunctionalExpenses TotalFunctionalExpensesGrp
# F9_09_PC_TOTAL_FUNDRAISE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# F9_09_PC_TOTAL_MGMT_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# F9_09_PC_TOTAL_PROG_SVCE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# F9_10_PC_BOND_LIABILITIES_EOY TaxExemptBondLiabilities TaxExemptBondLiabilitiesGrp
# F9_10_PC_CASH_NON_INTEREST_BOY CashNonInterestBearing CashNonInterestBearingGrp
# F9_10_PC_CASH_NON_INTEREST_EOY CashNonInterestBearing CashNonInterestBearingGrp
# F9_10_PC_LAND_BLDG_EQPMT LandBldgEquipCostOrOtherBssAmt LandBuildingsEquipmentBasis
# F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN LandBldgEquipAccumDeprecAmt LandBldgEquipmentAccumDeprec
# F9_10_PC_LOANS_FROM_OFFICERS_EOY LoansFromOfficersDirectors LoansFromOfficersDirectorsGrp
# F9_10_PC_ORG_FOLLOWS_SFAS117 OrganizationFollowsSFAS117Ind FollowSFAS117
# F9_10_PC_ORG_NOT_FOLLOW_SFAS117 DoNotFollowSFAS117 OrgDoesNotFollowSFAS117Ind
# F9_10_PC_OTHER_LIABILITIES_EOY OtherLiabilities OtherLiabilitiesGrp
# F9_10_PC_RET_EARNINGS_ENDWMT_EOY RtnEarnEndowmentIncmOthFndsGrp RetainedEarningsEndowmentEtc
# F9_10_PC_SAVINGS_TEMP_INVEST_BOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# F9_10_PC_SAVINGS_TEMP_INVEST_EOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# F9_10_PC_SECURED_MORTGAGES_EOY MortNotesPyblSecuredInvestProp MortgNotesPyblScrdInvstPropGrp
# F9_10_PC_UNSECURED_NOTES_BOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# F9_10_PC_UNSECURED_NOTES_EOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# F9_10_PZ_TOTAL_ASSETS_EOY TotalAssets TotalAssetsGrp
# F9_11_PC_RECNCLTN_DONATED_SVCES DonatedServicesAndUseFcltsAmt ReconcilationDonatedServices
# F9_11_PC_RECNCLTN_INVSTMNT_EXP ReconcilationInvestExpenses InvestmentExpenseAmt
# F9_11_PC_RECNCLTN_PRIOR_PER_ADJ ReconcilationPriorAdjustment PriorPeriodAdjustmentsAmt
# F9_11_PC_RECNCLTN_REV_LESS_EXP ReconcilationRevenueExpnssAmt ReconcilationRevenueExpenses
# F9_11_PC_RECNCLTN_UNRLZD_GAIN ReconciliationUnrealizedInvest NetUnrlzdGainsLossesInvstAmt
# F9_12_PC_ACCNT_COMPILE_OR_REVIEW AccountantCompileOrReview AccountantCompileOrReviewInd
# F9_12_PC_ACCTG_METHOD_ACCRUAL MethodOfAccountingAccrualInd MethodOfAccountingAccrual
# F9_12_PC_ACCTG_METHOD_CASH MethodOfAccountingCash MethodOfAccountingCashInd
# F9_12_PC_ACCTG_METHOD_OTHER MethodOfAccountingOtherInd MethodOfAccountingOther
# F9_12_PC_AUDIT_COMMITTEE AuditCommittee AuditCommitteeInd
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD FederalGrantAuditPerformedInd FederalGrantAuditPerformed
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd FederalGrantAuditRequired
# F9_12_PC_FINCL_STMTS_AUDITED FSAudited FSAuditedInd
# []

# %% [markdown]
# #### Save DF

# %%
#import timeit
#start_time = timeit.default_timer()
#df.to_pickle('all filings - with 185 newly named control variables.pkl')
#elapsed = timeit.default_timer() - start_time
#rint('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  4.553268258333325

# %%
# %%time
df.to_pickle('all filings nov. 2020 - all control variables (renamed).pkl.gz', compression='gzip')
# Out:
# Wall time: 1h 8min 28s

# %% [markdown]
# ### Binarize

# %%
binarize_cols = [c for c in new_variables_df[new_variables_df['data_type_xsd'].isin(['BooleanType', 'CheckboxType'])]['variable_name_new'].tolist()] 
print(len(binarize_cols))
print(binarize_cols)
# Out:
# 58
# ['F9_00_HD_ADDR_CHANGE', 'F9_00_HD_AMENDED_RETURN', 'F9_00_HD_EXEMPT_STATUS_4847A1', 'F9_00_HD_EXEMPT_STATUS_501C', 'F9_00_HD_EXEMPT_STATUS_501C3', 'F9_00_HD_FINAL_RETURN', 'F9_00_HD_GROUP_RETURN', 'F9_00_HD_INCLUDES_SUBORD_ORGS', 'F9_00_HD_INITIAL_RETURN', 'F9_00_HD_TYPE_ORG_ASSOCIATION', 'F9_00_HD_TYPE_ORG_CORP', 'F9_00_HD_TYPE_ORG_OTHER', 'F9_00_HD_TYPE_ORG_TRUST', 'F9_01_PC_TERMINATION_CONTRACTION', 'F9_04_PC_FR_EVENT_INC_GT_15K', 'F9_04_PC_GAMING_INC_GT_15K', 'F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_06_PC_990_PROVIDED_GOV_BODY', 'F9_06_PC_ANNUAL_DISC_COVRD_PERS', 'F9_06_PC_CEO_COMPENSTN_PROCESS', 'F9_06_PC_CHANGES_ORGANIZING_DOCS', 'F9_06_PC_CONFLICT_OF_INTEREST', 'F9_06_PC_DECISIONS_SUBJ_APPROVAL', 'F9_06_PC_DELEGATION_MGT_DUTIES', 'F9_06_PC_DELEGATION_OF_MGT', 'F9_06_PC_DOCUMENT_RET_POLICY', 'F9_06_PC_ELECTION_BOARD_MEMBERS', 'F9_06_PC_FAMILY_OR_BUSINESS_REL', 'F9_06_PC_FORM_AVAIL_OWN_WEBSITE', 'F9_06_PC_FORM_UPON_REQUEST', 'F9_06_PC_JOINT_VENTURE_INVESTMNT', 'F9_06_PC_JOINT_VENTURE_POLICY', 'F9_06_PC_LOCAL_CHAPTERS', 'F9_06_PC_MATERIAL_DIVERSION', 'F9_06_PC_MEMBERS_OR_STOCKHOLDERS', 'F9_06_PC_MINUTES_COMMITTEES', 'F9_06_PC_MINUTES_GOVERNING_BODY', 'F9_06_PC_MONITORING_OF_COI_POLICY', 'F9_06_PC_OFFICER_MAILING_ADDRESS', 'F9_06_PC_OTHER_COMPENSTN_PROCESS', 'F9_06_PC_OTHER_WEBSITE', 'F9_06_PC_OWN_WEBSITE', 'F9_06_PC_POLICIES_GOVERN_CHAPTER', 'F9_06_PC_WHISTLEBLOWER_POLICY', 'F9_07_PC_COMPENSATION_OTHER_SRCE', 'F9_07_PC_FORMER_OFFICER_LISTED', 'F9_07_PC_NO_LISTED_PERS_COMPENSD', 'F9_07_PC_TOTAL_COMP_GRTR_150K', 'F9_10_PC_ORG_FOLLOWS_SFAS117', 'F9_10_PC_ORG_NOT_FOLLOW_SFAS117', 'F9_12_PC_ACCNT_COMPILE_OR_REVIEW', 'F9_12_PC_ACCTG_METHOD_ACCRUAL', 'F9_12_PC_ACCTG_METHOD_CASH', 'F9_12_PC_ACCTG_METHOD_OTHER', 'F9_12_PC_AUDIT_COMMITTEE', 'F9_12_PC_FED_GRNT_AUDIT_PERFORMD', 'F9_12_PC_FED_GRNT_AUDIT_REQUIRED', 'F9_12_PC_FINCL_STMTS_AUDITED']

# %%
for c in binarize_cols[:]:
    print(df[df[c].notnull()][c].value_counts().head(), '\n')
# Out:
# X    74526
# Name: F9_00_HD_ADDR_CHANGE, dtype: int64
#
# X    16642
# Name: F9_00_HD_AMENDED_RETURN, dtype: int64
#
# X    1514
# Name: F9_00_HD_EXEMPT_STATUS_4847A1, dtype: int64
#
# {'@organization501cTypeTxt': '6', '#text': 'X'}    98981
# {'@organization501cTypeTxt': '4', '#text': 'X'}    50870
# {'@organization501cTypeTxt': '5', '#text': 'X'}    43146
# {'@organization501cTypeTxt': '7', '#text': 'X'}    40186
# {'@typeOf501cOrganization': '6', '#text': 'X'}     32959
# Name: F9_00_HD_EXEMPT_STATUS_501C, dtype: int64
#
# X    1407131
# Name: F9_00_HD_EXEMPT_STATUS_501C3, dtype: int64
#
# X    10123
# Name: F9_00_HD_FINAL_RETURN, dtype: int64
#
# false    1112425
# 0         778013
# true        2360
# 1           2218
# Name: F9_00_HD_GROUP_RETURN, dtype: int64
#
# false                                                         283830
# 1                                                               7243
# true                                                            5132
# {'@referenceDocumentId': '', '#text': 'false'}                   462
# {'@referenceDocumentId': 'RetDoc2030100001', '#text': '0'}       429
# Name: F9_00_HD_INCLUDES_SUBORD_ORGS, dtype: int64
#
# X    18113
# Name: F9_00_HD_INITIAL_RETURN, dtype: int64
#
# X    83569
# Name: F9_00_HD_TYPE_ORG_ASSOCIATION, dtype: int64
#
# X    1666981
# Name: F9_00_HD_TYPE_ORG_CORP, dtype: int64
#
# X    45946
# Name: F9_00_HD_TYPE_ORG_OTHER, dtype: int64
#
# X    60917
# Name: F9_00_HD_TYPE_ORG_TRUST, dtype: int64
#
# X    13530
# Name: F9_01_PC_TERMINATION_CONTRACTION, dtype: int64
#
# false                                                           841251
# 0                                                               571809
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '1'}      136243
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'true'}     88991
# {'@referenceDocumentId': '990G', '#text': 'true'}                35786
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64
#
# false                                                            891322
# 0                                                                603964
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}       130262
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}     84674
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '0'}        29962
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64
#
# false                                                            894335
# 0                                                                605502
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}       141718
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}     85009
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}             31143
# Name: F9_04_PC_PROF_FR_EXP_GT_15K, dtype: int64
#
# true     709021
# 1        627411
# false    405764
# 0        152820
# Name: F9_06_PC_990_PROVIDED_GOV_BODY, dtype: int64
#
# true     547713
# 1        531855
# false    201338
# 0         45362
# Name: F9_06_PC_ANNUAL_DISC_COVRD_PERS, dtype: int64
#
# false    671987
# true     432154
# 1        400619
# 0        379478
# Name: F9_06_PC_CEO_COMPENSTN_PROCESS, dtype: int64
#
# false    1099910
# 0         759672
# 1          20559
# true       14875
# Name: F9_06_PC_CHANGES_ORGANIZING_DOCS, dtype: int64
#
# true     612834
# 1        576554
# false    501951
# 0        203677
# Name: F9_06_PC_CONFLICT_OF_INTEREST, dtype: int64
#
# false    948554
# 0        647595
# true     166231
# 1        132636
# Name: F9_06_PC_DECISIONS_SUBJ_APPROVAL, dtype: int64
#
# false    1066372
# 0         714855
# 1          65376
# true       48413
# Name: F9_06_PC_DELEGATION_MGT_DUTIES, dtype: int64
#
# false    1066372
# 0         714855
# 1          65376
# true       48413
# Name: F9_06_PC_DELEGATION_OF_MGT, dtype: int64
#
# false    642636
# 1        474254
# true     472149
# 0        305977
# Name: F9_06_PC_DOCUMENT_RET_POLICY, dtype: int64
#
# false    855613
# 0        559209
# true     259172
# 1        221022
# Name: F9_06_PC_ELECTION_BOARD_MEMBERS, dtype: int64
#
# false    968968
# 0        663430
# true     145817
# 1        116801
# Name: F9_06_PC_FAMILY_OR_BUSINESS_REL, dtype: int64
#
# X    117868
# Name: F9_06_PC_FORM_AVAIL_OWN_WEBSITE, dtype: int64
#
# X    1725127
# Name: F9_06_PC_FORM_UPON_REQUEST, dtype: int64
#
# false    1100961
# 0         765192
# 1          15039
# true       13824
# Name: F9_06_PC_JOINT_VENTURE_INVESTMNT, dtype: int64
#
# false    73047
# 1        11693
# true     10745
# 0         4405
# Name: F9_06_PC_JOINT_VENTURE_POLICY, dtype: int64
#
# false    1068218
# 0         733141
# 1          47090
# true       46567
# Name: F9_06_PC_LOCAL_CHAPTERS, dtype: int64
#
# false    1113490
# 0         779483
# true        1295
# 1            748
# Name: F9_06_PC_MATERIAL_DIVERSION, dtype: int64
#
# false    887552
# 0        572011
# true     227233
# 1        208220
# Name: F9_06_PC_MEMBERS_OR_STOCKHOLDERS, dtype: int64
#
# true     920474
# 1        690628
# false    187866
# 0         89508
# Name: F9_06_PC_MINUTES_COMMITTEES, dtype: int64
#
# true     1018320
# 1         770866
# false      96465
# 0           9365
# Name: F9_06_PC_MINUTES_GOVERNING_BODY, dtype: int64
#
# 1        512847
# true     507311
# false    240823
# 0         64354
# Name: F9_06_PC_MONITORING_OF_COI_POLICY, dtype: int64
#
# false    1092781
# 0         771422
# true       22004
# 1           8809
# Name: F9_06_PC_OFFICER_MAILING_ADDRESS, dtype: int64
#
# false    798051
# 0        487241
# true     304053
# 1        292819
# Name: F9_06_PC_OTHER_COMPENSTN_PROCESS, dtype: int64
#
# X    251612
# Name: F9_06_PC_OTHER_WEBSITE, dtype: int64
#
# X    117868
# Name: F9_06_PC_OWN_WEBSITE, dtype: int64
#
# false    58506
# 1        45605
# true     44303
# 0         2438
# Name: F9_06_PC_POLICIES_GOVERN_CHAPTER, dtype: int64
#
# false    705888
# 1        444334
# true     408897
# 0        335897
# Name: F9_06_PC_WHISTLEBLOWER_POLICY, dtype: int64
#
# false    1109515
# 0         774488
# 1           5743
# true        5270
# Name: F9_07_PC_COMPENSATION_OTHER_SRCE, dtype: int64
#
# false    1080894
# 0         753843
# true       33891
# 1          26388
# Name: F9_07_PC_FORMER_OFFICER_LISTED, dtype: int64
#
# X    805206
# Name: F9_07_PC_NO_LISTED_PERS_COMPENSD, dtype: int64
#
# false    974455
# 0        527991
# 1        252240
# true     140330
# Name: F9_07_PC_TOTAL_COMP_GRTR_150K, dtype: int64
#
# X    1427754
# Name: F9_10_PC_ORG_FOLLOWS_SFAS117, dtype: int64
#
# X    426692
# Name: F9_10_PC_ORG_NOT_FOLLOW_SFAS117, dtype: int64
#
# false    933125
# 0        713485
# true     181660
# 1         66746
# Name: F9_12_PC_ACCNT_COMPILE_OR_REVIEW, dtype: int64
#
# X    1263945
# Name: F9_12_PC_ACCTG_METHOD_ACCRUAL, dtype: int64
#
# X    591946
# Name: F9_12_PC_ACCTG_METHOD_CASH, dtype: int64
#
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH', '#text': 'X'}          11888
# X                                                                         4126
# {'@note': 'MODIFIED CASH', '#text': 'X'}                                  3117
# {'@methodOfAccountingOtherDesc': 'Modified Cash', '#text': 'X'}           2980
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH BASIS', '#text': 'X'}     1663
# Name: F9_12_PC_ACCTG_METHOD_OTHER, dtype: int64
#
# 1        458980
# true     445920
# false    132225
# 0         86728
# Name: F9_12_PC_AUDIT_COMMITTEE, dtype: int64
#
# 1        99466
# true     81735
# false    52656
# 0          631
# Name: F9_12_PC_FED_GRNT_AUDIT_PERFORMD, dtype: int64
#
# false    856280
# 0        680157
# 1         99977
# true      81907
# Name: F9_12_PC_FED_GRNT_AUDIT_REQUIRED, dtype: int64
#
# false    692500
# 1        485118
# true     422285
# 0        295113
# Name: F9_12_PC_FINCL_STMTS_AUDITED, dtype: int64

# %% [markdown]
# ##### BASED ON THE PRECEDING CODE BLOCK, THE FOLLOWING VARIABLES WILL LIKELY FAIL THE BINARIZATION PROCESS:

# %%
F9_00_HD_EXEMPT_STATUS_501C
F9_00_HD_INCLUDES_SUBORD_ORGS
F9_04_PC_FR_EVENT_INC_GT_15K
F9_04_PC_GAMING_INC_GT_15K
F9_04_PC_PROF_FR_EXP_GT_15K
F9_12_PC_ACCTG_METHOD_OTHER

# %% [markdown]
# - F9_12_PC_ACCTG_METHOD_OTHER
#     - some values are 'X' some are dictionaries --> depending on number of values, either do *np.where* or flatten, etc.
#     - {'#text': 'X', '@methodOfAccountingOtherDesc': 'MODIFIED CASH'}          7120
#     - X                                                                        3197
#     - {'@note': 'MODIFIED CASH', '#text': 'X'}                                 3117
#     - {'#text': 'X', '@methodOfAccountingOtherDesc': 'Modified Cash'}          1715
#     - {'#text': 'X', '@methodOfAccountingOtherDesc': 'MODIFIED CASH BASIS'}    1033

# %%
binarize_with_dict_cols = ['F9_00_HD_EXEMPT_STATUS_501C', 'F9_00_HD_INCLUDES_SUBORD_ORGS', 
                           'F9_04_PC_FR_EVENT_INC_GT_15K', 'F9_04_PC_GAMING_INC_GT_15K',
                           'F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_12_PC_ACCTG_METHOD_OTHER']

# %%
for c in binarize_with_dict_cols[:]:
    print(df[df[c].notnull()][c].value_counts()[:10], '\n')
# Out:
# {'@organization501cTypeTxt': '6', '#text': 'X'}     98981
# {'@organization501cTypeTxt': '4', '#text': 'X'}     50870
# {'@organization501cTypeTxt': '5', '#text': 'X'}     43146
# {'@organization501cTypeTxt': '7', '#text': 'X'}     40186
# {'@typeOf501cOrganization': '6', '#text': 'X'}      32959
# {'@typeOf501cOrganization': '3', '#text': 'X'}      28339
# {'@organization501cTypeTxt': '9', '#text': 'X'}     22467
# {'@typeOf501cOrganization': '4', '#text': 'X'}      16427
# {'@organization501cTypeTxt': '8', '#text': 'X'}     16414
# {'@organization501cTypeTxt': '19', '#text': 'X'}    16023
# Name: F9_00_HD_EXEMPT_STATUS_501C, dtype: int64
#
# false                                                             283830
# 1                                                                   7243
# true                                                                5132
# {'@referenceDocumentId': '', '#text': 'false'}                       462
# {'@referenceDocumentId': 'RetDoc2030100001', '#text': '0'}           429
# 0                                                                    172
# {'@referenceDocumentId': 'RetDoc1', '#text': 'false'}                142
# {'@referenceDocumentId': 'AffiliateListing', '#text': 'false'}        89
# {'@referenceDocumentId': 'AffiliateListing', '#text': 'true'}         63
# {'@referenceDocumentId': 'STM128', '#text': 'false'}                  40
# Name: F9_00_HD_INCLUDES_SUBORD_ORGS, dtype: int64
#
# false                                                           841251
# 0                                                               571809
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '1'}      136243
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'true'}     88991
# {'@referenceDocumentId': '990G', '#text': 'true'}                35786
# {'@referenceDocumentId': 'RetDoc5', '#text': 'true'}             30266
# 1                                                                26762
# {'@referenceDocumentId': 'RetDoc4', '#text': 'true'}             24097
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '1'}       21590
# {'@referenceDocumentId': 'RetDoc6', '#text': 'true'}             14389
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64
#
# false                                                            891322
# 0                                                                603964
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}       130262
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}     84674
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '0'}        29962
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}             29773
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}             23236
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}             14202
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '1'}        11456
# {'@referenceDocumentId': '990G', '#text': 'true'}                 10757
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64
#
# false                                                            894335
# 0                                                                605502
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}       141718
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}     85009
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}             31143
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}             27559
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '1'}        25291
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}             14547
# {'@referenceDocumentId': 'RetDoc3', '#text': 'false'}             10624
# {'@referenceDocumentId': '990G', '#text': 'true'}                 10189
# Name: F9_04_PC_PROF_FR_EXP_GT_15K, dtype: int64
#
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH', '#text': 'X'}          11888
# X                                                                         4126
# {'@note': 'MODIFIED CASH', '#text': 'X'}                                  3117
# {'@methodOfAccountingOtherDesc': 'Modified Cash', '#text': 'X'}           2980
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH BASIS', '#text': 'X'}     1663
# {'@methodOfAccountingOtherDesc': 'modified cash', '#text': 'X'}            870
# {'@methodOfAccountingOtherDesc': 'HYBRID', '#text': 'X'}                   806
# {'@note': 'Modified Cash', '#text': 'X'}                                   676
# {'@methodOfAccountingOtherDesc': 'Modified Cash Basis', '#text': 'X'}      671
# {'@methodOfAccountingOtherDesc': 'Modified cash', '#text': 'X'}            651
# Name: F9_12_PC_ACCTG_METHOD_OTHER, dtype: int64

# %%
print(len(binarize_cols))
binarize_cols = list(set(binarize_cols) - set(binarize_with_dict_cols))
print(len(binarize_cols))
# Out:
# 58
# 52

# %% [markdown]
# ##### Check *F9_12_PC_ACCTG_METHOD_OTHER*, *F9_00_HD_EXEMPT_STATUS_501C*, and *F9_00_HD_INCLUDES_SUBORD_ORGS*
# Based on the following frequencies,for *F9_12_PC_ACCTG_METHOD_OTHER* do an *np.where* and make it 'other'. Leave *F9_00_HD_EXEMPT_STATUS_501C* and *F9_00_HD_INCLUDES_SUBORD_ORGS* alone.

# %%
print(df[df['F9_00_HD_EXEMPT_STATUS_501C'].notnull()]['F9_00_HD_EXEMPT_STATUS_501C'].value_counts().head())
# Out:
# {'@organization501cTypeTxt': '6', '#text': 'X'}    98981
# {'@organization501cTypeTxt': '4', '#text': 'X'}    50870
# {'@organization501cTypeTxt': '5', '#text': 'X'}    43146
# {'@organization501cTypeTxt': '7', '#text': 'X'}    40186
# {'@typeOf501cOrganization': '6', '#text': 'X'}     32959
# Name: F9_00_HD_EXEMPT_STATUS_501C, dtype: int64

# %% [markdown]
# #### Fix *F9_00_HD_EXEMPT_STATUS_501C*

# %%
def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    elif key2 in x.keys():
        return x[key2]
    else:
        return np.nan

# %%
df['F9_00_HD_EXEMPT_STATUS_501C'] = df['F9_00_HD_EXEMPT_STATUS_501C'][:].apply(func, 
                            key1='@organization501cTypeTxt', key2 ='@typeOf501cOrganization')

# %%
#df = df.drop('Organization501c_type', 1)

# %%
df['F9_00_HD_EXEMPT_STATUS_501C'].value_counts()[:10]
# Out:
# 6     131940
# 4      67297
# 5      57680
# 7      53636
# 9      32535
# 3      28339
# 8      21452
# 19     20858
# 12     19202
# 14     18970
# Name: F9_00_HD_EXEMPT_STATUS_501C, dtype: int64

# %% [markdown]
# #### Fix other five variables

# %%
binarize_with_dict_cols
# Out:
# ['F9_00_HD_INCLUDES_SUBORD_ORGS',
#  'F9_04_PC_FR_EVENT_INC_GT_15K',
#  'F9_04_PC_GAMING_INC_GT_15K',
#  'F9_04_PC_PROF_FR_EXP_GT_15K',
#  'F9_12_PC_ACCTG_METHOD_OTHER']

# %%
def func_text(x, key1):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    
    elif type(x)==dict: 
        if key1 in x.keys():
            return x[key1]
    else:
        return x

# %%
df['F9_00_HD_INCLUDES_SUBORD_ORGS'] = df['F9_00_HD_INCLUDES_SUBORD_ORGS'][:].apply(func_text, 
                            key1='#text')

# %%
#df = df.drop('test', 1)

# %%
df['F9_00_HD_INCLUDES_SUBORD_ORGS'].value_counts()
# Out:
# false    284676
# 1          7243
# true       5345
# 0           640
# Name: F9_00_HD_INCLUDES_SUBORD_ORGS, dtype: int64

# %%
#binarize_with_dict_cols
# Out:
# ['F9_04_PC_FR_EVENT_INC_GT_15K',
#  'F9_04_PC_GAMING_INC_GT_15K',
#  'F9_04_PC_PROF_FR_EXP_GT_15K',
#  'F9_12_PC_ACCTG_METHOD_OTHER']

# %%
df['F9_04_PC_FR_EVENT_INC_GT_15K'] = df['F9_04_PC_FR_EVENT_INC_GT_15K'][:].apply(func_text, 
                            key1='#text')

# %%
df['F9_04_PC_FR_EVENT_INC_GT_15K'].value_counts()
# Out:
# false    863971
# 0        587063
# true     250814
# 1        193168
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64

# %%
for c in binarize_with_dict_cols[:]:
    print(df[df[c].notnull()][c].value_counts()[:10], '\n')
# Out:
# false                                                           841251
# 0                                                               571809
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '1'}      136243
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'true'}     88991
# {'@referenceDocumentId': '990G', '#text': 'true'}                35786
# {'@referenceDocumentId': 'RetDoc5', '#text': 'true'}             30266
# 1                                                                26762
# {'@referenceDocumentId': 'RetDoc4', '#text': 'true'}             24097
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '1'}       21590
# {'@referenceDocumentId': 'RetDoc6', '#text': 'true'}             14389
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64
#
# false                                                            891322
# 0                                                                603964
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}       130262
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}     84674
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '0'}        29962
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}             29773
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}             23236
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}             14202
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '1'}        11456
# {'@referenceDocumentId': '990G', '#text': 'true'}                 10757
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64
#
# false                                                            894335
# 0                                                                605502
# {'@referenceDocumentId': 'RetDoc1041300001', '#text': '0'}       141718
# {'@referenceDocumentId': 'IRS990ScheduleG', '#text': 'false'}     85009
# {'@referenceDocumentId': 'RetDoc5', '#text': 'false'}             31143
# {'@referenceDocumentId': 'RetDoc4', '#text': 'false'}             27559
# {'@referenceDocumentId': 'RetDoc1041200001', '#text': '1'}        25291
# {'@referenceDocumentId': 'RetDoc6', '#text': 'false'}             14547
# {'@referenceDocumentId': 'RetDoc3', '#text': 'false'}             10624
# {'@referenceDocumentId': '990G', '#text': 'true'}                 10189
# Name: F9_04_PC_PROF_FR_EXP_GT_15K, dtype: int64
#
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH', '#text': 'X'}          11888
# X                                                                         4126
# {'@note': 'MODIFIED CASH', '#text': 'X'}                                  3117
# {'@methodOfAccountingOtherDesc': 'Modified Cash', '#text': 'X'}           2980
# {'@methodOfAccountingOtherDesc': 'MODIFIED CASH BASIS', '#text': 'X'}     1663
# {'@methodOfAccountingOtherDesc': 'modified cash', '#text': 'X'}            870
# {'@methodOfAccountingOtherDesc': 'HYBRID', '#text': 'X'}                   806
# {'@note': 'Modified Cash', '#text': 'X'}                                   676
# {'@methodOfAccountingOtherDesc': 'Modified Cash Basis', '#text': 'X'}      671
# {'@methodOfAccountingOtherDesc': 'Modified cash', '#text': 'X'}            651
# Name: F9_12_PC_ACCTG_METHOD_OTHER, dtype: int64

# %%
df['F9_04_PC_GAMING_INC_GT_15K'] = df['F9_04_PC_GAMING_INC_GT_15K'][:].apply(func_text, 
                            key1='#text')

# %%
df['F9_04_PC_GAMING_INC_GT_15K'].value_counts()
# Out:
# false    1073662
# 0         764352
# true       41123
# 1          15879
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64

# %%
df['F9_04_PC_PROF_FR_EXP_GT_15K'] = df['F9_04_PC_PROF_FR_EXP_GT_15K'][:].apply(func_text, 
                            key1='#text')

# %%
df['F9_04_PC_FR_EVENT_INC_GT_15K'].value_counts()
# Out:
# false    863971
# 0        587063
# true     250814
# 1        193168
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64

# %% [markdown]
# #### Fix *F9_12_PC_ACCTG_METHOD_OTHER*

# %%
def func_text2(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    
    elif type(x)==dict: 
        if key1 in x.keys():
            return x[key1]
        elif key2 in x.keys():
            return x[key2]
    else:
        return x

# %%
df['F9_12_PC_ACCTG_METHOD_OTHER'] = df['F9_12_PC_ACCTG_METHOD_OTHER'][:].apply(func_text2, 
                            key1='@note', key2='@methodOfAccountingOtherDesc')

# %%
#df=df.drop('test', 1)

# %%
df['F9_12_PC_ACCTG_METHOD_OTHER'].value_counts()[:10]
# Out:
# MODIFIED CASH          15005
# X                       4126
# Modified Cash           3656
# MODIFIED CASH BASIS     2062
# modified cash           1109
# HYBRID                  1090
# Modified cash            816
# Modified Cash Basis      789
# MODIFIED ACCRUAL         736
# MODIFIED CAS             674
# Name: F9_12_PC_ACCTG_METHOD_OTHER, dtype: int64

# %% [markdown]
# ##### Remove two variables from *binarize_cols*

# %%
print(len(binarize_cols))
binarize_cols.remove('F9_12_PC_ACCTG_METHOD_OTHER') 
binarize_cols.remove('F9_00_HD_EXEMPT_STATUS_501C')
print(len(binarize_cols))
# Out:
# 58
# 56

# %% [markdown]
# #### Create *501c3* variable

# %%
df['F9_00_HD_EXEMPT_STATUS_501C'].value_counts()[:10]
# Out:
# 6     131940
# 4      67297
# 5      57680
# 7      53636
# 9      32535
# 3      28339
# 8      21452
# 19     20858
# 12     19202
# 14     18970
# Name: F9_00_HD_EXEMPT_STATUS_501C, dtype: int64

# %%
df['F9_00_HD_EXEMPT_STATUS_501C3'].value_counts()
# Out:
# X    1407131
# Name: F9_00_HD_EXEMPT_STATUS_501C3, dtype: int64

# %%
pd.crosstab(df['F9_00_HD_EXEMPT_STATUS_501C3'], df['F9_00_HD_EXEMPT_STATUS_501C'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
1407131+28339
# Out:
# 1435470

# %%
df['501c3'] = np.where(df['F9_00_HD_EXEMPT_STATUS_501C3']=='X', 1, 0)
print(df['501c3'].value_counts(),'\n')
print(348990+1058141)
df['501c3'] = np.where(df['F9_00_HD_EXEMPT_STATUS_501C']=='3', 1, df['501c3'])
print(df['501c3'].value_counts())
# Out:
# 1    1407131
# 0     487885
# Name: 501c3, dtype: int64
#
# 1407131
# 1    1435470
# 0     459546
# Name: 501c3, dtype: int64

# %% [markdown]
# #### Save DF

# %%
# %%time
df.to_pickle('all filings nov. 2020 - all control variables (renamed).pkl.gz', compression='gzip')
# Out:
# Wall time: 1h 24min 22s

# %% [markdown]
# # Binarize Columns

# %%
for col in binarize_cols:
    print(df[col].value_counts(), '\n\n')
# Out:
# X    74526
# Name: F9_00_HD_ADDR_CHANGE, dtype: int64
#
#
# X    16642
# Name: F9_00_HD_AMENDED_RETURN, dtype: int64
#
#
# X    1514
# Name: F9_00_HD_EXEMPT_STATUS_4847A1, dtype: int64
#
#
# X    1407131
# Name: F9_00_HD_EXEMPT_STATUS_501C3, dtype: int64
#
#
# X    10123
# Name: F9_00_HD_FINAL_RETURN, dtype: int64
#
#
# false    1112425
# 0         778013
# true        2360
# 1           2218
# Name: F9_00_HD_GROUP_RETURN, dtype: int64
#
#
# false    284676
# 1          7243
# true       5345
# 0           640
# Name: F9_00_HD_INCLUDES_SUBORD_ORGS, dtype: int64
#
#
# X    18113
# Name: F9_00_HD_INITIAL_RETURN, dtype: int64
#
#
# X    83569
# Name: F9_00_HD_TYPE_ORG_ASSOCIATION, dtype: int64
#
#
# X    1666981
# Name: F9_00_HD_TYPE_ORG_CORP, dtype: int64
#
#
# X    45946
# Name: F9_00_HD_TYPE_ORG_OTHER, dtype: int64
#
#
# X    60917
# Name: F9_00_HD_TYPE_ORG_TRUST, dtype: int64
#
#
# X    13530
# Name: F9_01_PC_TERMINATION_CONTRACTION, dtype: int64
#
#
# false    863971
# 0        587063
# true     250814
# 1        193168
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64
#
#
# false    1073662
# 0         764352
# true       41123
# 1          15879
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64
#
#
# false    1087124
# 0         753460
# true       27661
# 1          26771
# Name: F9_04_PC_PROF_FR_EXP_GT_15K, dtype: int64
#
#
# true     709021
# 1        627411
# false    405764
# 0        152820
# Name: F9_06_PC_990_PROVIDED_GOV_BODY, dtype: int64
#
#
# true     547713
# 1        531855
# false    201338
# 0         45362
# Name: F9_06_PC_ANNUAL_DISC_COVRD_PERS, dtype: int64
#
#
# false    671987
# true     432154
# 1        400619
# 0        379478
# Name: F9_06_PC_CEO_COMPENSTN_PROCESS, dtype: int64
#
#
# false    1099910
# 0         759672
# 1          20559
# true       14875
# Name: F9_06_PC_CHANGES_ORGANIZING_DOCS, dtype: int64
#
#
# true     612834
# 1        576554
# false    501951
# 0        203677
# Name: F9_06_PC_CONFLICT_OF_INTEREST, dtype: int64
#
#
# false    948554
# 0        647595
# true     166231
# 1        132636
# Name: F9_06_PC_DECISIONS_SUBJ_APPROVAL, dtype: int64
#
#
# false    1066372
# 0         714855
# 1          65376
# true       48413
# Name: F9_06_PC_DELEGATION_MGT_DUTIES, dtype: int64
#
#
# false    1066372
# 0         714855
# 1          65376
# true       48413
# Name: F9_06_PC_DELEGATION_OF_MGT, dtype: int64
#
#
# false    642636
# 1        474254
# true     472149
# 0        305977
# Name: F9_06_PC_DOCUMENT_RET_POLICY, dtype: int64
#
#
# false    855613
# 0        559209
# true     259172
# 1        221022
# Name: F9_06_PC_ELECTION_BOARD_MEMBERS, dtype: int64
#
#
# false    968968
# 0        663430
# true     145817
# 1        116801
# Name: F9_06_PC_FAMILY_OR_BUSINESS_REL, dtype: int64
#
#
# X    117868
# Name: F9_06_PC_FORM_AVAIL_OWN_WEBSITE, dtype: int64
#
#
# X    1725127
# Name: F9_06_PC_FORM_UPON_REQUEST, dtype: int64
#
#
# false    1100961
# 0         765192
# 1          15039
# true       13824
# Name: F9_06_PC_JOINT_VENTURE_INVESTMNT, dtype: int64
#
#
# false    73047
# 1        11693
# true     10745
# 0         4405
# Name: F9_06_PC_JOINT_VENTURE_POLICY, dtype: int64
#
#
# false    1068218
# 0         733141
# 1          47090
# true       46567
# Name: F9_06_PC_LOCAL_CHAPTERS, dtype: int64
#
#
# false    1113490
# 0         779483
# true        1295
# 1            748
# Name: F9_06_PC_MATERIAL_DIVERSION, dtype: int64
#
#
# false    887552
# 0        572011
# true     227233
# 1        208220
# Name: F9_06_PC_MEMBERS_OR_STOCKHOLDERS, dtype: int64
#
#
# true     920474
# 1        690628
# false    187866
# 0         89508
# Name: F9_06_PC_MINUTES_COMMITTEES, dtype: int64
#
#
# true     1018320
# 1         770866
# false      96465
# 0           9365
# Name: F9_06_PC_MINUTES_GOVERNING_BODY, dtype: int64
#
#
# 1        512847
# true     507311
# false    240823
# 0         64354
# Name: F9_06_PC_MONITORING_OF_COI_POLICY, dtype: int64
#
#
# false    1092781
# 0         771422
# true       22004
# 1           8809
# Name: F9_06_PC_OFFICER_MAILING_ADDRESS, dtype: int64
#
#
# false    798051
# 0        487241
# true     304053
# 1        292819
# Name: F9_06_PC_OTHER_COMPENSTN_PROCESS, dtype: int64
#
#
# X    251612
# Name: F9_06_PC_OTHER_WEBSITE, dtype: int64
#
#
# X    117868
# Name: F9_06_PC_OWN_WEBSITE, dtype: int64
#
#
# false    58506
# 1        45605
# true     44303
# 0         2438
# Name: F9_06_PC_POLICIES_GOVERN_CHAPTER, dtype: int64
#
#
# false    705888
# 1        444334
# true     408897
# 0        335897
# Name: F9_06_PC_WHISTLEBLOWER_POLICY, dtype: int64
#
#
# false    1109515
# 0         774488
# 1           5743
# true        5270
# Name: F9_07_PC_COMPENSATION_OTHER_SRCE, dtype: int64
#
#
# false    1080894
# 0         753843
# true       33891
# 1          26388
# Name: F9_07_PC_FORMER_OFFICER_LISTED, dtype: int64
#
#
# X    805206
# Name: F9_07_PC_NO_LISTED_PERS_COMPENSD, dtype: int64
#
#
# false    974455
# 0        527991
# 1        252240
# true     140330
# Name: F9_07_PC_TOTAL_COMP_GRTR_150K, dtype: int64
#
#
# X    1427754
# Name: F9_10_PC_ORG_FOLLOWS_SFAS117, dtype: int64
#
#
# X    426692
# Name: F9_10_PC_ORG_NOT_FOLLOW_SFAS117, dtype: int64
#
#
# false    933125
# 0        713485
# true     181660
# 1         66746
# Name: F9_12_PC_ACCNT_COMPILE_OR_REVIEW, dtype: int64
#
#
# X    1263945
# Name: F9_12_PC_ACCTG_METHOD_ACCRUAL, dtype: int64
#
#
# X    591946
# Name: F9_12_PC_ACCTG_METHOD_CASH, dtype: int64
#
#
# 1        458980
# true     445920
# false    132225
# 0         86728
# Name: F9_12_PC_AUDIT_COMMITTEE, dtype: int64
#
#
# 1        99466
# true     81735
# false    52656
# 0          631
# Name: F9_12_PC_FED_GRNT_AUDIT_PERFORMD, dtype: int64
#
#
# false    856280
# 0        680157
# 1         99977
# true      81907
# Name: F9_12_PC_FED_GRNT_AUDIT_REQUIRED, dtype: int64
#
#
# false    692500
# 1        485118
# true     422285
# 0        295113
# Name: F9_12_PC_FINCL_STMTS_AUDITED, dtype: int64

# %%
print(len(binarize_cols))
# Out:
# 56

# %%
def binarize(df, variable):
    print(df[variable].value_counts(), '\n')
    df[variable] = np.where(df[variable]=='true', 1, df[variable])
    df[variable] = np.where(df[variable]=='false', 0, df[variable])
    df[variable] = np.where(df[variable]=='1', 1, df[variable])
    df[variable] = np.where(df[variable]=='0', 0, df[variable])
    df[variable] = np.where(df[variable]=='X', 1, df[variable])
    print(df[variable].value_counts(), '\n\n')
    return df.sample(10)[['EIN', variable]]

# %%
for col in binarize_cols:
    binarize(df, col)
# Out:
# X    74526
# Name: F9_00_HD_ADDR_CHANGE, dtype: int64
#
# 1    74526
# Name: F9_00_HD_ADDR_CHANGE, dtype: int64
#
#
# X    16642
# Name: F9_00_HD_AMENDED_RETURN, dtype: int64
#
# 1    16642
# Name: F9_00_HD_AMENDED_RETURN, dtype: int64
#
#
# X    1514
# Name: F9_00_HD_EXEMPT_STATUS_4847A1, dtype: int64
#
# 1    1514
# Name: F9_00_HD_EXEMPT_STATUS_4847A1, dtype: int64
#
#
# X    1407131
# Name: F9_00_HD_EXEMPT_STATUS_501C3, dtype: int64
#
# 1    1407131
# Name: F9_00_HD_EXEMPT_STATUS_501C3, dtype: int64
#
#
# X    10123
# Name: F9_00_HD_FINAL_RETURN, dtype: int64
#
# 1    10123
# Name: F9_00_HD_FINAL_RETURN, dtype: int64
#
#
# false    1112425
# 0         778013
# true        2360
# 1           2218
# Name: F9_00_HD_GROUP_RETURN, dtype: int64
#
# 0    1890438
# 1       4578
# Name: F9_00_HD_GROUP_RETURN, dtype: int64
#
#
# false    284676
# 1          7243
# true       5345
# 0           640
# Name: F9_00_HD_INCLUDES_SUBORD_ORGS, dtype: int64
#
# 0    285316
# 1     12588
# Name: F9_00_HD_INCLUDES_SUBORD_ORGS, dtype: int64
#
#
# X    18113
# Name: F9_00_HD_INITIAL_RETURN, dtype: int64
#
# 1    18113
# Name: F9_00_HD_INITIAL_RETURN, dtype: int64
#
#
# X    83569
# Name: F9_00_HD_TYPE_ORG_ASSOCIATION, dtype: int64
#
# 1    83569
# Name: F9_00_HD_TYPE_ORG_ASSOCIATION, dtype: int64
#
#
# X    1666981
# Name: F9_00_HD_TYPE_ORG_CORP, dtype: int64
#
# 1    1666981
# Name: F9_00_HD_TYPE_ORG_CORP, dtype: int64
#
#
# X    45946
# Name: F9_00_HD_TYPE_ORG_OTHER, dtype: int64
#
# 1    45946
# Name: F9_00_HD_TYPE_ORG_OTHER, dtype: int64
#
#
# X    60917
# Name: F9_00_HD_TYPE_ORG_TRUST, dtype: int64
#
# 1    60917
# Name: F9_00_HD_TYPE_ORG_TRUST, dtype: int64
#
#
# X    13530
# Name: F9_01_PC_TERMINATION_CONTRACTION, dtype: int64
#
# 1    13530
# Name: F9_01_PC_TERMINATION_CONTRACTION, dtype: int64
#
#
# false    863971
# 0        587063
# true     250814
# 1        193168
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64
#
# 0    1451034
# 1     443982
# Name: F9_04_PC_FR_EVENT_INC_GT_15K, dtype: int64
#
#
# false    1073662
# 0         764352
# true       41123
# 1          15879
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64
#
# 0    1838014
# 1      57002
# Name: F9_04_PC_GAMING_INC_GT_15K, dtype: int64
#
#
# false    1087124
# 0         753460
# true       27661
# 1          26771
# Name: F9_04_PC_PROF_FR_EXP_GT_15K, dtype: int64
#
# 0    1840584
# 1      54432
# Name: F9_04_PC_PROF_FR_EXP_GT_15K, dtype: int64
#
#
# true     709021
# 1        627411
# false    405764
# 0        152820
# Name: F9_06_PC_990_PROVIDED_GOV_BODY, dtype: int64
#
# 1    1336432
# 0     558584
# Name: F9_06_PC_990_PROVIDED_GOV_BODY, dtype: int64
#
#
# true     547713
# 1        531855
# false    201338
# 0         45362
# Name: F9_06_PC_ANNUAL_DISC_COVRD_PERS, dtype: int64
#
# 1    1079568
# 0     246700
# Name: F9_06_PC_ANNUAL_DISC_COVRD_PERS, dtype: int64
#
#
# false    671987
# true     432154
# 1        400619
# 0        379478
# Name: F9_06_PC_CEO_COMPENSTN_PROCESS, dtype: int64
#
# 0    1051465
# 1     832773
# Name: F9_06_PC_CEO_COMPENSTN_PROCESS, dtype: int64
#
#
# false    1099910
# 0         759672
# 1          20559
# true       14875
# Name: F9_06_PC_CHANGES_ORGANIZING_DOCS, dtype: int64
#
# 0    1859582
# 1      35434
# Name: F9_06_PC_CHANGES_ORGANIZING_DOCS, dtype: int64
#
#
# true     612834
# 1        576554
# false    501951
# 0        203677
# Name: F9_06_PC_CONFLICT_OF_INTEREST, dtype: int64
#
# 1    1189388
# 0     705628
# Name: F9_06_PC_CONFLICT_OF_INTEREST, dtype: int64
#
#
# false    948554
# 0        647595
# true     166231
# 1        132636
# Name: F9_06_PC_DECISIONS_SUBJ_APPROVAL, dtype: int64
#
# 0    1596149
# 1     298867
# Name: F9_06_PC_DECISIONS_SUBJ_APPROVAL, dtype: int64
#
#
# false    1066372
# 0         714855
# 1          65376
# true       48413
# Name: F9_06_PC_DELEGATION_MGT_DUTIES, dtype: int64
#
# 0    1781227
# 1     113789
# Name: F9_06_PC_DELEGATION_MGT_DUTIES, dtype: int64
#
#
# false    1066372
# 0         714855
# 1          65376
# true       48413
# Name: F9_06_PC_DELEGATION_OF_MGT, dtype: int64
#
# 0    1781227
# 1     113789
# Name: F9_06_PC_DELEGATION_OF_MGT, dtype: int64
#
#
# false    642636
# 1        474254
# true     472149
# 0        305977
# Name: F9_06_PC_DOCUMENT_RET_POLICY, dtype: int64
#
# 0    948613
# 1    946403
# Name: F9_06_PC_DOCUMENT_RET_POLICY, dtype: int64
#
#
# false    855613
# 0        559209
# true     259172
# 1        221022
# Name: F9_06_PC_ELECTION_BOARD_MEMBERS, dtype: int64
#
# 0    1414822
# 1     480194
# Name: F9_06_PC_ELECTION_BOARD_MEMBERS, dtype: int64
#
#
# false    968968
# 0        663430
# true     145817
# 1        116801
# Name: F9_06_PC_FAMILY_OR_BUSINESS_REL, dtype: int64
#
# 0    1632398
# 1     262618
# Name: F9_06_PC_FAMILY_OR_BUSINESS_REL, dtype: int64
#
#
# X    117868
# Name: F9_06_PC_FORM_AVAIL_OWN_WEBSITE, dtype: int64
#
# 1    117868
# Name: F9_06_PC_FORM_AVAIL_OWN_WEBSITE, dtype: int64
#
#
# X    1725127
# Name: F9_06_PC_FORM_UPON_REQUEST, dtype: int64
#
# 1    1725127
# Name: F9_06_PC_FORM_UPON_REQUEST, dtype: int64
#
#
# false    1100961
# 0         765192
# 1          15039
# true       13824
# Name: F9_06_PC_JOINT_VENTURE_INVESTMNT, dtype: int64
#
# 0    1866153
# 1      28863
# Name: F9_06_PC_JOINT_VENTURE_INVESTMNT, dtype: int64
#
#
# false    73047
# 1        11693
# true     10745
# 0         4405
# Name: F9_06_PC_JOINT_VENTURE_POLICY, dtype: int64
#
# 0    77452
# 1    22438
# Name: F9_06_PC_JOINT_VENTURE_POLICY, dtype: int64
#
#
# false    1068218
# 0         733141
# 1          47090
# true       46567
# Name: F9_06_PC_LOCAL_CHAPTERS, dtype: int64
#
# 0    1801359
# 1      93657
# Name: F9_06_PC_LOCAL_CHAPTERS, dtype: int64
#
#
# false    1113490
# 0         779483
# true        1295
# 1            748
# Name: F9_06_PC_MATERIAL_DIVERSION, dtype: int64
#
# 0    1892973
# 1       2043
# Name: F9_06_PC_MATERIAL_DIVERSION, dtype: int64
#
#
# false    887552
# 0        572011
# true     227233
# 1        208220
# Name: F9_06_PC_MEMBERS_OR_STOCKHOLDERS, dtype: int64
#
# 0    1459563
# 1     435453
# Name: F9_06_PC_MEMBERS_OR_STOCKHOLDERS, dtype: int64
#
#
# true     920474
# 1        690628
# false    187866
# 0         89508
# Name: F9_06_PC_MINUTES_COMMITTEES, dtype: int64
#
# 1    1611102
# 0     277374
# Name: F9_06_PC_MINUTES_COMMITTEES, dtype: int64
#
#
# true     1018320
# 1         770866
# false      96465
# 0           9365
# Name: F9_06_PC_MINUTES_GOVERNING_BODY, dtype: int64
#
# 1    1789186
# 0     105830
# Name: F9_06_PC_MINUTES_GOVERNING_BODY, dtype: int64
#
#
# 1        512847
# true     507311
# false    240823
# 0         64354
# Name: F9_06_PC_MONITORING_OF_COI_POLICY, dtype: int64
#
# 1    1020158
# 0     305177
# Name: F9_06_PC_MONITORING_OF_COI_POLICY, dtype: int64
#
#
# false    1092781
# 0         771422
# true       22004
# 1           8809
# Name: F9_06_PC_OFFICER_MAILING_ADDRESS, dtype: int64
#
# 0    1864203
# 1      30813
# Name: F9_06_PC_OFFICER_MAILING_ADDRESS, dtype: int64
#
#
# false    798051
# 0        487241
# true     304053
# 1        292819
# Name: F9_06_PC_OTHER_COMPENSTN_PROCESS, dtype: int64
#
# 0    1285292
# 1     596872
# Name: F9_06_PC_OTHER_COMPENSTN_PROCESS, dtype: int64
#
#
# X    251612
# Name: F9_06_PC_OTHER_WEBSITE, dtype: int64
#
# 1    251612
# Name: F9_06_PC_OTHER_WEBSITE, dtype: int64
#
#
# X    117868
# Name: F9_06_PC_OWN_WEBSITE, dtype: int64
#
# 1    117868
# Name: F9_06_PC_OWN_WEBSITE, dtype: int64
#
#
# false    58506
# 1        45605
# true     44303
# 0         2438
# Name: F9_06_PC_POLICIES_GOVERN_CHAPTER, dtype: int64
#
# 1    89908
# 0    60944
# Name: F9_06_PC_POLICIES_GOVERN_CHAPTER, dtype: int64
#
#
# false    705888
# 1        444334
# true     408897
# 0        335897
# Name: F9_06_PC_WHISTLEBLOWER_POLICY, dtype: int64
#
# 0    1041785
# 1     853231
# Name: F9_06_PC_WHISTLEBLOWER_POLICY, dtype: int64
#
#
# false    1109515
# 0         774488
# 1           5743
# true        5270
# Name: F9_07_PC_COMPENSATION_OTHER_SRCE, dtype: int64
#
# 0    1884003
# 1      11013
# Name: F9_07_PC_COMPENSATION_OTHER_SRCE, dtype: int64
#
#
# false    1080894
# 0         753843
# true       33891
# 1          26388
# Name: F9_07_PC_FORMER_OFFICER_LISTED, dtype: int64
#
# 0    1834737
# 1      60279
# Name: F9_07_PC_FORMER_OFFICER_LISTED, dtype: int64
#
#
# X    805206
# Name: F9_07_PC_NO_LISTED_PERS_COMPENSD, dtype: int64
#
# 1    805206
# Name: F9_07_PC_NO_LISTED_PERS_COMPENSD, dtype: int64
#
#
# false    974455
# 0        527991
# 1        252240
# true     140330
# Name: F9_07_PC_TOTAL_COMP_GRTR_150K, dtype: int64
#
# 0    1502446
# 1     392570
# Name: F9_07_PC_TOTAL_COMP_GRTR_150K, dtype: int64
#
#
# X    1427754
# Name: F9_10_PC_ORG_FOLLOWS_SFAS117, dtype: int64
#
# 1    1427754
# Name: F9_10_PC_ORG_FOLLOWS_SFAS117, dtype: int64
#
#
# X    426692
# Name: F9_10_PC_ORG_NOT_FOLLOW_SFAS117, dtype: int64
# 1    426692
# Name: F9_10_PC_ORG_NOT_FOLLOW_SFAS117, dtype: int64
#
#
# false    933125
# 0        713485
# true     181660
# 1         66746
# Name: F9_12_PC_ACCNT_COMPILE_OR_REVIEW, dtype: int64
#
# 0    1646610
# 1     248406
# Name: F9_12_PC_ACCNT_COMPILE_OR_REVIEW, dtype: int64
#
#
# X    1263945
# Name: F9_12_PC_ACCTG_METHOD_ACCRUAL, dtype: int64
#
# 1    1263945
# Name: F9_12_PC_ACCTG_METHOD_ACCRUAL, dtype: int64
#
#
# X    591946
# Name: F9_12_PC_ACCTG_METHOD_CASH, dtype: int64
#
# 1    591946
# Name: F9_12_PC_ACCTG_METHOD_CASH, dtype: int64
#
#
# 1        458980
# true     445920
# false    132225
# 0         86728
# Name: F9_12_PC_AUDIT_COMMITTEE, dtype: int64
#
# 1    904900
# 0    218953
# Name: F9_12_PC_AUDIT_COMMITTEE, dtype: int64
#
#
# 1        99466
# true     81735
# false    52656
# 0          631
# Name: F9_12_PC_FED_GRNT_AUDIT_PERFORMD, dtype: int64
#
# 1    181201
# 0     53287
# Name: F9_12_PC_FED_GRNT_AUDIT_PERFORMD, dtype: int64
#
#
# false    856280
# 0        680157
# 1         99977
# true      81907
# Name: F9_12_PC_FED_GRNT_AUDIT_REQUIRED, dtype: int64
#
# 0    1536437
# 1     181884
# Name: F9_12_PC_FED_GRNT_AUDIT_REQUIRED, dtype: int64
#
#
# false    692500
# 1        485118
# true     422285
# 0        295113
# Name: F9_12_PC_FINCL_STMTS_AUDITED, dtype: int64
#
# 0    987613
# 1    907403
# Name: F9_12_PC_FINCL_STMTS_AUDITED, dtype: int64

# %%
df[binarize_cols].sample(10)
# Out:
#         F9_00_HD_ADDR_CHANGE F9_00_HD_AMENDED_RETURN  \
# 1179867                  NaN                     NaN
# 643125                   NaN                     NaN
# 894438                   NaN                     NaN
# 1886060                  NaN                     NaN
# 1679603                  NaN                     NaN
# 1182054                  NaN                       1
# 1808096                  NaN                     NaN
# 805562                   NaN                     NaN
# 505590                   NaN                     NaN
# 513674                     1                     NaN
#
#         F9_00_HD_EXEMPT_STATUS_4847A1 F9_00_HD_EXEMPT_STATUS_501C3  \
# 1179867                           NaN                            1
# 643125                            NaN                            1
# 894438                            NaN                            1
# 1886060                           NaN                            1
# 1679603                           NaN                            1
# 1182054                           NaN                            1
# 1808096                           NaN                            1
# 805562                            NaN                            1
# 505590                            NaN                            1
# 513674                            NaN                            1
#
#         F9_00_HD_FINAL_RETURN F9_00_HD_GROUP_RETURN  \
# 1179867                   NaN                     0
# 643125                    NaN                     0
# 894438                    NaN                     0
# 1886060                   NaN                     0
# 1679603                   NaN                     0
# 1182054                   NaN                     0
# 1808096                   NaN                     0
# 805562                    NaN                     0
# 505590                    NaN                     0
# 513674                    NaN                     0
#
#         F9_00_HD_INCLUDES_SUBORD_ORGS F9_00_HD_INITIAL_RETURN  \
# 1179867                           NaN                     NaN
# 643125                            NaN                     NaN
# 894438                            NaN                     NaN
# 1886060                             0                       1
# 1679603                           NaN                     NaN
# 1182054                           NaN                     NaN
# 1808096                           NaN                     NaN
# 805562                            NaN                     NaN
# 505590                            NaN                     NaN
# 513674                            NaN                     NaN
#
#         F9_00_HD_TYPE_ORG_ASSOCIATION F9_00_HD_TYPE_ORG_CORP  \
# 1179867                           NaN                      1
# 643125                            NaN                    NaN
# 894438                            NaN                      1
# 1886060                           NaN                      1
# 1679603                           NaN                      1
# 1182054                           NaN                      1
# 1808096                           NaN                      1
# 805562                            NaN                    NaN
# 505590                            NaN                      1
# 513674                            NaN                      1
#
#         F9_00_HD_TYPE_ORG_OTHER F9_00_HD_TYPE_ORG_TRUST  \
# 1179867                     NaN                     NaN
# 643125                        1                     NaN
# 894438                      NaN                     NaN
# 1886060                     NaN                     NaN
# 1679603                     NaN                     NaN
# 1182054                     NaN                     NaN
# 1808096                     NaN                     NaN
# 805562                        1                     NaN
# 505590                      NaN                     NaN
# 513674                      NaN                     NaN
#
#         F9_01_PC_TERMINATION_CONTRACTION F9_04_PC_FR_EVENT_INC_GT_15K  \
# 1179867                              NaN                            0
# 643125                               NaN                            0
# 894438                               NaN                            1
# 1886060                              NaN                            0
# 1679603                              NaN                            0
# 1182054                              NaN                            0
# 1808096                              NaN                            0
# 805562                               NaN                            0
# 505590                               NaN                            1
# 513674                               NaN                            0
#
#         F9_04_PC_GAMING_INC_GT_15K F9_04_PC_PROF_FR_EXP_GT_15K  \
# 1179867                          0                           0
# 643125                           0                           0
# 894438                           0                           0
# 1886060                          0                           0
# 1679603                          0                           0
# 1182054                          0                           0
# 1808096                          0                           0
# 805562                           0                           0
# 505590                           0                           0
# 513674                           0                           0
#
#         F9_06_PC_990_PROVIDED_GOV_BODY F9_06_PC_ANNUAL_DISC_COVRD_PERS  \
# 1179867                              1                             NaN
# 643125                               1                               1
# 894438                               1                             NaN
# 1886060                              1                               0
# 1679603                              0                               0
# 1182054                              1                             NaN
# 1808096                              1                               1
# 805562                               1                               1
# 505590                               1                               1
# 513674                               1                               1
#
#         F9_06_PC_CEO_COMPENSTN_PROCESS F9_06_PC_CHANGES_ORGANIZING_DOCS  \
# 1179867                              1                                0
# 643125                               1                                0
# 894438                               1                                0
# 1886060                              0                                0
# 1679603                              1                                0
# 1182054                              0                                0
# 1808096                              1                                0
# 805562                               0                                0
# 505590                               1                                0
# 513674                               1                                0
#
#         F9_06_PC_CONFLICT_OF_INTEREST F9_06_PC_DECISIONS_SUBJ_APPROVAL  \
# 1179867                             0                                0
# 643125                              1                                0
# 894438                              0                                0
# 1886060                             0                                0
# 1679603                             1                                0
# 1182054                             0                                0
# 1808096                             1                                0
# 805562                              1                                0
# 505590                              1                                0
# 513674                              1                                0
#
#         F9_06_PC_DELEGATION_MGT_DUTIES F9_06_PC_DELEGATION_OF_MGT  \
# 1179867                              0                          0
# 643125                               0                          0
# 894438                               0                          0
# 1886060                              1                          1
# 1679603                              0                          0
# 1182054                              0                          0
# 1808096                              0                          0
# 805562                               0                          0
# 505590                               0                          0
# 513674                               0                          0
#
#         F9_06_PC_DOCUMENT_RET_POLICY F9_06_PC_ELECTION_BOARD_MEMBERS  \
# 1179867                            0                               0
# 643125                             0                               0
# 894438                             0                               0
# 1886060                            0                               0
# 1679603                            0                               0
# 1182054                            0                               0
# 1808096                            0                               0
# 805562                             0                               0
# 505590                             1                               0
# 513674                             1                               0
#
#         F9_06_PC_FAMILY_OR_BUSINESS_REL F9_06_PC_FORM_AVAIL_OWN_WEBSITE  \
# 1179867                               1                             NaN
# 643125                                0                             NaN
# 894438                                0                             NaN
# 1886060                               0                             NaN
# 1679603                               0                             NaN
# 1182054                               0                             NaN
# 1808096                               0                               1
# 805562                                0                             NaN
# 505590                                0                             NaN
# 513674                                0                             NaN
#
#         F9_06_PC_FORM_UPON_REQUEST F9_06_PC_JOINT_VENTURE_INVESTMNT  \
# 1179867                          1                                0
# 643125                           1                                0
# 894438                           1                                0
# 1886060                          1                                0
# 1679603                          1                                0
# 1182054                          1                                0
# 1808096                          1                                0
# 805562                           1                                0
# 505590                           1                                0
# 513674                           1                                0
#
#         F9_06_PC_JOINT_VENTURE_POLICY F9_06_PC_LOCAL_CHAPTERS  \
# 1179867                           NaN                       0
# 643125                            NaN                       0
# 894438                            NaN                       0
# 1886060                           NaN                       0
# 1679603                           NaN                       0
# 1182054                           NaN                       0
# 1808096                           NaN                       0
# 805562                            NaN                       0
# 505590                            NaN                       0
# 513674                            NaN                       1
#
#         F9_06_PC_MATERIAL_DIVERSION F9_06_PC_MEMBERS_OR_STOCKHOLDERS  \
# 1179867                           0                                0
# 643125                            0                                0
# 894438                            0                                0
# 1886060                           0                                0
# 1679603                           0                                0
# 1182054                           0                                0
# 1808096                           0                                0
# 805562                            0                                0
# 505590                            0                                0
# 513674                            0                                0
#
#         F9_06_PC_MINUTES_COMMITTEES F9_06_PC_MINUTES_GOVERNING_BODY  \
# 1179867                           1                               1
# 643125                            0                               1
# 894438                            1                               1
# 1886060                           0                               1
# 1679603                           1                               1
# 1182054                           1                               1
# 1808096                           0                               1
# 805562                            1                               1
# 505590                            1                               1
# 513674                            1                               1
#
#         F9_06_PC_MONITORING_OF_COI_POLICY F9_06_PC_OFFICER_MAILING_ADDRESS  \
# 1179867                               NaN                                0
# 643125                                  0                                0
# 894438                                NaN                                0
# 1886060                                 0                                0
# 1679603                                 1                                0
# 1182054                               NaN                                0
# 1808096                                 1                                0
# 805562                                  1                                0
# 505590                                  1                                0
# 513674                                  1                                0
#
#         F9_06_PC_OTHER_COMPENSTN_PROCESS F9_06_PC_OTHER_WEBSITE  \
# 1179867                                1                    NaN
# 643125                                 0                    NaN
# 894438                                 1                    NaN
# 1886060                                0                    NaN
# 1679603                                0                    NaN
# 1182054                                0                    NaN
# 1808096                                0                      1
# 805562                                 0                    NaN
# 505590                                 0                      1
# 513674                                 0                    NaN
#
#         F9_06_PC_OWN_WEBSITE F9_06_PC_POLICIES_GOVERN_CHAPTER  \
# 1179867                  NaN                              NaN
# 643125                   NaN                              NaN
# 894438                   NaN                              NaN
# 1886060                  NaN                              NaN
# 1679603                  NaN                              NaN
# 1182054                  NaN                              NaN
# 1808096                    1                              NaN
# 805562                   NaN                              NaN
# 505590                   NaN                              NaN
# 513674                   NaN                                1
#
#         F9_06_PC_WHISTLEBLOWER_POLICY F9_07_PC_COMPENSATION_OTHER_SRCE  \
# 1179867                             0                                0
# 643125                              0                                0
# 894438                              0                                0
# 1886060                             0                                0
# 1679603                             1                                0
# 1182054                             0                                0
# 1808096                             1                                0
# 805562                              1                                0
# 505590                              0                                0
# 513674                              1                                0
#
#         F9_07_PC_FORMER_OFFICER_LISTED F9_07_PC_NO_LISTED_PERS_COMPENSD  \
# 1179867                              1                              NaN
# 643125                               0                              NaN
# 894438                               0                              NaN
# 1886060                              0                                1
# 1679603                              0                              NaN
# 1182054                              0                              NaN
# 1808096                              0                              NaN
# 805562                               0                                1
# 505590                               0                                1
# 513674                               0                              NaN
#
#         F9_07_PC_TOTAL_COMP_GRTR_150K F9_10_PC_ORG_FOLLOWS_SFAS117  \
# 1179867                             0                            1
# 643125                              0                            1
# 894438                              0                            1
# 1886060                             0                            1
# 1679603                             0                            1
# 1182054                             0                            1
# 1808096                             0                          NaN
# 805562                              0                            1
# 505590                              0                          NaN
# 513674                              0                            1
#
#         F9_10_PC_ORG_NOT_FOLLOW_SFAS117 F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 1179867                             NaN                                0
# 643125                              NaN                                0
# 894438                              NaN                                0
# 1886060                             NaN                                0
# 1679603                             NaN                                0
# 1182054                             NaN                                0
# 1808096                             NaN                                0
# 805562                              NaN                                1
# 505590                                1                                0
# 513674                              NaN                                0
#
#         F9_12_PC_ACCTG_METHOD_ACCRUAL F9_12_PC_ACCTG_METHOD_CASH  \
# 1179867                           NaN                          1
# 643125                              1                        NaN
# 894438                            NaN                          1
# 1886060                             1                        NaN
# 1679603                             1                        NaN
# 1182054                           NaN                          1
# 1808096                           NaN                          1
# 805562                              1                        NaN
# 505590                              1                        NaN
# 513674                              1                        NaN
#
#         F9_12_PC_AUDIT_COMMITTEE F9_12_PC_FED_GRNT_AUDIT_PERFORMD  \
# 1179867                      NaN                              NaN
# 643125                         1                                1
# 894438                       NaN                              NaN
# 1886060                      NaN                              NaN
# 1679603                        0                              NaN
# 1182054                      NaN                              NaN
# 1808096                      NaN                              NaN
# 805562                         1                              NaN
# 505590                       NaN                              NaN
# 513674                       NaN                              NaN
#
#         F9_12_PC_FED_GRNT_AUDIT_REQUIRED F9_12_PC_FINCL_STMTS_AUDITED
# 1179867                                0                            0
# 643125                                 1                            1
# 894438                                 0                            0
# 1886060                                0                            0
# 1679603                                0                            1
# 1182054                                0                            0
# 1808096                                0                            0
# 805562                                 0                            0
# 505590                                 0                            0
# 513674                                 0                            0

# %% [markdown]
# ### Check that total number of values in new variable equal sum of prior 2 variables

# %%
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    #print(row['variable_name_new'])
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    print(len(df[df[row['original_names'][0]].notnull()]) + len(df[df[row['original_names'][1]].notnull()]))    
    print(len(df[df[row['variable_name_new']].notnull()]), '\n')
    #print(len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n')
# Out:
# F9_00_HD_ADDR_CHANGE AddressChange AddressChangeInd
# 74526
# 74526
#
# F9_00_HD_AMENDED_RETURN AmendedReturn AmendedReturnInd
# 16642
# 16642
#
# F9_00_HD_CTRY_OF_DOMICILE CountryLegalDomicile LegalDomicileCountryCd
# 1021
# 1021
#
# F9_00_HD_EXEMPT_STATUS_4847A1 Organization4947a1NotPFInd Organization4947a1
# 1514
# 1514
#
# F9_00_HD_EXEMPT_STATUS_501C Organization501cInd Organization501c
# 486371
# 486371
#
# F9_00_HD_EXEMPT_STATUS_501C3 Organization501c3 Organization501c3Ind
# 1407131
# 1407131
#
# F9_00_HD_FINAL_RETURN FinalReturnInd TerminatedReturn
# 10123
# 10123
#
# F9_00_HD_GROSS_EXEMPT_NUM GroupExemptionNum GroupExemptionNumber
# 65491
# 65491
#
# F9_00_HD_GROSS_RCPT GrossReceiptsAmt GrossReceipts
# 1895016
# 1895016
#
# F9_00_HD_GROUP_RETURN GroupReturnForAffiliates GroupReturnForAffiliatesInd
# 1895016
# 1895016
#
# F9_00_HD_INCLUDES_SUBORD_ORGS AllAffiliatesIncluded AllAffiliatesIncludedInd
# 297904
# 297904
#
# F9_00_HD_INITIAL_RETURN InitialReturn InitialReturnInd
# 18113
# 18113
#
# F9_00_HD_PRIN_OFF_NAME PrincipalOfficerNm NameOfPrincipalOfficerPerson
# 1591259
# 1591259
#
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# 1895016
# 1895016
#
# F9_00_HD_SPECIAL_CONDITION_DESC SpecialConditionDesc SpecialConditionDescription
# 801
# 801
#
# F9_00_HD_STATE_OF_DOMICILE LegalDomicileStateCd StateLegalDomicile
# 1787678
# 1787678
#
# F9_00_HD_TAX_PER_END TaxPeriodEndDate TaxPeriodEndDt
# 1895016
# 1895016
#
# F9_00_HD_TAX_YEAR TaxYr TaxYear
# 1895016
# 1895016
#
# F9_00_HD_TIME_STAMP ReturnTs Timestamp
# 1895016
# 1895016
#
# F9_00_HD_TYPE_ORG_ASSOCIATION TypeOfOrganizationAssocInd TypeOfOrganizationAssociation
# 83569
# 83569
#
# F9_00_HD_TYPE_ORG_CORP TypeOfOrganizationCorpInd TypeOfOrganizationCorporation
# 1666981
# 1666981
#
# F9_00_HD_TYPE_ORG_OTHER TypeOfOrganizationOther TypeOfOrganizationOtherInd
# 45946
# 45946
#
# F9_00_HD_TYPE_ORG_OTHER_DESC TypeOfOrgOtherDescription OtherOrganizationDsc
# 34088
# 34088
#
# F9_00_HD_TYPE_ORG_TRUST TypeOfOrganizationTrustInd TypeOfOrganizationTrust
# 60917
# 60917
#
# F9_00_HD_WEBSITE WebSite WebsiteAddressTxt
# 1697924
# 1697924
#
# F9_00_HD_YEAR_FORMED FormationYr YearFormation
# 1747938
# 1747938
#
# F9_01_PC_BEN_PAID_MEMB_PRIOR PYBenefitsPaidToMembersAmt BenefitsPaidToMembersPriorYear
# 881997
# 881997
#
# F9_01_PC_CONTR_GRANTS_CURR CYContributionsGrantsAmt ContributionsGrantsCurrentYear
# 1895016
# 1895016
#
# F9_01_PC_CONTR_GRANTS_PRIOR PYContributionsGrantsAmt ContributionsGrantsPriorYear
# 1636002
# 1636002
#
# F9_01_PC_GRANTS_PRIOR PYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsPriorYear
# 1077233
# 1077233
#
# F9_01_PC_INDEP_VOTING_MEMB VotingMembersIndependentCnt NbrIndependentVotingMembers
# 1895016
# 1895016
#
# F9_01_PC_INVEST_INCOME_PRIOR InvestmentIncomePriorYear PYInvestmentIncomeAmt
# 1594890
# 1594890
#
# F9_01_PC_NET_ASSETS_BOY NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesBOY
# 1871194
# 1871194
#
# F9_01_PC_OTHER_EXPENSE_PRIOR OtherExpensePriorYear PYOtherExpensesAmt
# 1828459
# 1828459
#
# F9_01_PC_OTHER_REV_PRIOR PYOtherRevenueAmt OtherRevenuePriorYear
# 1425060
# 1425060
#
# F9_01_PC_PROF_FUNDRISING_EXP_CURR CYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpCY
# 1895016
# 1895016
#
# F9_01_PC_PROF_FUNDRISING_EXP_PRIOR PYTotalProfFndrsngExpnsAmt TotalProfFundrsngExpPriorYear
# 867879
# 867879
#
# F9_01_PC_PROG_SERVICE_REV_PRIOR PYProgramServiceRevenueAmt ProgramServiceRevenuePriorYear
# 1498797
# 1498797
#
# F9_01_PC_REV_LESS_EXP_CURR CYRevenuesLessExpensesAmt RevenuesLessExpensesCY
# 1895016
# 1895016
#
# F9_01_PC_REV_LESS_EXP_PRIOR RevenuesLessExpensesPriorYear PYRevenuesLessExpensesAmt
# 1836077
# 1836077
#
# F9_01_PC_TERMINATION_CONTRACTION ContractTerminationInd TerminationOrContraction
# 13530
# 13530
#
# F9_01_PC_TOT_ASSETS_EOY TotalAssetsEOYAmt TotalAssetsEOY
# 1895016
# 1895016
#
# F9_01_PC_TOT_EXP_PRIOR TotalExpensesPriorYear PYTotalExpensesAmt
# 1834415
# 1834415
#
# F9_01_PC_TOT_FNDR_EXP_CURR CYTotalFundraisingExpenseAmt TotalFundrsngExpCurrentYear
# 1895016
# 1895016
#
# F9_01_PC_TOT_INDIV_EMPLOYED TotalNbrEmployees TotalEmployeeCnt
# 1895016
# 1895016
#
# F9_01_PC_TOT_INDIV_VOLUNTEERS TotalVolunteersCnt TotalNbrVolunteers
# 1394860
# 1394860
#
# F9_01_PC_TOT_LIABILITIES_EOY TotalLiabilitiesEOYAmt TotalLiabilitiesEOY
# 1895016
# 1895016
#
# F9_01_PC_TOT_REVENUE_PRIOR TotalRevenuePriorYear PYTotalRevenueAmt
# 1838139
# 1838139
#
# F9_01_PC_TOT_UBI_GROSS TotalGrossUBIAmt TotalGrossUBI
# 1895016
# 1895016
#
# F9_01_PC_TOT_UBI_NET NetUnrelatedBusTxblIncmAmt NetUnrelatedBusinessTxblIncome
# 1005664
# 1005664
#
# F9_01_PC_VOTING_MEMB_GOV_BODY NbrVotingMembersGoverningBody VotingMembersGoverningBodyCnt
# 1895016
# 1895016
#
# F9_01_PZ_BEN_PAID_TO_MEMB_CURR CYBenefitsPaidToMembersAmt BenefitsPaidToMembersCY
# 1895016
# 1895016
#
# F9_01_PZ_GRANTS_PAID_CURR CYGrantsAndSimilarPaidAmt GrantsAndSimilarAmntsCY
# 1895016
# 1895016
#
# F9_01_PZ_INVEST_INCOME_CURR CYInvestmentIncomeAmt InvestmentIncomeCurrentYear
# 1895016
# 1895016
#
# F9_01_PZ_NAFB_EOY NetAssetsOrFundBalancesEOYAmt NetAssetsOrFundBalancesEOY
# 1895016
# 1895016
#
# F9_01_PZ_ORGANIZATIONAL_MISSION ActivityOrMissionDescription ActivityOrMissionDesc
# 1895016
# 1895016
#
# F9_01_PZ_OTHER_EXPENSE_CURR OtherExpensesCurrentYear CYOtherExpensesAmt
# 1895016
# 1895016
#
# F9_01_PZ_OTHER_REV_CURR CYOtherRevenueAmt OtherRevenueCurrentYear
# 1895016
# 1895016
#
# F9_01_PZ_PROG_SERVICE_REV_CURR CYProgramServiceRevenueAmt ProgramServiceRevenueCY
# 1895016
# 1895016
#
# F9_01_PZ_SALARIES_CURR CYSalariesCompEmpBnftPaidAmt SalariesEtcCurrentYear
# 1895016
# 1895016
#
# F9_01_PZ_SALARIES_PRIOR SalariesEtcPriorYear PYSalariesCompEmpBnftPaidAmt
# 1529943
# 1529943
#
# F9_01_PZ_TOT_ASSETS_BOY TotalAssetsBOYAmt TotalAssetsBOY
# 1873181
# 1873181
#
# F9_01_PZ_TOT_EXP_CURR CYTotalExpensesAmt TotalExpensesCurrentYear
# 1895016
# 1895016
#
# F9_01_PZ_TOT_LIAB_BOY TotalLiabilitiesBOY TotalLiabilitiesBOYAmt
# 1608706
# 1608706
#
# F9_01_PZ_TOT_REV_CURR TotalRevenueCurrentYear CYTotalRevenueAmt
# 1895016
# 1895016
#
# F9_04_PC_FR_EVENT_INC_GT_15K FundraisingActivities FundraisingActivitiesInd
# 1895016
# 1895016
#
# F9_04_PC_GAMING_INC_GT_15K Gaming GamingActivitiesInd
# 1895016
# 1895016
#
# F9_04_PC_PROF_FR_EXP_GT_15K ProfessionalFundraisingInd ProfessionalFundraising
# 1895016
# 1895016
#
# F9_06_PC_990_PROVIDED_GOV_BODY Form990ProvidedToGvrnBodyInd Form990ProvidedToGoverningBody
# 1895016
# 1895016
#
# F9_06_PC_ANNUAL_DISC_COVRD_PERS AnnualDisclosureCoveredPersons AnnualDisclosureCoveredPrsnInd
# 1326268
# 1326268
#
# F9_06_PC_CEO_COMPENSTN_PROCESS CompensationProcessCEOInd CompensationProcessCEO
# 1884238
# 1884238
#
# F9_06_PC_CHANGES_ORGANIZING_DOCS ChangesToOrganizingDocs ChangeToOrgDocumentsInd
# 1895016
# 1895016
#
# F9_06_PC_CONFLICT_OF_INTEREST ConflictOfInterestPolicy ConflictOfInterestPolicyInd
# 1895016
# 1895016
#
# F9_06_PC_DECISIONS_SUBJ_APPROVAL DecisionsSubjectToApprovaInd DecisionsSubjectToApproval
# 1895016
# 1895016
#
# F9_06_PC_DELEGATION_MGT_DUTIES DelegationOfManagementDuties DelegationOfMgmtDutiesInd
# 1895016
# 1895016
#
# F9_06_PC_DELEGATION_OF_MGT DelegationOfManagementDuties DelegationOfMgmtDutiesInd
# 1895016
# 1895016
#
# F9_06_PC_DOCUMENT_RET_POLICY DocumentRetentionPolicy DocumentRetentionPolicyInd
# 1895016
# 1895016
#
# F9_06_PC_ELECTION_BOARD_MEMBERS ElectionOfBoardMembersInd ElectionOfBoardMembers
# 1895016
# 1895016
#
# F9_06_PC_FAMILY_OR_BUSINESS_REL FamilyOrBusinessRelationship FamilyOrBusinessRlnInd
# 1895016
# 1895016
#
# F9_06_PC_FORM_AVAIL_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# 117868
# 117868
#
# F9_06_PC_FORM_UPON_REQUEST UponRequest UponRequestInd
# 1725127
# 1725127
#
# F9_06_PC_JOINT_VENTURE_INVESTMNT InvestmentInJointVentureInd InvestmentInJointVenture
# 1895016
# 1895016
#
# F9_06_PC_JOINT_VENTURE_POLICY WrittenPolicyOrProcedure WrittenPolicyOrProcedureInd
# 99890
# 99890
#
# F9_06_PC_LOCAL_CHAPTERS LocalChaptersInd LocalChapters
# 1895016
# 1895016
#
# F9_06_PC_MATERIAL_DIVERSION MaterialDiversionOrMisuseInd MaterialDiversionOrMisuse
# 1895016
# 1895016
#
# F9_06_PC_MEMBERS_OR_STOCKHOLDERS MembersOrStockholders MembersOrStockholdersInd
# 1895016
# 1895016
#
# F9_06_PC_MINUTES_COMMITTEES MinutesOfCommittees MinutesOfCommitteesInd
# 1888476
# 1888476
#
# F9_06_PC_MINUTES_GOVERNING_BODY MinutesOfGoverningBodyInd MinutesOfGoverningBody
# 1895016
# 1895016
#
# F9_06_PC_MONITORING_OF_COI_POLICY RegularMonitoringEnfrcInd RegularMonitoringEnforcement
# 1325335
# 1325335
#
# F9_06_PC_NUM_IND_VOTING_MEMBERS NumberIndependentVotingMembers IndependentVotingMemberCnt
# 1895016
# 1895016
#
# F9_06_PC_NUM_VOTING_GOV_MEMBERS GoverningBodyVotingMembersCnt NbrVotingGoverningBodyMembers
# 1895016
# 1895016
#
# F9_06_PC_OFFICER_MAILING_ADDRESS OfficerMailingAddressInd OfficerMailingAddress
# 1895016
# 1895016
#
# F9_06_PC_OTHER_COMPENSTN_PROCESS CompensationProcessOther CompensationProcessOtherInd
# 1882164
# 1882164
#
# F9_06_PC_OTHER_WEBSITE OtherWebsite OtherWebsiteInd
# 251612
# 251612
#
# F9_06_PC_OWN_WEBSITE OwnWebsiteInd OwnWebsite
# 117868
# 117868
#
# F9_06_PC_POLICIES_GOVERN_CHAPTER PoliciesReferenceChaptersInd PoliciesReferenceChapters
# 150852
# 150852
#
# F9_06_PC_STATES_WHERE_RET_FILED StatesWhereCopyOfReturnIsFiled StatesWhereCopyOfReturnIsFldCd
# 967132
# 967132
#
# F9_06_PC_WHISTLEBLOWER_POLICY WhistleblowerPolicy WhistleblowerPolicyInd
# 1895016
# 1895016
#
# F9_07_PC_COMPENSATION_OTHER_SRCE CompensationFromOtherSources CompensationFromOtherSrcsInd
# 1895016
# 1895016
#
# F9_07_PC_FORMER_OFFICER_LISTED FormerOfcrEmployeesListedInd FormersListed
# 1895016
# 1895016
#
# F9_07_PC_NO_LISTED_PERS_COMPENSD NoListedPersonsCompensated NoListedPersonsCompensatedInd
# 805206
# 805206
#
# F9_07_PC_NUM_CONTRCTRS_GRTR_100K NumberOfContractorsGT100K CntrctRcvdGreaterThan100KCnt
# 1190581
# 1190581
#
# F9_07_PC_NUM_INDS_GREATER_100K NumberIndividualsGT100K IndivRcvdGreaterThan100KCnt
# 1343113
# 1343113
#
# F9_07_PC_TOTAL_COMP_GRTR_150K TotalCompGT150K TotalCompGreaterThan150KInd
# 1895016
# 1895016
#
# F9_07_PC_TOT_OTHER_COMPENSATION TotalOtherCompensation TotalOtherCompensationAmt
# 1155231
# 1155231
#
# F9_07_PC_TOT_REPRT_COMP_FROM_ORG TotalReportableCompFromOrgAmt TotalReportableCompFromOrg
# 1417627
# 1417627
#
# F9_07_PC_TOT_REPRT_COMP_RLTD_ORG TotReportableCompRltdOrgAmt TotalReportableCompFrmRltdOrgs
# 1049376
# 1049376
#
# F9_08_PC_ALL_OTHER_CONTRIBUTIONS AllOtherContributions AllOtherContributionsAmt
# 1252275
# 1252275
#
# F9_08_PC_CONTS_REPRTD_FNDRAISNG CntrbtnsRprtdFundraisingEvents ContriRptFundraisingEventAmt
# 315209
# 315209
#
# F9_08_PC_COST_OF_GOODS_SOLD CostOfGoodsSoldAmt CostOfGoodsSold
# 258222
# 258222
#
# F9_08_PC_FEDERATED_CAMPAIGNS FederatedCampaignsAmt FederatedCampaigns
# 127613
# 127613
#
# F9_08_PC_FUNDRAISING_DIRECT_EXP FundraisingDirectExpenses FundraisingDirectExpensesAmt
# 517853
# 517853
#
# F9_08_PC_FUNDRAISING_EVENTS FundraisingEvents FundraisingAmt
# 333970
# 333970
#
# F9_08_PC_FUNDRAISING_GROSS_INC GrossIncomeFundraisingEvents FundraisingGrossIncomeAmt
# 538184
# 538184
#
# F9_08_PC_GAMING_DIRECT_EXPENSES GamingDirectExpenses GamingDirectExpensesAmt
# 105402
# 105402
#
# F9_08_PC_GAMING_GROSS_INCOME GamingGrossIncomeAmt GrossIncomeGaming
# 110711
# 110711
#
# F9_08_PC_GOVERNMENT_GRANTS GovernmentGrants GovernmentGrantsAmt
# 526124
# 526124
#
# F9_08_PC_GROSS_SALES_INVENTORY GrossSalesOfInventoryAmt GrossSalesOfInventory
# 272555
# 272555
#
# F9_08_PC_MEMBERSHIP_DUES MembershipDuesAmt MembershipDues
# 332392
# 332392
#
# F9_08_PC_NONCASH_CONTRIBUTIONS NoncashContributions NoncashContributionsAmt
# 310269
# 310269
#
# F9_08_PC_PROGRAM_SVCE_REV_TOTAL TotalProgramServiceRevenue TotalProgramServiceRevenueAmt
# 1417558
# 1417558
#
# F9_08_PC_RELATED_ORGANIZATIONS RelatedOrganizationsAmt RelatedOrganizations
# 126705
# 126705
#
# F9_08_PC_TOTAL_CONTRIBUTIONS TotalContributionsAmt TotalContributions
# 1573627
# 1573627
#
# F9_08_PC_TOTAL_OTHER_REVENUE TotalOtherRevenue OtherRevenueTotalAmt
# 999485
# 999485
#
# F9_08_PC_TOTAL_PROG_SVCE_REVENUE TotalProgramServiceRevenue TotalProgramServiceRevenueAmt
# 1417558
# 1417558
#
# F9_08_PC_TOTAL_REVENUE TotalRevenueGrp TotalRevenue
# 1895016
# 1895016
#
# F9_09_PC_COMP_DISQUAL_FUNDRAISE CompDisqualPersonsGrp CompDisqualPersons
# 494846
# 494846
#
# F9_09_PC_COMP_DISQUAL_MGMT CompDisqualPersonsGrp CompDisqualPersons
# 494846
# 494846
#
# F9_09_PC_COMP_DISQUAL_PROG_SVCE CompDisqualPersonsGrp CompDisqualPersons
# 494846
# 494846
#
# F9_09_PC_COMP_DISQUAL_TOTAL CompDisqualPersonsGrp CompDisqualPersons
# 494846
# 494846
#
# F9_09_PC_COMP_OFFICERS_FUNDRAISE CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 1116541
# 1116541
#
# F9_09_PC_COMP_OFFICERS_MGMT CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 1116541
# 1116541
#
# F9_09_PC_COMP_OFFICERS_PROG_SVCE CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 1116541
# 1116541
#
# F9_09_PC_COMP_OFFICERS_TOTAL CompCurrentOfficersDirectors CompCurrentOfcrDirectorsGrp
# 1116541
# 1116541
#
# F9_09_PC_FEES_FOR_SVCE_ACCT_TOT FeesForServicesAccounting FeesForServicesAccountingGrp
# 1552649
# 1552649
#
# F9_09_PC_FEES_FOR_SVCE_INVST_TOT FeesForSrvcInvstMgmntFeesGrp FeesForServicesInvstMgmntFees
# 638630
# 638630
#
# F9_09_PC_FEES_FOR_SVCE_LEGL_TOT FeesForServicesLegalGrp FeesForServicesLegal
# 933536
# 933536
#
# F9_09_PC_FEES_FOR_SVCE_LOBB_TOT FeesForServicesLobbyingGrp FeesForServicesLobbying
# 503239
# 503239
#
# F9_09_PC_FEES_FOR_SVCE_MGMT_TOT FeesForServicesManagement FeesForServicesManagementGrp
# 666943
# 666943
#
# F9_09_PC_FEES_FOR_SVCE_OTH_TOT FeesForServicesOtherGrp FeesForServicesOther
# 1125576
# 1125576
#
# F9_09_PC_OTHER_EMP_BEN_FUNDRAISE OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 1100934
# 1100934
#
# F9_09_PC_OTHER_EMP_BEN_MGMT OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 1100934
# 1100934
#
# F9_09_PC_OTHER_EMP_BEN_PROG_SVCE OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 1100934
# 1100934
#
# F9_09_PC_OTHER_EMP_BEN_TOTAL OtherEmployeeBenefitsGrp OtherEmployeeBenefits
# 1100934
# 1100934
#
# F9_09_PC_OTHER_SALARY_FUNDRAISE OtherSalariesAndWagesGrp OtherSalariesAndWages
# 1356492
# 1356492
#
# F9_09_PC_OTHER_SALARY_MGMT OtherSalariesAndWagesGrp OtherSalariesAndWages
# 1356492
# 1356492
#
# F9_09_PC_OTHER_SALARY_PROG_SVCE OtherSalariesAndWagesGrp OtherSalariesAndWages
# 1356492
# 1356492
#
# F9_09_PC_OTHER_SALARY_TOTAL OtherSalariesAndWagesGrp OtherSalariesAndWages
# 1356492
# 1356492
#
# F9_09_PC_PAYROLL_TAX_FUNDRAISE PayrollTaxes PayrollTaxesGrp
# 1340164
# 1340164
#
# F9_09_PC_PAYROLL_TAX_MGMT PayrollTaxes PayrollTaxesGrp
# 1340164
# 1340164
#
# F9_09_PC_PAYROLL_TAX_PROG_SVCE PayrollTaxes PayrollTaxesGrp
# 1340164
# 1340164
#
# F9_09_PC_PAYROLL_TAX_TOTAL PayrollTaxes PayrollTaxesGrp
# 1340164
# 1340164
#
# F9_09_PC_PENSION_CONT_FUNDRAISE PensionPlanContributionsGrp PensionPlanContributions
# 815166
# 815166
#
# F9_09_PC_PENSION_CONT_MGMT PensionPlanContributionsGrp PensionPlanContributions
# 815166
# 815166
#
# F9_09_PC_PENSION_CONT_PROG_SVCE PensionPlanContributionsGrp PensionPlanContributions
# 815166
# 815166
#
# F9_09_PC_PENSION_CONT_TOTAL PensionPlanContributionsGrp PensionPlanContributions
# 815166
# 815166
#
# F9_09_PC_TOTAL_FUNC_EXPENSES TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 1895016
# 1895016
#
# F9_09_PC_TOTAL_FUNDRAISE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 1895016
# 1895016
#
# F9_09_PC_TOTAL_MGMT_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 1895016
# 1895016
#
# F9_09_PC_TOTAL_PROG_SVCE_EXPENSE TotalFunctionalExpenses TotalFunctionalExpensesGrp
# 1895016
# 1895016
#
# F9_10_PC_BOND_LIABILITIES_EOY TaxExemptBondLiabilities TaxExemptBondLiabilitiesGrp
# 139363
# 139363
#
# F9_10_PC_CASH_NON_INTEREST_BOY CashNonInterestBearing CashNonInterestBearingGrp
# 1737673
# 1737673
#
# F9_10_PC_CASH_NON_INTEREST_EOY CashNonInterestBearing CashNonInterestBearingGrp
# 1737673
# 1737673
#
# F9_10_PC_LAND_BLDG_EQPMT LandBldgEquipCostOrOtherBssAmt LandBuildingsEquipmentBasis
# 1404101
# 1404101
#
# F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN LandBldgEquipAccumDeprecAmt LandBldgEquipmentAccumDeprec
# 1345960
# 1345960
#
# F9_10_PC_LOANS_FROM_OFFICERS_EOY LoansFromOfficersDirectors LoansFromOfficersDirectorsGrp
# 144698
# 144698
#
# F9_10_PC_ORG_FOLLOWS_SFAS117 OrganizationFollowsSFAS117Ind FollowSFAS117
# 1427754
# 1427754
#
# F9_10_PC_ORG_NOT_FOLLOW_SFAS117 DoNotFollowSFAS117 OrgDoesNotFollowSFAS117Ind
# 426692
# 426692
#
# F9_10_PC_OTHER_LIABILITIES_EOY OtherLiabilities OtherLiabilitiesGrp
# 831722
# 831722
#
# F9_10_PC_RET_EARNINGS_ENDWMT_EOY RtnEarnEndowmentIncmOthFndsGrp RetainedEarningsEndowmentEtc
# 416947
# 416947
#
# F9_10_PC_SAVINGS_TEMP_INVEST_BOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# 1267553
# 1267553
#
# F9_10_PC_SAVINGS_TEMP_INVEST_EOY SavingsAndTempCashInvestments SavingsAndTempCashInvstGrp
# 1267553
# 1267553
#
# F9_10_PC_SECURED_MORTGAGES_EOY MortNotesPyblSecuredInvestProp MortgNotesPyblScrdInvstPropGrp
# 496096
# 496096
#
# F9_10_PC_UNSECURED_NOTES_BOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# 199633
# 199633
#
# F9_10_PC_UNSECURED_NOTES_EOY UnsecuredNotesLoansPayable UnsecuredNotesLoansPayableGrp
# 199633
# 199633
#
# F9_10_PZ_TOTAL_ASSETS_EOY TotalAssets TotalAssetsGrp
# 1895016
# 1895016
#
# F9_11_PC_RECNCLTN_DONATED_SVCES DonatedServicesAndUseFcltsAmt ReconcilationDonatedServices
# 51256
# 51256
#
# F9_11_PC_RECNCLTN_INVSTMNT_EXP ReconcilationInvestExpenses InvestmentExpenseAmt
# 40632
# 40632
#
# F9_11_PC_RECNCLTN_PRIOR_PER_ADJ ReconcilationPriorAdjustment PriorPeriodAdjustmentsAmt
# 141358
# 141358
#
# F9_11_PC_RECNCLTN_REV_LESS_EXP ReconcilationRevenueExpnssAmt ReconcilationRevenueExpenses
# 1861706
# 1861706
#
# F9_11_PC_RECNCLTN_UNRLZD_GAIN ReconciliationUnrealizedInvest NetUnrlzdGainsLossesInvstAmt
# 401729
# 401729
#
# F9_12_PC_ACCNT_COMPILE_OR_REVIEW AccountantCompileOrReview AccountantCompileOrReviewInd
# 1895016
# 1895016
#
# F9_12_PC_ACCTG_METHOD_ACCRUAL MethodOfAccountingAccrualInd MethodOfAccountingAccrual
# 1263945
# 1263945
#
# F9_12_PC_ACCTG_METHOD_CASH MethodOfAccountingCash MethodOfAccountingCashInd
# 591946
# 591946
#
# F9_12_PC_ACCTG_METHOD_OTHER MethodOfAccountingOtherInd MethodOfAccountingOther
# 39125
# 39125
#
# F9_12_PC_AUDIT_COMMITTEE AuditCommittee AuditCommitteeInd
# 1123853
# 1123853
#
# F9_12_PC_FED_GRNT_AUDIT_PERFORMD FederalGrantAuditPerformedInd FederalGrantAuditPerformed
# 234488
# 234488
#
# F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd FederalGrantAuditRequired
# 1718321
# 1718321
#
# F9_12_PC_FINCL_STMTS_AUDITED FSAudited FSAuditedInd
# 1895016
# 1895016

# %% [markdown]
# <br><br>
# From the above we are fine with deleting the 138 variables related to the 69 above variables in *variable_name_new* (numbers from earlier version of notebook).

# %% [markdown]
# ### Inspect the Combined and Original Variables
# Here I'm showing one variable

# %%
df[df['F9_12_PC_FED_GRNT_AUDIT_REQUIRED'].notnull()].sample(5)[['F9_12_PC_FED_GRNT_AUDIT_REQUIRED', 'FederalGrantAuditRequiredInd', 'FederalGrantAuditRequired']]
# Out:
#         F9_12_PC_FED_GRNT_AUDIT_REQUIRED FederalGrantAuditRequiredInd  \
# 1781328                                0                        false
# 1449422                                0                        false
# 1781643                                0                        false
# 1518949                                0                            0
# 1850438                                0                        false
#
#         FederalGrantAuditRequired
# 1781328                       NaN
# 1449422                       NaN
# 1781643                       NaN
# 1518949                       NaN
# 1850438                       NaN

# %% [markdown]
# ### Drop variables

# %%
new_variables_df['original_names'].tolist()
# Out:
# [['AddressChange', 'AddressChangeInd'],
#  ['AmendedReturn', 'AmendedReturnInd'],
#  ['BuildTS'],
#  ['CountryLegalDomicile', 'LegalDomicileCountryCd'],
#  ['Organization4947a1NotPFInd', 'Organization4947a1'],
#  ['Organization501cInd', 'Organization501c'],
#  ['Organization501c3', 'Organization501c3Ind'],
#  ['Filer'],
#  ['FinalReturnInd', 'TerminatedReturn'],
#  ['GroupExemptionNum', 'GroupExemptionNumber'],
#  ['GrossReceiptsAmt', 'GrossReceipts'],
#  ['GroupReturnForAffiliates', 'GroupReturnForAffiliatesInd'],
#  ['AllAffiliatesIncluded', 'AllAffiliatesIncludedInd'],
#  ['InitialReturn', 'InitialReturnInd'],
#  ['PrincipalOfficerNm', 'NameOfPrincipalOfficerPerson'],
#  ['BusinessOfficerGrp', 'Officer'],
#  ['SpecialConditionDesc', 'SpecialConditionDescription'],
#  ['LegalDomicileStateCd', 'StateLegalDomicile'],
#  ['TaxPeriodEndDate', 'TaxPeriodEndDt'],
#  ['TaxYr', 'TaxYear'],
#  ['ReturnTs', 'Timestamp'],
#  ['TypeOfOrganizationAssocInd', 'TypeOfOrganizationAssociation'],
#  ['TypeOfOrganizationCorpInd', 'TypeOfOrganizationCorporation'],
#  ['TypeOfOrganizationOther', 'TypeOfOrganizationOtherInd'],
#  ['TypeOfOrgOtherDescription', 'OtherOrganizationDsc'],
#  ['TypeOfOrganizationTrustInd', 'TypeOfOrganizationTrust'],
#  ['WebSite', 'WebsiteAddressTxt'],
#  ['FormationYr', 'YearFormation'],
#  ['PYBenefitsPaidToMembersAmt', 'BenefitsPaidToMembersPriorYear'],
#  ['CYContributionsGrantsAmt', 'ContributionsGrantsCurrentYear'],
#  ['PYContributionsGrantsAmt', 'ContributionsGrantsPriorYear'],
#  ['PYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsPriorYear'],
#  ['VotingMembersIndependentCnt', 'NbrIndependentVotingMembers'],
#  ['InvestmentIncomePriorYear', 'PYInvestmentIncomeAmt'],
#  ['NetAssetsOrFundBalancesBOYAmt', 'NetAssetsOrFundBalancesBOY'],
#  ['OtherExpensePriorYear', 'PYOtherExpensesAmt'],
#  ['PYOtherRevenueAmt', 'OtherRevenuePriorYear'],
#  ['CYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpCY'],
#  ['PYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpPriorYear'],
#  ['PYProgramServiceRevenueAmt', 'ProgramServiceRevenuePriorYear'],
#  ['CYRevenuesLessExpensesAmt', 'RevenuesLessExpensesCY'],
#  ['RevenuesLessExpensesPriorYear', 'PYRevenuesLessExpensesAmt'],
#  ['ContractTerminationInd', 'TerminationOrContraction'],
#  ['TotalAssetsEOYAmt', 'TotalAssetsEOY'],
#  ['TotalExpensesPriorYear', 'PYTotalExpensesAmt'],
#  ['CYTotalFundraisingExpenseAmt', 'TotalFundrsngExpCurrentYear'],
#  ['TotalNbrEmployees', 'TotalEmployeeCnt'],
#  ['TotalVolunteersCnt', 'TotalNbrVolunteers'],
#  ['TotalLiabilitiesEOYAmt', 'TotalLiabilitiesEOY'],
#  ['TotalRevenuePriorYear', 'PYTotalRevenueAmt'],
#  ['TotalGrossUBIAmt', 'TotalGrossUBI'],
#  ['NetUnrelatedBusTxblIncmAmt', 'NetUnrelatedBusinessTxblIncome'],
#  ['NbrVotingMembersGoverningBody', 'VotingMembersGoverningBodyCnt'],
#  ['CYBenefitsPaidToMembersAmt', 'BenefitsPaidToMembersCY'],
#  ['CYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsCY'],
#  ['CYInvestmentIncomeAmt', 'InvestmentIncomeCurrentYear'],
#  ['NetAssetsOrFundBalancesEOYAmt', 'NetAssetsOrFundBalancesEOY'],
#  ['ActivityOrMissionDescription', 'ActivityOrMissionDesc'],
#  ['OtherExpensesCurrentYear', 'CYOtherExpensesAmt'],
#  ['CYOtherRevenueAmt', 'OtherRevenueCurrentYear'],
#  ['CYProgramServiceRevenueAmt', 'ProgramServiceRevenueCY'],
#  ['CYSalariesCompEmpBnftPaidAmt', 'SalariesEtcCurrentYear'],
#  ['SalariesEtcPriorYear', 'PYSalariesCompEmpBnftPaidAmt'],
#  ['TotalAssetsBOYAmt', 'TotalAssetsBOY'],
#  ['CYTotalExpensesAmt', 'TotalExpensesCurrentYear'],
#  ['TotalLiabilitiesBOY', 'TotalLiabilitiesBOYAmt'],
#  ['TotalRevenueCurrentYear', 'CYTotalRevenueAmt'],
#  ['FundraisingActivities', 'FundraisingActivitiesInd'],
#  ['Gaming', 'GamingActivitiesInd'],
#  ['ProfessionalFundraisingInd', 'ProfessionalFundraising'],
#  ['Form990ProvidedToGvrnBodyInd', 'Form990ProvidedToGoverningBody'],
#  ['AnnualDisclosureCoveredPersons', 'AnnualDisclosureCoveredPrsnInd'],
#  ['CompensationProcessCEOInd', 'CompensationProcessCEO'],
#  ['ChangesToOrganizingDocs', 'ChangeToOrgDocumentsInd'],
#  ['ConflictOfInterestPolicy', 'ConflictOfInterestPolicyInd'],
#  ['DecisionsSubjectToApprovaInd', 'DecisionsSubjectToApproval'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DocumentRetentionPolicy', 'DocumentRetentionPolicyInd'],
#  ['ElectionOfBoardMembersInd', 'ElectionOfBoardMembers'],
#  ['FamilyOrBusinessRelationship', 'FamilyOrBusinessRlnInd'],
#  ['OwnWebsiteInd', 'OwnWebsite'],
#  ['UponRequest', 'UponRequestInd'],
#  ['InvestmentInJointVentureInd', 'InvestmentInJointVenture'],
#  ['WrittenPolicyOrProcedure', 'WrittenPolicyOrProcedureInd'],
#  ['LocalChaptersInd', 'LocalChapters'],
#  ['MaterialDiversionOrMisuseInd', 'MaterialDiversionOrMisuse'],
#  ['MembersOrStockholders', 'MembersOrStockholdersInd'],
#  ['MinutesOfCommittees', 'MinutesOfCommitteesInd'],
#  ['MinutesOfGoverningBodyInd', 'MinutesOfGoverningBody'],
#  ['RegularMonitoringEnfrcInd', 'RegularMonitoringEnforcement'],
#  ['NumberIndependentVotingMembers', 'IndependentVotingMemberCnt'],
#  ['GoverningBodyVotingMembersCnt', 'NbrVotingGoverningBodyMembers'],
#  ['OfficerMailingAddressInd', 'OfficerMailingAddress'],
#  ['CompensationProcessOther', 'CompensationProcessOtherInd'],
#  ['OtherWebsite', 'OtherWebsiteInd'],
#  ['OwnWebsiteInd', 'OwnWebsite'],
#  ['PoliciesReferenceChaptersInd', 'PoliciesReferenceChapters'],
#  ['StatesWhereCopyOfReturnIsFiled', 'StatesWhereCopyOfReturnIsFldCd'],
#  ['WhistleblowerPolicy', 'WhistleblowerPolicyInd'],
#  ['CompensationFromOtherSources', 'CompensationFromOtherSrcsInd'],
#  ['FormerOfcrEmployeesListedInd', 'FormersListed'],
#  ['NoListedPersonsCompensated', 'NoListedPersonsCompensatedInd'],
#  ['NumberOfContractorsGT100K', 'CntrctRcvdGreaterThan100KCnt'],
#  ['NumberIndividualsGT100K', 'IndivRcvdGreaterThan100KCnt'],
#  ['TotalCompGT150K', 'TotalCompGreaterThan150KInd'],
#  ['TotalOtherCompensation', 'TotalOtherCompensationAmt'],
#  ['TotalReportableCompFromOrgAmt', 'TotalReportableCompFromOrg'],
#  ['TotReportableCompRltdOrgAmt', 'TotalReportableCompFrmRltdOrgs'],
#  ['AllOtherContributions', 'AllOtherContributionsAmt'],
#  ['CntrbtnsRprtdFundraisingEvents', 'ContriRptFundraisingEventAmt'],
#  ['CostOfGoodsSoldAmt', 'CostOfGoodsSold'],
#  ['FederatedCampaignsAmt', 'FederatedCampaigns'],
#  ['FundraisingDirectExpenses', 'FundraisingDirectExpensesAmt'],
#  ['FundraisingEvents', 'FundraisingAmt'],
#  ['GrossIncomeFundraisingEvents', 'FundraisingGrossIncomeAmt'],
#  ['GamingDirectExpenses', 'GamingDirectExpensesAmt'],
#  ['GamingGrossIncomeAmt', 'GrossIncomeGaming'],
#  ['GovernmentGrants', 'GovernmentGrantsAmt'],
#  ['GrossSalesOfInventoryAmt', 'GrossSalesOfInventory'],
#  ['MembershipDuesAmt', 'MembershipDues'],
#  ['NoncashContributions', 'NoncashContributionsAmt'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['RelatedOrganizationsAmt', 'RelatedOrganizations'],
#  ['TotalContributionsAmt', 'TotalContributions'],
#  ['TotalOtherRevenue', 'OtherRevenueTotalAmt'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['TotalRevenueGrp', 'TotalRevenue'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['FeesForServicesAccounting', 'FeesForServicesAccountingGrp'],
#  ['FeesForServicesProfFundraising'],
#  ['FeesForSrvcInvstMgmntFeesGrp', 'FeesForServicesInvstMgmntFees'],
#  ['FeesForServicesLegalGrp', 'FeesForServicesLegal'],
#  ['FeesForServicesLobbyingGrp', 'FeesForServicesLobbying'],
#  ['FeesForServicesManagement', 'FeesForServicesManagementGrp'],
#  ['FeesForServicesOtherGrp', 'FeesForServicesOther'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TaxExemptBondLiabilities', 'TaxExemptBondLiabilitiesGrp'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['LandBldgEquipCostOrOtherBssAmt', 'LandBuildingsEquipmentBasis'],
#  ['LandBldgEquipAccumDeprecAmt', 'LandBldgEquipmentAccumDeprec'],
#  ['LoansFromOfficersDirectors', 'LoansFromOfficersDirectorsGrp'],
#  ['OrganizationFollowsSFAS117Ind', 'FollowSFAS117'],
#  ['DoNotFollowSFAS117', 'OrgDoesNotFollowSFAS117Ind'],
#  ['OtherLiabilities', 'OtherLiabilitiesGrp'],
#  ['RtnEarnEndowmentIncmOthFndsGrp', 'RetainedEarningsEndowmentEtc'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['MortNotesPyblSecuredInvestProp', 'MortgNotesPyblScrdInvstPropGrp'],
#  ['UnsecuredNotesLoansPayable', 'UnsecuredNotesLoansPayableGrp'],
#  ['UnsecuredNotesLoansPayable', 'UnsecuredNotesLoansPayableGrp'],
#  ['TotalAssets', 'TotalAssetsGrp'],
#  ['DonatedServicesAndUseFcltsAmt', 'ReconcilationDonatedServices'],
#  ['ReconcilationInvestExpenses', 'InvestmentExpenseAmt'],
#  ['ReconcilationPriorAdjustment', 'PriorPeriodAdjustmentsAmt'],
#  ['ReconcilationRevenueExpnssAmt', 'ReconcilationRevenueExpenses'],
#  ['ReconciliationUnrealizedInvest', 'NetUnrlzdGainsLossesInvstAmt'],
#  ['AccountantCompileOrReview', 'AccountantCompileOrReviewInd'],
#  ['MethodOfAccountingAccrualInd', 'MethodOfAccountingAccrual'],
#  ['MethodOfAccountingCash', 'MethodOfAccountingCashInd'],
#  ['MethodOfAccountingOtherInd', 'MethodOfAccountingOther'],
#  ['AuditCommittee', 'AuditCommitteeInd'],
#  ['FederalGrantAuditPerformedInd', 'FederalGrantAuditPerformed'],
#  ['FederalGrantAuditRequiredInd', 'FederalGrantAuditRequired'],
#  ['FSAudited', 'FSAuditedInd'],
#  ['TaxPeriod']]

# %%
new_variables_df[new_variables_df['len']!=2]['original_names'].tolist()
# Out:
# [['BuildTS'], ['Filer'], ['FeesForServicesProfFundraising'], ['TaxPeriod']]

# %%
new_variables_df[new_variables_df['len']==2]['original_names'].tolist()
# Out:
# [['AddressChange', 'AddressChangeInd'],
#  ['AmendedReturn', 'AmendedReturnInd'],
#  ['CountryLegalDomicile', 'LegalDomicileCountryCd'],
#  ['Organization4947a1NotPFInd', 'Organization4947a1'],
#  ['Organization501cInd', 'Organization501c'],
#  ['Organization501c3', 'Organization501c3Ind'],
#  ['FinalReturnInd', 'TerminatedReturn'],
#  ['GroupExemptionNum', 'GroupExemptionNumber'],
#  ['GrossReceiptsAmt', 'GrossReceipts'],
#  ['GroupReturnForAffiliates', 'GroupReturnForAffiliatesInd'],
#  ['AllAffiliatesIncluded', 'AllAffiliatesIncludedInd'],
#  ['InitialReturn', 'InitialReturnInd'],
#  ['PrincipalOfficerNm', 'NameOfPrincipalOfficerPerson'],
#  ['BusinessOfficerGrp', 'Officer'],
#  ['SpecialConditionDesc', 'SpecialConditionDescription'],
#  ['LegalDomicileStateCd', 'StateLegalDomicile'],
#  ['TaxPeriodEndDate', 'TaxPeriodEndDt'],
#  ['TaxYr', 'TaxYear'],
#  ['ReturnTs', 'Timestamp'],
#  ['TypeOfOrganizationAssocInd', 'TypeOfOrganizationAssociation'],
#  ['TypeOfOrganizationCorpInd', 'TypeOfOrganizationCorporation'],
#  ['TypeOfOrganizationOther', 'TypeOfOrganizationOtherInd'],
#  ['TypeOfOrgOtherDescription', 'OtherOrganizationDsc'],
#  ['TypeOfOrganizationTrustInd', 'TypeOfOrganizationTrust'],
#  ['WebSite', 'WebsiteAddressTxt'],
#  ['FormationYr', 'YearFormation'],
#  ['PYBenefitsPaidToMembersAmt', 'BenefitsPaidToMembersPriorYear'],
#  ['CYContributionsGrantsAmt', 'ContributionsGrantsCurrentYear'],
#  ['PYContributionsGrantsAmt', 'ContributionsGrantsPriorYear'],
#  ['PYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsPriorYear'],
#  ['VotingMembersIndependentCnt', 'NbrIndependentVotingMembers'],
#  ['InvestmentIncomePriorYear', 'PYInvestmentIncomeAmt'],
#  ['NetAssetsOrFundBalancesBOYAmt', 'NetAssetsOrFundBalancesBOY'],
#  ['OtherExpensePriorYear', 'PYOtherExpensesAmt'],
#  ['PYOtherRevenueAmt', 'OtherRevenuePriorYear'],
#  ['CYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpCY'],
#  ['PYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpPriorYear'],
#  ['PYProgramServiceRevenueAmt', 'ProgramServiceRevenuePriorYear'],
#  ['CYRevenuesLessExpensesAmt', 'RevenuesLessExpensesCY'],
#  ['RevenuesLessExpensesPriorYear', 'PYRevenuesLessExpensesAmt'],
#  ['ContractTerminationInd', 'TerminationOrContraction'],
#  ['TotalAssetsEOYAmt', 'TotalAssetsEOY'],
#  ['TotalExpensesPriorYear', 'PYTotalExpensesAmt'],
#  ['CYTotalFundraisingExpenseAmt', 'TotalFundrsngExpCurrentYear'],
#  ['TotalNbrEmployees', 'TotalEmployeeCnt'],
#  ['TotalVolunteersCnt', 'TotalNbrVolunteers'],
#  ['TotalLiabilitiesEOYAmt', 'TotalLiabilitiesEOY'],
#  ['TotalRevenuePriorYear', 'PYTotalRevenueAmt'],
#  ['TotalGrossUBIAmt', 'TotalGrossUBI'],
#  ['NetUnrelatedBusTxblIncmAmt', 'NetUnrelatedBusinessTxblIncome'],
#  ['NbrVotingMembersGoverningBody', 'VotingMembersGoverningBodyCnt'],
#  ['CYBenefitsPaidToMembersAmt', 'BenefitsPaidToMembersCY'],
#  ['CYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsCY'],
#  ['CYInvestmentIncomeAmt', 'InvestmentIncomeCurrentYear'],
#  ['NetAssetsOrFundBalancesEOYAmt', 'NetAssetsOrFundBalancesEOY'],
#  ['ActivityOrMissionDescription', 'ActivityOrMissionDesc'],
#  ['OtherExpensesCurrentYear', 'CYOtherExpensesAmt'],
#  ['CYOtherRevenueAmt', 'OtherRevenueCurrentYear'],
#  ['CYProgramServiceRevenueAmt', 'ProgramServiceRevenueCY'],
#  ['CYSalariesCompEmpBnftPaidAmt', 'SalariesEtcCurrentYear'],
#  ['SalariesEtcPriorYear', 'PYSalariesCompEmpBnftPaidAmt'],
#  ['TotalAssetsBOYAmt', 'TotalAssetsBOY'],
#  ['CYTotalExpensesAmt', 'TotalExpensesCurrentYear'],
#  ['TotalLiabilitiesBOY', 'TotalLiabilitiesBOYAmt'],
#  ['TotalRevenueCurrentYear', 'CYTotalRevenueAmt'],
#  ['FundraisingActivities', 'FundraisingActivitiesInd'],
#  ['Gaming', 'GamingActivitiesInd'],
#  ['ProfessionalFundraisingInd', 'ProfessionalFundraising'],
#  ['Form990ProvidedToGvrnBodyInd', 'Form990ProvidedToGoverningBody'],
#  ['AnnualDisclosureCoveredPersons', 'AnnualDisclosureCoveredPrsnInd'],
#  ['CompensationProcessCEOInd', 'CompensationProcessCEO'],
#  ['ChangesToOrganizingDocs', 'ChangeToOrgDocumentsInd'],
#  ['ConflictOfInterestPolicy', 'ConflictOfInterestPolicyInd'],
#  ['DecisionsSubjectToApprovaInd', 'DecisionsSubjectToApproval'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd'],
#  ['DocumentRetentionPolicy', 'DocumentRetentionPolicyInd'],
#  ['ElectionOfBoardMembersInd', 'ElectionOfBoardMembers'],
#  ['FamilyOrBusinessRelationship', 'FamilyOrBusinessRlnInd'],
#  ['OwnWebsiteInd', 'OwnWebsite'],
#  ['UponRequest', 'UponRequestInd'],
#  ['InvestmentInJointVentureInd', 'InvestmentInJointVenture'],
#  ['WrittenPolicyOrProcedure', 'WrittenPolicyOrProcedureInd'],
#  ['LocalChaptersInd', 'LocalChapters'],
#  ['MaterialDiversionOrMisuseInd', 'MaterialDiversionOrMisuse'],
#  ['MembersOrStockholders', 'MembersOrStockholdersInd'],
#  ['MinutesOfCommittees', 'MinutesOfCommitteesInd'],
#  ['MinutesOfGoverningBodyInd', 'MinutesOfGoverningBody'],
#  ['RegularMonitoringEnfrcInd', 'RegularMonitoringEnforcement'],
#  ['NumberIndependentVotingMembers', 'IndependentVotingMemberCnt'],
#  ['GoverningBodyVotingMembersCnt', 'NbrVotingGoverningBodyMembers'],
#  ['OfficerMailingAddressInd', 'OfficerMailingAddress'],
#  ['CompensationProcessOther', 'CompensationProcessOtherInd'],
#  ['OtherWebsite', 'OtherWebsiteInd'],
#  ['OwnWebsiteInd', 'OwnWebsite'],
#  ['PoliciesReferenceChaptersInd', 'PoliciesReferenceChapters'],
#  ['StatesWhereCopyOfReturnIsFiled', 'StatesWhereCopyOfReturnIsFldCd'],
#  ['WhistleblowerPolicy', 'WhistleblowerPolicyInd'],
#  ['CompensationFromOtherSources', 'CompensationFromOtherSrcsInd'],
#  ['FormerOfcrEmployeesListedInd', 'FormersListed'],
#  ['NoListedPersonsCompensated', 'NoListedPersonsCompensatedInd'],
#  ['NumberOfContractorsGT100K', 'CntrctRcvdGreaterThan100KCnt'],
#  ['NumberIndividualsGT100K', 'IndivRcvdGreaterThan100KCnt'],
#  ['TotalCompGT150K', 'TotalCompGreaterThan150KInd'],
#  ['TotalOtherCompensation', 'TotalOtherCompensationAmt'],
#  ['TotalReportableCompFromOrgAmt', 'TotalReportableCompFromOrg'],
#  ['TotReportableCompRltdOrgAmt', 'TotalReportableCompFrmRltdOrgs'],
#  ['AllOtherContributions', 'AllOtherContributionsAmt'],
#  ['CntrbtnsRprtdFundraisingEvents', 'ContriRptFundraisingEventAmt'],
#  ['CostOfGoodsSoldAmt', 'CostOfGoodsSold'],
#  ['FederatedCampaignsAmt', 'FederatedCampaigns'],
#  ['FundraisingDirectExpenses', 'FundraisingDirectExpensesAmt'],
#  ['FundraisingEvents', 'FundraisingAmt'],
#  ['GrossIncomeFundraisingEvents', 'FundraisingGrossIncomeAmt'],
#  ['GamingDirectExpenses', 'GamingDirectExpensesAmt'],
#  ['GamingGrossIncomeAmt', 'GrossIncomeGaming'],
#  ['GovernmentGrants', 'GovernmentGrantsAmt'],
#  ['GrossSalesOfInventoryAmt', 'GrossSalesOfInventory'],
#  ['MembershipDuesAmt', 'MembershipDues'],
#  ['NoncashContributions', 'NoncashContributionsAmt'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['RelatedOrganizationsAmt', 'RelatedOrganizations'],
#  ['TotalContributionsAmt', 'TotalContributions'],
#  ['TotalOtherRevenue', 'OtherRevenueTotalAmt'],
#  ['TotalProgramServiceRevenue', 'TotalProgramServiceRevenueAmt'],
#  ['TotalRevenueGrp', 'TotalRevenue'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompDisqualPersonsGrp', 'CompDisqualPersons'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['CompCurrentOfficersDirectors', 'CompCurrentOfcrDirectorsGrp'],
#  ['FeesForServicesAccounting', 'FeesForServicesAccountingGrp'],
#  ['FeesForSrvcInvstMgmntFeesGrp', 'FeesForServicesInvstMgmntFees'],
#  ['FeesForServicesLegalGrp', 'FeesForServicesLegal'],
#  ['FeesForServicesLobbyingGrp', 'FeesForServicesLobbying'],
#  ['FeesForServicesManagement', 'FeesForServicesManagementGrp'],
#  ['FeesForServicesOtherGrp', 'FeesForServicesOther'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherEmployeeBenefitsGrp', 'OtherEmployeeBenefits'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['OtherSalariesAndWagesGrp', 'OtherSalariesAndWages'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PayrollTaxes', 'PayrollTaxesGrp'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['PensionPlanContributionsGrp', 'PensionPlanContributions'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TotalFunctionalExpenses', 'TotalFunctionalExpensesGrp'],
#  ['TaxExemptBondLiabilities', 'TaxExemptBondLiabilitiesGrp'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['CashNonInterestBearing', 'CashNonInterestBearingGrp'],
#  ['LandBldgEquipCostOrOtherBssAmt', 'LandBuildingsEquipmentBasis'],
#  ['LandBldgEquipAccumDeprecAmt', 'LandBldgEquipmentAccumDeprec'],
#  ['LoansFromOfficersDirectors', 'LoansFromOfficersDirectorsGrp'],
#  ['OrganizationFollowsSFAS117Ind', 'FollowSFAS117'],
#  ['DoNotFollowSFAS117', 'OrgDoesNotFollowSFAS117Ind'],
#  ['OtherLiabilities', 'OtherLiabilitiesGrp'],
#  ['RtnEarnEndowmentIncmOthFndsGrp', 'RetainedEarningsEndowmentEtc'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['SavingsAndTempCashInvestments', 'SavingsAndTempCashInvstGrp'],
#  ['MortNotesPyblSecuredInvestProp', 'MortgNotesPyblScrdInvstPropGrp'],
#  ['UnsecuredNotesLoansPayable', 'UnsecuredNotesLoansPayableGrp'],
#  ['UnsecuredNotesLoansPayable', 'UnsecuredNotesLoansPayableGrp'],
#  ['TotalAssets', 'TotalAssetsGrp'],
#  ['DonatedServicesAndUseFcltsAmt', 'ReconcilationDonatedServices'],
#  ['ReconcilationInvestExpenses', 'InvestmentExpenseAmt'],
#  ['ReconcilationPriorAdjustment', 'PriorPeriodAdjustmentsAmt'],
#  ['ReconcilationRevenueExpnssAmt', 'ReconcilationRevenueExpenses'],
#  ['ReconciliationUnrealizedInvest', 'NetUnrlzdGainsLossesInvstAmt'],
#  ['AccountantCompileOrReview', 'AccountantCompileOrReviewInd'],
#  ['MethodOfAccountingAccrualInd', 'MethodOfAccountingAccrual'],
#  ['MethodOfAccountingCash', 'MethodOfAccountingCashInd'],
#  ['MethodOfAccountingOtherInd', 'MethodOfAccountingOther'],
#  ['AuditCommittee', 'AuditCommitteeInd'],
#  ['FederalGrantAuditPerformedInd', 'FederalGrantAuditPerformed'],
#  ['FederalGrantAuditRequiredInd', 'FederalGrantAuditRequired'],
#  ['FSAudited', 'FSAuditedInd']]

# %%
flat_list = [item for sublist in new_variables_df[new_variables_df['len']==2]['original_names'].tolist() for item in sublist]
print(len(flat_list))
print(flat_list[:])
# Out:
# 378
# ['AddressChange', 'AddressChangeInd', 'AmendedReturn', 'AmendedReturnInd', 'CountryLegalDomicile', 'LegalDomicileCountryCd', 'Organization4947a1NotPFInd', 'Organization4947a1', 'Organization501cInd', 'Organization501c', 'Organization501c3', 'Organization501c3Ind', 'FinalReturnInd', 'TerminatedReturn', 'GroupExemptionNum', 'GroupExemptionNumber', 'GrossReceiptsAmt', 'GrossReceipts', 'GroupReturnForAffiliates', 'GroupReturnForAffiliatesInd', 'AllAffiliatesIncluded', 'AllAffiliatesIncludedInd', 'InitialReturn', 'InitialReturnInd', 'PrincipalOfficerNm', 'NameOfPrincipalOfficerPerson', 'BusinessOfficerGrp', 'Officer', 'SpecialConditionDesc', 'SpecialConditionDescription', 'LegalDomicileStateCd', 'StateLegalDomicile', 'TaxPeriodEndDate', 'TaxPeriodEndDt', 'TaxYr', 'TaxYear', 'ReturnTs', 'Timestamp', 'TypeOfOrganizationAssocInd', 'TypeOfOrganizationAssociation', 'TypeOfOrganizationCorpInd', 'TypeOfOrganizationCorporation', 'TypeOfOrganizationOther', 'TypeOfOrganizationOtherInd', 'TypeOfOrgOtherDescription', 'OtherOrganizationDsc', 'TypeOfOrganizationTrustInd', 'TypeOfOrganizationTrust', 'WebSite', 'WebsiteAddressTxt', 'FormationYr', 'YearFormation', 'PYBenefitsPaidToMembersAmt', 'BenefitsPaidToMembersPriorYear', 'CYContributionsGrantsAmt', 'ContributionsGrantsCurrentYear', 'PYContributionsGrantsAmt', 'ContributionsGrantsPriorYear', 'PYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsPriorYear', 'VotingMembersIndependentCnt', 'NbrIndependentVotingMembers', 'InvestmentIncomePriorYear', 'PYInvestmentIncomeAmt', 'NetAssetsOrFundBalancesBOYAmt', 'NetAssetsOrFundBalancesBOY', 'OtherExpensePriorYear', 'PYOtherExpensesAmt', 'PYOtherRevenueAmt', 'OtherRevenuePriorYear', 'CYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpCY', 'PYTotalProfFndrsngExpnsAmt', 'TotalProfFundrsngExpPriorYear', 'PYProgramServiceRevenueAmt', 'ProgramServiceRevenuePriorYear', 'CYRevenuesLessExpensesAmt', 'RevenuesLessExpensesCY', 'RevenuesLessExpensesPriorYear', 'PYRevenuesLessExpensesAmt', 'ContractTerminationInd', 'TerminationOrContraction', 'TotalAssetsEOYAmt', 'TotalAssetsEOY', 'TotalExpensesPriorYear', 'PYTotalExpensesAmt', 'CYTotalFundraisingExpenseAmt', 'TotalFundrsngExpCurrentYear', 'TotalNbrEmployees', 'TotalEmployeeCnt', 'TotalVolunteersCnt', 'TotalNbrVolunteers', 'TotalLiabilitiesEOYAmt', 'TotalLiabilitiesEOY', 'TotalRevenuePriorYear', 'PYTotalRevenueAmt', 'TotalGrossUBIAmt', 'TotalGrossUBI', 'NetUnrelatedBusTxblIncmAmt', 'NetUnrelatedBusinessTxblIncome', 'NbrVotingMembersGoverningBody', 'VotingMembersGoverningBodyCnt', 'CYBenefitsPaidToMembersAmt', 'BenefitsPaidToMembersCY', 'CYGrantsAndSimilarPaidAmt', 'GrantsAndSimilarAmntsCY', 'CYInvestmentIncomeAmt', 'InvestmentIncomeCurrentYear', 'NetAssetsOrFundBalancesEOYAmt', 'NetAssetsOrFundBalancesEOY', 'ActivityOrMissionDescription', 'ActivityOrMissionDesc', 'OtherExpensesCurrentYear', 'CYOtherExpensesAmt', 'CYOtherRevenueAmt', 'OtherRevenueCurrentYear', 'CYProgramServiceRevenueAmt', 'ProgramServiceRevenueCY', 'CYSalariesCompEmpBnftPaidAmt', 'SalariesEtcCurrentYear', 'SalariesEtcPriorYear', 'PYSalariesCompEmpBnftPaidAmt', 'TotalAssetsBOYAmt', 'TotalAssetsBOY', 'CYTotalExpensesAmt', 'TotalExpensesCurrentYear', 'TotalLiabilitiesBOY', 'TotalLiabilitiesBOYAmt', 'TotalRevenueCurrentYear', 'CYTotalRevenueAmt', 'FundraisingActivities', 'FundraisingActivitiesInd', 'Gaming', 'GamingActivitiesInd', 'ProfessionalFundraisingInd', 'ProfessionalFundraising', 'Form990ProvidedToGvrnBodyInd', 'Form990ProvidedToGoverningBody', 'AnnualDisclosureCoveredPersons', 'AnnualDisclosureCoveredPrsnInd', 'CompensationProcessCEOInd', 'CompensationProcessCEO', 'ChangesToOrganizingDocs', 'ChangeToOrgDocumentsInd', 'ConflictOfInterestPolicy', 'ConflictOfInterestPolicyInd', 'DecisionsSubjectToApprovaInd', 'DecisionsSubjectToApproval', 'DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd', 'DelegationOfManagementDuties', 'DelegationOfMgmtDutiesInd', 'DocumentRetentionPolicy', 'DocumentRetentionPolicyInd', 'ElectionOfBoardMembersInd', 'Electio ...

# %% [markdown]
# <br> Flatten a list of lists: https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-list-of-lists

# %%
print(len([c for c in df.columns.tolist() if c not in flat_list]))
print([c for c in df.columns.tolist() if c not in flat_list])
# Out:
# 199
# ['OrganizationName', 'URL', 'DLN', 'TaxPeriod', 'EIN', 'F9_09_PC_FEES_FOR_SVCE_FR_TOT', 'fiscal_year', 'Filer', 'F9_00_HD_BUILD_TIME_STAMP', 'F9_00_HD_ADDR_CHANGE', 'F9_00_HD_AMENDED_RETURN', 'F9_00_HD_CTRY_OF_DOMICILE', 'F9_00_HD_EXEMPT_STATUS_4847A1', 'F9_00_HD_EXEMPT_STATUS_501C', 'F9_00_HD_EXEMPT_STATUS_501C3', 'F9_00_HD_FINAL_RETURN', 'F9_00_HD_GROSS_EXEMPT_NUM', 'F9_00_HD_GROSS_RCPT', 'F9_00_HD_GROUP_RETURN', 'F9_00_HD_INCLUDES_SUBORD_ORGS', 'F9_00_HD_INITIAL_RETURN', 'F9_00_HD_PRIN_OFF_NAME', 'F9_00_HD_SIGNING_OFFICER_SIGNTR', 'F9_00_HD_SPECIAL_CONDITION_DESC', 'F9_00_HD_STATE_OF_DOMICILE', 'F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR', 'F9_00_HD_TIME_STAMP', 'F9_00_HD_TYPE_ORG_ASSOCIATION', 'F9_00_HD_TYPE_ORG_CORP', 'F9_00_HD_TYPE_ORG_OTHER', 'F9_00_HD_TYPE_ORG_OTHER_DESC', 'F9_00_HD_TYPE_ORG_TRUST', 'F9_00_HD_WEBSITE', 'F9_00_HD_YEAR_FORMED', 'F9_01_PC_BEN_PAID_MEMB_PRIOR', 'F9_01_PC_CONTR_GRANTS_CURR', 'F9_01_PC_CONTR_GRANTS_PRIOR', 'F9_01_PC_GRANTS_PRIOR', 'F9_01_PC_INDEP_VOTING_MEMB', 'F9_01_PC_INVEST_INCOME_PRIOR', 'F9_01_PC_NET_ASSETS_BOY', 'F9_01_PC_OTHER_EXPENSE_PRIOR', 'F9_01_PC_OTHER_REV_PRIOR', 'F9_01_PC_PROF_FUNDRISING_EXP_CURR', 'F9_01_PC_PROF_FUNDRISING_EXP_PRIOR', 'F9_01_PC_PROG_SERVICE_REV_PRIOR', 'F9_01_PC_REV_LESS_EXP_CURR', 'F9_01_PC_REV_LESS_EXP_PRIOR', 'F9_01_PC_TERMINATION_CONTRACTION', 'F9_01_PC_TOT_ASSETS_EOY', 'F9_01_PC_TOT_EXP_PRIOR', 'F9_01_PC_TOT_FNDR_EXP_CURR', 'F9_01_PC_TOT_INDIV_EMPLOYED', 'F9_01_PC_TOT_INDIV_VOLUNTEERS', 'F9_01_PC_TOT_LIABILITIES_EOY', 'F9_01_PC_TOT_REVENUE_PRIOR', 'F9_01_PC_TOT_UBI_GROSS', 'F9_01_PC_TOT_UBI_NET', 'F9_01_PC_VOTING_MEMB_GOV_BODY', 'F9_01_PZ_BEN_PAID_TO_MEMB_CURR', 'F9_01_PZ_GRANTS_PAID_CURR', 'F9_01_PZ_INVEST_INCOME_CURR', 'F9_01_PZ_NAFB_EOY', 'F9_01_PZ_ORGANIZATIONAL_MISSION', 'F9_01_PZ_OTHER_EXPENSE_CURR', 'F9_01_PZ_OTHER_REV_CURR', 'F9_01_PZ_PROG_SERVICE_REV_CURR', 'F9_01_PZ_SALARIES_CURR', 'F9_01_PZ_SALARIES_PRIOR', 'F9_01_PZ_TOT_ASSETS_BOY', 'F9_01_PZ_TOT_EXP_CURR', 'F9_01_PZ_TOT_LIAB_BOY', 'F9_01_PZ_TOT_REV_CURR', 'F9_04_PC_FR_EVENT_INC_GT_15K', 'F9_04_PC_GAMING_INC_GT_15K', 'F9_04_PC_PROF_FR_EXP_GT_15K', 'F9_06_PC_990_PROVIDED_GOV_BODY', 'F9_06_PC_ANNUAL_DISC_COVRD_PERS', 'F9_06_PC_CEO_COMPENSTN_PROCESS', 'F9_06_PC_CHANGES_ORGANIZING_DOCS', 'F9_06_PC_CONFLICT_OF_INTEREST', 'F9_06_PC_DECISIONS_SUBJ_APPROVAL', 'F9_06_PC_DELEGATION_MGT_DUTIES', 'F9_06_PC_DELEGATION_OF_MGT', 'F9_06_PC_DOCUMENT_RET_POLICY', 'F9_06_PC_ELECTION_BOARD_MEMBERS', 'F9_06_PC_FAMILY_OR_BUSINESS_REL', 'F9_06_PC_FORM_AVAIL_OWN_WEBSITE', 'F9_06_PC_FORM_UPON_REQUEST', 'F9_06_PC_JOINT_VENTURE_INVESTMNT', 'F9_06_PC_JOINT_VENTURE_POLICY', 'F9_06_PC_LOCAL_CHAPTERS', 'F9_06_PC_MATERIAL_DIVERSION', 'F9_06_PC_MEMBERS_OR_STOCKHOLDERS', 'F9_06_PC_MINUTES_COMMITTEES', 'F9_06_PC_MINUTES_GOVERNING_BODY', 'F9_06_PC_MONITORING_OF_COI_POLICY', 'F9_06_PC_NUM_IND_VOTING_MEMBERS', 'F9_06_PC_NUM_VOTING_GOV_MEMBERS', 'F9_06_PC_OFFICER_MAILING_ADDRESS', 'F9_06_PC_OTHER_COMPENSTN_PROCESS', 'F9_06_PC_OTHER_WEBSITE', 'F9_06_PC_OWN_WEBSITE', 'F9_06_PC_POLICIES_GOVERN_CHAPTER', 'F9_06_PC_STATES_WHERE_RET_FILED', 'F9_06_PC_WHISTLEBLOWER_POLICY', 'F9_07_PC_COMPENSATION_OTHER_SRCE', 'F9_07_PC_FORMER_OFFICER_LISTED', 'F9_07_PC_NO_LISTED_PERS_COMPENSD', 'F9_07_PC_NUM_CONTRCTRS_GRTR_100K', 'F9_07_PC_NUM_INDS_GREATER_100K', 'F9_07_PC_TOTAL_COMP_GRTR_150K', 'F9_07_PC_TOT_OTHER_COMPENSATION', 'F9_07_PC_TOT_REPRT_COMP_FROM_ORG', 'F9_07_PC_TOT_REPRT_COMP_RLTD_ORG', 'F9_08_PC_ALL_OTHER_CONTRIBUTIONS', 'F9_08_PC_CONTS_REPRTD_FNDRAISNG', 'F9_08_PC_COST_OF_GOODS_SOLD', 'F9_08_PC_FEDERATED_CAMPAIGNS', 'F9_08_PC_FUNDRAISING_DIRECT_EXP', 'F9_08_PC_FUNDRAISING_EVENTS', 'F9_08_PC_FUNDRAISING_GROSS_INC', 'F9_08_PC_GAMING_DIRECT_EXPENSES', 'F9_08_PC_GAMING_GROSS_INCOME', 'F9_08_PC_GOVERNMENT_GRANTS', 'F9_08_PC_GROSS_SALES_INVENTORY', 'F9_08_PC_MEMBERSHIP_DUES', 'F9_08_PC_NONCASH_CONTRIBUTIONS', 'F9_08_PC_PROGRAM_SVCE_REV_TOTAL', 'F9_08_PC_RELATED_ORGANIZATIONS', 'F9_08_PC_TOTAL_CONTRIBUTIONS', 'F9_08_PC_TOTAL_OTHER_REVENUE', 'F9_0 ...

# %%
print(len(new_variables_df['variable_name_new'].tolist()))
# Out:
# 193

# %%
set([c for c in df.columns.tolist() if c not in flat_list]) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'501c3', 'DLN', 'EIN', 'Filer', 'OrganizationName', 'URL', 'fiscal_year'}

# %% [markdown]
# <br>The following block drops 324 columns

# %%
print(len(df.columns))
df = df[[c for c in df.columns.tolist() if c not in flat_list]]
print(len(df.columns))
df[:2]
# Out:
# 523
# 199
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod        EIN F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 0  93493313013011    201012  232705170                           NaN
# 1  93493313013111    201106  581805618                {'Total': '0'}
#
#   fiscal_year  \
# 0        2010
# 1        2011
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
# 1  {'EIN': '581805618', 'Name': {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}, 'NameControl': 'TORR', 'Phone': '7033415000', 'USAddress': {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA'...
#
#   F9_00_HD_BUILD_TIME_STAMP F9_00_HD_ADDR_CHANGE F9_00_HD_AMENDED_RETURN  \
# 0      2016-02-24 21:20:13Z                    1                     NaN
# 1      2016-02-24 21:20:13Z                  NaN                     NaN
#
#   F9_00_HD_CTRY_OF_DOMICILE F9_00_HD_EXEMPT_STATUS_4847A1  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
#
#   F9_00_HD_EXEMPT_STATUS_501C F9_00_HD_EXEMPT_STATUS_501C3  \
# 0                         NaN                            1
# 1                         NaN                            1
#
#   F9_00_HD_FINAL_RETURN F9_00_HD_GROSS_EXEMPT_NUM F9_00_HD_GROSS_RCPT  \
# 0                   NaN                       NaN             1473903
# 1                   NaN                      1736              266420
#
#   F9_00_HD_GROUP_RETURN F9_00_HD_INCLUDES_SUBORD_ORGS F9_00_HD_INITIAL_RETURN  \
# 0                     0                           NaN                     NaN
# 1                     0                             0                     NaN
#
#   F9_00_HD_PRIN_OFF_NAME  \
# 0          MICHAEL ANTON
# 1                    NaN
#
#                                                                                                 F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#   F9_00_HD_SPECIAL_CONDITION_DESC F9_00_HD_STATE_OF_DOMICILE  \
# 0                             NaN                         PA
# 1                             NaN                         WY
#
#   F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR        F9_00_HD_TIME_STAMP  \
# 0           2010-12-31              2010  2011-11-09T06:41:09-06:00
# 1           2011-06-30              2010  2011-11-09T07:32:06-08:00
#
#   F9_00_HD_TYPE_ORG_ASSOCIATION F9_00_HD_TYPE_ORG_CORP  \
# 0                           NaN                      1
# 1                           NaN                      1
#
#   F9_00_HD_TYPE_ORG_OTHER F9_00_HD_TYPE_ORG_OTHER_DESC  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
#
#   F9_00_HD_TYPE_ORG_TRUST F9_00_HD_WEBSITE F9_00_HD_YEAR_FORMED  \
# 0                     NaN              N/A                 1992
# 1                     NaN              N/A                 1993
#
#   F9_01_PC_BEN_PAID_MEMB_PRIOR F9_01_PC_CONTR_GRANTS_CURR  \
# 0                            0                    1439340
# 1                          NaN                          0
#
#   F9_01_PC_CONTR_GRANTS_PRIOR F9_01_PC_GRANTS_PRIOR  \
# 0                     1044925                638637
# 1                         NaN                   NaN
#
#   F9_01_PC_INDEP_VOTING_MEMB F9_01_PC_INVEST_INCOME_PRIOR  \
# 0                         10                        30447
# 1                         13                         1425
#
#   F9_01_PC_NET_ASSETS_BOY F9_01_PC_OTHER_EXPENSE_PRIOR  \
# 0                 1753405                       243131
# 1                 1437850                       189785
#
#   F9_01_PC_OTHER_REV_PRIOR F9_01_PC_PROF_FUNDRISING_EXP_CURR  \
# 0                        0                                 0
# 1                      NaN                                 0
#
#   F9_01_PC_PROF_FUNDRISING_EXP_PRIOR F9_01_PC_PROG_SERVICE_REV_PRIOR  \
# 0                                  0                               0
# 1                                NaN                          222839
#
#   F9_01_PC_REV_LESS_EXP_CURR F9_01_PC_REV_LESS_EXP_PRIOR  \
# 0                      89152                      193604
# 1                     -39085                      -36926
#
#   F9_01_PC_TERMINATION_CONTRACTION F9_01_PC_TOT_ASSETS_EOY  \
# 0                              NaN                 2440859
# 1                              NaN                 1433342
#
#   F9_01_PC_TOT_EXP_PRIOR F9_01_PC_TOT_FNDR_EXP_CURR  \
# 0                 881768                     195892
# 1                 261190                          0
#
#   F9_01_PC_TOT_INDIV_EMPLOYED F9_01_PC_TOT_INDIV_VOLUNTEERS  \
# 0                           0                             0
# 1                           0                           NaN
#
#   F9_01_PC_TOT_LIABILITIES_EOY F9_01_PC_TOT_REVENUE_PRIOR  \
# 0                       450430                    1075372
# 1                        34577                     224264
#
#   F9_01_PC_TOT_UBI_GROSS F9_01_PC_TOT_UBI_NET F9_01_PC_VOTING_MEMB_GOV_BODY  \
# 0                      0                    0                            10
# 1                      0                  NaN                            19
#
#   F9_01_PZ_BEN_PAID_TO_MEMB_CURR F9_01_PZ_GRANTS_PAID_CURR  \
# 0                              0                    925000
# 1                              0                         0
#
#   F9_01_PZ_INVEST_INCOME_CURR F9_01_PZ_NAFB_EOY  \
# 0                       33563           1990429
# 1                         828           1398765
#
#                                                                                                                  F9_01_PZ_ORGANIZATIONAL_MISSION  \
# 0                                                       MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
# 1  PROVIDE HOUSING FOR THE ELDERLY AND THE DISABLED UNDER SECTION 202 OF THE NATIONAL HOUSING ACT UNDER AN AGREEMENT WITH THE DEPARTMENT OF HUD.
#
#   F9_01_PZ_OTHER_EXPENSE_CURR F9_01_PZ_OTHER_REV_CURR  \
# 0                      459751                    1000
# 1                      222550                       0
#
#   F9_01_PZ_PROG_SERVICE_REV_CURR F9_01_PZ_SALARIES_CURR  \
# 0                              0                      0
# 1                         265592                  82955
#
#   F9_01_PZ_SALARIES_PRIOR F9_01_PZ_TOT_ASSETS_BOY F9_01_PZ_TOT_EXP_CURR  \
# 0                       0                 1925215               1384751
# 1                   71405                 1455332                305505
#
#   F9_01_PZ_TOT_LIAB_BOY F9_01_PZ_TOT_REV_CURR F9_04_PC_FR_EVENT_INC_GT_15K  \
# 0                171810               1473903                            0
# 1                 17482                266420                            0
#
#   F9_04_PC_GAMING_INC_GT_15K F9_04_PC_PROF_FR_EXP_GT_15K  \
# 0                          0                           0
# 1                          0                           0
#
#   F9_06_PC_990_PROVIDED_GOV_BODY F9_06_PC_ANNUAL_DISC_COVRD_PERS  \
# 0                              1                               1
# 1                              1                               1
#
#   F9_06_PC_CEO_COMPENSTN_PROCESS F9_06_PC_CHANGES_ORGANIZING_DOCS  \
# 0                              0                                0
# 1                              1                                0
#
#   F9_06_PC_CONFLICT_OF_INTEREST F9_06_PC_DECISIONS_SUBJ_APPROVAL  \
# 0                             1                                0
# 1                             1                                1
#
#   F9_06_PC_DELEGATION_MGT_DUTIES F9_06_PC_DELEGATION_OF_MGT  \
# 0                              0                          0
# 1                              1                          1
#
#   F9_06_PC_DOCUMENT_RET_POLICY F9_06_PC_ELECTION_BOARD_MEMBERS  \
# 0                            0                               0
# 1                            0                               1
#
#   F9_06_PC_FAMILY_OR_BUSINESS_REL F9_06_PC_FORM_AVAIL_OWN_WEBSITE  \
# 0                               0                             NaN
# 1                               1                             NaN
#
#   F9_06_PC_FORM_UPON_REQUEST F9_06_PC_JOINT_VENTURE_INVESTMNT  \
# 0                          1                                0
# 1                          1                                0
#
#   F9_06_PC_JOINT_VENTURE_POLICY F9_06_PC_LOCAL_CHAPTERS  \
# 0                           NaN                       0
# 1                             0                       0
#
#   F9_06_PC_MATERIAL_DIVERSION F9_06_PC_MEMBERS_OR_STOCKHOLDERS  \
# 0                           0                                0
# 1                           0                                0
#
#   F9_06_PC_MINUTES_COMMITTEES F9_06_PC_MINUTES_GOVERNING_BODY  \
# 0                           1                               1
# 1                           1                               1
#
#   F9_06_PC_MONITORING_OF_COI_POLICY F9_06_PC_NUM_IND_VOTING_MEMBERS  \
# 0                                 1                              10
# 1                                 1                              13
#
#   F9_06_PC_NUM_VOTING_GOV_MEMBERS F9_06_PC_OFFICER_MAILING_ADDRESS  \
# 0                              10                                0
# 1                              19                                0
#
#   F9_06_PC_OTHER_COMPENSTN_PROCESS F9_06_PC_OTHER_WEBSITE  \
# 0                                0                    NaN
# 1                                1                    NaN
#
#   F9_06_PC_OWN_WEBSITE F9_06_PC_POLICIES_GOVERN_CHAPTER  \
# 0                  NaN                              NaN
# 1                  NaN                                0
#
#   F9_06_PC_STATES_WHERE_RET_FILED F9_06_PC_WHISTLEBLOWER_POLICY  \
# 0                    [PA, NJ, DE]                             0
# 1                             NaN                             0
#
#   F9_07_PC_COMPENSATION_OTHER_SRCE F9_07_PC_FORMER_OFFICER_LISTED  \
# 0                                0                              0
# 1                                0                              1
#
#   F9_07_PC_NO_LISTED_PERS_COMPENSD F9_07_PC_NUM_CONTRCTRS_GRTR_100K  \
# 0                                1                                0
# 1                              NaN                                0
#
#   F9_07_PC_NUM_INDS_GREATER_100K F9_07_PC_TOTAL_COMP_GRTR_150K  \
# 0                              0                             0
# 1                              0                             1
#
#   F9_07_PC_TOT_OTHER_COMPENSATION F9_07_PC_TOT_REPRT_COMP_FROM_ORG  \
# 0                               0                                0
# 1                          411648                              NaN
#
#   F9_07_PC_TOT_REPRT_COMP_RLTD_ORG F9_08_PC_ALL_OTHER_CONTRIBUTIONS  \
# 0                                0                          1439340
# 1                          1180355                              NaN
#
#   F9_08_PC_CONTS_REPRTD_FNDRAISNG F9_08_PC_COST_OF_GOODS_SOLD  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
#
#   F9_08_PC_FEDERATED_CAMPAIGNS F9_08_PC_FUNDRAISING_DIRECT_EXP  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
#
#   F9_08_PC_FUNDRAISING_EVENTS F9_08_PC_FUNDRAISING_GROSS_INC  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
#
#   F9_08_PC_GAMING_DIRECT_EXPENSES F9_08_PC_GAMING_GROSS_INCOME  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
#
#   F9_08_PC_GOVERNMENT_GRANTS F9_08_PC_GROSS_SALES_INVENTORY  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   F9_08_PC_MEMBERSHIP_DUES F9_08_PC_NONCASH_CONTRIBUTIONS  \
# 0                      NaN                            NaN
# 1                      NaN                            NaN
#
#   F9_08_PC_PROGRAM_SVCE_REV_TOTAL F9_08_PC_RELATED_ORGANIZATIONS  \
# 0                             NaN                            NaN
# 1                          265592                            NaN
#
#   F9_08_PC_TOTAL_CONTRIBUTIONS F9_08_PC_TOTAL_OTHER_REVENUE  \
# 0                      1439340                         1000
# 1                            0                            0
#
#   F9_08_PC_TOTAL_PROG_SVCE_REVENUE  \
# 0                              NaN
# 1                           265592
#
#                                                                                                                     F9_08_PC_TOTAL_REVENUE  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
# 1                                                              {'TotalRevenueColumn': '266420', 'RelatedOrExemptFunctionIncome': '266420'}
#
#   F9_09_PC_COMP_DISQUAL_FUNDRAISE F9_09_PC_COMP_DISQUAL_MGMT  \
# 0                             NaN                        NaN
# 1                  {'Total': '0'}             {'Total': '0'}
#
#   F9_09_PC_COMP_DISQUAL_PROG_SVCE F9_09_PC_COMP_DISQUAL_TOTAL  \
# 0                             NaN                         NaN
# 1                  {'Total': '0'}              {'Total': '0'}
#
#   F9_09_PC_COMP_OFFICERS_FUNDRAISE F9_09_PC_COMP_OFFICERS_MGMT  \
# 0                              NaN                         NaN
# 1                   {'Total': '0'}              {'Total': '0'}
#
#   F9_09_PC_COMP_OFFICERS_PROG_SVCE F9_09_PC_COMP_OFFICERS_TOTAL  \
# 0                              NaN                          NaN
# 1                   {'Total': '0'}               {'Total': '0'}
#
#                        F9_09_PC_FEES_FOR_SVCE_ACCT_TOT  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
# 1    {'Total': '7500', 'ManagementAndGeneral': '7500'}
#
#   F9_09_PC_FEES_FOR_SVCE_INVST_TOT  \
# 0                              NaN
# 1                   {'Total': '0'}
#
#                    F9_09_PC_FEES_FOR_SVCE_LEGL_TOT  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
# 1                                   {'Total': '0'}
#
#   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT  \
# 0                             NaN
# 1                  {'Total': '0'}
#
#                        F9_09_PC_FEES_FOR_SVCE_MGMT_TOT  \
# 0                                                  NaN
# 1  {'Total': '21600', 'ManagementAndGeneral': '21600'}
#
#   F9_09_PC_FEES_FOR_SVCE_OTH_TOT  \
# 0                            NaN
# 1                 {'Total': '0'}
#
#                  F9_09_PC_OTHER_EMP_BEN_FUNDRAISE  \
# 0                                             NaN
# 1  {'Total': '17714', 'ProgramServices': '17714'}
#
#                       F9_09_PC_OTHER_EMP_BEN_MGMT  \
# 0                                             NaN
# 1  {'Total': '17714', 'ProgramServices': '17714'}
#
#                  F9_09_PC_OTHER_EMP_BEN_PROG_SVCE  \
# 0                                             NaN
# 1  {'Total': '17714', 'ProgramServices': '17714'}
#
#                      F9_09_PC_OTHER_EMP_BEN_TOTAL  \
# 0                                             NaN
# 1  {'Total': '17714', 'ProgramServices': '17714'}
#
#                   F9_09_PC_OTHER_SALARY_FUNDRAISE  \
# 0                                             NaN
# 1  {'Total': '59440', 'ProgramServices': '59440'}
#
#                        F9_09_PC_OTHER_SALARY_MGMT  \
# 0                                             NaN
# 1  {'Total': '59440', 'ProgramServices': '59440'}
#
#                   F9_09_PC_OTHER_SALARY_PROG_SVCE  \
# 0                                             NaN
# 1  {'Total': '59440', 'ProgramServices': '59440'}
#
#                       F9_09_PC_OTHER_SALARY_TOTAL  \
# 0                                             NaN
# 1  {'Total': '59440', 'ProgramServices': '59440'}
#
#                  F9_09_PC_PAYROLL_TAX_FUNDRAISE  \
# 0                                           NaN
# 1  {'Total': '5801', 'ProgramServices': '5801'}
#
#                       F9_09_PC_PAYROLL_TAX_MGMT  \
# 0                                           NaN
# 1  {'Total': '5801', 'ProgramServices': '5801'}
#
#                  F9_09_PC_PAYROLL_TAX_PROG_SVCE  \
# 0                                           NaN
# 1  {'Total': '5801', 'ProgramServices': '5801'}
#
#                      F9_09_PC_PAYROLL_TAX_TOTAL  \
# 0                                           NaN
# 1  {'Total': '5801', 'ProgramServices': '5801'}
#
#   F9_09_PC_PENSION_CONT_FUNDRAISE F9_09_PC_PENSION_CONT_MGMT  \
# 0                             NaN                        NaN
# 1                  {'Total': '0'}             {'Total': '0'}
#
#   F9_09_PC_PENSION_CONT_PROG_SVCE F9_09_PC_PENSION_CONT_TOTAL  \
# 0                             NaN                         NaN
# 1                  {'Total': '0'}              {'Total': '0'}
#
#                                                                                     F9_09_PC_TOTAL_FUNC_EXPENSES  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
# 1          {'Total': '305505', 'ProgramServices': '276405', 'ManagementAndGeneral': '29100', 'Fundraising': '0'}
#
#                                                                                 F9_09_PC_TOTAL_FUNDRAISE_EXPENSE  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
# 1          {'Total': '305505', 'ProgramServices': '276405', 'ManagementAndGeneral': '29100', 'Fundraising': '0'}
#
#                                                                                      F9_09_PC_TOTAL_MGMT_EXPENSE  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
# 1          {'Total': '305505', 'ProgramServices': '276405', 'ManagementAndGeneral': '29100', 'Fundraising': '0'}
#
#                                                                                 F9_09_PC_TOTAL_PROG_SVCE_EXPENSE  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
# 1          {'Total': '305505', 'ProgramServices': '276405', 'ManagementAndGeneral': '29100', 'Fundraising': '0'}
#
#   F9_10_PC_BOND_LIABILITIES_EOY  F9_10_PC_CASH_NON_INTEREST_BOY  \
# 0                           NaN                             NaN
# 1                           NaN  {'BOY': '250', 'EOY': '22261'}
#
#    F9_10_PC_CASH_NON_INTEREST_EOY F9_10_PC_LAND_BLDG_EQPMT  \
# 0                             NaN                   256845
# 1  {'BOY': '250', 'EOY': '22261'}                  2187206
#
#   F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 0                            86228                              NaN
# 1                           904332                              NaN
#
#   F9_10_PC_ORG_FOLLOWS_SFAS117 F9_10_PC_ORG_NOT_FOLLOW_SFAS117  \
# 0                            1                             NaN
# 1                            1                             NaN
#
#       F9_10_PC_OTHER_LIABILITIES_EOY F9_10_PC_RET_EARNINGS_ENDWMT_EOY  \
# 0  {'BOY': '51640', 'EOY': '240077'}                              NaN
# 1    {'BOY': '9203', 'EOY': '11349'}                              NaN
#
#      F9_10_PC_SAVINGS_TEMP_INVEST_BOY    F9_10_PC_SAVINGS_TEMP_INVEST_EOY  \
# 0  {'BOY': '332660', 'EOY': '270700'}  {'BOY': '332660', 'EOY': '270700'}
# 1                        {'EOY': '0'}                        {'EOY': '0'}
#
#    F9_10_PC_SECURED_MORTGAGES_EOY F9_10_PC_UNSECURED_NOTES_BOY  \
# 0                             NaN                          NaN
# 1  {'BOY': '6219', 'EOY': '7035'}                          NaN
#
#   F9_10_PC_UNSECURED_NOTES_EOY             F9_10_PZ_TOTAL_ASSETS_EOY  \
# 0                          NaN  {'BOY': '1925215', 'EOY': '2440859'}
# 1                          NaN  {'BOY': '1455332', 'EOY': '1433342'}
#
#   F9_11_PC_RECNCLTN_DONATED_SVCES F9_11_PC_RECNCLTN_INVSTMNT_EXP  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
#
#   F9_11_PC_RECNCLTN_PRIOR_PER_ADJ F9_11_PC_RECNCLTN_REV_LESS_EXP  \
# 0                             NaN                          89152
# 1                             NaN                         -39085
#
#   F9_11_PC_RECNCLTN_UNRLZD_GAIN F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 0                           NaN                                0
# 1                           NaN                                0
#
#   F9_12_PC_ACCTG_METHOD_ACCRUAL F9_12_PC_ACCTG_METHOD_CASH  \
# 0                             1                        NaN
# 1                             1                        NaN
#
#   F9_12_PC_ACCTG_METHOD_OTHER F9_12_PC_AUDIT_COMMITTEE  \
# 0                         NaN                        1
# 1                         NaN                        1
#
#   F9_12_PC_FED_GRNT_AUDIT_PERFORMD F9_12_PC_FED_GRNT_AUDIT_REQUIRED  \
# 0                              NaN                                0
# 1                                1                                1
#
#   F9_12_PC_FINCL_STMTS_AUDITED  501c3
# 0                            1      1
# 1                            1      1

# %% [markdown]
# ##### Verify

# %%
print(len(df.columns.tolist()))
# Out:
# 199

# %%
set(df.columns.tolist()) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'501c3', 'DLN', 'EIN', 'Filer', 'OrganizationName', 'URL', 'fiscal_year'}

# %%
set(new_variables_df['variable_name_new'].tolist()) - set(df.columns.tolist())
# Out:
# {'F9_00_HD_FILER_STATE_US'}

# %% [markdown]
# ##### Save DF

# %%
# %%time
df.to_pickle('all filings nov. 2020 - all control variables (renamed).pkl.gz', compression='gzip')
# Out:
# Wall time: 34min 19s

# %%
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:1]
# Out:
# # of columns: 199
# # of observations: 1895016
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod        EIN F9_09_PC_FEES_FOR_SVCE_FR_TOT  \
# 0  93493313013011    201012  232705170                           NaN
#
#   fiscal_year  \
# 0        2010
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
#
#   F9_00_HD_BUILD_TIME_STAMP F9_00_HD_ADDR_CHANGE F9_00_HD_AMENDED_RETURN  \
# 0      2016-02-24 21:20:13Z                    1                     NaN
#
#   F9_00_HD_CTRY_OF_DOMICILE F9_00_HD_EXEMPT_STATUS_4847A1  \
# 0                       NaN                           NaN
#
#   F9_00_HD_EXEMPT_STATUS_501C F9_00_HD_EXEMPT_STATUS_501C3  \
# 0                         NaN                            1
#
#   F9_00_HD_FINAL_RETURN F9_00_HD_GROSS_EXEMPT_NUM F9_00_HD_GROSS_RCPT  \
# 0                   NaN                       NaN             1473903
#
#   F9_00_HD_GROUP_RETURN F9_00_HD_INCLUDES_SUBORD_ORGS F9_00_HD_INITIAL_RETURN  \
# 0                     0                           NaN                     NaN
#
#   F9_00_HD_PRIN_OFF_NAME  \
# 0          MICHAEL ANTON
#
#                                                                                                 F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   F9_00_HD_SPECIAL_CONDITION_DESC F9_00_HD_STATE_OF_DOMICILE  \
# 0                             NaN                         PA
#
#   F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR        F9_00_HD_TIME_STAMP  \
# 0           2010-12-31              2010  2011-11-09T06:41:09-06:00
#
#   F9_00_HD_TYPE_ORG_ASSOCIATION F9_00_HD_TYPE_ORG_CORP  \
# 0                           NaN                      1
#
#   F9_00_HD_TYPE_ORG_OTHER F9_00_HD_TYPE_ORG_OTHER_DESC  \
# 0                     NaN                          NaN
#
#   F9_00_HD_TYPE_ORG_TRUST F9_00_HD_WEBSITE F9_00_HD_YEAR_FORMED  \
# 0                     NaN              N/A                 1992
#
#   F9_01_PC_BEN_PAID_MEMB_PRIOR F9_01_PC_CONTR_GRANTS_CURR  \
# 0                            0                    1439340
#
#   F9_01_PC_CONTR_GRANTS_PRIOR F9_01_PC_GRANTS_PRIOR  \
# 0                     1044925                638637
#
#   F9_01_PC_INDEP_VOTING_MEMB F9_01_PC_INVEST_INCOME_PRIOR  \
# 0                         10                        30447
#
#   F9_01_PC_NET_ASSETS_BOY F9_01_PC_OTHER_EXPENSE_PRIOR  \
# 0                 1753405                       243131
#
#   F9_01_PC_OTHER_REV_PRIOR F9_01_PC_PROF_FUNDRISING_EXP_CURR  \
# 0                        0                                 0
#
#   F9_01_PC_PROF_FUNDRISING_EXP_PRIOR F9_01_PC_PROG_SERVICE_REV_PRIOR  \
# 0                                  0                               0
#
#   F9_01_PC_REV_LESS_EXP_CURR F9_01_PC_REV_LESS_EXP_PRIOR  \
# 0                      89152                      193604
#
#   F9_01_PC_TERMINATION_CONTRACTION F9_01_PC_TOT_ASSETS_EOY  \
# 0                              NaN                 2440859
#
#   F9_01_PC_TOT_EXP_PRIOR F9_01_PC_TOT_FNDR_EXP_CURR  \
# 0                 881768                     195892
#
#   F9_01_PC_TOT_INDIV_EMPLOYED F9_01_PC_TOT_INDIV_VOLUNTEERS  \
# 0                           0                             0
#
#   F9_01_PC_TOT_LIABILITIES_EOY F9_01_PC_TOT_REVENUE_PRIOR  \
# 0                       450430                    1075372
#
#   F9_01_PC_TOT_UBI_GROSS F9_01_PC_TOT_UBI_NET F9_01_PC_VOTING_MEMB_GOV_BODY  \
# 0                      0                    0                            10
#
#   F9_01_PZ_BEN_PAID_TO_MEMB_CURR F9_01_PZ_GRANTS_PAID_CURR  \
# 0                              0                    925000
#
#   F9_01_PZ_INVEST_INCOME_CURR F9_01_PZ_NAFB_EOY  \
# 0                       33563           1990429
#
#                                                             F9_01_PZ_ORGANIZATIONAL_MISSION  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   F9_01_PZ_OTHER_EXPENSE_CURR F9_01_PZ_OTHER_REV_CURR  \
# 0                      459751                    1000
#
#   F9_01_PZ_PROG_SERVICE_REV_CURR F9_01_PZ_SALARIES_CURR  \
# 0                              0                      0
#
#   F9_01_PZ_SALARIES_PRIOR F9_01_PZ_TOT_ASSETS_BOY F9_01_PZ_TOT_EXP_CURR  \
# 0                       0                 1925215               1384751
#
#   F9_01_PZ_TOT_LIAB_BOY F9_01_PZ_TOT_REV_CURR F9_04_PC_FR_EVENT_INC_GT_15K  \
# 0                171810               1473903                            0
#
#   F9_04_PC_GAMING_INC_GT_15K F9_04_PC_PROF_FR_EXP_GT_15K  \
# 0                          0                           0
#
#   F9_06_PC_990_PROVIDED_GOV_BODY F9_06_PC_ANNUAL_DISC_COVRD_PERS  \
# 0                              1                               1
#
#   F9_06_PC_CEO_COMPENSTN_PROCESS F9_06_PC_CHANGES_ORGANIZING_DOCS  \
# 0                              0                                0
#
#   F9_06_PC_CONFLICT_OF_INTEREST F9_06_PC_DECISIONS_SUBJ_APPROVAL  \
# 0                             1                                0
#
#   F9_06_PC_DELEGATION_MGT_DUTIES F9_06_PC_DELEGATION_OF_MGT  \
# 0                              0                          0
#
#   F9_06_PC_DOCUMENT_RET_POLICY F9_06_PC_ELECTION_BOARD_MEMBERS  \
# 0                            0                               0
#
#   F9_06_PC_FAMILY_OR_BUSINESS_REL F9_06_PC_FORM_AVAIL_OWN_WEBSITE  \
# 0                               0                             NaN
#
#   F9_06_PC_FORM_UPON_REQUEST F9_06_PC_JOINT_VENTURE_INVESTMNT  \
# 0                          1                                0
#
#   F9_06_PC_JOINT_VENTURE_POLICY F9_06_PC_LOCAL_CHAPTERS  \
# 0                           NaN                       0
#
#   F9_06_PC_MATERIAL_DIVERSION F9_06_PC_MEMBERS_OR_STOCKHOLDERS  \
# 0                           0                                0
#
#   F9_06_PC_MINUTES_COMMITTEES F9_06_PC_MINUTES_GOVERNING_BODY  \
# 0                           1                               1
#
#   F9_06_PC_MONITORING_OF_COI_POLICY F9_06_PC_NUM_IND_VOTING_MEMBERS  \
# 0                                 1                              10
#
#   F9_06_PC_NUM_VOTING_GOV_MEMBERS F9_06_PC_OFFICER_MAILING_ADDRESS  \
# 0                              10                                0
#
#   F9_06_PC_OTHER_COMPENSTN_PROCESS F9_06_PC_OTHER_WEBSITE  \
# 0                                0                    NaN
#
#   F9_06_PC_OWN_WEBSITE F9_06_PC_POLICIES_GOVERN_CHAPTER  \
# 0                  NaN                              NaN
#
#   F9_06_PC_STATES_WHERE_RET_FILED F9_06_PC_WHISTLEBLOWER_POLICY  \
# 0                    [PA, NJ, DE]                             0
#
#   F9_07_PC_COMPENSATION_OTHER_SRCE F9_07_PC_FORMER_OFFICER_LISTED  \
# 0                                0                              0
#
#   F9_07_PC_NO_LISTED_PERS_COMPENSD F9_07_PC_NUM_CONTRCTRS_GRTR_100K  \
# 0                                1                                0
#
#   F9_07_PC_NUM_INDS_GREATER_100K F9_07_PC_TOTAL_COMP_GRTR_150K  \
# 0                              0                             0
#
#   F9_07_PC_TOT_OTHER_COMPENSATION F9_07_PC_TOT_REPRT_COMP_FROM_ORG  \
# 0                               0                                0
#
#   F9_07_PC_TOT_REPRT_COMP_RLTD_ORG F9_08_PC_ALL_OTHER_CONTRIBUTIONS  \
# 0                                0                          1439340
#
#   F9_08_PC_CONTS_REPRTD_FNDRAISNG F9_08_PC_COST_OF_GOODS_SOLD  \
# 0                             NaN                         NaN
#
#   F9_08_PC_FEDERATED_CAMPAIGNS F9_08_PC_FUNDRAISING_DIRECT_EXP  \
# 0                          NaN                             NaN
#
#   F9_08_PC_FUNDRAISING_EVENTS F9_08_PC_FUNDRAISING_GROSS_INC  \
# 0                         NaN                            NaN
#
#   F9_08_PC_GAMING_DIRECT_EXPENSES F9_08_PC_GAMING_GROSS_INCOME  \
# 0                             NaN                          NaN
#
#   F9_08_PC_GOVERNMENT_GRANTS F9_08_PC_GROSS_SALES_INVENTORY  \
# 0                        NaN                            NaN
#
#   F9_08_PC_MEMBERSHIP_DUES F9_08_PC_NONCASH_CONTRIBUTIONS  \
# 0                      NaN                            NaN
#
#   F9_08_PC_PROGRAM_SVCE_REV_TOTAL F9_08_PC_RELATED_ORGANIZATIONS  \
# 0                             NaN                            NaN
#
#   F9_08_PC_TOTAL_CONTRIBUTIONS F9_08_PC_TOTAL_OTHER_REVENUE  \
# 0                      1439340                         1000
#
#   F9_08_PC_TOTAL_PROG_SVCE_REVENUE  \
# 0                              NaN
#
#                                                                                                                     F9_08_PC_TOTAL_REVENUE  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
#
#   F9_09_PC_COMP_DISQUAL_FUNDRAISE F9_09_PC_COMP_DISQUAL_MGMT  \
# 0                             NaN                        NaN
#
#   F9_09_PC_COMP_DISQUAL_PROG_SVCE F9_09_PC_COMP_DISQUAL_TOTAL  \
# 0                             NaN                         NaN
#
#   F9_09_PC_COMP_OFFICERS_FUNDRAISE F9_09_PC_COMP_OFFICERS_MGMT  \
# 0                              NaN                         NaN
#
#   F9_09_PC_COMP_OFFICERS_PROG_SVCE F9_09_PC_COMP_OFFICERS_TOTAL  \
# 0                              NaN                          NaN
#
#                        F9_09_PC_FEES_FOR_SVCE_ACCT_TOT  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
#
#   F9_09_PC_FEES_FOR_SVCE_INVST_TOT  \
# 0                              NaN
#
#                    F9_09_PC_FEES_FOR_SVCE_LEGL_TOT  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
#
#   F9_09_PC_FEES_FOR_SVCE_LOBB_TOT F9_09_PC_FEES_FOR_SVCE_MGMT_TOT  \
# 0                             NaN                             NaN
#
#   F9_09_PC_FEES_FOR_SVCE_OTH_TOT F9_09_PC_OTHER_EMP_BEN_FUNDRAISE  \
# 0                            NaN                              NaN
#
#   F9_09_PC_OTHER_EMP_BEN_MGMT F9_09_PC_OTHER_EMP_BEN_PROG_SVCE  \
# 0                         NaN                              NaN
#
#   F9_09_PC_OTHER_EMP_BEN_TOTAL F9_09_PC_OTHER_SALARY_FUNDRAISE  \
# 0                          NaN                             NaN
#
#   F9_09_PC_OTHER_SALARY_MGMT F9_09_PC_OTHER_SALARY_PROG_SVCE  \
# 0                        NaN                             NaN
#
#   F9_09_PC_OTHER_SALARY_TOTAL F9_09_PC_PAYROLL_TAX_FUNDRAISE  \
# 0                         NaN                            NaN
#
#   F9_09_PC_PAYROLL_TAX_MGMT F9_09_PC_PAYROLL_TAX_PROG_SVCE  \
# 0                       NaN                            NaN
#
#   F9_09_PC_PAYROLL_TAX_TOTAL F9_09_PC_PENSION_CONT_FUNDRAISE  \
# 0                        NaN                             NaN
#
#   F9_09_PC_PENSION_CONT_MGMT F9_09_PC_PENSION_CONT_PROG_SVCE  \
# 0                        NaN                             NaN
#
#   F9_09_PC_PENSION_CONT_TOTAL  \
# 0                         NaN
#
#                                                                                     F9_09_PC_TOTAL_FUNC_EXPENSES  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#                                                                                 F9_09_PC_TOTAL_FUNDRAISE_EXPENSE  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#                                                                                      F9_09_PC_TOTAL_MGMT_EXPENSE  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#                                                                                 F9_09_PC_TOTAL_PROG_SVCE_EXPENSE  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#   F9_10_PC_BOND_LIABILITIES_EOY F9_10_PC_CASH_NON_INTEREST_BOY  \
# 0                           NaN                            NaN
#
#   F9_10_PC_CASH_NON_INTEREST_EOY F9_10_PC_LAND_BLDG_EQPMT  \
# 0                            NaN                   256845
#
#   F9_10_PC_LAND_BLDG_EQPMT_DEPRCTN F9_10_PC_LOANS_FROM_OFFICERS_EOY  \
# 0                            86228                              NaN
#
#   F9_10_PC_ORG_FOLLOWS_SFAS117 F9_10_PC_ORG_NOT_FOLLOW_SFAS117  \
# 0                            1                             NaN
#
#       F9_10_PC_OTHER_LIABILITIES_EOY F9_10_PC_RET_EARNINGS_ENDWMT_EOY  \
# 0  {'BOY': '51640', 'EOY': '240077'}                              NaN
#
#      F9_10_PC_SAVINGS_TEMP_INVEST_BOY    F9_10_PC_SAVINGS_TEMP_INVEST_EOY  \
# 0  {'BOY': '332660', 'EOY': '270700'}  {'BOY': '332660', 'EOY': '270700'}
#
#   F9_10_PC_SECURED_MORTGAGES_EOY F9_10_PC_UNSECURED_NOTES_BOY  \
# 0                            NaN                          NaN
#
#   F9_10_PC_UNSECURED_NOTES_EOY             F9_10_PZ_TOTAL_ASSETS_EOY  \
# 0                          NaN  {'BOY': '1925215', 'EOY': '2440859'}
#
#   F9_11_PC_RECNCLTN_DONATED_SVCES F9_11_PC_RECNCLTN_INVSTMNT_EXP  \
# 0                             NaN                            NaN
#
#   F9_11_PC_RECNCLTN_PRIOR_PER_ADJ F9_11_PC_RECNCLTN_REV_LESS_EXP  \
# 0                             NaN                          89152
#
#   F9_11_PC_RECNCLTN_UNRLZD_GAIN F9_12_PC_ACCNT_COMPILE_OR_REVIEW  \
# 0                           NaN                                0
#
#   F9_12_PC_ACCTG_METHOD_ACCRUAL F9_12_PC_ACCTG_METHOD_CASH  \
# 0                             1                        NaN
#
#   F9_12_PC_ACCTG_METHOD_OTHER F9_12_PC_AUDIT_COMMITTEE  \
# 0                         NaN                        1
#
#   F9_12_PC_FED_GRNT_AUDIT_PERFORMD F9_12_PC_FED_GRNT_AUDIT_REQUIRED  \
# 0                              NaN                                0
#
#   F9_12_PC_FINCL_STMTS_AUDITED  501c3
# 0                            1      1
