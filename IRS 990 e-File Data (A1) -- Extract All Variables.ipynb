# %% [markdown]
# # Overview
# In this notebook I read in a concordance file that has **_all_** reconciled variables to date
# - The file is called *concordance_VERIFIED.xlsx*
#
# # TO DO:
# - In second notebook simply combine and rename
# - In third notebook binarize all relevant variables
#     - Add a column to concordance file that notes all 'binarize' variables
# - Rationalize and/or combine/modify remaining notebooks as needed in order to generate variables

# %% [markdown]
# # Load Packages and Connect to MongoDB

# %%
import sys
import time
import json

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
#http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 250)

# %% [markdown]
# #### Set working directory

# %%
#cd '/Users/gsaxton/Dropbox/990 e-file data'

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# #### MongoDB
# Depending on the project, I will store the data in SQLite or MongoDB. This time I'll use MongoDB -- it's great for storing JSON data where each observation could have different variables. Before we get to the interesting part the following code blocks set up the MongoDB environment and the new database we'll be using.
#
# **_Note:_** In a terminal we'll have to start MongoDB by running the command *mongod* or *sudo mongod*. Then we run the following code block here to access MongoDB.

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient()

# %%
print(pymongo.__version__)
# Out:
# 3.9.0

# %%
MongoClient().list_database_names()
# Out:
# ['ICIJ',
#  'OWS',
#  'Panama',
#  'SMC',
#  'admin',
#  'cashtags',
#  'config',
#  'irs_990_db',
#  'local',
#  'paradisepapers',
#  'sp500',
#  'test']

# %% [markdown]
# ##### This first database we'll define is for storing the File LISTINGS information we've generated above.

# %%
# DEFINE MY mongoDB DATABASE
db = client['irs_990_db']

# DEFINE MY COLLECTION HOUSING 990 DATA
filings_990 = db['filings_990']

# %%
MongoClient().list_database_names()
# Out:
# ['ICIJ',
#  'OWS',
#  'Panama',
#  'SMC',
#  'admin',
#  'cashtags',
#  'config',
#  'irs_990_db',
#  'local',
#  'paradisepapers',
#  'sp500',
#  'test']

# %%
client.list_database_names()
# Out:
# ['ICIJ',
#  'OWS',
#  'Panama',
#  'SMC',
#  'admin',
#  'cashtags',
#  'config',
#  'irs_990_db',
#  'local',
#  'paradisepapers',
#  'sp500',
#  'test']

# %% [markdown]
# <br>When we set up our database in an earlier tutorial, we set a unique constraint on the collection based on *URL*. This averted duplicates from being inserted.

# %% [markdown]
# DuplicateKeyError: E11000 duplicate key error collection: irs_990_db.filings_990 index: URL_1 dup key: { : "https://s3.amazonaws.com/irs-form-990/201100129349301055_public.xml" }
#
# db.getCollection('filings_990').find({'URL' : "https://s3.amazonaws.com/irs-form-990/201100129349301055_public.xml" })

# %%
#OLD CODE
#db.getCollection('filings_990').find({'URL' : "https://s3.amazonaws.com/irs-form-990/201100259349301110_public.xml" })

# %%
db.filings_990.find_one({'URL' : "https://s3.amazonaws.com/irs-form-990/201100289349300910_public.xml" })
# Out:
# {'_id': ObjectId('5d01cfed78ffca27b428aa97'),
#  'OrganizationName': 'ASSEMBLEIA DE DEUS MINISTERIO BELEM CHUR',
#  'ObjectId': '201100289349300910',
#  'URL': 'https://s3.amazonaws.com/irs-form-990/201100289349300910_public.xml',
#  'SubmittedOn': '2011-09-22',
#  'DLN': '93493028009101',
#  'LastUpdated': '2016-03-21T17:23:53',
#  'TaxPeriod': '201012',
#  'FormType': '990',
#  'EIN': '954745380',
#  '@xmlns': 'http://www.irs.gov/efile',
#  '@returnVersion': '2010v3.2',
#  'ReturnHeader': {'@binaryAttachmentCount': '0',
#   'Timestamp': '2011-01-28T13:07:07-08:00',
#   'TaxPeriodEndDate': '2010-12-31',
#   'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'VIRULAS GENERAL OFFICE'},
#    'PreparerFirmUSAddress': {'AddressLine1': '4138 ATLANTIC AVE',
#     'City': 'Long Beach',
#     'State': 'CA',
#     'ZIPCode': '90807'}},
#   'ReturnType': '990',
#   'TaxPeriodBeginDate': '2010-01-01',
#   'Filer': {'EIN': '954745380',
#    'Name': {'BusinessNameLine1': 'ASSEMBLEIA DE DEUS MINISTERIO BELEM CHUR'},
#    'NameControl': 'ASSE',
#    'USAddress': {'AddressLine1': '6520 ARIZONA AVE',
#     'City': 'Los Angeles',
#     'State': 'CA',
#     'ZIPCode': '90045'}},
#   'Officer': {'Name': 'JOEL A DA SILVA',
#    'Title': 'PASTOR',
#    'Phone': '3104149879',
#    'DateSigned': '2011-01-19',
#    'AuthorizeThirdParty': 'false'},
#   'Preparer': {'Name': 'MARIO R VIRULA',
#    'Phone': '5629881169',
#    'DatePrepared': '2011-01-28',
#    'SelfEmployed': 'X'},
#   'TaxYear': '2010',
#   'BuildTS': '2016-02-24 21:20:13Z'},
#  '@documentCount': '3',
#  'IRS990ScheduleA': {'@documentId': '990A', 'Church170b1Ai': 'X'},
#  'IRS990ScheduleO': {'@documentId': '990O',
#   'GeneralExplanation': [{'Identifier': '01. Form 990 governing body review (Part VI, line 11)',
#     'Explanation': 'JOEL A DA SILVA IS AUTHORIZED TO REVIEW AND SIGN WITHOUT THE GOVERNING BODY'},
#    {'Identifier': '02. Governing documents, etc, available to public (Part VI, line 19)',
#     'Explanation': 'nNO OTHER DOCUMENTS ARE AVAILABLE TO THE PUBLIC'}]},
#  '@documentId': '990',
#  'NameOfPrincipalOfficerPerson': 'JOEL A DA SILVA',
#  'GrossReceipts': '68057',
#  'GroupReturnForAffiliates': 'false',
#  'Organization501c3': 'X',
#  'TypeOfOrganizationOther': 'X',
#  'TypeOfOrgOtherDescription': 'CHURCH',
#  'YearFormation': '1999',
#  'StateLegalDomicile': 'CA',
#  'ActivityOrMissionDescription': 'FAMILIES AND TEENAGERS ARE COUNCELED AND SHOWN A BETTER ALTERNATIVE FROM GANGS DIVORCES TO FORM A BETTER SOCIETY',
#  'NbrVotingMembersGoverningBody': '7',
#  'NbrIndependentVotingMembers': '0',
#  'TotalNbrEmployees': '0',
#  'TotalGrossUBI': '0',
#  'NetUnrelatedBusinessTxblIncome': '0',
#  'ContributionsGrantsCurrentYear': '68057',
#  'ProgramServiceRevenueCY': '0',
#  'InvestmentIncomeCurrentYear': '0',
#  'OtherRevenueCurrentYear': '0',
#  'TotalRevenueCurrentYear': '68057',
#  'GrantsAndSimilarAmntsCY': '0',
#  'BenefitsPaidToMembersCY': '0',
#  'SalariesEtcCurrentYear': '23400',
#  'TotalProfFundrsngExpCY': '0',
#  'TotalFundrsngExpCurrentYear': '0',
#  'OtherExpensesCurrentYear': '43346',
#  'TotalExpensesCurrentYear': '66746',
#  'RevenuesLessExpensesCY': '1311',
#  'TotalAssetsEOY': '1311',
#  'TotalLiabilitiesEOY': '0',
#  'NetAssetsOrFundBalancesEOY': '1311',
#  'MissionDescription': 'FAMILIES AND TEENAGERS ARE COUNCELED AND SHOWN A BETTER ALTERNATIVE FROM GANGS DIVORCES TO FORM A BETTER SOCIETY',
#  'SignificantNewProgramServices': 'false',
#  'SignificantChange': 'false',
#  'Expense': '66746',
#  'Description': 'ALL FAMILIES YOUTHS AND PEOPLE FROM VARIOUS BACKROUNDS ARE COUNCELED AND SHOWN A BETTER WAY OF LIFE THAN FROM DIVORCES AND GANGS AND DRUGS SO THAT WE CAN FORM A BETTER SOCIETY',
#  'TotalProgramServiceExpense': '66746',
#  'DescribedIn501C3': {'@referenceDocumentId': '990A', '#text': 'true'},
#  'ScheduleBRequired': 'false',
#  'PoliticalActivities': 'false',
#  'LobbyingActivities': 'false',
#  'DonorAdvisedFunds': 'false',
#  'ConservationEasements': 'false',
#  'CollectionsOfArt': 'false',
#  'CreditCounseling': 'false',
#  'TermOrPermanentEndowments': 'false',
#  'ReportLandBldgEquip': 'false',
#  'ReportInvestOthSecurities': 'false',
#  'ReportProgRelInvest': 'false',
#  'ReportOtherAssets': 'false',
#  'ReportOtherLiabilities': 'false',
#  'ReportFin48Footnote': 'false',
#  'IndependentAuditFinancialStmt': 'false',
#  'ConsolidatedAuditFinancialStmt': 'false',
#  'School': 'false',
#  'ForeignOffice': 'false',
#  'ForeignActivities': 'false',
#  'MoreThan5000KToOrganizations': 'false',
#  'MoreThan5000KToIndividuals': 'false',
#  'ProfessionalFundraising': 'false',
#  'FundraisingActivities': 'false',
#  'Gaming': 'false',
#  'Hospital': 'false',
#  'GrantsToOrganizations': 'false',
#  'GrantsToIndividuals': 'false',
#  'ScheduleJRequired': 'false',
#  'TaxExemptBonds': 'false',
#  'ExcessBenefitTransaction': 'false',
#  'PriorExcessBenefitTransaction': 'false',
#  'LoanToOfficerOrDQP': 'false',
#  'GrantToRelatedPerson': 'false',
#  'BsnssRltnshpWithOrganization': 'false',
#  'BsnssRltnshpThruFamilyMember': 'false',
#  'OfficerEntityWithBsnssRltnshp': 'false',
#  'DeductibleNonCashContributions': 'false',
#  'DeductibleContributionsOfArt': 'false',
#  'Terminated': 'false',
#  'PartialLiquidation': 'false',
#  'DisregardedEntity': 'false',
#  'RelatedEntity': 'false',
#  'RelatedOrgControlledEntity': 'false',
#  'TransactionRelatedEntity': 'false',
#  'TransfersToExemptNonChrtblOrg': 'false',
#  'ActivitiesConductedPartnership': 'false',
#  'ScheduleORequired': 'true',
#  'NumberFormsTransmittedWith1096': '0',
#  'NumberW2GIncluded': '0',
#  'ComplianceWithBackupWitholding': 'false',
#  'NumberOfEmployees': '0',
#  'EmploymentTaxReturnsFiled': 'false',
#  'UnrelatedBusinessIncome': 'false',
#  'ForeignFinancialAccount': 'false',
#  'ProhibitedTaxShelterTrans': 'false',
#  'TaxablePartyNotification': 'false',
#  'NonDeductibleContributions': 'false',
#  'QuidProQuoContributions': 'false',
#  'Form8282PropertyDisposedOf': 'false',
#  'FundsToPayPremiums': 'false',
#  'PremiumsPaid': 'false',
#  'Form8899Filed': 'false',
#  'Form1098CFiled': 'false',
#  'ExcessBusinessHoldings': 'false',
#  'TaxableDistributions': 'false',
#  'DistributionToDonor': 'false',
#  'IndoorTanningServices': 'false',
#  'InfoInScheduleOPartVI': 'X',
#  'NbrVotingGoverningBodyMembers': '7',
#  'NumberIndependentVotingMembers': '0',
#  'FamilyOrBusinessRelationship': 'false',
#  'DelegationOfManagementDuties': 'false',
#  'ChangesToOrganizingDocs': 'false',
#  'MaterialDiversionOrMisuse': 'false',
#  'MembersOrStockholders': 'false',
#  'ElectionOfBoardMembers': 'false',
#  'DecisionsSubjectToApproval': 'false',
#  'MinutesOfGoverningBody': 'true',
#  'MinutesOfCommittees': 'true',
#  'OfficerMailingAddress': 'false',
#  'LocalChapters': 'false',
#  'Form990ProvidedToGoverningBody': 'false',
#  'ConflictOfInterestPolicy': 'false',
#  'WhistleblowerPolicy': 'false',
#  'DocumentRetentionPolicy': 'false',
#  'CompensationProcessCEO': 'false',
#  'CompensationProcessOther': 'false',
#  'InvestmentInJointVenture': 'false',
#  'StatesWhereCopyOfReturnIsFiled': 'CA',
#  'UponRequest': 'X',
#  'TheBooksAreInCareOf': {'NamePerson': 'JOEL A DA SILVA',
#   'TelephoneNumber': '3104149879',
#   'AddressUS': {'AddressLine1': '6520 ARIZONA AVE',
#    'City': 'Los Angeles',
#    'State': 'CA',
#    'ZIPCode': '90045'}},
#  'Form990PartVIISectionA': {'NamePerson': 'JOEL A DA SILVA',
#   'Title': 'PRESIDENT',
#   'AverageHoursPerWeek': '40.00',
#   'IndividualTrusteeOrDirector': 'X',
#   'Officer': 'X',
#   'KeyEmployee': 'X',
#   'HighestCompensatedEmployee': 'X',
#   'ReportableCompFromOrganization': '23400',
#   'ReportableCompFromRelatedOrgs': '0',
#   'OtherCompensation': '0'},
#  'TotalReportableCompFromOrg': '23400',
#  'TotalReportableCompFrmRltdOrgs': '0',
#  'TotalOtherCompensation': '0',
#  'NumberIndividualsGT100K': '0',
#  'FormersListed': 'false',
#  'TotalCompGT150K': 'false',
#  'CompensationFromOtherSources': 'false',
#  'RelatedOrganizations': '68057',
#  'TotalContributions': '68057',
#  'TotalRevenue': {'TotalRevenueColumn': '68057',
#   'RelatedOrExemptFunctionIncome': '0',
#   'UnrelatedBusinessRevenue': '0',
#   'ExclusionAmount': '0'},
#  'OtherSalariesAndWages': {'Total': '23400', 'ProgramServices': '23400'},
#  'OtherExpenses': {'Description': 'CHURCH EXPENSES',
#   'Total': '43346',
#   'ProgramServices': '43346'},
#  'TotalFunctionalExpenses': {'Total': '66746',
#   'ProgramServices': '66746',
#   'ManagementAndGeneral': '0',
#   'Fundraising': '0'},
#  'CashNonInterestBearing': {'EOY': '1311'},
#  'TotalAssets': {'BOY': '0', 'EOY': '1311'},
#  'TotalLiabilities': {'BOY': '0', 'EOY': '0'},
#  'FollowSFAS117': 'X',
#  'UnrestrictedNetAssets': {'EOY': '1311'},
#  'TotalNetAssetsFundBalances': {'BOY': '0', 'EOY': '1311'},
#  'TotalLiabNetAssetsFundBalances': {'BOY': '0', 'EOY': '1311'},
#  'ReconcilationRevenueExpenses': '1311',
#  'MethodOfAccountingCash': 'X',
#  'AccountantCompileOrReview': 'false',
#  'FSAudited': 'false'}

# %%
#db.filings_990.create_index([('URL', pymongo.ASCENDING)], unique=True)

# %%
list(db.filings_990.index_information())
# Out:
# ['_id_', 'URL_1']

# %% [markdown]
# <br>Check how many observations in the database table.
#
# NOTE: in the *v1* file there are ~70,000 duplicates_v1

# %%
1617904 - 1587557
# Out:
# 30347

# %%
filings_990.estimated_document_count()
# Out:
# 1895016

# %%
#import timeit
#start_time = timeit.default_timer()
#df = pd.DataFrame(list(filings_990.find({}, {'URL':1, 
#    '_id':0})))
#elapsed = timeit.default_timer() - start_time
#print('# of minutes: ', elapsed/60)
#print("Number of columns:", len(df.columns))
#print("Number of observations:", len(df))
#df[:1]

# %%
#duplicateRowsDF = df[df.duplicated(['URL'])]
#print("Number of columns:", len(duplicateRowsDF.columns))
#print("Number of observations:", len(duplicateRowsDF))

# %%
#df['test'] = 1

# %%
#dups = df.groupby('URL').count()
#dups[:1]

# %%
#dups['test'].value_counts()

# %%
filings_990.estimated_document_count()
# Out:
# 1895016

# %% [markdown]
# # Read in Concordance File
# We are going to read in two codebooks. First, there is the 'concordance' file. Specifically, before re-arranging and renaming variables, we will read in the relevant section from the *master concordance* file, and then use this file to identify the relevant 'compensation' variables. In a following notebook, we will be using the *new_variable_name* field as our variable name.

# %%
concordance = pd.read_excel('concordance_VERIFIED.xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# # of columns: 17
# # of observations: 384
#                                    xpath project     variable_name_new  \
# 0  /Return/ReturnHeader/TaxPeriodEndDate     NaN  F9_00_HD_TAX_PER_END
# 1    /Return/ReturnHeader/TaxPeriodEndDt     NaN  F9_00_HD_TAX_PER_END
#
#    # of Characters (newly named) variable name notes  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
#
#                        PARSING NOTES OTHER NOTES          description  \
# 0  Will be nested under ReturnHeader         NaN  Tax period end date
# 1  Will be nested under ReturnHeader         NaN  Tax period end date
#
#   location_code part data_type_xsd python_data_type         fill_null  \
# 0        HEADER   HD      DateType           string  Do not fill null
# 1        HEADER   HD      DateType           string  Do not fill null
#
#   BINARIZE      MongoDB_Name sub_key sub_sub_key
# 0      NaN  TaxPeriodEndDate     NaN         NaN
# 1      NaN    TaxPeriodEndDt     NaN         NaN

# %% [markdown]
# <br>Check MongoDB_Name

# %%
print(len(concordance['MongoDB_Name'].tolist()))
print(len(set(concordance['MongoDB_Name'].tolist())))
# Out:
# 384
# 328

# %%
mongo_cols = concordance[:]['MongoDB_Name'].tolist()
print(len(mongo_cols))
print(len(set(mongo_cols)))
mongo_cols = list(set(mongo_cols))
print(len(mongo_cols))
print(mongo_cols[:5])
# Out:
# 384
# 328
# 328
# ['OtherSalariesAndWages', 'ReconcilationDonatedServices', 'RtnEarnEndowmentIncmOthFndsGrp', 'NbrVotingMembersGoverningBody', 'CYOtherExpensesAmt']

# %% [markdown]
# # Extract Data from MongoDB Databse

# %% [markdown]
# Print out a sorted list of our desired columns.

# %%
mongo_cols = [x for x in mongo_cols if str(x) != 'nan']
print(len(mongo_cols))
# Out:
# 328

# %%
print(len(sorted(mongo_cols)))
# Out:
# 328

# %% [markdown]
# <br>Use 'helper' loop to print out variables for MongoDB -- we'll copy and paste this in our next block of code

# %%
for c in sorted(mongo_cols):
    print("    '"+c+"'"+': 1, ')
# Out:
#     'AccountantCompileOrReview': 1,
#     'AccountantCompileOrReviewInd': 1,
#     'ActivityOrMissionDesc': 1,
#     'ActivityOrMissionDescription': 1,
#     'AddressChange': 1,
#     'AddressChangeInd': 1,
#     'AllAffiliatesIncluded': 1,
#     'AllAffiliatesIncludedInd': 1,
#     'AllOtherContributions': 1,
#     'AllOtherContributionsAmt': 1,
#     'AmendedReturn': 1,
#     'AmendedReturnInd': 1,
#     'AnnualDisclosureCoveredPersons': 1,
#     'AnnualDisclosureCoveredPrsnInd': 1,
#     'AuditCommittee': 1,
#     'AuditCommitteeInd': 1,
#     'BenefitsPaidToMembersCY': 1,
#     'BenefitsPaidToMembersPriorYear': 1,
#     'BuildTS': 1,
#     'BusinessOfficerGrp': 1,
#     'CYBenefitsPaidToMembersAmt': 1,
#     'CYContributionsGrantsAmt': 1,
#     'CYGrantsAndSimilarPaidAmt': 1,
#     'CYInvestmentIncomeAmt': 1,
#     'CYOtherExpensesAmt': 1,
#     'CYOtherRevenueAmt': 1,
#     'CYProgramServiceRevenueAmt': 1,
#     'CYRevenuesLessExpensesAmt': 1,
#     'CYSalariesCompEmpBnftPaidAmt': 1,
#     'CYTotalExpensesAmt': 1,
#     'CYTotalFundraisingExpenseAmt': 1,
#     'CYTotalProfFndrsngExpnsAmt': 1,
#     'CYTotalRevenueAmt': 1,
#     'CashNonInterestBearing': 1,
#     'CashNonInterestBearingGrp': 1,
#     'ChangeToOrgDocumentsInd': 1,
#     'ChangesToOrganizingDocs': 1,
#     'CntrbtnsRprtdFundraisingEvents': 1,
#     'CntrctRcvdGreaterThan100KCnt': 1,
#     'CompCurrentOfcrDirectorsGrp': 1,
#     'CompCurrentOfficersDirectors': 1,
#     'CompDisqualPersons': 1,
#     'CompDisqualPersonsGrp': 1,
#     'CompensationFromOtherSources': 1,
#     'CompensationFromOtherSrcsInd': 1,
#     'CompensationProcessCEO': 1,
#     'CompensationProcessCEOInd': 1,
#     'CompensationProcessOther': 1,
#     'CompensationProcessOtherInd': 1,
#     'ConflictOfInterestPolicy': 1,
#     'ConflictOfInterestPolicyInd': 1,
#     'ContractTerminationInd': 1,
#     'ContriRptFundraisingEventAmt': 1,
#     'ContributionsGrantsCurrentYear': 1,
#     'ContributionsGrantsPriorYear': 1,
#     'CostOfGoodsSold': 1,
#     'CostOfGoodsSoldAmt': 1,
#     'CountryLegalDomicile': 1,
#     'DecisionsSubjectToApprovaInd': 1,
#     'DecisionsSubjectToApproval': 1,
#     'DelegationOfManagementDuties': 1,
#     'DelegationOfMgmtDutiesInd': 1,
#     'DoNotFollowSFAS117': 1,
#     'DocumentRetentionPolicy': 1,
#     'DocumentRetentionPolicyInd': 1,
#     'DonatedServicesAndUseFcltsAmt': 1,
#     'ElectionOfBoardMembers': 1,
#     'ElectionOfBoardMembersInd': 1,
#     'FSAudited': 1,
#     'FSAuditedInd': 1,
#     'FamilyOrBusinessRelationship': 1,
#     'FamilyOrBusinessRlnInd': 1,
#     'FederalGrantAuditPerformed': 1,
#     'FederalGrantAuditPerformedInd': 1,
#     'FederalGrantAuditRequired': 1,
#     'FederalGrantAuditRequiredInd': 1,
#     'FederatedCampaigns': 1,
#     'FederatedCampaignsAmt': 1,
#     'FeesForServicesAccounting': 1,
#     'FeesForServicesAccountingGrp': 1,
#     'FeesForServicesInvstMgmntFees': 1,
#     'FeesForServicesLegal': 1,
#     'FeesForServicesLegalGrp': 1,
#     'FeesForServicesLobbying': 1,
#     'FeesForServicesLobbyingGrp': 1,
#     'FeesForServicesManagement': 1,
#     'FeesForServicesManagementGrp': 1,
#     'FeesForServicesOther': 1,
#     'FeesForServicesOtherGrp': 1,
#     'FeesForServicesProfFundraising': 1,
#     'FeesForSrvcInvstMgmntFeesGrp': 1,
#     'Filer': 1,
#     'FinalReturnInd': 1,
#     'FollowSFAS117': 1,
#     'Form990ProvidedToGoverningBody': 1,
#     'Form990ProvidedToGvrnBodyInd': 1,
#     'FormationYr': 1,
#     'FormerOfcrEmployeesListedInd': 1,
#     'FormersListed': 1,
#     'FundraisingActivities': 1,
#     'FundraisingActivitiesInd': 1,
#     'FundraisingAmt': 1,
#     'FundraisingDirectExpenses': 1,
#     'FundraisingDirectExpensesAmt': 1,
#     'FundraisingEvents': 1,
#     'FundraisingGrossIncomeAmt': 1,
#     'Gaming': 1,
#     'GamingActivitiesInd': 1,
#     'GamingDirectExpenses': 1,
#     'GamingDirectExpensesAmt': 1,
#     'GamingGrossIncomeAmt': 1,
#     'GoverningBodyVotingMembersCnt': 1,
#     'GovernmentGrants': 1,
#     'GovernmentGrantsAmt': 1,
#     'GrantsAndSimilarAmntsCY': 1,
#     'GrantsAndSimilarAmntsPriorYear': 1,
#     'GrossIncomeFundraisingEvents': 1,
#     'GrossIncomeGaming': 1,
#     'GrossReceipts': 1,
#     'GrossReceiptsAmt': 1,
#     'GrossSalesOfInventory': 1,
#     'GrossSalesOfInventoryAmt': 1,
#     'GroupExemptionNum': 1,
#     'GroupExemptionNumber': 1,
#     'GroupReturnForAffiliates': 1,
#     'GroupReturnForAffiliatesInd': 1,
#     'IndependentVotingMemberCnt': 1,
#     'IndivRcvdGreaterThan100KCnt': 1,
#     'InitialReturn': 1,
#     'InitialReturnInd': 1,
#     'InvestmentExpenseAmt': 1,
#     'InvestmentInJointVenture': 1,
#     'InvestmentInJointVentureInd': 1,
#     'InvestmentIncomeCurrentYear': 1,
#     'InvestmentIncomePriorYear': 1,
#     'LandBldgEquipAccumDeprecAmt': 1,
#     'LandBldgEquipCostOrOtherBssAmt': 1,
#     'LandBldgEquipmentAccumDeprec': 1,
#     'LandBuildingsEquipmentBasis': 1,
#     'LegalDomicileCountryCd': 1,
#     'LegalDomicileStateCd': 1,
#     'LoansFromOfficersDirectors': 1,
#     'LoansFromOfficersDirectorsGrp': 1,
#     'LocalChapters': 1,
#     'LocalChaptersInd': 1,
#     'MaterialDiversionOrMisuse': 1,
#     'MaterialDiversionOrMisuseInd': 1,
#     'MembersOrStockholders': 1,
#     'MembersOrStockholdersInd': 1,
#     'MembershipDues': 1,
#     'MembershipDuesAmt': 1,
#     'MethodOfAccountingAccrual': 1,
#     'MethodOfAccountingAccrualInd': 1,
#     'MethodOfAccountingCash': 1,
#     'MethodOfAccountingCashInd': 1,
#     'MethodOfAccountingOther': 1,
#     'MethodOfAccountingOtherInd': 1,
#     'MinutesOfCommittees': 1,
#     'MinutesOfCommitteesInd': 1,
#     'MinutesOfGoverningBody': 1,
#     'MinutesOfGoverningBodyInd': 1,
#     'MortNotesPyblSecuredInvestProp': 1,
#     'MortgNotesPyblScrdInvstPropGrp': 1,
#     'NameOfPrincipalOfficerPerson': 1,
#     'NbrIndependentVotingMembers': 1,
#     'NbrVotingGoverningBodyMembers': 1,
#     'NbrVotingMembersGoverningBody': 1,
#     'NetAssetsOrFundBalancesBOY': 1,
#     'NetAssetsOrFundBalancesBOYAmt': 1,
#     'NetAssetsOrFundBalancesEOY': 1,
#     'NetAssetsOrFundBalancesEOYAmt': 1,
#     'NetUnrelatedBusTxblIncmAmt': 1,
#     'NetUnrelatedBusinessTxblIncome': 1,
#     'NetUnrlzdGainsLossesInvstAmt': 1,
#     'NoListedPersonsCompensated': 1,
#     'NoListedPersonsCompensatedInd': 1,
#     'NoncashContributions': 1,
#     'NoncashContributionsAmt': 1,
#     'NumberIndependentVotingMembers': 1,
#     'NumberIndividualsGT100K': 1,
#     'NumberOfContractorsGT100K': 1,
#     'Officer': 1,
#     'OfficerMailingAddress': 1,
#     'OfficerMailingAddressInd': 1,
#     'OrgDoesNotFollowSFAS117Ind': 1,
#     'Organization4947a1': 1,
#     'Organization4947a1NotPFInd': 1,
#     'Organization501c': 1,
#     'Organization501c3': 1,
#     'Organization501c3Ind': 1,
#     'Organization501cInd': 1,
#     'OrganizationFollowsSFAS117Ind': 1,
#     'OtherEmployeeBenefits': 1,
#     'OtherEmployeeBenefitsGrp': 1,
#     'OtherExpensePriorYear': 1,
#     'OtherExpensesCurrentYear': 1,
#     'OtherLiabilities': 1,
#     'OtherLiabilitiesGrp': 1,
#     'OtherOrganizationDsc': 1,
#     'OtherRevenueCurrentYear': 1,
#     'OtherRevenuePriorYear': 1,
#     'OtherRevenueTotalAmt': 1,
#     'OtherSalariesAndWages': 1,
#     'OtherSalariesAndWagesGrp': 1,
#     'OtherWebsite': 1,
#     'OtherWebsiteInd': 1,
#     'OwnWebsite': 1,
#     'OwnWebsiteInd': 1,
#     'PYBenefitsPaidToMembersAmt': 1,
#     'PYContributionsGrantsAmt': 1,
#     'PYGrantsAndSimilarPaidAmt': 1,
#     'PYInvestmentIncomeAmt': 1,
#     'PYOtherExpensesAmt': 1,
#     'PYOtherRevenueAmt': 1,
#     'PYProgramServiceRevenueAmt': 1,
#     'PYRevenuesLessExpensesAmt': 1,
#     'PYSalariesCompEmpBnftPaidAmt': 1,
#     'PYTotalExpensesAmt': 1,
#     'PYTotalProfFndrsngExpnsAmt': 1,
#     'PYTotalRevenueAmt': 1,
#     'PayrollTaxes': 1,
#     'PayrollTaxesGrp': 1,
#     'PensionPlanContributions': 1,
#     'PensionPlanContributionsGrp': 1,
#     'PoliciesReferenceChapters': 1,
#     'PoliciesReferenceChaptersInd': 1,
#     'PrincipalOfficerNm': 1,
#     'PriorPeriodAdjustmentsAmt': 1,
#     'ProfessionalFundraising': 1,
#     'ProfessionalFundraisingInd': 1,
#     'ProgramServiceRevenueCY': 1,
#     'ProgramServiceRevenuePriorYear': 1,
#     'ReconcilationDonatedServices': 1,
#     'ReconcilationInvestExpenses': 1,
#     'ReconcilationPriorAdjustment': 1,
#     'ReconcilationRevenueExpenses': 1,
#     'ReconcilationRevenueExpnssAmt': 1,
#     'ReconciliationUnrealizedInvest': 1,
#     'RegularMonitoringEnforcement': 1,
#     'RegularMonitoringEnfrcInd': 1,
#     'RelatedOrganizations': 1,
#     'RelatedOrganizationsAmt': 1,
#     'RetainedEarningsEndowmentEtc': 1,
#     'ReturnTs': 1,
#     'RevenuesLessExpensesCY': 1,
#     'RevenuesLessExpensesPriorYear': 1,
#     'RtnEarnEndowmentIncmOthFndsGrp': 1,
#     'SalariesEtcCurrentYear': 1,
#     'SalariesEtcPriorYear': 1,
#     'SavingsAndTempCashInvestments': 1,
#     'SavingsAndTempCashInvstGrp': 1,
#     'SpecialConditionDesc': 1,
#     'SpecialConditionDescription': 1,
#     'StateLegalDomicile': 1,
#     'StatesWhereCopyOfReturnIsFiled': 1,
#     'StatesWhereCopyOfReturnIsFldCd': 1,
#     'TaxExemptBondLiabilities': 1,
#     'TaxExemptBondLiabilitiesGrp': 1,
#     'TaxPeriod': 1,
#     'TaxPeriodEndDate': 1,
#     'TaxPeriodEndDt': 1,
#     'TaxYear': 1,
#     'TaxYr': 1,
#     'TerminatedReturn': 1,
#     'TerminationOrContraction': 1,
#     'Timestamp': 1,
#     'TotReportableCompRltdOrgAmt': 1,
#     'TotalAssets': 1,
#     'TotalAssetsBOY': 1,
#     'TotalAssetsBOYAmt': 1,
#     'TotalAssetsEOY': 1,
#     'TotalAssetsEOYAmt': 1,
#     'TotalAssetsGrp': 1,
#     'TotalCompGT150K': 1,
#     'TotalCompGreaterThan150KInd': 1,
#     'TotalContributions': 1,
#     'TotalContributionsAmt': 1,
#     'TotalEmployeeCnt': 1,
#     'TotalExpensesCurrentYear': 1,
#     'TotalExpensesPriorYear': 1,
#     'TotalFunctionalExpenses': 1,
#     'TotalFunctionalExpensesGrp': 1,
#     'TotalFundrsngExpCurrentYear': 1,
#     'TotalGrossUBI': 1,
#     'TotalGrossUBIAmt': 1,
#     'TotalLiabilitiesBOY': 1,
#     'TotalLiabilitiesBOYAmt': 1,
#     'TotalLiabilitiesEOY': 1,
#     'TotalLiabilitiesEOYAmt': 1,
#     'TotalNbrEmployees': 1,
#     'TotalNbrVolunteers': 1,
#     'TotalOtherCompensation': 1,
#     'TotalOtherCompensationAmt': 1,
#     'TotalOtherRevenue': 1,
#     'TotalProfFundrsngExpCY': 1,
#     'TotalProfFundrsngExpPriorYear': 1,
#     'TotalProgramServiceRevenue': 1,
#     'TotalProgramServiceRevenueAmt': 1,
#     'TotalReportableCompFrmRltdOrgs': 1,
#     'TotalReportableCompFromOrg': 1,
#     'TotalReportableCompFromOrgAmt': 1,
#     'TotalRevenue': 1,
#     'TotalRevenueCurrentYear': 1,
#     'TotalRevenueGrp': 1,
#     'TotalRevenuePriorYear': 1,
#     'TotalVolunteersCnt': 1,
#     'TypeOfOrgOtherDescription': 1,
#     'TypeOfOrganizationAssocInd': 1,
#     'TypeOfOrganizationAssociation': 1,
#     'TypeOfOrganizationCorpInd': 1,
#     'TypeOfOrganizationCorporation': 1,
#     'TypeOfOrganizationOther': 1,
#     'TypeOfOrganizationOtherInd': 1,
#     'TypeOfOrganizationTrust': 1,
#     'TypeOfOrganizationTrustInd': 1,
#     'UnsecuredNotesLoansPayable': 1,
#     'UnsecuredNotesLoansPayableGrp': 1,
#     'UponRequest': 1,
#     'UponRequestInd': 1,
#     'VotingMembersGoverningBodyCnt': 1,
#     'VotingMembersIndependentCnt': 1,
#     'WebSite': 1,
#     'WebsiteAddressTxt': 1,
#     'WhistleblowerPolicy': 1,
#     'WhistleblowerPolicyInd': 1,
#     'WrittenPolicyOrProcedure': 1,
#     'WrittenPolicyOrProcedureInd': 1,
#     'YearFormation': 1,

# %% [markdown]
# ### View one row of data from our database
# Paste variables from above into code block below then run to view first row of data. Note that we include four identifier columns (*EIN, OrganizationName, DLN*, and *URL*). We also include *_id* (a MongoDB column) with a '0' tag, meaning we don't want this otherwise automatically included column.

# %%
for f in filings_990.find({})[:1]:
    print(sorted(f.keys()))
# Out:
# ['@documentCount', '@documentId', '@referenceDocumentId', '@returnVersion', '@xmlns', '@xmlns:xsi', '@xsi:schemaLocation', 'AccountantCompileOrReview', 'AccountsPayableAccruedExpenses', 'AccountsReceivable', 'ActivitiesConductedPartnership', 'ActivityOrMissionDescription', 'AddressChange', 'AddressPrincipalOfficerUS', 'AllOtherContributions', 'AllOtherExpenses', 'AnnualDisclosureCoveredPersons', 'AuditCommittee', 'BenefitsPaidToMembersCY', 'BenefitsPaidToMembersPriorYear', 'BsnssRltnshpThruFamilyMember', 'BsnssRltnshpWithOrganization', 'ChangesToOrganizingDocs', 'CollectionsOfArt', 'CompensationFromOtherSources', 'CompensationProcessCEO', 'CompensationProcessOther', 'ComplianceWithBackupWitholding', 'ConflictOfInterestPolicy', 'ConservationEasements', 'ConsolidatedAuditFinancialStmt', 'ContributionsGrantsCurrentYear', 'ContributionsGrantsPriorYear', 'CreditCounseling', 'DLN', 'DecisionsSubjectToApproval', 'DeductibleContributionsOfArt', 'DeductibleNonCashContributions', 'DelegationOfManagementDuties', 'DepreciationDepletion', 'DescribedIn501C3', 'Description', 'DisregardedEntity', 'DocumentRetentionPolicy', 'DonorAdvisedFunds', 'EIN', 'ElectionOfBoardMembers', 'ExcessBenefitTransaction', 'Expense', 'FSAudited', 'FamilyOrBusinessRelationship', 'FederalGrantAuditRequired', 'FeesForServicesAccounting', 'FeesForServicesLegal', 'FinancialStatementSeparate', 'FollowSFAS117', 'ForeignActivities', 'ForeignFinancialAccount', 'ForeignOffice', 'Form8282PropertyDisposedOf', 'Form990PartVIISectionA', 'Form990ProvidedToGoverningBody', 'FormType', 'FormersListed', 'FundraisingActivities', 'FundsToPayPremiums', 'Gaming', 'GrantToRelatedPerson', 'Grants', 'GrantsAndSimilarAmntsCY', 'GrantsAndSimilarAmntsPriorYear', 'GrantsPayable', 'GrantsToDomesticIndividuals', 'GrantsToDomesticOrgs', 'GrantsToIndividuals', 'GrantsToOrganizations', 'GrossReceipts', 'GroupReturnForAffiliates', 'Hospital', 'IRS990ScheduleA', 'IRS990ScheduleB', 'IRS990ScheduleD', 'IRS990ScheduleI', 'IRS990ScheduleO', 'IndependentAuditFinancialStmt', 'IndoorTanningServices', 'InfoInScheduleOPartIII', 'InfoInScheduleOPartVI', 'InfoInScheduleOPartXI', 'InfoInScheduleOPartXII', 'InvestmentInJointVenture', 'InvestmentIncome', 'InvestmentIncomeCurrentYear', 'InvestmentIncomePriorYear', 'InvestmentsOtherSecurities', 'LandBldgEquipmentAccumDeprec', 'LandBuildingsEquipmentBasis', 'LandBuildingsEquipmentBasisNet', 'LastUpdated', 'LoanToOfficerOrDQP', 'LobbyingActivities', 'LocalChapters', 'MaterialDiversionOrMisuse', 'MembersOrStockholders', 'MethodOfAccountingAccrual', 'MinutesOfCommittees', 'MinutesOfGoverningBody', 'MissionDescription', 'MoreThan5000KToIndividuals', 'MoreThan5000KToOrganizations', 'NameOfPrincipalOfficerPerson', 'NbrIndependentVotingMembers', 'NbrVotingGoverningBodyMembers', 'NbrVotingMembersGoverningBody', 'NetAssetsOrFundBalancesBOY', 'NetAssetsOrFundBalancesEOY', 'NetUnrelatedBusinessTxblIncome', 'NoListedPersonsCompensated', 'NonDeductibleContributions', 'NumberFormsTransmittedWith1096', 'NumberIndependentVotingMembers', 'NumberIndividualsGT100K', 'NumberOfContractorsGT100K', 'NumberOfEmployees', 'NumberW2GIncluded', 'ObjectId', 'OfficeExpenses', 'OfficerEntityWithBsnssRltnshp', 'OfficerMailingAddress', 'Organization501c3', 'OrganizationName', 'OtherExpensePriorYear', 'OtherExpenses', 'OtherExpensesCurrentYear', 'OtherLiabilities', 'OtherRevenueCurrentYear', 'OtherRevenueMisc', 'OtherRevenuePriorYear', 'PartialLiquidation', 'PaymentsToAffiliates', 'PoliticalActivities', 'PremiumsPaid', 'PriorExcessBenefitTransaction', 'ProfessionalFundraising', 'ProgramServiceRevenueCY', 'ProgramServiceRevenuePriorYear', 'ProhibitedTaxShelterTrans', 'QuidProQuoContributions', 'ReconcilationOtherChanges', 'ReconcilationRevenueExpenses', 'RegularMonitoringEnforcement', 'RelatedEntity', 'RelatedOrgControlledEntity', 'ReportFin48Footnote', 'ReportInvestOthSecurities', 'ReportLandBldgEquip', 'ReportOtherAssets', 'ReportOtherLiabilities', 'ReportProgRelInvest', 'ReturnHeader', 'RevenuesL ...

# %%
df = pd.DataFrame(list(filings_990.find({}, {'_id': 0, 'EIN': 1, 'OrganizationName': 1, 'DLN': 1, 'URL': 1, 
    'TaxPeriod': 1, #'TaxYr': 1, 'TaxPeriodEndDate': 1, 'TaxPeriodEndDt': 1, 
    'ReturnHeader.TaxYear': 1, 'ReturnHeader.TaxYr': 1,
    #'ReturnHeader': 1,
    'ReturnHeader.TaxPeriodEndDate': 1, 'ReturnHeader.TaxPeriodEndDt': 1,                                       
    'AccountantCompileOrReview': 1, 
    'YearFormation': 1})[:10]))
df
# Out:
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
# 2         HOUSTON VOA INDEPENDENT HOUSING INC HEIGHTS MANOR
# 3                                   FAITH-HAVEN CORPORATION
# 4                               OCHSNER COMMUNITY HOSPITALS
# 5                                  HOUSTON HOUSE FOUNDATION
# 6                                     ADOPTION PLANNING INC
# 7                        CHAMPAIGN RESIDENTIAL SERVICES INC
# 8                              GLENOAKS HOSPITAL FOUNDATION
# 9                            ST PAULS CLINIC FOUNDATION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
# 2  https://s3.amazonaws.com/irs-form-990/201113139349301316_public.xml
# 3  https://s3.amazonaws.com/irs-form-990/201113139349301321_public.xml
# 4  https://s3.amazonaws.com/irs-form-990/201113139349301326_public.xml
# 5  https://s3.amazonaws.com/irs-form-990/201113139349301331_public.xml
# 6  https://s3.amazonaws.com/irs-form-990/201113139349301336_public.xml
# 7  https://s3.amazonaws.com/irs-form-990/201113139349301346_public.xml
# 8  https://s3.amazonaws.com/irs-form-990/201113139349301406_public.xml
# 9  https://s3.amazonaws.com/irs-form-990/201113139349301431_public.xml
#
#               DLN TaxPeriod        EIN  \
# 0  93493313013011    201012  232705170
# 1  93493313013111    201106  581805618
# 2  93493313013161    201106  581876019
# 3  93493313013211    201106  391083432
# 4  93493313013261    201012  205297040
# 5  93493313013311    201012  760314047
# 6  93493313013361    201012  581916251
# 7  93493313013461    201012  341200331
# 8  93493313014061    201012  363926044
# 9  93493313014311    201106  202752128
#
#                                             ReturnHeader YearFormation  \
# 0  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1992
# 1  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          1993
# 2  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          1990
# 3  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          1965
# 4  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          2006
# 5  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1990
# 6  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1989
# 7  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1977
# 8  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1992
# 9  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          2006
#
#   AccountantCompileOrReview
# 0                         0
# 1                     false
# 2                     false
# 3                      true
# 4                         0
# 5                     false
# 6                     false
# 7                      true
# 8                         0
# 9                         0

# %%
df['TAXYEAR'] = df['ReturnHeader'].apply(lambda x: x['TaxYear'])

# %%
df
# Out:
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
# 2         HOUSTON VOA INDEPENDENT HOUSING INC HEIGHTS MANOR
# 3                                   FAITH-HAVEN CORPORATION
# 4                               OCHSNER COMMUNITY HOSPITALS
# 5                                  HOUSTON HOUSE FOUNDATION
# 6                                     ADOPTION PLANNING INC
# 7                        CHAMPAIGN RESIDENTIAL SERVICES INC
# 8                              GLENOAKS HOSPITAL FOUNDATION
# 9                            ST PAULS CLINIC FOUNDATION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
# 2  https://s3.amazonaws.com/irs-form-990/201113139349301316_public.xml
# 3  https://s3.amazonaws.com/irs-form-990/201113139349301321_public.xml
# 4  https://s3.amazonaws.com/irs-form-990/201113139349301326_public.xml
# 5  https://s3.amazonaws.com/irs-form-990/201113139349301331_public.xml
# 6  https://s3.amazonaws.com/irs-form-990/201113139349301336_public.xml
# 7  https://s3.amazonaws.com/irs-form-990/201113139349301346_public.xml
# 8  https://s3.amazonaws.com/irs-form-990/201113139349301406_public.xml
# 9  https://s3.amazonaws.com/irs-form-990/201113139349301431_public.xml
#
#               DLN TaxPeriod        EIN  \
# 0  93493313013011    201012  232705170
# 1  93493313013111    201106  581805618
# 2  93493313013161    201106  581876019
# 3  93493313013211    201106  391083432
# 4  93493313013261    201012  205297040
# 5  93493313013311    201012  760314047
# 6  93493313013361    201012  581916251
# 7  93493313013461    201012  341200331
# 8  93493313014061    201012  363926044
# 9  93493313014311    201106  202752128
#
#                                             ReturnHeader YearFormation  \
# 0  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1992
# 1  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          1993
# 2  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          1990
# 3  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          1965
# 4  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          2006
# 5  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1990
# 6  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1989
# 7  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1977
# 8  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}          1992
# 9  {'TaxPeriodEndDate': '2011-06-30', 'TaxYear': '2010'}          2006
#
#   AccountantCompileOrReview TAXYEAR
# 0                         0    2010
# 1                     false    2010
# 2                     false    2010
# 3                      true    2010
# 4                         0    2010
# 5                     false    2010
# 6                     false    2010
# 7                      true    2010
# 8                         0    2010
# 9                         0    2010

# %% [markdown]
# # Read 990 DB into PANDAS DF
# We can modify the above code block to read all filings into a PANDAS dataframe.

# %% [markdown]
# #### Iterator approach for large datasets
# http://deo.im/2016/09/22/Load-data-from-mongodb-to-Pandas-DataFrame/
#
# n.b. - I added 'sort=False' in the last row in order to turn off future warning. I may need to add this to the append function as well

# %%
def iterator2dataframe(iterator, chunk_size: int):
    #Turn an iterator into multiple small pandas.DataFrame
    #This is a balance between memory and efficiency
    records = []
    frames = []
    for i, record in enumerate(iterator):
        records.append(record)
        if i % chunk_size == chunk_size - 1:
            frames.append(pd.DataFrame(records))
            records = []
    if records:
        frames.append(pd.DataFrame(records))
    return pd.concat(frames, sort=False) if frames else pd.DataFrame()

# %% [markdown]
# ## Now get key data

# %%
import timeit
start_time = timeit.default_timer()

dfx = iterator2dataframe(filings_990.find({}, {'_id': 0, 'EIN': 1, #'OrganizationName': 1, 'DLN': 1, 'URL': 1,                
    'Form990PartIV': 1, 
    'FundraisingActivities': 1, 
    'FundraisingActivitiesInd': 1, 
    'Gaming': 1, 
    'GamingActivitiesInd': 1, 
    'ProfessionalFundraising': 1, 
    'ProfessionalFundraisingInd': 1,
    'Organization501c': 1,
    'Organization501cInd': 1,                                               
    'Organization501c3': 1,
    'Organization501c3Ind': 1})[:10000], 1000)
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60) 
print("Number of columns:", len(dfx.columns))
print("Number of observations:", len(dfx))
dfx[:1]
# Out:
# # of minutes:  0.09721179666667012
# Number of columns: 6
# Number of observations: 10000
#          EIN Organization501c3 ProfessionalFundraising FundraisingActivities  \
# 0  232705170                 X                       0                     0
#
#   Gaming Organization501c
# 0      0              NaN

# %%
# %%time
cursor = filings_990.find({}, {'_id': 0, 'EIN': 1, #'OrganizationName': 1, 'DLN': 1, 'URL': 1,                
    'Form990PartIV': 1, 
    'FundraisingActivities': 1, 
    'FundraisingActivitiesInd': 1, 
    'Gaming': 1, 
    'GamingActivitiesInd': 1, 
    'ProfessionalFundraising': 1, 
    'ProfessionalFundraisingInd': 1,
    'Organization501c': 1,
    'Organization501cInd': 1,                                               
    'Organization501c3': 1,
    'Organization501c3Ind': 1})
dfx = pd.DataFrame()
for batch in batched(cursor, 10000):
    dfx = dfx.append(batch, ignore_index=True)
dfx[:1]
# Out:
# Wall time: 9min 22s
#          EIN Organization501c3 ProfessionalFundraising FundraisingActivities  \
# 0  232705170                 X                       0                     0
#
#   Gaming Organization501c Organization501c3Ind ProfessionalFundraisingInd  \
# 0      0              NaN                  NaN                        NaN
#
#   FundraisingActivitiesInd GamingActivitiesInd Organization501cInd
# 0                      NaN                 NaN                 NaN

# %%
print(len(dfx))
# Out:
# 1895016

# %%
import timeit
start_time = timeit.default_timer()

df = iterator2dataframe(filings_990.find({}, {'_id': 0, 'EIN': 1, 'OrganizationName': 1, 'DLN': 1, 'URL': 1,                
    'TaxPeriod': 1,
    'ReturnHeader': 1}), 10000)
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60) 
print("Number of columns:", len(df.columns))
print("Number of observations:", len(df))
df[:1]
# Out:
# # of minutes:  114.27548303
# Number of columns: 6
# Number of observations: 1895016
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod        EIN  \
# 0  93493313013011    201012  232705170
#
#                                                                                                                                                                                                                                                 ReturnHeader
# 0  {'@binaryAttachmentCount': '0', 'Timestamp': '2011-11-09T06:41:09-06:00', 'TaxPeriodEndDate': '2010-12-31', 'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'CONCANNON MILLER & CO PC'}, 'PreparerFirmUSAddress': {'AddressLine1': ...

# %% [markdown]
# # 2/14/2020 -- Flatten *ReturnHeader* column
# # THIS IS A NEW APPROACH --> FLATTEN THEN REMOVE NON-USED COLUMNS
# # BE SURE TO FOLLOW THROUGH WITH CHANGES TO THE FOLLOWING VARIABLES IN SUBSEQUENT NOTEBOOKS:
#     'ReturnHeader.TaxYear': 1, 'ReturnHeader.TaxYr': 1,
#     'ReturnHeader.TaxPeriodEndDate': 1, 'ReturnHeader.TaxPeriodEndDt': 1,
#
# # 2/19/2020 -- Also added in *Filer* in order to get state
# - See *IRS 990 e-File Data -- CONTROL VARIABLES (A8) -- Prepare Dataset for Statistical Analysis (Select Cases - 501c3, valid data).ipynb*

# %%
import timeit
start_time = timeit.default_timer()
print("Number of columns:", len(df.columns))
df = pd.concat([df.drop(['ReturnHeader'], axis=1), df['ReturnHeader'].apply(pd.Series)], axis=1)
print('# of minutes: ', elapsed/60) 
print("Number of columns:", len(df.columns))
df[:2]
# Out:
# Number of columns: 6
# # of minutes:  114.27548303
# Number of columns: 28
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#               DLN TaxPeriod        EIN @binaryAttachmentCount  \
# 0  93493313013011    201012  232705170                      0
# 1  93493313013111    201106  581805618                      0
#
#                    Timestamp TaxPeriodEndDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31
# 1  2011-11-09T07:32:06-08:00       2011-06-30
#
#                                                                                                                                                                                                                     PreparerFirm  \
# 0  {'PreparerFirmBusinessName': {'BusinessNameLine1': 'CONCANNON MILLER & CO PC'}, 'PreparerFirmUSAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY SUITE 30', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '180172285'}}
# 1             {'PreparerFirmBusinessName': {'BusinessNameLine1': 'MADDOX & ASSOCIATES APC'}, 'PreparerFirmUSAddress': {'AddressLine1': '5627 BANKERS AVE BLDG 2', 'City': 'BATON ROUGE', 'State': 'LA', 'ZIPCode': '708082610'}}
#
#   ReturnType TaxPeriodBeginDate  \
# 0        990         2010-01-01
# 1        990         2010-07-01
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
# 1  {'EIN': '581805618', 'Name': {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}, 'NameControl': 'TORR', 'Phone': '7033415000', 'USAddress': {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA'...
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#                                                 Preparer TaxYear  \
# 0  {'Name': 'E BARRY HETZEL CPA', 'Phone': '6104335501'}    2010
# 1     {'Name': 'WILLIAM B BEALE', 'Phone': '2259263360'}    2010
#
#                 BuildTS DisasterRelief @binaryAttachmentCnt ReturnTs  \
# 0  2016-02-24 21:20:13Z            NaN                  NaN      NaN
# 1  2016-02-24 21:20:13Z            NaN                  NaN      NaN
#
#   TaxPeriodEndDt PreparerFirmGrp ReturnTypeCd TaxPeriodBeginDt  \
# 0            NaN             NaN          NaN              NaN
# 1            NaN             NaN          NaN              NaN
#
#   BusinessOfficerGrp PreparerPersonGrp TaxYr DisasterReliefTxt  \
# 0                NaN               NaN   NaN               NaN
# 1                NaN               NaN   NaN               NaN
#
#   FilingSecurityInformation
# 0                       NaN
# 1                       NaN

# %% [markdown]
# <br>Save DF

# %%
import timeit
start_time = timeit.default_timer()
df.to_pickle('all filings nov. 2020 - select ReturnHeader variables.pkl.gz', compression='gzip')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  4.347203583333339

# %%
print([c for c in df.columns.tolist() if c not in mongo_cols])
omit_cols = ['@binaryAttachmentCount', 'PreparerFirm', 'ReturnType', 'TaxPeriodBeginDate', 'Preparer', 
             'DisasterRelief', '@binaryAttachmentCnt', 'PreparerFirmGrp', 'ReturnTypeCd', 'TaxPeriodBeginDt', 
             'PreparerPersonGrp', 'DisasterReliefTxt', 'FilingSecurityInformation']
print(len(df.columns))
df = df[[c for c in df.columns.tolist() if c not in omit_cols]]
print(len(df))
print(len(df.columns))
df[:1]
# Out:
# ['OrganizationName', 'URL', 'DLN', 'EIN', '@binaryAttachmentCount', 'PreparerFirm', 'ReturnType', 'TaxPeriodBeginDate', 'Preparer', 'DisasterRelief', '@binaryAttachmentCnt', 'PreparerFirmGrp', 'ReturnTypeCd', 'TaxPeriodBeginDt', 'PreparerPersonGrp', 'DisasterReliefTxt', 'FilingSecurityInformation']
# 28
# 1895016
# 15
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod        EIN                  Timestamp  \
# 0  93493313013011    201012  232705170  2011-11-09T06:41:09-06:00
#
#   TaxPeriodEndDate  \
# 0       2010-12-31
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   TaxYear               BuildTS ReturnTs TaxPeriodEndDt BusinessOfficerGrp  \
# 0    2010  2016-02-24 21:20:13Z      NaN            NaN                NaN
#
#   TaxYr
# 0   NaN

# %% [markdown]
# <br>Save *ReturnHeader* DF

# %%
import timeit
start_time = timeit.default_timer()
df.to_pickle('all filings nov. 2020 - select ReturnHeader variables.pkl.gz', compression='gzip')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  2.9783590866666296

# %% [markdown]
# # ENDED HERE 11/23/2020

# %% [markdown]
# # 2/14/2020
# # Update remainder by including only *ReturnHeader* instead of these four:
#
#     'ReturnHeader.TaxYear': 1, 'ReturnHeader.TaxYr': 1,
#     'ReturnHeader.TaxPeriodEndDate': 1, 'ReturnHeader.TaxPeriodEndDt': 1,

# %%
import timeit
start_time = timeit.default_timer()

df = iterator2dataframe(filings_990.find({}, {'_id': 0, 'EIN': 1, 'OrganizationName': 1, 'DLN': 1, 'URL': 1,                
    'TaxPeriod': 1,
    #'ReturnHeader.TaxYear': 1, 'ReturnHeader.TaxYr': 1,
    #'ReturnHeader.TaxPeriodEndDate': 1, 'ReturnHeader.TaxPeriodEndDt': 1,  
    'ReturnHeader': 1,                                              
    'AccountantCompileOrReview': 1, 
    'AccountantCompileOrReviewInd': 1, 
    'ActivityOrMissionDesc': 1, 
    'ActivityOrMissionDescription': 1, 
    'AddressChange': 1, 
    'AddressChangeInd': 1, 
    'AllAffiliatesIncluded': 1, 
    'AllAffiliatesIncludedInd': 1, 
    'AllOtherContributions': 1, 
    'AllOtherContributionsAmt': 1, 
    'AmendedReturn': 1, 
    'AmendedReturnInd': 1, 
    'AnnualDisclosureCoveredPersons': 1, 
    'AnnualDisclosureCoveredPrsnInd': 1, 
    'AuditCommittee': 1, 
    'AuditCommitteeInd': 1, 
    'BenefitsPaidToMembersCY': 1, 
    'BenefitsPaidToMembersPriorYear': 1, 
    'CYBenefitsPaidToMembersAmt': 1, 
    'CYContributionsGrantsAmt': 1, 
    'CYGrantsAndSimilarPaidAmt': 1, 
    'CYInvestmentIncomeAmt': 1, 
    'CYOtherExpensesAmt': 1, 
    'CYOtherRevenueAmt': 1, 
    'CYProgramServiceRevenueAmt': 1, 
    'CYRevenuesLessExpensesAmt': 1, 
    'CYSalariesCompEmpBnftPaidAmt': 1, 
    'CYTotalExpensesAmt': 1, 
    'CYTotalFundraisingExpenseAmt': 1, 
    'CYTotalProfFndrsngExpnsAmt': 1, 
    'CYTotalRevenueAmt': 1, 
    'CashNonInterestBearing': 1, 
    'CashNonInterestBearingGrp': 1, 
    'ChangeToOrgDocumentsInd': 1, 
    'ChangesToOrganizingDocs': 1, 
    'CntrbtnsRprtdFundraisingEvents': 1, 
    'CntrctRcvdGreaterThan100KCnt': 1, 
    'CompCurrentOfcrDirectorsGrp': 1, 
    'CompCurrentOfficersDirectors': 1, 
    'CompDisqualPersons': 1, 
    'CompDisqualPersonsGrp': 1, 
    'CompensationFromOtherSources': 1, 
    'CompensationFromOtherSrcsInd': 1, 
    'CompensationProcessCEO': 1, 
    'CompensationProcessCEOInd': 1, 
    'CompensationProcessOther': 1, 
    'CompensationProcessOtherInd': 1, 
    'ConflictOfInterestPolicy': 1, 
    'ConflictOfInterestPolicyInd': 1, 
    'ContractTerminationInd': 1, 
    'ContriRptFundraisingEventAmt': 1, 
    'ContributionsGrantsCurrentYear': 1, 
    'ContributionsGrantsPriorYear': 1, 
    'CostOfGoodsSold': 1, 
    'CostOfGoodsSoldAmt': 1, 
    'CountryLegalDomicile': 1, 
    'DecisionsSubjectToApprovaInd': 1, 
    'DecisionsSubjectToApproval': 1, 
    'DelegationOfManagementDuties': 1, 
    'DelegationOfMgmtDutiesInd': 1, 
    'DoNotFollowSFAS117': 1, 
    'DocumentRetentionPolicy': 1, 
    'DocumentRetentionPolicyInd': 1, 
    'DonatedServicesAndUseFcltsAmt': 1, 
    'ElectionOfBoardMembers': 1, 
    'ElectionOfBoardMembersInd': 1, 
    'FSAudited': 1, 
    'FSAuditedInd': 1, 
    'FamilyOrBusinessRelationship': 1, 
    'FamilyOrBusinessRlnInd': 1, 
    'FederalGrantAuditPerformed': 1, 
    'FederalGrantAuditPerformedInd': 1, 
    'FederalGrantAuditRequired': 1, 
    'FederalGrantAuditRequiredInd': 1, 
    'FederatedCampaigns': 1, 
    'FederatedCampaignsAmt': 1, 
    'FeesForServicesAccounting': 1, 
    'FeesForServicesAccountingGrp': 1, 
    'FeesForServicesInvstMgmntFees': 1, 
    'FeesForServicesLegal': 1, 
    'FeesForServicesLegalGrp': 1, 
    'FeesForServicesLobbying': 1, 
    'FeesForServicesLobbyingGrp': 1, 
    'FeesForServicesManagement': 1, 
    'FeesForServicesManagementGrp': 1, 
    'FeesForServicesOther': 1, 
    'FeesForServicesOtherGrp': 1, 
    'FeesForServicesProfFundraising': 1, 
    'FeesForSrvcInvstMgmntFeesGrp': 1, 
    'FinalReturnInd': 1, 
    'FollowSFAS117': 1, 
    'Form990ProvidedToGoverningBody': 1, 
    'Form990ProvidedToGvrnBodyInd': 1, 
    'FormationYr': 1, 
    'FormerOfcrEmployeesListedInd': 1, 
    'FormersListed': 1, 
    'FundraisingAmt': 1, 
    'FundraisingDirectExpenses': 1, 
    'FundraisingDirectExpensesAmt': 1, 
    'FundraisingEvents': 1, 
    'FundraisingGrossIncomeAmt': 1, 
    'GamingDirectExpenses': 1, 
    'GamingDirectExpensesAmt': 1, 
    'GamingGrossIncomeAmt': 1, 
    'GoverningBodyVotingMembersCnt': 1, 
    'GovernmentGrants': 1, 
    'GovernmentGrantsAmt': 1, 
    'GrantsAndSimilarAmntsCY': 1, 
    'GrantsAndSimilarAmntsPriorYear': 1, 
    'GrossIncomeFundraisingEvents': 1, 
    'GrossIncomeGaming': 1, 
    'GrossReceipts': 1, 
    'GrossReceiptsAmt': 1, 
    'GrossSalesOfInventory': 1, 
    'GrossSalesOfInventoryAmt': 1, 
    'GroupExemptionNum': 1, 
    'GroupExemptionNumber': 1, 
    'GroupReturnForAffiliates': 1, 
    'GroupReturnForAffiliatesInd': 1, 
    'IndependentVotingMemberCnt': 1, 
    'IndivRcvdGreaterThan100KCnt': 1, 
    'InitialReturn': 1, 
    'InitialReturnInd': 1, 
    'InvestmentExpenseAmt': 1, 
    'InvestmentInJointVenture': 1, 
    'InvestmentInJointVentureInd': 1, 
    'InvestmentIncomeCurrentYear': 1, 
    'InvestmentIncomePriorYear': 1, 
    'LandBldgEquipAccumDeprecAmt': 1, 
    'LandBldgEquipCostOrOtherBssAmt': 1, 
    'LandBldgEquipmentAccumDeprec': 1, 
    'LandBuildingsEquipmentBasis': 1, 
    'LegalDomicileCountryCd': 1, 
    'LegalDomicileStateCd': 1, 
    'LoansFromOfficersDirectors': 1, 
    'LoansFromOfficersDirectorsGrp': 1, 
    'LocalChapters': 1, 
    'LocalChaptersInd': 1, 
    'MaterialDiversionOrMisuse': 1, 
    'MaterialDiversionOrMisuseInd': 1, 
    'MembersOrStockholders': 1, 
    'MembersOrStockholdersInd': 1, 
    'MembershipDues': 1, 
    'MembershipDuesAmt': 1, 
    'MethodOfAccountingAccrual': 1, 
    'MethodOfAccountingAccrualInd': 1, 
    'MethodOfAccountingCash': 1, 
    'MethodOfAccountingCashInd': 1, 
    'MethodOfAccountingOther': 1, 
    'MethodOfAccountingOtherInd': 1, 
    'MinutesOfCommittees': 1, 
    'MinutesOfCommitteesInd': 1, 
    'MinutesOfGoverningBody': 1, 
    'MinutesOfGoverningBodyInd': 1, 
    'MortNotesPyblSecuredInvestProp': 1, 
    'MortgNotesPyblScrdInvstPropGrp': 1, 
    'NameOfPrincipalOfficerPerson': 1, 
    'NbrIndependentVotingMembers': 1, 
    'NbrVotingGoverningBodyMembers': 1, 
    'NbrVotingMembersGoverningBody': 1, 
    'NetAssetsOrFundBalancesBOY': 1, 
    'NetAssetsOrFundBalancesBOYAmt': 1, 
    'NetAssetsOrFundBalancesEOY': 1, 
    'NetAssetsOrFundBalancesEOYAmt': 1, 
    'NetUnrelatedBusTxblIncmAmt': 1, 
    'NetUnrelatedBusinessTxblIncome': 1, 
    'NetUnrlzdGainsLossesInvstAmt': 1, 
    'NoListedPersonsCompensated': 1, 
    'NoListedPersonsCompensatedInd': 1, 
    'NoncashContributions': 1, 
    'NoncashContributionsAmt': 1, 
    'NumberIndependentVotingMembers': 1, 
    'NumberIndividualsGT100K': 1, 
    'NumberOfContractorsGT100K': 1, 
    'OfficerMailingAddress': 1, 
    'OfficerMailingAddressInd': 1, 
    'OrgDoesNotFollowSFAS117Ind': 1, 
    'Organization4947a1': 1, 
    'Organization4947a1NotPFInd': 1, 
    'Organization501c': 1, 
    'Organization501c3': 1, 
    'Organization501c3Ind': 1, 
    'Organization501cInd': 1, 
    'OrganizationFollowsSFAS117Ind': 1, 
    'OtherEmployeeBenefits': 1, 
    'OtherEmployeeBenefitsGrp': 1, 
    'OtherExpensePriorYear': 1, 
    'OtherExpensesCurrentYear': 1, 
    'OtherLiabilities': 1, 
    'OtherLiabilitiesGrp': 1, 
    'OtherOrganizationDsc': 1, 
    'OtherRevenueCurrentYear': 1, 
    'OtherRevenuePriorYear': 1, 
    'OtherRevenueTotalAmt': 1, 
    'OtherSalariesAndWages': 1, 
    'OtherSalariesAndWagesGrp': 1, 
    'OtherWebsite': 1, 
    'OtherWebsiteInd': 1, 
    'OwnWebsite': 1, 
    'OwnWebsiteInd': 1, 
    'PYBenefitsPaidToMembersAmt': 1, 
    'PYContributionsGrantsAmt': 1, 
    'PYGrantsAndSimilarPaidAmt': 1, 
    'PYInvestmentIncomeAmt': 1, 
    'PYOtherExpensesAmt': 1, 
    'PYOtherRevenueAmt': 1, 
    'PYProgramServiceRevenueAmt': 1, 
    'PYRevenuesLessExpensesAmt': 1, 
    'PYSalariesCompEmpBnftPaidAmt': 1, 
    'PYTotalExpensesAmt': 1, 
    'PYTotalProfFndrsngExpnsAmt': 1, 
    'PYTotalRevenueAmt': 1, 
    'PayrollTaxes': 1, 
    'PayrollTaxesGrp': 1, 
    'PensionPlanContributions': 1, 
    'PensionPlanContributionsGrp': 1, 
    'PoliciesReferenceChapters': 1, 
    'PoliciesReferenceChaptersInd': 1, 
    'PrincipalOfficerNm': 1, 
    'PriorPeriodAdjustmentsAmt': 1, 
    'ProgramServiceRevenueCY': 1, 
    'ProgramServiceRevenuePriorYear': 1, 
    'ReconcilationDonatedServices': 1, 
    'ReconcilationInvestExpenses': 1, 
    'ReconcilationPriorAdjustment': 1, 
    'ReconcilationRevenueExpenses': 1, 
    'ReconcilationRevenueExpnssAmt': 1, 
    'ReconciliationUnrealizedInvest': 1, 
    'RegularMonitoringEnforcement': 1, 
    'RegularMonitoringEnfrcInd': 1, 
    'RelatedOrganizations': 1, 
    'RelatedOrganizationsAmt': 1, 
    'RetainedEarningsEndowmentEtc': 1, 
    #'ReturnHeader.TaxPeriodEndDate': 1, 
    #'ReturnHeader.TaxPeriodEndDt': 1, 
    #'ReturnHeader.TaxYear': 1, 
    #'ReturnHeader.TaxYr': 1, 
    'RevenuesLessExpensesCY': 1, 
    'RevenuesLessExpensesPriorYear': 1, 
    'RtnEarnEndowmentIncmOthFndsGrp': 1, 
    'SalariesEtcCurrentYear': 1, 
    'SalariesEtcPriorYear': 1, 
    'SavingsAndTempCashInvestments': 1, 
    'SavingsAndTempCashInvstGrp': 1, 
    'SpecialConditionDesc': 1, 
    'SpecialConditionDescription': 1, 
    'StateLegalDomicile': 1, 
    'StatesWhereCopyOfReturnIsFiled': 1, 
    'StatesWhereCopyOfReturnIsFldCd': 1, 
    'TaxExemptBondLiabilities': 1, 
    'TaxExemptBondLiabilitiesGrp': 1, 
    'TaxPeriod': 1, 
    'TerminatedReturn': 1, 
    'TerminationOrContraction': 1, 
    'TotReportableCompRltdOrgAmt': 1, 
    'TotalAssets': 1, 
    'TotalAssetsBOY': 1, 
    'TotalAssetsBOYAmt': 1, 
    'TotalAssetsEOY': 1, 
    'TotalAssetsEOYAmt': 1, 
    'TotalAssetsGrp': 1, 
    'TotalCompGT150K': 1, 
    'TotalCompGreaterThan150KInd': 1, 
    'TotalContributions': 1, 
    'TotalContributionsAmt': 1, 
    'TotalEmployeeCnt': 1, 
    'TotalExpensesCurrentYear': 1, 
    'TotalExpensesPriorYear': 1, 
    'TotalFunctionalExpenses': 1, 
    'TotalFunctionalExpensesGrp': 1, 
    'TotalFundrsngExpCurrentYear': 1, 
    'TotalGrossUBI': 1, 
    'TotalGrossUBIAmt': 1, 
    'TotalLiabilitiesBOY': 1, 
    'TotalLiabilitiesBOYAmt': 1, 
    'TotalLiabilitiesEOY': 1, 
    'TotalLiabilitiesEOYAmt': 1, 
    'TotalNbrEmployees': 1, 
    'TotalNbrVolunteers': 1, 
    'TotalOtherCompensation': 1, 
    'TotalOtherCompensationAmt': 1, 
    'TotalOtherRevenue': 1, 
    'TotalProfFundrsngExpCY': 1, 
    'TotalProfFundrsngExpPriorYear': 1, 
    'TotalProgramServiceRevenue': 1, 
    'TotalProgramServiceRevenueAmt': 1, 
    'TotalReportableCompFrmRltdOrgs': 1, 
    'TotalReportableCompFromOrg': 1, 
    'TotalReportableCompFromOrgAmt': 1, 
    'TotalRevenue': 1, 
    'TotalRevenueCurrentYear': 1, 
    'TotalRevenueGrp': 1, 
    'TotalRevenuePriorYear': 1, 
    'TotalVolunteersCnt': 1, 
    'TypeOfOrgOtherDescription': 1, 
    'TypeOfOrganizationAssocInd': 1, 
    'TypeOfOrganizationAssociation': 1, 
    'TypeOfOrganizationCorpInd': 1, 
    'TypeOfOrganizationCorporation': 1, 
    'TypeOfOrganizationOther': 1, 
    'TypeOfOrganizationOtherInd': 1, 
    'TypeOfOrganizationTrust': 1, 
    'TypeOfOrganizationTrustInd': 1, 
    'UnsecuredNotesLoansPayable': 1, 
    'UnsecuredNotesLoansPayableGrp': 1, 
    'UponRequest': 1, 
    'UponRequestInd': 1, 
    'VotingMembersGoverningBodyCnt': 1, 
    'VotingMembersIndependentCnt': 1, 
    'WebSite': 1, 
    'WebsiteAddressTxt': 1, 
    'WhistleblowerPolicy': 1, 
    'WhistleblowerPolicyInd': 1, 
    'WrittenPolicyOrProcedure': 1, 
    'WrittenPolicyOrProcedureInd': 1, 
    'YearFormation': 1}), 10000)
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60) 
print("Number of columns:", len(df.columns))
print("Number of observations:", len(df))
df[:1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-eaddc39352c6> in <module>
#     322     'WrittenPolicyOrProcedure': 1,
#     323     'WrittenPolicyOrProcedureInd': 1,
# --> 324     'YearFormation': 1}), 10000)
#     325 elapsed = timeit.default_timer() - start_time
#     326 print('# of minutes: ', elapsed/60)
#
# <ipython-input-20-cfd51d13c460> in iterator2dataframe(iterator, chunk_size)
#       4     records = []
#       5     frames = []
# ----> 6     for i, record in enumerate(iterator):
#       7         records.append(record)
#       8         if i % chunk_size == chunk_size - 1:
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1154         if self.__empty:
#    1155             raise StopIteration
# -> 1156         if len(self.__data) or self._refresh():
#    1157             if self.__manipulate:
#    1158                 _db = self.__collection.database
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1091                                     self.__max_await_time_ms,
#    1092                                     self.__exhaust_mgr)
# -> 1093             self.__send_message(g)
#    1094
#    1095         return len(self.__data)
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     953             response = client._run_operation_with_response(
#     954                 operation, self._unpack_response, exhaust=self.__exhaust,
# --> 955                 address=self.__address)
#     956         except OperationFailure:
#     957             self.__killed = True
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1345             address=address,
#    1346             retryable=isinstance(operation, message._Query),
# -> 1347             exhaust=exhaust)
#    1348
#    1349     def _retry_with_session(self, retryable, func, session, bulk):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1463                         # not support retryable reads, raise the last error.
#    1464                         raise last_error
# -> 1465                     return func(session, server, sock_info, slave_ok)
#    1466             except ServerSelectionTimeoutError:
#    1467                 if retrying:
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _cmd(session, server, sock_info, slave_ok)
#    1339                 self._event_listeners,
#    1340                 exhaust,
# -> 1341                 unpack_res)
#    1342
#    1343         return self._retryable_read(
#
# ~\Anaconda3\lib\site-packages\pymongo\server.py in run_operation_with_response(self, sock_info, operation, set_slave_okay, listeners, exhaust, unpack_res)
#     115             if send_message:
#     116                 sock_info.send_message(data, max_doc_size)
# --> 117                 reply = sock_info.receive_message(request_id)
#     118             else:
#     119                 reply = sock_info.receive_message(None)
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in receive_message(self, request_id)
#     644                                    self.max_message_size)
#     645         except BaseException as error:
# --> 646             self._raise_connection_failure(error)
#     647
#     648     def _raise_if_not_writable(self, unacknowledged):
#
# ~\Anaconda3\lib\site-packages\pymongo\pool.py in receive_message(self, request_id)
#     642         try:
#     643             return receive_message(self.sock, request_id,
# --> 644                                    self.max_message_size)
#     645         except BaseException as error:
#     646             self._raise_connection_failure(error)
#
# ~\Anaconda3\lib\site-packages\pymongo\network.py in receive_message(sock, request_id, max_message_size)
#     194     # Ignore the response's request id.
#     195     length, _, response_to, op_code = _UNPACK_HEADER(
# --> 196         _receive_data_on_socket(sock, 16))
#     197     # No request_id for exhaust cursor "getMore".
#     198     if request_id is not None:
#
# ~\Anaconda3\lib\site-packages\pymongo\network.py in _receive_data_on_socket(sock, length)
#     253         while bytes_read < length:
#     254             try:
# --> 255                 chunk_length = sock.recv_into(mv[bytes_read:])
#     256             except (IOError, OSError) as exc:
#     257                 if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# <br>Feb. 2020 run was 1.7 million observations and previous run was 1,617,920 observations. <br><br>

# %%
def batched(cursor, batch_size):
    batch = []
    for doc in cursor:
        batch.append(doc)
        if batch and not len(batch) % batch_size:
            yield batch
            batch = []
    if batch:   # last documents
        yield batch

# %%
cursor = filings_990.find({}, {'_id': 0, 'EIN': 1, 'OrganizationName': 1, 'DLN': 1, 'URL': 1,  'ReturnHeader': 1,
    'AccountantCompileOrReview': 1, 
    'AccountantCompileOrReviewInd': 1, 
    'ActivityOrMissionDesc': 1, 
    'ActivityOrMissionDescription': 1, 
    'AddressChange': 1, 
    'AddressChangeInd': 1, 
    'AllAffiliatesIncluded': 1, 
    'AllAffiliatesIncludedInd': 1, 
    'AllOtherContributions': 1, 
    'AllOtherContributionsAmt': 1, 
    'AmendedReturn': 1, 
    'AmendedReturnInd': 1, 
    'AnnualDisclosureCoveredPersons': 1, 
    'AnnualDisclosureCoveredPrsnInd': 1, 
    'AuditCommittee': 1, 
    'AuditCommitteeInd': 1, 
    'BenefitsPaidToMembersCY': 1, 
    'BenefitsPaidToMembersPriorYear': 1, 
    'BuildTS': 1, 
    'BusinessOfficerGrp': 1, 
    'CYBenefitsPaidToMembersAmt': 1, 
    'CYContributionsGrantsAmt': 1, 
    'CYGrantsAndSimilarPaidAmt': 1, 
    'CYInvestmentIncomeAmt': 1, 
    'CYOtherExpensesAmt': 1, 
    'CYOtherRevenueAmt': 1, 
    'CYProgramServiceRevenueAmt': 1, 
    'CYRevenuesLessExpensesAmt': 1, 
    'CYSalariesCompEmpBnftPaidAmt': 1, 
    'CYTotalExpensesAmt': 1, 
    'CYTotalFundraisingExpenseAmt': 1, 
    'CYTotalProfFndrsngExpnsAmt': 1, 
    'CYTotalRevenueAmt': 1, 
    'CashNonInterestBearing': 1, 
    'CashNonInterestBearingGrp': 1, 
    'ChangeToOrgDocumentsInd': 1, 
    'ChangesToOrganizingDocs': 1, 
    'CntrbtnsRprtdFundraisingEvents': 1, 
    'CntrctRcvdGreaterThan100KCnt': 1, 
    'CompCurrentOfcrDirectorsGrp': 1, 
    'CompCurrentOfficersDirectors': 1, 
    'CompDisqualPersons': 1, 
    'CompDisqualPersonsGrp': 1, 
    'CompensationFromOtherSources': 1, 
    'CompensationFromOtherSrcsInd': 1, 
    'CompensationProcessCEO': 1, 
    'CompensationProcessCEOInd': 1, 
    'CompensationProcessOther': 1, 
    'CompensationProcessOtherInd': 1, 
    'ConflictOfInterestPolicy': 1, 
    'ConflictOfInterestPolicyInd': 1, 
    'ContractTerminationInd': 1, 
    'ContriRptFundraisingEventAmt': 1, 
    'ContributionsGrantsCurrentYear': 1, 
    'ContributionsGrantsPriorYear': 1, 
    'CostOfGoodsSold': 1, 
    'CostOfGoodsSoldAmt': 1, 
    'CountryLegalDomicile': 1, 
    'DecisionsSubjectToApprovaInd': 1, 
    'DecisionsSubjectToApproval': 1, 
    'DelegationOfManagementDuties': 1, 
    'DelegationOfMgmtDutiesInd': 1, 
    'DoNotFollowSFAS117': 1, 
    'DocumentRetentionPolicy': 1, 
    'DocumentRetentionPolicyInd': 1, 
    'DonatedServicesAndUseFcltsAmt': 1, 
    'ElectionOfBoardMembers': 1, 
    'ElectionOfBoardMembersInd': 1, 
    'FSAudited': 1, 
    'FSAuditedInd': 1, 
    'FamilyOrBusinessRelationship': 1, 
    'FamilyOrBusinessRlnInd': 1, 
    'FederalGrantAuditPerformed': 1, 
    'FederalGrantAuditPerformedInd': 1, 
    'FederalGrantAuditRequired': 1, 
    'FederalGrantAuditRequiredInd': 1, 
    'FederatedCampaigns': 1, 
    'FederatedCampaignsAmt': 1, 
    'FeesForServicesAccounting': 1, 
    'FeesForServicesAccountingGrp': 1, 
    'FeesForServicesInvstMgmntFees': 1, 
    'FeesForServicesLegal': 1, 
    'FeesForServicesLegalGrp': 1, 
    'FeesForServicesLobbying': 1, 
    'FeesForServicesLobbyingGrp': 1, 
    'FeesForServicesManagement': 1, 
    'FeesForServicesManagementGrp': 1, 
    'FeesForServicesOther': 1, 
    'FeesForServicesOtherGrp': 1, 
    'FeesForServicesProfFundraising': 1, 
    'FeesForSrvcInvstMgmntFeesGrp': 1, 
    'Filer': 1, 
    'FinalReturnInd': 1, 
    'FollowSFAS117': 1, 
    'Form990ProvidedToGoverningBody': 1, 
    'Form990ProvidedToGvrnBodyInd': 1, 
    'FormationYr': 1, 
    'FormerOfcrEmployeesListedInd': 1, 
    'FormersListed': 1, 
    'FundraisingActivities': 1, 
    'FundraisingActivitiesInd': 1, 
    'FundraisingAmt': 1, 
    'FundraisingDirectExpenses': 1, 
    'FundraisingDirectExpensesAmt': 1, 
    'FundraisingEvents': 1, 
    'FundraisingGrossIncomeAmt': 1, 
    'Gaming': 1, 
    'GamingActivitiesInd': 1, 
    'GamingDirectExpenses': 1, 
    'GamingDirectExpensesAmt': 1, 
    'GamingGrossIncomeAmt': 1, 
    'GoverningBodyVotingMembersCnt': 1, 
    'GovernmentGrants': 1, 
    'GovernmentGrantsAmt': 1, 
    'GrantsAndSimilarAmntsCY': 1, 
    'GrantsAndSimilarAmntsPriorYear': 1, 
    'GrossIncomeFundraisingEvents': 1, 
    'GrossIncomeGaming': 1, 
    'GrossReceipts': 1, 
    'GrossReceiptsAmt': 1, 
    'GrossSalesOfInventory': 1, 
    'GrossSalesOfInventoryAmt': 1, 
    'GroupExemptionNum': 1, 
    'GroupExemptionNumber': 1, 
    'GroupReturnForAffiliates': 1, 
    'GroupReturnForAffiliatesInd': 1, 
    'IndependentVotingMemberCnt': 1, 
    'IndivRcvdGreaterThan100KCnt': 1, 
    'InitialReturn': 1, 
    'InitialReturnInd': 1, 
    'InvestmentExpenseAmt': 1, 
    'InvestmentInJointVenture': 1, 
    'InvestmentInJointVentureInd': 1, 
    'InvestmentIncomeCurrentYear': 1, 
    'InvestmentIncomePriorYear': 1, 
    'LandBldgEquipAccumDeprecAmt': 1, 
    'LandBldgEquipCostOrOtherBssAmt': 1, 
    'LandBldgEquipmentAccumDeprec': 1, 
    'LandBuildingsEquipmentBasis': 1, 
    'LegalDomicileCountryCd': 1, 
    'LegalDomicileStateCd': 1, 
    'LoansFromOfficersDirectors': 1, 
    'LoansFromOfficersDirectorsGrp': 1, 
    'LocalChapters': 1, 
    'LocalChaptersInd': 1, 
    'MaterialDiversionOrMisuse': 1, 
    'MaterialDiversionOrMisuseInd': 1, 
    'MembersOrStockholders': 1, 
    'MembersOrStockholdersInd': 1, 
    'MembershipDues': 1, 
    'MembershipDuesAmt': 1, 
    'MethodOfAccountingAccrual': 1, 
    'MethodOfAccountingAccrualInd': 1, 
    'MethodOfAccountingCash': 1, 
    'MethodOfAccountingCashInd': 1, 
    'MethodOfAccountingOther': 1, 
    'MethodOfAccountingOtherInd': 1, 
    'MinutesOfCommittees': 1, 
    'MinutesOfCommitteesInd': 1, 
    'MinutesOfGoverningBody': 1, 
    'MinutesOfGoverningBodyInd': 1, 
    'MortNotesPyblSecuredInvestProp': 1, 
    'MortgNotesPyblScrdInvstPropGrp': 1, 
    'NameOfPrincipalOfficerPerson': 1, 
    'NbrIndependentVotingMembers': 1, 
    'NbrVotingGoverningBodyMembers': 1, 
    'NbrVotingMembersGoverningBody': 1, 
    'NetAssetsOrFundBalancesBOY': 1, 
    'NetAssetsOrFundBalancesBOYAmt': 1, 
    'NetAssetsOrFundBalancesEOY': 1, 
    'NetAssetsOrFundBalancesEOYAmt': 1, 
    'NetUnrelatedBusTxblIncmAmt': 1, 
    'NetUnrelatedBusinessTxblIncome': 1, 
    'NetUnrlzdGainsLossesInvstAmt': 1, 
    'NoListedPersonsCompensated': 1, 
    'NoListedPersonsCompensatedInd': 1, 
    'NoncashContributions': 1, 
    'NoncashContributionsAmt': 1, 
    'NumberIndependentVotingMembers': 1, 
    'NumberIndividualsGT100K': 1, 
    'NumberOfContractorsGT100K': 1, 
    'Officer': 1, 
    'OfficerMailingAddress': 1, 
    'OfficerMailingAddressInd': 1, 
    'OrgDoesNotFollowSFAS117Ind': 1, 
    'Organization4947a1': 1, 
    'Organization4947a1NotPFInd': 1, 
    'Organization501c': 1, 
    'Organization501c3': 1, 
    'Organization501c3Ind': 1, 
    'Organization501cInd': 1, 
    'OrganizationFollowsSFAS117Ind': 1, 
    'OtherEmployeeBenefits': 1, 
    'OtherEmployeeBenefitsGrp': 1, 
    'OtherExpensePriorYear': 1, 
    'OtherExpensesCurrentYear': 1, 
    'OtherLiabilities': 1, 
    'OtherLiabilitiesGrp': 1, 
    'OtherOrganizationDsc': 1, 
    'OtherRevenueCurrentYear': 1, 
    'OtherRevenuePriorYear': 1, 
    'OtherRevenueTotalAmt': 1, 
    'OtherSalariesAndWages': 1, 
    'OtherSalariesAndWagesGrp': 1, 
    'OtherWebsite': 1, 
    'OtherWebsiteInd': 1, 
    'OwnWebsite': 1, 
    'OwnWebsiteInd': 1, 
    'PYBenefitsPaidToMembersAmt': 1, 
    'PYContributionsGrantsAmt': 1, 
    'PYGrantsAndSimilarPaidAmt': 1, 
    'PYInvestmentIncomeAmt': 1, 
    'PYOtherExpensesAmt': 1, 
    'PYOtherRevenueAmt': 1, 
    'PYProgramServiceRevenueAmt': 1, 
    'PYRevenuesLessExpensesAmt': 1, 
    'PYSalariesCompEmpBnftPaidAmt': 1, 
    'PYTotalExpensesAmt': 1, 
    'PYTotalProfFndrsngExpnsAmt': 1, 
    'PYTotalRevenueAmt': 1, 
    'PayrollTaxes': 1, 
    'PayrollTaxesGrp': 1, 
    'PensionPlanContributions': 1, 
    'PensionPlanContributionsGrp': 1, 
    'PoliciesReferenceChapters': 1, 
    'PoliciesReferenceChaptersInd': 1, 
    'PrincipalOfficerNm': 1, 
    'PriorPeriodAdjustmentsAmt': 1, 
    'ProfessionalFundraising': 1, 
    'ProfessionalFundraisingInd': 1, 
    'ProgramServiceRevenueCY': 1, 
    'ProgramServiceRevenuePriorYear': 1, 
    'ReconcilationDonatedServices': 1, 
    'ReconcilationInvestExpenses': 1, 
    'ReconcilationPriorAdjustment': 1, 
    'ReconcilationRevenueExpenses': 1, 
    'ReconcilationRevenueExpnssAmt': 1, 
    'ReconciliationUnrealizedInvest': 1, 
    'RegularMonitoringEnforcement': 1, 
    'RegularMonitoringEnfrcInd': 1, 
    'RelatedOrganizations': 1, 
    'RelatedOrganizationsAmt': 1, 
    'RetainedEarningsEndowmentEtc': 1, 
    'ReturnTs': 1, 
    'RevenuesLessExpensesCY': 1, 
    'RevenuesLessExpensesPriorYear': 1, 
    'RtnEarnEndowmentIncmOthFndsGrp': 1, 
    'SalariesEtcCurrentYear': 1, 
    'SalariesEtcPriorYear': 1, 
    'SavingsAndTempCashInvestments': 1, 
    'SavingsAndTempCashInvstGrp': 1, 
    'SpecialConditionDesc': 1, 
    'SpecialConditionDescription': 1, 
    'StateLegalDomicile': 1, 
    'StatesWhereCopyOfReturnIsFiled': 1, 
    'StatesWhereCopyOfReturnIsFldCd': 1, 
    'TaxExemptBondLiabilities': 1, 
    'TaxExemptBondLiabilitiesGrp': 1, 
    'TaxPeriod': 1, 
    'TaxPeriodEndDate': 1, 
    'TaxPeriodEndDt': 1, 
    'TaxYear': 1, 
    'TaxYr': 1, 
    'TerminatedReturn': 1, 
    'TerminationOrContraction': 1, 
    'Timestamp': 1, 
    'TotReportableCompRltdOrgAmt': 1, 
    'TotalAssets': 1, 
    'TotalAssetsBOY': 1, 
    'TotalAssetsBOYAmt': 1, 
    'TotalAssetsEOY': 1, 
    'TotalAssetsEOYAmt': 1, 
    'TotalAssetsGrp': 1, 
    'TotalCompGT150K': 1, 
    'TotalCompGreaterThan150KInd': 1, 
    'TotalContributions': 1, 
    'TotalContributionsAmt': 1, 
    'TotalEmployeeCnt': 1, 
    'TotalExpensesCurrentYear': 1, 
    'TotalExpensesPriorYear': 1, 
    'TotalFunctionalExpenses': 1, 
    'TotalFunctionalExpensesGrp': 1, 
    'TotalFundrsngExpCurrentYear': 1, 
    'TotalGrossUBI': 1, 
    'TotalGrossUBIAmt': 1, 
    'TotalLiabilitiesBOY': 1, 
    'TotalLiabilitiesBOYAmt': 1, 
    'TotalLiabilitiesEOY': 1, 
    'TotalLiabilitiesEOYAmt': 1, 
    'TotalNbrEmployees': 1, 
    'TotalNbrVolunteers': 1, 
    'TotalOtherCompensation': 1, 
    'TotalOtherCompensationAmt': 1, 
    'TotalOtherRevenue': 1, 
    'TotalProfFundrsngExpCY': 1, 
    'TotalProfFundrsngExpPriorYear': 1, 
    'TotalProgramServiceRevenue': 1, 
    'TotalProgramServiceRevenueAmt': 1, 
    'TotalReportableCompFrmRltdOrgs': 1, 
    'TotalReportableCompFromOrg': 1, 
    'TotalReportableCompFromOrgAmt': 1, 
    'TotalRevenue': 1, 
    'TotalRevenueCurrentYear': 1, 
    'TotalRevenueGrp': 1, 
    'TotalRevenuePriorYear': 1, 
    'TotalVolunteersCnt': 1, 
    'TypeOfOrgOtherDescription': 1, 
    'TypeOfOrganizationAssocInd': 1, 
    'TypeOfOrganizationAssociation': 1, 
    'TypeOfOrganizationCorpInd': 1, 
    'TypeOfOrganizationCorporation': 1, 
    'TypeOfOrganizationOther': 1, 
    'TypeOfOrganizationOtherInd': 1, 
    'TypeOfOrganizationTrust': 1, 
    'TypeOfOrganizationTrustInd': 1, 
    'UnsecuredNotesLoansPayable': 1, 
    'UnsecuredNotesLoansPayableGrp': 1, 
    'UponRequest': 1, 
    'UponRequestInd': 1, 
    'VotingMembersGoverningBodyCnt': 1, 
    'VotingMembersIndependentCnt': 1, 
    'WebSite': 1, 
    'WebsiteAddressTxt': 1, 
    'WhistleblowerPolicy': 1, 
    'WhistleblowerPolicyInd': 1, 
    'WrittenPolicyOrProcedure': 1, 
    'WrittenPolicyOrProcedureInd': 1, 
    'YearFormation': 1})

# %% [markdown]
# # THIS WORKED!

# %%
# %%time
df = pd.DataFrame()
for batch in batched(cursor, 100000):
    df = df.append(batch, ignore_index=True)
df[:1]
# Out:
# Wall time: 1h 33min 37s
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod        EIN  \
# 0  93493313013011    201012  232705170
#
#                                                                                                                                                                                                                                                 ReturnHeader  \
# 0  {'@binaryAttachmentCount': '0', 'Timestamp': '2011-11-09T06:41:09-06:00', 'TaxPeriodEndDate': '2010-12-31', 'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'CONCANNON MILLER & CO PC'}, 'PreparerFirmUSAddress': {'AddressLine1': ...
#
#   AddressChange NameOfPrincipalOfficerPerson GrossReceipts  \
# 0             X                MICHAEL ANTON       1473903
#
#   GroupReturnForAffiliates Organization501c3 WebSite  \
# 0                        0                 X     N/A
#
#   TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 0                             X          1992                 PA
#
#                                                                ActivityOrMissionDescription  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
#
#   ProfessionalFundraising FundraisingActivities Gaming  \
# 0                       0                     0      0
#
#   NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 0                            10                             10
#
#   FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 0                            0                            0
#
#   ChangesToOrganizingDocs MaterialDiversionOrMisuse MembersOrStockholders  \
# 0                       0                         0                     0
#
#   ElectionOfBoardMembers DecisionsSubjectToApproval MinutesOfGoverningBody  \
# 0                      0                          0                      1
#
#   MinutesOfCommittees OfficerMailingAddress LocalChapters  \
# 0                   1                     0             0
#
#   Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 0                              1                        1
#
#   AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 0                              1                            1
#
#   WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 0                   0                       0                      0
#
#   CompensationProcessOther InvestmentInJointVenture  \
# 0                        0                        0
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0                   [PA, NJ, DE]           X                          X
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
#
#                               FeesForServicesLegal  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 0  {'BOY': '332660', 'EOY': '270700'}                      256845
#
#   LandBldgEquipmentAccumDeprec                           TotalAssets  \
# 0                        86228  {'BOY': '1925215', 'EOY': '2440859'}
#
#                     OtherLiabilities FollowSFAS117  \
# 0  {'BOY': '51640', 'EOY': '240077'}             X
#
#   ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 0                        89152                         X
#
#   AccountantCompileOrReview FSAudited AuditCommittee  \
# 0                         0         1              1
#
#   FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 0                         0                   NaN                  NaN
#
#   PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 0                       NaN                      NaN
#
#   TotalProgramServiceRevenue CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                        NaN                          NaN                NaN
#
#   OtherSalariesAndWages PensionPlanContributions OtherEmployeeBenefits  \
# 0                   NaN                      NaN                   NaN
#
#   PayrollTaxes FeesForServicesManagement FeesForServicesLobbying  \
# 0          NaN                       NaN                     NaN
#
#   FeesForServicesProfFundraising FeesForServicesInvstMgmntFees  \
# 0                            NaN                           NaN
#
#   FeesForServicesOther CashNonInterestBearing MortNotesPyblSecuredInvestProp  \
# 0                  NaN                    NaN                            NaN
#
#   FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 0                        NaN                        NaN
#
#   MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 0                    NaN                      NaN          NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0               NaN                            NaN                  NaN
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                          NaN                       NaN                NaN
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0              NaN                     NaN                   NaN
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0             NaN                NaN                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0           NaN            NaN               NaN                  NaN
#
#   NoncashContributions OwnWebsite UnsecuredNotesLoansPayable  \
# 0                  NaN        NaN                        NaN
#
#   TypeOfOrganizationOther Organization501c TypeOfOrganizationTrust  \
# 0                     NaN              NaN                     NaN
#
#   TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 0                           NaN                  NaN           NaN
#
#   TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 0                       NaN              NaN                      NaN
#
#   SpecialConditionDescription Organization4947a1  \
# 0                         NaN                NaN
#
#   ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 0                            NaN                          NaN
#
#   ReconcilationDonatedServices ReconcilationInvestExpenses PrincipalOfficerNm  \
# 0                          NaN                         NaN                NaN
#
#   GrossReceiptsAmt GroupReturnForAffiliatesInd Organization501c3Ind  \
# 0              NaN                         NaN                  NaN
#
#   TypeOfOrganizationCorpInd FormationYr LegalDomicileStateCd  \
# 0                       NaN         NaN                  NaN
#
#   ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                   NaN                           NaN
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                         NaN              NaN              NaN
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                      NaN                        NaN                   NaN
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0               NaN               NaN                       NaN
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                        NaN                          NaN
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                        NaN                          NaN                NaN
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0                NaN                       NaN               NaN
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0               NaN                    NaN                           NaN
#
#   NetAssetsOrFundBalancesEOYAmt ProfessionalFundraisingInd  \
# 0                           NaN                        NaN
#
#   FundraisingActivitiesInd GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 0                      NaN                 NaN                           NaN
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                        NaN                    NaN                       NaN
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                     NaN                          NaN
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                      NaN                       NaN
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                          NaN                       NaN
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                    NaN                      NaN              NaN
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                          NaN                         NaN
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                    NaN                        NaN                       NaN
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                         NaN                         NaN
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                            NaN                           NaN
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                          NaN                         NaN
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                          NaN               NaN            NaN
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                      NaN                   NaN                  NaN
#
#   TotalRevenueGrp FeesForServicesAccountingGrp TotalFunctionalExpensesGrp  \
# 0             NaN                          NaN                        NaN
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                       NaN            NaN                        NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                            NaN                           NaN
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                       NaN                          NaN          NaN
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                          NaN               NaN                NaN
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                        NaN                      NaN
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                        NaN                   NaN               NaN
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0               NaN                       NaN                        NaN
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                          NaN                        NaN                NaN
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0                NaN                       NaN                    NaN
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                            NaN                       NaN            NaN
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                           NaN                         NaN
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                       NaN                         NaN
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                          NaN                 NaN
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                           NaN                       NaN
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                          NaN                          NaN
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt CompCurrentOfcrDirectorsGrp  \
# 0                      NaN                NaN                         NaN
#
#   OtherSalariesAndWagesGrp PensionPlanContributionsGrp  \
# 0                      NaN                         NaN
#
#   OtherEmployeeBenefitsGrp PayrollTaxesGrp FeesForServicesOtherGrp  \
# 0                      NaN             NaN                     NaN
#
#   SavingsAndTempCashInvstGrp LandBldgEquipCostOrOtherBssAmt  \
# 0                        NaN                            NaN
#
#   LandBldgEquipAccumDeprecAmt MortgNotesPyblScrdInvstPropGrp  \
# 0                         NaN                            NaN
#
#   OtherLiabilitiesGrp OrganizationFollowsSFAS117Ind  \
# 0                 NaN                           NaN
#
#   NetUnrlzdGainsLossesInvstAmt AuditCommitteeInd AllAffiliatesIncludedInd  \
# 0                          NaN               NaN                      NaN
#
#   CompDisqualPersonsGrp FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 0                        NaN                          NaN
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 0                          NaN                     NaN
#
#   TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 0                         NaN                           NaN
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                           NaN                       NaN
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                           NaN                          NaN             NaN
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0              NaN                         NaN                     NaN
#
#   OwnWebsiteInd DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0           NaN                           NaN                    NaN
#
#   TypeOfOrganizationTrustInd FinalReturnInd ContractTerminationInd  \
# 0                        NaN            NaN                    NaN
#
#   GroupExemptionNum FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0               NaN                   NaN                        NaN
#
#   OtherOrganizationDsc TypeOfOrganizationAssocInd InitialReturnInd  \
# 0                  NaN                        NaN              NaN
#
#   GamingGrossIncomeAmt GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 0                  NaN                     NaN                        NaN
#
#   InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 0                  NaN                 NaN                        NaN
#
#   AmendedReturnInd SpecialConditionDesc
# 0              NaN                  NaN

# %% [markdown]
# #### Save DF

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %%
# %%time
df.to_pickle('all filings nov. 2020 - all control variables.pkl.gz', compression='gzip')
# Out:
# Wall time: 26min 48s

# %% [markdown]
# # Note 1/1/2021
# One row has several missing variables fixed in two subsequent notebooks. See the next few code blocks. Fix in next iteration.
#
# Not sure why this happened. The index file has the correct information, and this should have just been inserted.
# - {"EIN":"204814407","TaxPeriod":"201812","DLN":"93493319065509","FormType":"990","URL":"https://s3.amazonaws.com/irs-form-990/201903199349306550_public.xml","OrganizationName":"PLAY FLAG FOOTBALL","SubmittedOn":"2020-01-17","ObjectId":"201903199349306550","LastUpdated":"2020-07-28T16:00:13"}

# %%
df.loc[[1895015]]
# Out:
#         OrganizationName  URL  DLN TaxPeriod  EIN  \
# 1895015              NaN  NaN  NaN       NaN  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ReturnHeader  \
# 1895015  {'@binaryAttachmentCnt': '0', 'ReturnTs': '2019-11-15T10:29:26-06:00', 'TaxPeriodEndDt': '2018-12-31', 'PreparerFirmGrp': {'PreparerFirmEIN': '770051130', 'PreparerFirmName': {'BusinessNameLine1Txt': 'ABBOTT STRINGHAM & LYNCH'}, 'PreparerUSAddress': {'AddressLine1Txt': '1530 MERIDIAN AVE 2ND FLR', 'CityNm': 'SAN JOSE', 'StateAbbreviationCd': 'CA', 'ZIPCd': '95125'}}, 'ReturnTypeCd': '990', 'TaxPeriodBeginDt': '2018-01-01', 'Filer': {'EIN': '204814407', 'BusinessName': {'BusinessNameLine1Txt': 'PLAY FLAG FOOTBALL'}, 'BusinessNameControlTxt': 'PLAY', 'PhoneNum': '4083700500', 'USAddress': {'AddressLine1Txt': '545 WESTCHESTER DR NO A', 'CityNm': 'CAMPBELL', 'StateAbbreviationCd': 'CA', 'ZIPCd': '95008'}}, 'BusinessOfficerGrp': {'PersonNm': 'JOHN MORA', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '4083700500', 'SignatureDt': '2019-11-14', 'DiscussWithPaidPreparerInd': '1'}, 'PreparerPersonGrp': {'PreparerPersonNm': 'FRANK L BOITANO', 'PTIN': 'P00058069', 'PhoneNum': '4083778700', 'PreparationDt': '2019-11-14'}, 'FilingSecurityInformation': {'IPAddress': {'IPv4AddressTxt': '12.217.167.71'}, 'IPDt': '2019-11-14', 'IPTm': '12:01:59', 'IPTimezoneCd': 'PS', 'FilingLicenseTypeCd': 'P', 'AtSubmissionCreationDeviceId': 'F2CBB06AF0C0BFA6D697359176620E55FDB7D752', 'AtSubmissionFilingDeviceId': 'A3800E77008D47A4C38094878DB0F53CA65DCD5F'}, 'TaxYr': '2018', 'BuildTS': '2020-04-17 16:48:07Z'}
#
#         AddressChange NameOfPrincipalOfficerPerson GrossReceipts  \
# 1895015           NaN                          NaN           NaN
#
#         GroupReturnForAffiliates Organization501c3 WebSite  \
# 1895015                      NaN               NaN     NaN
#
#         TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 1895015                           NaN           NaN                NaN
#
#         ActivityOrMissionDescription NbrVotingMembersGoverningBody  \
# 1895015                          NaN                           NaN
#
#         NbrIndependentVotingMembers TotalNbrEmployees TotalNbrVolunteers  \
# 1895015                         NaN               NaN                NaN
#
#         TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 1895015           NaN                            NaN
#
#         ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 1895015                          NaN                            NaN
#
#         ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 1895015                            NaN                     NaN
#
#         InvestmentIncomePriorYear InvestmentIncomeCurrentYear  \
# 1895015                       NaN                         NaN
#
#         OtherRevenuePriorYear OtherRevenueCurrentYear TotalRevenuePriorYear  \
# 1895015                   NaN                     NaN                   NaN
#
#         TotalRevenueCurrentYear GrantsAndSimilarAmntsPriorYear  \
# 1895015                     NaN                            NaN
#
#         GrantsAndSimilarAmntsCY BenefitsPaidToMembersPriorYear  \
# 1895015                     NaN                            NaN
#
#         BenefitsPaidToMembersCY SalariesEtcPriorYear SalariesEtcCurrentYear  \
# 1895015                     NaN                  NaN                    NaN
#
#         TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 1895015                           NaN                    NaN
#
#         TotalFundrsngExpCurrentYear OtherExpensePriorYear  \
# 1895015                         NaN                   NaN
#
#         OtherExpensesCurrentYear TotalExpensesPriorYear  \
# 1895015                      NaN                    NaN
#
#         TotalExpensesCurrentYear RevenuesLessExpensesPriorYear  \
# 1895015                      NaN                           NaN
#
#         RevenuesLessExpensesCY TotalAssetsBOY TotalAssetsEOY  \
# 1895015                    NaN            NaN            NaN
#
#         TotalLiabilitiesBOY TotalLiabilitiesEOY NetAssetsOrFundBalancesBOY  \
# 1895015                 NaN                 NaN                        NaN
#
#         NetAssetsOrFundBalancesEOY ProfessionalFundraising  \
# 1895015                        NaN                     NaN
#
#         FundraisingActivities Gaming NbrVotingGoverningBodyMembers  \
# 1895015                   NaN    NaN                           NaN
#
#         NumberIndependentVotingMembers FamilyOrBusinessRelationship  \
# 1895015                            NaN                          NaN
#
#         DelegationOfManagementDuties ChangesToOrganizingDocs  \
# 1895015                          NaN                     NaN
#
#         MaterialDiversionOrMisuse MembersOrStockholders  \
# 1895015                       NaN                   NaN
#
#         ElectionOfBoardMembers DecisionsSubjectToApproval  \
# 1895015                    NaN                        NaN
#
#         MinutesOfGoverningBody MinutesOfCommittees OfficerMailingAddress  \
# 1895015                    NaN                 NaN                   NaN
#
#         LocalChapters Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 1895015           NaN                            NaN                      NaN
#
#         AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 1895015                            NaN                          NaN
#
#         WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 1895015                 NaN                     NaN                    NaN
#
#         CompensationProcessOther InvestmentInJointVenture  \
# 1895015                      NaN                      NaN
#
#         StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 1895015                            NaN         NaN                        NaN
#
#         TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 1895015                        NaN                            NaN
#
#         TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 1895015                    NaN                     NaN           NaN
#
#         TotalCompGT150K CompensationFromOtherSources  \
# 1895015             NaN                          NaN
#
#         NumberOfContractorsGT100K AllOtherContributions TotalContributions  \
# 1895015                       NaN                   NaN                NaN
#
#         TotalOtherRevenue TotalRevenue FeesForServicesLegal  \
# 1895015               NaN          NaN                  NaN
#
#         FeesForServicesAccounting TotalFunctionalExpenses  \
# 1895015                       NaN                     NaN
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 1895015                           NaN                         NaN
#
#         LandBldgEquipmentAccumDeprec TotalAssets OtherLiabilities  \
# 1895015                          NaN         NaN              NaN
#
#         FollowSFAS117 ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 1895015           NaN                          NaN                       NaN
#
#         AccountantCompileOrReview FSAudited AuditCommittee  \
# 1895015                       NaN       NaN            NaN
#
#         FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 1895015                       NaN                   NaN                  NaN
#
#         PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 1895015                       NaN                      NaN
#
#         TotalProgramServiceRevenue CompCurrentOfficersDirectors  \
# 1895015                        NaN                          NaN
#
#         CompDisqualPersons OtherSalariesAndWages PensionPlanContributions  \
# 1895015                NaN                   NaN                      NaN
#
#         OtherEmployeeBenefits PayrollTaxes FeesForServicesManagement  \
# 1895015                   NaN          NaN                       NaN
#
#         FeesForServicesLobbying FeesForServicesProfFundraising  \
# 1895015                     NaN                            NaN
#
#         FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 1895015                           NaN                  NaN
#
#         CashNonInterestBearing MortNotesPyblSecuredInvestProp  \
# 1895015                    NaN                            NaN
#
#         FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 1895015                        NaN                        NaN
#
#         MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 1895015                    NaN                      NaN          NaN
#
#         FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 1895015               NaN                            NaN                  NaN
#
#         GrossIncomeFundraisingEvents FundraisingDirectExpenses  \
# 1895015                          NaN                       NaN
#
#         FederatedCampaigns GovernmentGrants MethodOfAccountingOther  \
# 1895015                NaN              NaN                     NaN
#
#         GrossSalesOfInventory CostOfGoodsSold DoNotFollowSFAS117  \
# 1895015                   NaN             NaN                NaN
#
#         RetainedEarningsEndowmentEtc InitialReturn MembershipDues  \
# 1895015                          NaN           NaN            NaN
#
#         GrossIncomeGaming GamingDirectExpenses NoncashContributions  \
# 1895015               NaN                  NaN                  NaN
#
#         OwnWebsite UnsecuredNotesLoansPayable TypeOfOrganizationOther  \
# 1895015        NaN                        NaN                     NaN
#
#         Organization501c TypeOfOrganizationTrust  \
# 1895015              NaN                     NaN
#
#         TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 1895015                           NaN                  NaN           NaN
#
#         TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 1895015                       NaN              NaN                      NaN
#
#         SpecialConditionDescription Organization4947a1  \
# 1895015                         NaN                NaN
#
#         ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 1895015                            NaN                          NaN
#
#         ReconcilationDonatedServices ReconcilationInvestExpenses  \
# 1895015                          NaN                         NaN
#
#         PrincipalOfficerNm GrossReceiptsAmt GroupReturnForAffiliatesInd  \
# 1895015          JOHN MORA             1075                           0
#
#         Organization501c3Ind TypeOfOrganizationCorpInd FormationYr  \
# 1895015                    X                         X        2006
#
#         LegalDomicileStateCd  \
# 1895015                   CA
#
#                                           ActivityOrMissionDesc  \
# 1895015  OPERATING YOUTH SPORTS PROGRAMS FOR THE PUBLIC BENEFIT
#
#         VotingMembersGoverningBodyCnt VotingMembersIndependentCnt  \
# 1895015                             3                           0
#
#         TotalEmployeeCnt TotalGrossUBIAmt CYContributionsGrantsAmt  \
# 1895015                0                0                        0
#
#         CYProgramServiceRevenueAmt CYInvestmentIncomeAmt CYOtherRevenueAmt  \
# 1895015                       1075                     0                 0
#
#         CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 1895015              1075                         0
#
#         CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 1895015                          0                            0
#
#         CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt  \
# 1895015                          0                            0
#
#         CYOtherExpensesAmt CYTotalExpensesAmt CYRevenuesLessExpensesAmt  \
# 1895015              10378              10378                     -9303
#
#         TotalAssetsBOYAmt TotalAssetsEOYAmt TotalLiabilitiesEOYAmt  \
# 1895015             32567             23264                      0
#
#         NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 1895015                         32567                         23264
#
#         ProfessionalFundraisingInd FundraisingActivitiesInd  \
# 1895015                          0                        0
#
#         GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 1895015                   0                             3
#
#         IndependentVotingMemberCnt FamilyOrBusinessRlnInd  \
# 1895015                          0                      0
#
#         DelegationOfMgmtDutiesInd ChangeToOrgDocumentsInd  \
# 1895015                         0                       0
#
#         MaterialDiversionOrMisuseInd MembersOrStockholdersInd  \
# 1895015                            0                        0
#
#         ElectionOfBoardMembersInd DecisionsSubjectToApprovaInd  \
# 1895015                         0                            0
#
#         MinutesOfGoverningBodyInd MinutesOfCommitteesInd  \
# 1895015                         1                      1
#
#         OfficerMailingAddressInd LocalChaptersInd  \
# 1895015                        0                0
#
#         Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 1895015                            0                           1
#
#         WhistleblowerPolicyInd DocumentRetentionPolicyInd  \
# 1895015                      1                          1
#
#         CompensationProcessCEOInd CompensationProcessOtherInd  \
# 1895015                         0                           0
#
#         InvestmentInJointVentureInd StatesWhereCopyOfReturnIsFldCd  \
# 1895015                           0                             CA
#
#         NoListedPersonsCompensatedInd FormerOfcrEmployeesListedInd  \
# 1895015                             X                            0
#
#         TotalCompGreaterThan150KInd CompensationFromOtherSrcsInd  \
# 1895015                           0                            0
#
#         MembershipDuesAmt FundraisingAmt AllOtherContributionsAmt  \
# 1895015               NaN            NaN                      NaN
#
#         TotalContributionsAmt OtherRevenueTotalAmt  \
# 1895015                   NaN                  NaN
#
#                                                                                                                             TotalRevenueGrp  \
# 1895015  {'TotalRevenueColumnAmt': '1075', 'RelatedOrExemptFuncIncomeAmt': '1075', 'UnrelatedBusinessRevenueAmt': '0', 'ExclusionAmt': '0'}
#
#         FeesForServicesAccountingGrp  \
# 1895015                          NaN
#
#                                                                                             TotalFunctionalExpensesGrp  \
# 1895015  {'TotalAmt': '10378', 'ProgramServicesAmt': '8649', 'ManagementAndGeneralAmt': '1729', 'FundraisingAmt': '0'}
#
#                     CashNonInterestBearingGrp  \
# 1895015  {'BOYAmt': '6630', 'EOYAmt': '4245'}
#
#                                  TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 1895015  {'BOYAmt': '32567', 'EOYAmt': '23264'}                        NaN
#
#         RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 1895015                            NaN                         -9303
#
#         MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 1895015                         X                            0            0
#
#         FederalGrantAuditRequiredInd         WebsiteAddressTxt  \
# 1895015                            0  WWW.PLAYFLAGFOOTBALL.COM
#
#         TotalVolunteersCnt NetUnrelatedBusTxblIncmAmt  \
# 1895015                300                          0
#
#         PYContributionsGrantsAmt PYProgramServiceRevenueAmt  \
# 1895015                        0                        250
#
#         PYInvestmentIncomeAmt PYOtherRevenueAmt PYTotalRevenueAmt  \
# 1895015                     0                 0               250
#
#         PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 1895015                         0                          0
#
#         PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt  \
# 1895015                            0                          0
#
#         PYOtherExpensesAmt PYTotalExpensesAmt PYRevenuesLessExpensesAmt  \
# 1895015               8092               8092                     -7842
#
#         TotalLiabilitiesBOYAmt AnnualDisclosureCoveredPrsnInd  \
# 1895015                      0                              1
#
#         RegularMonitoringEnfrcInd UponRequestInd  \
# 1895015                         1              X
#
#         TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 1895015                             0                           0
#
#         TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 1895015                         0                           0
#
#         CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 1895015                            0                 NaN
#
#         TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 1895015                          1075                       NaN
#
#         ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 1895015                          NaN                          NaN
#
#         GrossSalesOfInventoryAmt CostOfGoodsSoldAmt  \
# 1895015                      NaN                NaN
#
#         CompCurrentOfcrDirectorsGrp OtherSalariesAndWagesGrp  \
# 1895015                         NaN                      NaN
#
#         PensionPlanContributionsGrp OtherEmployeeBenefitsGrp PayrollTaxesGrp  \
# 1895015                         NaN                      NaN             NaN
#
#         FeesForServicesOtherGrp SavingsAndTempCashInvstGrp  \
# 1895015                     NaN                        NaN
#
#         LandBldgEquipCostOrOtherBssAmt LandBldgEquipAccumDeprecAmt  \
# 1895015                         215130                      196111
#
#         MortgNotesPyblScrdInvstPropGrp OtherLiabilitiesGrp  \
# 1895015                            NaN                 NaN
#
#         OrganizationFollowsSFAS117Ind NetUnrlzdGainsLossesInvstAmt  \
# 1895015                             X                          NaN
#
#         AuditCommitteeInd AllAffiliatesIncludedInd CompDisqualPersonsGrp  \
# 1895015               NaN                      NaN                   NaN
#
#         FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 1895015                          NaN                     NaN
#
#         FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 1895015                        NaN                          NaN
#
#         MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 1895015                          NaN                     NaN
#
#         TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 1895015                         NaN                           NaN
#
#         UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 1895015                           NaN                       NaN
#
#         FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd  \
# 1895015                           NaN                          NaN
#
#         OtherWebsiteInd AddressChangeInd WrittenPolicyOrProcedureInd  \
# 1895015             NaN              NaN                         NaN
#
#         RelatedOrganizationsAmt OwnWebsiteInd DonatedServicesAndUseFcltsAmt  \
# 1895015                     NaN           NaN                           NaN
#
#         LegalDomicileCountryCd TypeOfOrganizationTrustInd FinalReturnInd  \
# 1895015                    NaN                        NaN            NaN
#
#         ContractTerminationInd GroupExemptionNum FederatedCampaignsAmt  \
# 1895015                    NaN               NaN                   NaN
#
#         TypeOfOrganizationOtherInd OtherOrganizationDsc  \
# 1895015                        NaN                  NaN
#
#         TypeOfOrganizationAssocInd InitialReturnInd GamingGrossIncomeAmt  \
# 1895015                        NaN              NaN                  NaN
#
#         GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 1895015                     NaN                        NaN
#
#         InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 1895015                  NaN                 NaN                        NaN
#
#         AmendedReturnInd SpecialConditionDesc
# 1895015              NaN                  NaN

# %%
# *IRS 990 e-File Data -- CONTROL VARIABLES (A4-1) -- Change Data Types.ipynb*
df.loc[1895015, 'EIN'] = '204814407'

# *IRS 990 e-File Data -- CONTROL VARIABLES (A4-2) -- Fill in Missing Values.ipynb*
df.loc[1895015, 'OrganizationName'] = 'PLAY FLAG FOOTBALL'

# This notebook: *IRS 990 e-File Data -- CONTROL VARIABLES (A1) -- Extract All Variables (py36).ipynb*
df.loc[1895015, 'URL'] = 'https://s3.amazonaws.com/irs-form-990/201903199349306550_public.xml'
df.loc[1895015, 'DLN'] = '93493319065509'
df.loc[1895015, 'TaxPeriod'] = '201812'

df.loc[[1895015]]
# Out:
#            OrganizationName  \
# 1895015  PLAY FLAG FOOTBALL
#
#                                                                          URL  \
# 1895015  https://s3.amazonaws.com/irs-form-990/201903199349306550_public.xml
#
#                     DLN TaxPeriod        EIN  \
# 1895015  93493319065509    201812  204814407
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ReturnHeader  \
# 1895015  {'@binaryAttachmentCnt': '0', 'ReturnTs': '2019-11-15T10:29:26-06:00', 'TaxPeriodEndDt': '2018-12-31', 'PreparerFirmGrp': {'PreparerFirmEIN': '770051130', 'PreparerFirmName': {'BusinessNameLine1Txt': 'ABBOTT STRINGHAM & LYNCH'}, 'PreparerUSAddress': {'AddressLine1Txt': '1530 MERIDIAN AVE 2ND FLR', 'CityNm': 'SAN JOSE', 'StateAbbreviationCd': 'CA', 'ZIPCd': '95125'}}, 'ReturnTypeCd': '990', 'TaxPeriodBeginDt': '2018-01-01', 'Filer': {'EIN': '204814407', 'BusinessName': {'BusinessNameLine1Txt': 'PLAY FLAG FOOTBALL'}, 'BusinessNameControlTxt': 'PLAY', 'PhoneNum': '4083700500', 'USAddress': {'AddressLine1Txt': '545 WESTCHESTER DR NO A', 'CityNm': 'CAMPBELL', 'StateAbbreviationCd': 'CA', 'ZIPCd': '95008'}}, 'BusinessOfficerGrp': {'PersonNm': 'JOHN MORA', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '4083700500', 'SignatureDt': '2019-11-14', 'DiscussWithPaidPreparerInd': '1'}, 'PreparerPersonGrp': {'PreparerPersonNm': 'FRANK L BOITANO', 'PTIN': 'P00058069', 'PhoneNum': '4083778700', 'PreparationDt': '2019-11-14'}, 'FilingSecurityInformation': {'IPAddress': {'IPv4AddressTxt': '12.217.167.71'}, 'IPDt': '2019-11-14', 'IPTm': '12:01:59', 'IPTimezoneCd': 'PS', 'FilingLicenseTypeCd': 'P', 'AtSubmissionCreationDeviceId': 'F2CBB06AF0C0BFA6D697359176620E55FDB7D752', 'AtSubmissionFilingDeviceId': 'A3800E77008D47A4C38094878DB0F53CA65DCD5F'}, 'TaxYr': '2018', 'BuildTS': '2020-04-17 16:48:07Z'}
#
#         AddressChange NameOfPrincipalOfficerPerson GrossReceipts  \
# 1895015           NaN                          NaN           NaN
#
#         GroupReturnForAffiliates Organization501c3 WebSite  \
# 1895015                      NaN               NaN     NaN
#
#         TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 1895015                           NaN           NaN                NaN
#
#         ActivityOrMissionDescription NbrVotingMembersGoverningBody  \
# 1895015                          NaN                           NaN
#
#         NbrIndependentVotingMembers TotalNbrEmployees TotalNbrVolunteers  \
# 1895015                         NaN               NaN                NaN
#
#         TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 1895015           NaN                            NaN
#
#         ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 1895015                          NaN                            NaN
#
#         ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 1895015                            NaN                     NaN
#
#         InvestmentIncomePriorYear InvestmentIncomeCurrentYear  \
# 1895015                       NaN                         NaN
#
#         OtherRevenuePriorYear OtherRevenueCurrentYear TotalRevenuePriorYear  \
# 1895015                   NaN                     NaN                   NaN
#
#         TotalRevenueCurrentYear GrantsAndSimilarAmntsPriorYear  \
# 1895015                     NaN                            NaN
#
#         GrantsAndSimilarAmntsCY BenefitsPaidToMembersPriorYear  \
# 1895015                     NaN                            NaN
#
#         BenefitsPaidToMembersCY SalariesEtcPriorYear SalariesEtcCurrentYear  \
# 1895015                     NaN                  NaN                    NaN
#
#         TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 1895015                           NaN                    NaN
#
#         TotalFundrsngExpCurrentYear OtherExpensePriorYear  \
# 1895015                         NaN                   NaN
#
#         OtherExpensesCurrentYear TotalExpensesPriorYear  \
# 1895015                      NaN                    NaN
#
#         TotalExpensesCurrentYear RevenuesLessExpensesPriorYear  \
# 1895015                      NaN                           NaN
#
#         RevenuesLessExpensesCY TotalAssetsBOY TotalAssetsEOY  \
# 1895015                    NaN            NaN            NaN
#
#         TotalLiabilitiesBOY TotalLiabilitiesEOY NetAssetsOrFundBalancesBOY  \
# 1895015                 NaN                 NaN                        NaN
#
#         NetAssetsOrFundBalancesEOY ProfessionalFundraising  \
# 1895015                        NaN                     NaN
#
#         FundraisingActivities Gaming NbrVotingGoverningBodyMembers  \
# 1895015                   NaN    NaN                           NaN
#
#         NumberIndependentVotingMembers FamilyOrBusinessRelationship  \
# 1895015                            NaN                          NaN
#
#         DelegationOfManagementDuties ChangesToOrganizingDocs  \
# 1895015                          NaN                     NaN
#
#         MaterialDiversionOrMisuse MembersOrStockholders  \
# 1895015                       NaN                   NaN
#
#         ElectionOfBoardMembers DecisionsSubjectToApproval  \
# 1895015                    NaN                        NaN
#
#         MinutesOfGoverningBody MinutesOfCommittees OfficerMailingAddress  \
# 1895015                    NaN                 NaN                   NaN
#
#         LocalChapters Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 1895015           NaN                            NaN                      NaN
#
#         AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 1895015                            NaN                          NaN
#
#         WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 1895015                 NaN                     NaN                    NaN
#
#         CompensationProcessOther InvestmentInJointVenture  \
# 1895015                      NaN                      NaN
#
#         StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 1895015                            NaN         NaN                        NaN
#
#         TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 1895015                        NaN                            NaN
#
#         TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 1895015                    NaN                     NaN           NaN
#
#         TotalCompGT150K CompensationFromOtherSources  \
# 1895015             NaN                          NaN
#
#         NumberOfContractorsGT100K AllOtherContributions TotalContributions  \
# 1895015                       NaN                   NaN                NaN
#
#         TotalOtherRevenue TotalRevenue FeesForServicesLegal  \
# 1895015               NaN          NaN                  NaN
#
#         FeesForServicesAccounting TotalFunctionalExpenses  \
# 1895015                       NaN                     NaN
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 1895015                           NaN                         NaN
#
#         LandBldgEquipmentAccumDeprec TotalAssets OtherLiabilities  \
# 1895015                          NaN         NaN              NaN
#
#         FollowSFAS117 ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 1895015           NaN                          NaN                       NaN
#
#         AccountantCompileOrReview FSAudited AuditCommittee  \
# 1895015                       NaN       NaN            NaN
#
#         FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 1895015                       NaN                   NaN                  NaN
#
#         PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 1895015                       NaN                      NaN
#
#         TotalProgramServiceRevenue CompCurrentOfficersDirectors  \
# 1895015                        NaN                          NaN
#
#         CompDisqualPersons OtherSalariesAndWages PensionPlanContributions  \
# 1895015                NaN                   NaN                      NaN
#
#         OtherEmployeeBenefits PayrollTaxes FeesForServicesManagement  \
# 1895015                   NaN          NaN                       NaN
#
#         FeesForServicesLobbying FeesForServicesProfFundraising  \
# 1895015                     NaN                            NaN
#
#         FeesForServicesInvstMgmntFees FeesForServicesOther  \
# 1895015                           NaN                  NaN
#
#         CashNonInterestBearing MortNotesPyblSecuredInvestProp  \
# 1895015                    NaN                            NaN
#
#         FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 1895015                        NaN                        NaN
#
#         MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 1895015                    NaN                      NaN          NaN
#
#         FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 1895015               NaN                            NaN                  NaN
#
#         GrossIncomeFundraisingEvents FundraisingDirectExpenses  \
# 1895015                          NaN                       NaN
#
#         FederatedCampaigns GovernmentGrants MethodOfAccountingOther  \
# 1895015                NaN              NaN                     NaN
#
#         GrossSalesOfInventory CostOfGoodsSold DoNotFollowSFAS117  \
# 1895015                   NaN             NaN                NaN
#
#         RetainedEarningsEndowmentEtc InitialReturn MembershipDues  \
# 1895015                          NaN           NaN            NaN
#
#         GrossIncomeGaming GamingDirectExpenses NoncashContributions  \
# 1895015               NaN                  NaN                  NaN
#
#         OwnWebsite UnsecuredNotesLoansPayable TypeOfOrganizationOther  \
# 1895015        NaN                        NaN                     NaN
#
#         Organization501c TypeOfOrganizationTrust  \
# 1895015              NaN                     NaN
#
#         TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 1895015                           NaN                  NaN           NaN
#
#         TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 1895015                       NaN              NaN                      NaN
#
#         SpecialConditionDescription Organization4947a1  \
# 1895015                         NaN                NaN
#
#         ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 1895015                            NaN                          NaN
#
#         ReconcilationDonatedServices ReconcilationInvestExpenses  \
# 1895015                          NaN                         NaN
#
#         PrincipalOfficerNm GrossReceiptsAmt GroupReturnForAffiliatesInd  \
# 1895015          JOHN MORA             1075                           0
#
#         Organization501c3Ind TypeOfOrganizationCorpInd FormationYr  \
# 1895015                    X                         X        2006
#
#         LegalDomicileStateCd  \
# 1895015                   CA
#
#                                           ActivityOrMissionDesc  \
# 1895015  OPERATING YOUTH SPORTS PROGRAMS FOR THE PUBLIC BENEFIT
#
#         VotingMembersGoverningBodyCnt VotingMembersIndependentCnt  \
# 1895015                             3                           0
#
#         TotalEmployeeCnt TotalGrossUBIAmt CYContributionsGrantsAmt  \
# 1895015                0                0                        0
#
#         CYProgramServiceRevenueAmt CYInvestmentIncomeAmt CYOtherRevenueAmt  \
# 1895015                       1075                     0                 0
#
#         CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 1895015              1075                         0
#
#         CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 1895015                          0                            0
#
#         CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt  \
# 1895015                          0                            0
#
#         CYOtherExpensesAmt CYTotalExpensesAmt CYRevenuesLessExpensesAmt  \
# 1895015              10378              10378                     -9303
#
#         TotalAssetsBOYAmt TotalAssetsEOYAmt TotalLiabilitiesEOYAmt  \
# 1895015             32567             23264                      0
#
#         NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 1895015                         32567                         23264
#
#         ProfessionalFundraisingInd FundraisingActivitiesInd  \
# 1895015                          0                        0
#
#         GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 1895015                   0                             3
#
#         IndependentVotingMemberCnt FamilyOrBusinessRlnInd  \
# 1895015                          0                      0
#
#         DelegationOfMgmtDutiesInd ChangeToOrgDocumentsInd  \
# 1895015                         0                       0
#
#         MaterialDiversionOrMisuseInd MembersOrStockholdersInd  \
# 1895015                            0                        0
#
#         ElectionOfBoardMembersInd DecisionsSubjectToApprovaInd  \
# 1895015                         0                            0
#
#         MinutesOfGoverningBodyInd MinutesOfCommitteesInd  \
# 1895015                         1                      1
#
#         OfficerMailingAddressInd LocalChaptersInd  \
# 1895015                        0                0
#
#         Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 1895015                            0                           1
#
#         WhistleblowerPolicyInd DocumentRetentionPolicyInd  \
# 1895015                      1                          1
#
#         CompensationProcessCEOInd CompensationProcessOtherInd  \
# 1895015                         0                           0
#
#         InvestmentInJointVentureInd StatesWhereCopyOfReturnIsFldCd  \
# 1895015                           0                             CA
#
#         NoListedPersonsCompensatedInd FormerOfcrEmployeesListedInd  \
# 1895015                             X                            0
#
#         TotalCompGreaterThan150KInd CompensationFromOtherSrcsInd  \
# 1895015                           0                            0
#
#         MembershipDuesAmt FundraisingAmt AllOtherContributionsAmt  \
# 1895015               NaN            NaN                      NaN
#
#         TotalContributionsAmt OtherRevenueTotalAmt  \
# 1895015                   NaN                  NaN
#
#                                                                                                                             TotalRevenueGrp  \
# 1895015  {'TotalRevenueColumnAmt': '1075', 'RelatedOrExemptFuncIncomeAmt': '1075', 'UnrelatedBusinessRevenueAmt': '0', 'ExclusionAmt': '0'}
#
#         FeesForServicesAccountingGrp  \
# 1895015                          NaN
#
#                                                                                             TotalFunctionalExpensesGrp  \
# 1895015  {'TotalAmt': '10378', 'ProgramServicesAmt': '8649', 'ManagementAndGeneralAmt': '1729', 'FundraisingAmt': '0'}
#
#                     CashNonInterestBearingGrp  \
# 1895015  {'BOYAmt': '6630', 'EOYAmt': '4245'}
#
#                                  TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 1895015  {'BOYAmt': '32567', 'EOYAmt': '23264'}                        NaN
#
#         RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 1895015                            NaN                         -9303
#
#         MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 1895015                         X                            0            0
#
#         FederalGrantAuditRequiredInd         WebsiteAddressTxt  \
# 1895015                            0  WWW.PLAYFLAGFOOTBALL.COM
#
#         TotalVolunteersCnt NetUnrelatedBusTxblIncmAmt  \
# 1895015                300                          0
#
#         PYContributionsGrantsAmt PYProgramServiceRevenueAmt  \
# 1895015                        0                        250
#
#         PYInvestmentIncomeAmt PYOtherRevenueAmt PYTotalRevenueAmt  \
# 1895015                     0                 0               250
#
#         PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 1895015                         0                          0
#
#         PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt  \
# 1895015                            0                          0
#
#         PYOtherExpensesAmt PYTotalExpensesAmt PYRevenuesLessExpensesAmt  \
# 1895015               8092               8092                     -7842
#
#         TotalLiabilitiesBOYAmt AnnualDisclosureCoveredPrsnInd  \
# 1895015                      0                              1
#
#         RegularMonitoringEnfrcInd UponRequestInd  \
# 1895015                         1              X
#
#         TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 1895015                             0                           0
#
#         TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 1895015                         0                           0
#
#         CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 1895015                            0                 NaN
#
#         TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 1895015                          1075                       NaN
#
#         ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 1895015                          NaN                          NaN
#
#         GrossSalesOfInventoryAmt CostOfGoodsSoldAmt  \
# 1895015                      NaN                NaN
#
#         CompCurrentOfcrDirectorsGrp OtherSalariesAndWagesGrp  \
# 1895015                         NaN                      NaN
#
#         PensionPlanContributionsGrp OtherEmployeeBenefitsGrp PayrollTaxesGrp  \
# 1895015                         NaN                      NaN             NaN
#
#         FeesForServicesOtherGrp SavingsAndTempCashInvstGrp  \
# 1895015                     NaN                        NaN
#
#         LandBldgEquipCostOrOtherBssAmt LandBldgEquipAccumDeprecAmt  \
# 1895015                         215130                      196111
#
#         MortgNotesPyblScrdInvstPropGrp OtherLiabilitiesGrp  \
# 1895015                            NaN                 NaN
#
#         OrganizationFollowsSFAS117Ind NetUnrlzdGainsLossesInvstAmt  \
# 1895015                             X                          NaN
#
#         AuditCommitteeInd AllAffiliatesIncludedInd CompDisqualPersonsGrp  \
# 1895015               NaN                      NaN                   NaN
#
#         FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 1895015                          NaN                     NaN
#
#         FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 1895015                        NaN                          NaN
#
#         MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 1895015                          NaN                     NaN
#
#         TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 1895015                         NaN                           NaN
#
#         UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 1895015                           NaN                       NaN
#
#         FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd  \
# 1895015                           NaN                          NaN
#
#         OtherWebsiteInd AddressChangeInd WrittenPolicyOrProcedureInd  \
# 1895015             NaN              NaN                         NaN
#
#         RelatedOrganizationsAmt OwnWebsiteInd DonatedServicesAndUseFcltsAmt  \
# 1895015                     NaN           NaN                           NaN
#
#         LegalDomicileCountryCd TypeOfOrganizationTrustInd FinalReturnInd  \
# 1895015                    NaN                        NaN            NaN
#
#         ContractTerminationInd GroupExemptionNum FederatedCampaignsAmt  \
# 1895015                    NaN               NaN                   NaN
#
#         TypeOfOrganizationOtherInd OtherOrganizationDsc  \
# 1895015                        NaN                  NaN
#
#         TypeOfOrganizationAssocInd InitialReturnInd GamingGrossIncomeAmt  \
# 1895015                        NaN              NaN                  NaN
#
#         GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 1895015                     NaN                        NaN
#
#         InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 1895015                  NaN                 NaN                        NaN
#
#         AmendedReturnInd SpecialConditionDesc
# 1895015              NaN                  NaN

# %% [markdown]
# # ENDED HERE 2/24/2020

# %%
df['ReturnHeader'].sample(1)
# Out:
# 743750    {'@binaryAttachmentCnt': '0', 'ReturnTs': '2015-04-10T15:38:15-05:00', 'TaxPeriodEndDt': '2014-10-31', 'PreparerFirmGrp': {'PreparerFirmEIN': '990303190', 'PreparerFirmName': {'BusinessNameLine1': 'CARBONARO CPAS & MANAGEMENT GROUP'}, 'PreparerUS...
# Name: ReturnHeader, dtype: object

# %% [markdown]
# # Drop duplicates
# There are none in this round.

# %%
# %%time
duplicateRowsDF = df[df.duplicated(['URL'])]
print("Number of columns:", len(duplicateRowsDF.columns))
print("Number of observations:", len(duplicateRowsDF))
duplicateRowsDF = duplicateRowsDF.sort_values('URL')
duplicateRowsDF[['URL', 'OrganizationName', 'ReturnHeader']][:2]
# Out:
# Number of columns: 323
# Number of observations: 0
# Empty DataFrame
# Columns: [URL, OrganizationName, ReturnHeader]
# Index: []

# %%
#df[df['URL'].isin(['https://s3.amazonaws.com/irs-form-990/201100299349300805_public.xml',
#                   'https://s3.amazonaws.com/irs-form-990/201100319349300400_public.xml',
#                  ])][['URL', 'OrganizationName', 'ReturnHeader']]
# Out:
#                                                                        URL  \
# 37314  https://s3.amazonaws.com/irs-form-990/201100299349300805_public.xml
# 37315  https://s3.amazonaws.com/irs-form-990/201100319349300400_public.xml
#
#                                            OrganizationName  \
# 37314  ANGELA ARKELL MITCHELL FOUNDATION FOR LITERATURE INC
# 37315                   PLUMBERS AND PIPEFITTERS LU 495 JAC
#
#                                                                                                                                                                                                                                                     ReturnHeader
# 37314  {'@binaryAttachmentCount': '0', 'Timestamp': '2011-01-29T15:48:25-06:00', 'TaxPeriodEndDate': '2010-12-31', 'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'TISDALE CPA'}, 'PreparerFirmUSAddress': {'AddressLine1': '75 JUNCTION ...
# 37315  {'@binaryAttachmentCount': '0', 'Timestamp': '2011-01-31T09:39:58-05:00', 'TaxPeriodEndDate': '2010-12-31', 'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'CHARLES E WILLIAMS CPA'}, 'PreparerFirmUSAddress': {'AddressLine1': 'P...

# %%
#df = df.sort_values('URL')

# %%
#df[df['URL'].isin(['https://s3.amazonaws.com/irs-form-990/201100299349300805_public.xml',
#                   'https://s3.amazonaws.com/irs-form-990/201100319349300400_public.xml',
#                  ])]
# Out:
#      AccountantCompileOrReview                   ActivityOrMissionDescription  \
# 7314                         0         PROMOTE THE APPRECIATION OF LITERATURE
# 7315                      true  TRAIN APPRENTICES OF PLUMBERS LOCAL UNION 495
#
#      AddressChange AllAffiliatesIncluded AllOtherContributions AmendedReturn  \
# 7314           NaN                   NaN                 23238           NaN
# 7315           NaN                   NaN                230914           NaN
#
#      AnnualDisclosureCoveredPersons AuditCommittee BenefitsPaidToMembersCY  \
# 7314                            NaN            NaN                       0
# 7315                           true           true                       0
#
#      BenefitsPaidToMembersPriorYear CashNonInterestBearing  \
# 7314                              0                    NaN
# 7315                            NaN                    NaN
#
#      ChangesToOrganizingDocs CntrbtnsRprtdFundraisingEvents  \
# 7314                       0                            NaN
# 7315                   false                            NaN
#
#      CompCurrentOfficersDirectors CompDisqualPersons  \
# 7314                          NaN                NaN
# 7315                          NaN                NaN
#
#      CompensationFromOtherSources CompensationProcessCEO  \
# 7314                            0                      0
# 7315                        false                  false
#
#      CompensationProcessOther ConflictOfInterestPolicy  \
# 7314                        0                        0
# 7315                    false                     true
#
#      ContributionsGrantsCurrentYear ContributionsGrantsPriorYear  \
# 7314                          23238                        20339
# 7315                         230914                       106466
#
#      CostOfGoodsSold CountryLegalDomicile             DLN  \
# 7314             NaN                  NaN  93493029008051
# 7315             NaN                  NaN  93493031004001
#
#      DecisionsSubjectToApproval DelegationOfManagementDuties  \
# 7314                          0                            0
# 7315                      false                        false
#
#      DoNotFollowSFAS117 DocumentRetentionPolicy        EIN  \
# 7314                NaN                       0  043352779
# 7315                NaN                    true  310907387
#
#      ElectionOfBoardMembers FSAudited FamilyOrBusinessRelationship  \
# 7314                      0         0                            0
# 7315                  false     false                        false
#
#      FederalGrantAuditPerformed FederalGrantAuditRequired FederatedCampaigns  \
# 7314                        NaN                         0                NaN
# 7315                        NaN                     false                NaN
#
#                             FeesForServicesAccounting  \
# 7314  {'Total': '800', 'ManagementAndGeneral': '800'}
# 7315     {'Total': '2675', 'ProgramServices': '2675'}
#
#      FeesForServicesInvstMgmntFees FeesForServicesLegal  \
# 7314                           NaN                  NaN
# 7315                           NaN                  NaN
#
#      FeesForServicesLobbying FeesForServicesManagement  \
# 7314                     NaN                       NaN
# 7315                     NaN                       NaN
#
#                             FeesForServicesOther  \
# 7314  {'Total': '229', 'ProgramServices': '229'}
# 7315                                         NaN
#
#      FeesForServicesProfFundraising FollowSFAS117  \
# 7314                            NaN             X
# 7315                            NaN             X
#
#      Form990ProvidedToGoverningBody FormersListed FundraisingDirectExpenses  \
# 7314                              1             0                       NaN
# 7315                           true         false                       NaN
#
#      FundraisingEvents GamingDirectExpenses GovernmentGrants  \
# 7314               NaN                  NaN              NaN
# 7315               NaN                  NaN              NaN
#
#      GrantsAndSimilarAmntsCY GrantsAndSimilarAmntsPriorYear  \
# 7314                       0                              0
# 7315                       0                            NaN
#
#      GrossIncomeFundraisingEvents GrossIncomeGaming GrossReceipts  \
# 7314                          NaN               NaN         25359
# 7315                          NaN               NaN        694025
#
#      GrossSalesOfInventory GroupExemptionNumber GroupReturnForAffiliates  \
# 7314                   NaN                  NaN                        0
# 7315                   NaN                  NaN                    false
#
#      InitialReturn InvestmentInJointVenture InvestmentIncomeCurrentYear  \
# 7314           NaN                        0                          51
# 7315           NaN                    false                        8106
#
#      InvestmentIncomePriorYear LandBldgEquipmentAccumDeprec  \
# 7314                        51                          547
# 7315                     10066                        95383
#
#      LandBuildingsEquipmentBasis LoansFromOfficersDirectors LocalChapters  \
# 7314                        2000                        NaN             0
# 7315                       95383                        NaN         false
#
#      MaterialDiversionOrMisuse MembersOrStockholders MembershipDues  \
# 7314                         0                     0            NaN
# 7315                     false                 false            NaN
#
#      MethodOfAccountingAccrual MethodOfAccountingCash MethodOfAccountingOther  \
# 7314                       NaN                      X                     NaN
# 7315                       NaN                      X                     NaN
#
#      MinutesOfCommittees MinutesOfGoverningBody  \
# 7314                   1                      1
# 7315                true                   true
#
#      MortNotesPyblSecuredInvestProp NameOfPrincipalOfficerPerson  \
# 7314                            NaN           ROBERT MITCHELL JR
# 7315                            NaN                          NaN
#
#      NbrIndependentVotingMembers NbrVotingGoverningBodyMembers  \
# 7314                           5                             6
# 7315                           4                             6
#
#      NbrVotingMembersGoverningBody NetAssetsOrFundBalancesBOY  \
# 7314                             6                     103817
# 7315                             6                     766665
#
#      NetAssetsOrFundBalancesEOY NetUnrelatedBusinessTxblIncome  \
# 7314                     109727                              0
# 7315                     706570                              0
#
#      NoListedPersonsCompensated NoncashContributions  \
# 7314                          X                  NaN
# 7315                        NaN                  NaN
#
#      NumberIndependentVotingMembers NumberIndividualsGT100K  \
# 7314                              5                       0
# 7315                              4                       0
#
#      NumberOfContractorsGT100K OfficerMailingAddress Organization4947a1  \
# 7314                         0                     0                NaN
# 7315                       NaN                 false                NaN
#
#      Organization501c Organization501c3  \
# 7314              NaN                 X
# 7315              NaN                 X
#
#                                           OrganizationName  \
# 7314  ANGELA ARKELL MITCHELL FOUNDATION FOR LITERATURE INC
# 7315                   PLUMBERS AND PIPEFITTERS LU 495 JAC
#
#                                OtherEmployeeBenefits OtherExpensePriorYear  \
# 7314                                             NaN                 22119
# 7315  {'Total': '75124', 'ProgramServices': '75124'}                263455
#
#      OtherExpensesCurrentYear OtherLiabilities OtherRevenueCurrentYear  \
# 7314                    19449              NaN                       0
# 7315                   350664              NaN                       0
#
#      OtherRevenuePriorYear                             OtherSalariesAndWages  \
# 7314                     0                                               NaN
# 7315                   NaN  {'Total': '242271', 'ProgramServices': '242271'}
#
#      OtherWebsite OwnWebsite                                    PayrollTaxes  \
# 7314            X        NaN                                             NaN
# 7315          NaN        NaN  {'Total': '23932', 'ProgramServices': '23932'}
#
#                             PensionPlanContributions  \
# 7314                                             NaN
# 7315  {'Total': '62129', 'ProgramServices': '62129'}
#
#      PoliciesReferenceChapters ProgramServiceRevenueCY  \
# 7314                       NaN                    2070
# 7315                       NaN                  455005
#
#      ProgramServiceRevenuePriorYear ReconcilationRevenueExpenses  \
# 7314                           1860                         5910
# 7315                         652026                       -60095
#
#      RegularMonitoringEnforcement RelatedOrganizations  \
# 7314                          NaN                  NaN
# 7315                         true                  NaN
#
#      RetainedEarningsEndowmentEtc  \
# 7314                          NaN
# 7315                          NaN
#
#                                                ReturnHeader  \
# 7314  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}
# 7315  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}
#
#      RevenuesLessExpensesCY RevenuesLessExpensesPriorYear  \
# 7314                   5910                           131
# 7315                 -60095                         87695
#
#      SalariesEtcCurrentYear SalariesEtcPriorYear  \
# 7314                      0                    0
# 7315                 403456               417408
#
#            SavingsAndTempCashInvestments SpecialConditionDescription  \
# 7314  {'BOY': '103817', 'EOY': '108274'}                         NaN
# 7315  {'BOY': '766665', 'EOY': '711169'}                         NaN
#
#      StateLegalDomicile StatesWhereCopyOfReturnIsFiled  \
# 7314                 MA                             MA
# 7315                 OH                            NaN
#
#      TaxExemptBondLiabilities TaxPeriod TerminatedReturn  \
# 7314                      NaN    201012              NaN
# 7315                      NaN    201012              NaN
#
#      TerminationOrContraction                         TotalAssets  \
# 7314                      NaN  {'BOY': '103817', 'EOY': '109727'}
# 7315                      NaN  {'BOY': '766665', 'EOY': '711169'}
#
#      TotalAssetsBOY TotalAssetsEOY TotalCompGT150K TotalContributions  \
# 7314         103817         109727               0              23238
# 7315         766665         711169           false             230914
#
#      TotalExpensesCurrentYear TotalExpensesPriorYear  \
# 7314                    19449                  22119
# 7315                   754120                 680863
#
#                                                                                  TotalFunctionalExpenses  \
# 7314  {'Total': '19449', 'ProgramServices': '12789', 'ManagementAndGeneral': '6660', 'Fundraising': '0'}
# 7315   {'Total': '754120', 'ProgramServices': '754120', 'ManagementAndGeneral': '0', 'Fundraising': '0'}
#
#      TotalFundrsngExpCurrentYear TotalGrossUBI TotalLiabilitiesBOY  \
# 7314                           0             0                   0
# 7315                           0             0                 NaN
#
#      TotalLiabilitiesEOY TotalNbrEmployees TotalNbrVolunteers  \
# 7314                   0                 0                  0
# 7315                4599                31                NaN
#
#      TotalOtherCompensation TotalOtherRevenue TotalProfFundrsngExpCY  \
# 7314                      0               NaN                      0
# 7315                      0               NaN                      0
#
#      TotalProfFundrsngExpPriorYear TotalProgramServiceRevenue  \
# 7314                             0                       2070
# 7315                           NaN                     455005
#
#      TotalReportableCompFrmRltdOrgs TotalReportableCompFromOrg  \
# 7314                              0                          0
# 7315                         186642                       7677
#
#                                                                                                                               TotalRevenue  \
# 7314    {'TotalRevenueColumn': '25359', 'RelatedOrExemptFunctionIncome': '2070', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '51'}
# 7315  {'TotalRevenueColumn': '694025', 'RelatedOrExemptFunctionIncome': '463111', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '0'}
#
#      TotalRevenueCurrentYear TotalRevenuePriorYear TypeOfOrgOtherDescription  \
# 7314                   25359                 22250                       NaN
# 7315                  694025                768558                       NaN
#
#      TypeOfOrganizationAssociation TypeOfOrganizationCorporation  \
# 7314                           NaN                             X
# 7315                             X                           NaN
#
#      TypeOfOrganizationOther TypeOfOrganizationTrust  \
# 7314                     NaN                     NaN
# 7315                     NaN                     NaN
#
#                                                                       URL  \
# 7314  https://s3.amazonaws.com/irs-form-990/201100299349300805_public.xml
# 7315  https://s3.amazonaws.com/irs-form-990/201100319349300400_public.xml
#
#      UnsecuredNotesLoansPayable UponRequest                           WebSite  \
# 7314                        NaN           X  WWW.CONCORDFESTIVALOFAUTHORS.COM
# 7315                        NaN           X                               NaN
#
#      WhistleblowerPolicy WrittenPolicyOrProcedure YearFormation  \
# 7314                   0                      NaN          1997
# 7315                true                      NaN          1936
#
#      ReconcilationDonatedServices ReconcilationInvestExpenses  \
# 7314                          NaN                         NaN
# 7315                          NaN                         NaN
#
#      ReconcilationPriorAdjustment ReconciliationUnrealizedInvest  \
# 7314                          NaN                            NaN
# 7315                          NaN                            NaN
#
#      AccountantCompileOrReviewInd ActivityOrMissionDesc AddressChangeInd  \
# 7314                          NaN                   NaN              NaN
# 7315                          NaN                   NaN              NaN
#
#      AllAffiliatesIncludedInd AllOtherContributionsAmt AmendedReturnInd  \
# 7314                      NaN                      NaN              NaN
# 7315                      NaN                      NaN              NaN
#
#      AnnualDisclosureCoveredPrsnInd AuditCommitteeInd  \
# 7314                            NaN               NaN
# 7315                            NaN               NaN
#
#      CYBenefitsPaidToMembersAmt CYContributionsGrantsAmt  \
# 7314                        NaN                      NaN
# 7315                        NaN                      NaN
#
#      CYGrantsAndSimilarPaidAmt CYInvestmentIncomeAmt CYOtherExpensesAmt  \
# 7314                       NaN                   NaN                NaN
# 7315                       NaN                   NaN                NaN
#
#      CYOtherRevenueAmt CYProgramServiceRevenueAmt CYRevenuesLessExpensesAmt  \
# 7314               NaN                        NaN                       NaN
# 7315               NaN                        NaN                       NaN
#
#      CYSalariesCompEmpBnftPaidAmt CYTotalExpensesAmt  \
# 7314                          NaN                NaN
# 7315                          NaN                NaN
#
#      CYTotalFundraisingExpenseAmt CYTotalProfFndrsngExpnsAmt  \
# 7314                          NaN                        NaN
# 7315                          NaN                        NaN
#
#      CYTotalRevenueAmt CashNonInterestBearingGrp ChangeToOrgDocumentsInd  \
# 7314               NaN                       NaN                     NaN
# 7315               NaN                       NaN                     NaN
#
#      CntrctRcvdGreaterThan100KCnt CompCurrentOfcrDirectorsGrp  \
# 7314                          NaN                         NaN
# 7315                          NaN                         NaN
#
#      CompDisqualPersonsGrp CompensationFromOtherSrcsInd  \
# 7314                   NaN                          NaN
# 7315                   NaN                          NaN
#
#      CompensationProcessCEOInd CompensationProcessOtherInd  \
# 7314                       NaN                         NaN
# 7315                       NaN                         NaN
#
#      ConflictOfInterestPolicyInd ContractTerminationInd  \
# 7314                         NaN                    NaN
# 7315                         NaN                    NaN
#
#      ContriRptFundraisingEventAmt CostOfGoodsSoldAmt  \
# 7314                          NaN                NaN
# 7315                          NaN                NaN
#
#      DecisionsSubjectToApprovaInd DelegationOfMgmtDutiesInd  \
# 7314                          NaN                       NaN
# 7315                          NaN                       NaN
#
#      DocumentRetentionPolicyInd DonatedServicesAndUseFcltsAmt  \
# 7314                        NaN                           NaN
# 7315                        NaN                           NaN
#
#      ElectionOfBoardMembersInd FSAuditedInd FamilyOrBusinessRlnInd  \
# 7314                       NaN          NaN                    NaN
# 7315                       NaN          NaN                    NaN
#
#      FederalGrantAuditPerformedInd FederalGrantAuditRequiredInd  \
# 7314                           NaN                          NaN
# 7315                           NaN                          NaN
#
#      FederatedCampaignsAmt FeesForServicesAccountingGrp  \
# 7314                   NaN                          NaN
# 7315                   NaN                          NaN
#
#      FeesForServicesLegalGrp FeesForServicesLobbyingGrp  \
# 7314                     NaN                        NaN
# 7315                     NaN                        NaN
#
#      FeesForServicesManagementGrp FeesForServicesOtherGrp  \
# 7314                          NaN                     NaN
# 7315                          NaN                     NaN
#
#      FeesForSrvcInvstMgmntFeesGrp FinalReturnInd Form990ProvidedToGvrnBodyInd  \
# 7314                          NaN            NaN                          NaN
# 7315                          NaN            NaN                          NaN
#
#      FormationYr FormerOfcrEmployeesListedInd FundraisingAmt  \
# 7314         NaN                          NaN            NaN
# 7315         NaN                          NaN            NaN
#
#      FundraisingDirectExpensesAmt FundraisingGrossIncomeAmt  \
# 7314                          NaN                       NaN
# 7315                          NaN                       NaN
#
#      GamingDirectExpensesAmt GamingGrossIncomeAmt  \
# 7314                     NaN                  NaN
# 7315                     NaN                  NaN
#
#      GoverningBodyVotingMembersCnt GovernmentGrantsAmt GrossReceiptsAmt  \
# 7314                           NaN                 NaN              NaN
# 7315                           NaN                 NaN              NaN
#
#      GrossSalesOfInventoryAmt GroupExemptionNum GroupReturnForAffiliatesInd  \
# 7314                      NaN               NaN                         NaN
# 7315                      NaN               NaN                         NaN
#
#      IndependentVotingMemberCnt IndivRcvdGreaterThan100KCnt InitialReturnInd  \
# 7314                        NaN                         NaN              NaN
# 7315                        NaN                         NaN              NaN
#
#      InvestmentExpenseAmt InvestmentInJointVentureInd  \
# 7314                  NaN                         NaN
# 7315                  NaN                         NaN
#
#      LandBldgEquipAccumDeprecAmt LandBldgEquipCostOrOtherBssAmt  \
# 7314                         NaN                            NaN
# 7315                         NaN                            NaN
#
#      LegalDomicileCountryCd LegalDomicileStateCd  \
# 7314                    NaN                  NaN
# 7315                    NaN                  NaN
#
#      LoansFromOfficersDirectorsGrp LocalChaptersInd  \
# 7314                           NaN              NaN
# 7315                           NaN              NaN
#
#      MaterialDiversionOrMisuseInd MembersOrStockholdersInd MembershipDuesAmt  \
# 7314                          NaN                      NaN               NaN
# 7315                          NaN                      NaN               NaN
#
#      MethodOfAccountingAccrualInd MethodOfAccountingCashInd  \
# 7314                          NaN                       NaN
# 7315                          NaN                       NaN
#
#      MethodOfAccountingOtherInd MinutesOfCommitteesInd  \
# 7314                        NaN                    NaN
# 7315                        NaN                    NaN
#
#      MinutesOfGoverningBodyInd MortgNotesPyblScrdInvstPropGrp  \
# 7314                       NaN                            NaN
# 7315                       NaN                            NaN
#
#      NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 7314                           NaN                           NaN
# 7315                           NaN                           NaN
#
#      NetUnrelatedBusTxblIncmAmt NetUnrlzdGainsLossesInvstAmt  \
# 7314                        NaN                          NaN
# 7315                        NaN                          NaN
#
#      NoListedPersonsCompensatedInd NoncashContributionsAmt  \
# 7314                           NaN                     NaN
# 7315                           NaN                     NaN
#
#      OfficerMailingAddressInd OrgDoesNotFollowSFAS117Ind  \
# 7314                      NaN                        NaN
# 7315                      NaN                        NaN
#
#      Organization4947a1NotPFInd Organization501c3Ind Organization501cInd  \
# 7314                        NaN                  NaN                 NaN
# 7315                        NaN                  NaN                 NaN
#
#      OrganizationFollowsSFAS117Ind OtherEmployeeBenefitsGrp  \
# 7314                           NaN                      NaN
# 7315                           NaN                      NaN
#
#      OtherLiabilitiesGrp OtherOrganizationDsc OtherRevenueTotalAmt  \
# 7314                 NaN                  NaN                  NaN
# 7315                 NaN                  NaN                  NaN
#
#      OtherSalariesAndWagesGrp OtherWebsiteInd OwnWebsiteInd  \
# 7314                      NaN             NaN           NaN
# 7315                      NaN             NaN           NaN
#
#      PYBenefitsPaidToMembersAmt PYContributionsGrantsAmt  \
# 7314                        NaN                      NaN
# 7315                        NaN                      NaN
#
#      PYGrantsAndSimilarPaidAmt PYInvestmentIncomeAmt PYOtherExpensesAmt  \
# 7314                       NaN                   NaN                NaN
# 7315                       NaN                   NaN                NaN
#
#      PYOtherRevenueAmt PYProgramServiceRevenueAmt PYRevenuesLessExpensesAmt  \
# 7314               NaN                        NaN                       NaN
# 7315               NaN                        NaN                       NaN
#
#      PYSalariesCompEmpBnftPaidAmt PYTotalExpensesAmt  \
# 7314                          NaN                NaN
# 7315                          NaN                NaN
#
#      PYTotalProfFndrsngExpnsAmt PYTotalRevenueAmt PayrollTaxesGrp  \
# 7314                        NaN               NaN             NaN
# 7315                        NaN               NaN             NaN
#
#      PensionPlanContributionsGrp PoliciesReferenceChaptersInd  \
# 7314                         NaN                          NaN
# 7315                         NaN                          NaN
#
#      PrincipalOfficerNm PriorPeriodAdjustmentsAmt  \
# 7314                NaN                       NaN
# 7315                NaN                       NaN
#
#      ReconcilationRevenueExpnssAmt RegularMonitoringEnfrcInd  \
# 7314                           NaN                       NaN
# 7315                           NaN                       NaN
#
#      RelatedOrganizationsAmt RtnEarnEndowmentIncmOthFndsGrp  \
# 7314                     NaN                            NaN
# 7315                     NaN                            NaN
#
#      SavingsAndTempCashInvstGrp SpecialConditionDesc  \
# 7314                        NaN                  NaN
# 7315                        NaN                  NaN
#
#      StatesWhereCopyOfReturnIsFldCd TaxExemptBondLiabilitiesGrp  \
# 7314                            NaN                         NaN
# 7315                            NaN                         NaN
#
#      TotReportableCompRltdOrgAmt TotalAssetsBOYAmt TotalAssetsEOYAmt  \
# 7314                         NaN               NaN               NaN
# 7315                         NaN               NaN               NaN
#
#      TotalAssetsGrp TotalCompGreaterThan150KInd TotalContributionsAmt  \
# 7314            NaN                         NaN                   NaN
# 7315            NaN                         NaN                   NaN
#
#      TotalEmployeeCnt TotalFunctionalExpensesGrp TotalGrossUBIAmt  \
# 7314              NaN                        NaN              NaN
# 7315              NaN                        NaN              NaN
#
#      TotalLiabilitiesBOYAmt TotalLiabilitiesEOYAmt TotalOtherCompensationAmt  \
# 7314                    NaN                    NaN                       NaN
# 7315                    NaN                    NaN                       NaN
#
#      TotalProgramServiceRevenueAmt TotalReportableCompFromOrgAmt  \
# 7314                           NaN                           NaN
# 7315                           NaN                           NaN
#
#      TotalRevenueGrp TotalVolunteersCnt TypeOfOrganizationAssocInd  \
# 7314             NaN                NaN                        NaN
# 7315             NaN                NaN                        NaN
#
#      TypeOfOrganizationCorpInd TypeOfOrganizationOtherInd  \
# 7314                       NaN                        NaN
# 7315                       NaN                        NaN
#
#      TypeOfOrganizationTrustInd UnsecuredNotesLoansPayableGrp UponRequestInd  \
# 7314                        NaN                           NaN            NaN
# 7315                        NaN                           NaN            NaN
#
#      VotingMembersGoverningBodyCnt VotingMembersIndependentCnt  \
# 7314                           NaN                         NaN
# 7315                           NaN                         NaN
#
#      WebsiteAddressTxt WhistleblowerPolicyInd WrittenPolicyOrProcedureInd
# 7314               NaN                    NaN                         NaN
# 7315               NaN                    NaN                         NaN

# %%
#dfo = df.drop_duplicates(subset='URL')
#print(len(df),len(dfo))
#dfo[:1]
# Out:
# 1727056 1727056
#   AccountantCompileOrReview  \
# 0                         0
#
#                                                                ActivityOrMissionDescription  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   AddressChange AllAffiliatesIncluded AllOtherContributions AmendedReturn  \
# 0             X                   NaN               1439340           NaN
#
#   AnnualDisclosureCoveredPersons AuditCommittee BenefitsPaidToMembersCY  \
# 0                              1              1                       0
#
#   BenefitsPaidToMembersPriorYear CashNonInterestBearing  \
# 0                              0                    NaN
#
#   ChangesToOrganizingDocs CntrbtnsRprtdFundraisingEvents  \
# 0                       0                            NaN
#
#   CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                          NaN                NaN
#
#   CompensationFromOtherSources CompensationProcessCEO  \
# 0                            0                      0
#
#   CompensationProcessOther ConflictOfInterestPolicy  \
# 0                        0                        1
#
#   ContributionsGrantsCurrentYear ContributionsGrantsPriorYear CostOfGoodsSold  \
# 0                        1439340                      1044925             NaN
#
#   CountryLegalDomicile             DLN DecisionsSubjectToApproval  \
# 0                  NaN  93493313013011                          0
#
#   DelegationOfManagementDuties DoNotFollowSFAS117 DocumentRetentionPolicy  \
# 0                            0                NaN                       0
#
#          EIN ElectionOfBoardMembers FSAudited FamilyOrBusinessRelationship  \
# 0  232705170                      0         1                            0
#
#   FederalGrantAuditPerformed FederalGrantAuditRequired FederatedCampaigns  \
# 0                        NaN                         0                NaN
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
#
#   FeesForServicesInvstMgmntFees  \
# 0                           NaN
#
#                               FeesForServicesLegal FeesForServicesLobbying  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}                     NaN
#
#   FeesForServicesManagement FeesForServicesOther  \
# 0                       NaN                  NaN
#
#   FeesForServicesProfFundraising FollowSFAS117 Form990ProvidedToGoverningBody  \
# 0                            NaN             X                              1
#
#   FormersListed FundraisingDirectExpenses FundraisingEvents  \
# 0             0                       NaN               NaN
#
#   GamingDirectExpenses GovernmentGrants GrantsAndSimilarAmntsCY  \
# 0                  NaN              NaN                  925000
#
#   GrantsAndSimilarAmntsPriorYear GrossIncomeFundraisingEvents  \
# 0                         638637                          NaN
#
#   GrossIncomeGaming GrossReceipts GrossSalesOfInventory GroupExemptionNumber  \
# 0               NaN       1473903                   NaN                  NaN
#
#   GroupReturnForAffiliates InitialReturn InvestmentInJointVenture  \
# 0                        0           NaN                        0
#
#   InvestmentIncomeCurrentYear InvestmentIncomePriorYear  \
# 0                       33563                     30447
#
#   LandBldgEquipmentAccumDeprec LandBuildingsEquipmentBasis  \
# 0                        86228                      256845
#
#   LoansFromOfficersDirectors LocalChapters MaterialDiversionOrMisuse  \
# 0                        NaN             0                         0
#
#   MembersOrStockholders MembershipDues MethodOfAccountingAccrual  \
# 0                     0            NaN                         X
#
#   MethodOfAccountingCash MethodOfAccountingOther MinutesOfCommittees  \
# 0                    NaN                     NaN                   1
#
#   MinutesOfGoverningBody MortNotesPyblSecuredInvestProp  \
# 0                      1                            NaN
#
#   NameOfPrincipalOfficerPerson NbrIndependentVotingMembers  \
# 0                MICHAEL ANTON                          10
#
#   NbrVotingGoverningBodyMembers NbrVotingMembersGoverningBody  \
# 0                            10                            10
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
#
#   NetUnrelatedBusinessTxblIncome NoListedPersonsCompensated  \
# 0                              0                          X
#
#   NoncashContributions NumberIndependentVotingMembers NumberIndividualsGT100K  \
# 0                  NaN                             10                       0
#
#   NumberOfContractorsGT100K OfficerMailingAddress Organization4947a1  \
# 0                         0                     0                NaN
#
#   Organization501c Organization501c3  \
# 0              NaN                 X
#
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#   OtherEmployeeBenefits OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                   NaN                243131                   459751
#
#                     OtherLiabilities OtherRevenueCurrentYear  \
# 0  {'BOY': '51640', 'EOY': '240077'}                    1000
#
#   OtherRevenuePriorYear OtherSalariesAndWages OtherWebsite OwnWebsite  \
# 0                     0                   NaN          NaN        NaN
#
#   PayrollTaxes PensionPlanContributions PoliciesReferenceChapters  \
# 0          NaN                      NaN                       NaN
#
#   ProgramServiceRevenueCY ProgramServiceRevenuePriorYear  \
# 0                       0                              0
#
#   ReconcilationRevenueExpenses RegularMonitoringEnforcement  \
# 0                        89152                            1
#
#   RelatedOrganizations RetainedEarningsEndowmentEtc  \
# 0                  NaN                          NaN
#
#                                             ReturnHeader  \
# 0  {'TaxPeriodEndDate': '2010-12-31', 'TaxYear': '2010'}
#
#   RevenuesLessExpensesCY RevenuesLessExpensesPriorYear SalariesEtcCurrentYear  \
# 0                  89152                        193604                      0
#
#   SalariesEtcPriorYear       SavingsAndTempCashInvestments  \
# 0                    0  {'BOY': '332660', 'EOY': '270700'}
#
#   SpecialConditionDescription StateLegalDomicile  \
# 0                         NaN                 PA
#
#   StatesWhereCopyOfReturnIsFiled TaxExemptBondLiabilities TaxPeriod  \
# 0                   [PA, NJ, DE]                      NaN    201012
#
#   TerminatedReturn TerminationOrContraction  \
# 0              NaN                      NaN
#
#                             TotalAssets TotalAssetsBOY TotalAssetsEOY  \
# 0  {'BOY': '1925215', 'EOY': '2440859'}        1925215        2440859
#
#   TotalCompGT150K TotalContributions TotalExpensesCurrentYear  \
# 0               0            1439340                  1384751
#
#   TotalExpensesPriorYear  \
# 0                 881768
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#   TotalFundrsngExpCurrentYear TotalGrossUBI TotalLiabilitiesBOY  \
# 0                      195892             0              171810
#
#   TotalLiabilitiesEOY TotalNbrEmployees TotalNbrVolunteers  \
# 0              450430                 0                  0
#
#   TotalOtherCompensation TotalOtherRevenue TotalProfFundrsngExpCY  \
# 0                      0              1000                      0
#
#   TotalProfFundrsngExpPriorYear TotalProgramServiceRevenue  \
# 0                             0                        NaN
#
#   TotalReportableCompFrmRltdOrgs TotalReportableCompFromOrg  \
# 0                              0                          0
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
#
#   TotalRevenueCurrentYear TotalRevenuePriorYear TypeOfOrgOtherDescription  \
# 0                 1473903               1075372                       NaN
#
#   TypeOfOrganizationAssociation TypeOfOrganizationCorporation  \
# 0                           NaN                             X
#
#   TypeOfOrganizationOther TypeOfOrganizationTrust  \
# 0                     NaN                     NaN
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#   UnsecuredNotesLoansPayable UponRequest WebSite WhistleblowerPolicy  \
# 0                        NaN           X     N/A                   0
#
#   WrittenPolicyOrProcedure YearFormation ReconcilationDonatedServices  \
# 0                      NaN          1992                          NaN
#
#   ReconcilationInvestExpenses ReconcilationPriorAdjustment  \
# 0                         NaN                          NaN
#
#   ReconciliationUnrealizedInvest AccountantCompileOrReviewInd  \
# 0                            NaN                          NaN
#
#   ActivityOrMissionDesc AddressChangeInd AllAffiliatesIncludedInd  \
# 0                   NaN              NaN                      NaN
#
#   AllOtherContributionsAmt AmendedReturnInd AnnualDisclosureCoveredPrsnInd  \
# 0                      NaN              NaN                            NaN
#
#   AuditCommitteeInd CYBenefitsPaidToMembersAmt CYContributionsGrantsAmt  \
# 0               NaN                        NaN                      NaN
#
#   CYGrantsAndSimilarPaidAmt CYInvestmentIncomeAmt CYOtherExpensesAmt  \
# 0                       NaN                   NaN                NaN
#
#   CYOtherRevenueAmt CYProgramServiceRevenueAmt CYRevenuesLessExpensesAmt  \
# 0               NaN                        NaN                       NaN
#
#   CYSalariesCompEmpBnftPaidAmt CYTotalExpensesAmt  \
# 0                          NaN                NaN
#
#   CYTotalFundraisingExpenseAmt CYTotalProfFndrsngExpnsAmt CYTotalRevenueAmt  \
# 0                          NaN                        NaN               NaN
#
#   CashNonInterestBearingGrp ChangeToOrgDocumentsInd  \
# 0                       NaN                     NaN
#
#   CntrctRcvdGreaterThan100KCnt CompCurrentOfcrDirectorsGrp  \
# 0                          NaN                         NaN
#
#   CompDisqualPersonsGrp CompensationFromOtherSrcsInd  \
# 0                   NaN                          NaN
#
#   CompensationProcessCEOInd CompensationProcessOtherInd  \
# 0                       NaN                         NaN
#
#   ConflictOfInterestPolicyInd ContractTerminationInd  \
# 0                         NaN                    NaN
#
#   ContriRptFundraisingEventAmt CostOfGoodsSoldAmt  \
# 0                          NaN                NaN
#
#   DecisionsSubjectToApprovaInd DelegationOfMgmtDutiesInd  \
# 0                          NaN                       NaN
#
#   DocumentRetentionPolicyInd DonatedServicesAndUseFcltsAmt  \
# 0                        NaN                           NaN
#
#   ElectionOfBoardMembersInd FSAuditedInd FamilyOrBusinessRlnInd  \
# 0                       NaN          NaN                    NaN
#
#   FederalGrantAuditPerformedInd FederalGrantAuditRequiredInd  \
# 0                           NaN                          NaN
#
#   FederatedCampaignsAmt FeesForServicesAccountingGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForServicesManagementGrp  \
# 0                        NaN                          NaN
#
#   FeesForServicesOtherGrp FeesForSrvcInvstMgmntFeesGrp FinalReturnInd  \
# 0                     NaN                          NaN            NaN
#
#   Form990ProvidedToGvrnBodyInd FormationYr FormerOfcrEmployeesListedInd  \
# 0                          NaN         NaN                          NaN
#
#   FundraisingAmt FundraisingDirectExpensesAmt FundraisingGrossIncomeAmt  \
# 0            NaN                          NaN                       NaN
#
#   GamingDirectExpensesAmt GamingGrossIncomeAmt GoverningBodyVotingMembersCnt  \
# 0                     NaN                  NaN                           NaN
#
#   GovernmentGrantsAmt GrossReceiptsAmt GrossSalesOfInventoryAmt  \
# 0                 NaN              NaN                      NaN
#
#   GroupExemptionNum GroupReturnForAffiliatesInd IndependentVotingMemberCnt  \
# 0               NaN                         NaN                        NaN
#
#   IndivRcvdGreaterThan100KCnt InitialReturnInd InvestmentExpenseAmt  \
# 0                         NaN              NaN                  NaN
#
#   InvestmentInJointVentureInd LandBldgEquipAccumDeprecAmt  \
# 0                         NaN                         NaN
#
#   LandBldgEquipCostOrOtherBssAmt LegalDomicileCountryCd LegalDomicileStateCd  \
# 0                            NaN                    NaN                  NaN
#
#   LoansFromOfficersDirectorsGrp LocalChaptersInd MaterialDiversionOrMisuseInd  \
# 0                           NaN              NaN                          NaN
#
#   MembersOrStockholdersInd MembershipDuesAmt MethodOfAccountingAccrualInd  \
# 0                      NaN               NaN                          NaN
#
#   MethodOfAccountingCashInd MethodOfAccountingOtherInd MinutesOfCommitteesInd  \
# 0                       NaN                        NaN                    NaN
#
#   MinutesOfGoverningBodyInd MortgNotesPyblScrdInvstPropGrp  \
# 0                       NaN                            NaN
#
#   NetAssetsOrFundBalancesBOYAmt NetAssetsOrFundBalancesEOYAmt  \
# 0                           NaN                           NaN
#
#   NetUnrelatedBusTxblIncmAmt NetUnrlzdGainsLossesInvstAmt  \
# 0                        NaN                          NaN
#
#   NoListedPersonsCompensatedInd NoncashContributionsAmt  \
# 0                           NaN                     NaN
#
#   OfficerMailingAddressInd OrgDoesNotFollowSFAS117Ind  \
# 0                      NaN                        NaN
#
#   Organization4947a1NotPFInd Organization501c3Ind Organization501cInd  \
# 0                        NaN                  NaN                 NaN
#
#   OrganizationFollowsSFAS117Ind OtherEmployeeBenefitsGrp OtherLiabilitiesGrp  \
# 0                           NaN                      NaN                 NaN
#
#   OtherOrganizationDsc OtherRevenueTotalAmt OtherSalariesAndWagesGrp  \
# 0                  NaN                  NaN                      NaN
#
#   OtherWebsiteInd OwnWebsiteInd PYBenefitsPaidToMembersAmt  \
# 0             NaN           NaN                        NaN
#
#   PYContributionsGrantsAmt PYGrantsAndSimilarPaidAmt PYInvestmentIncomeAmt  \
# 0                      NaN                       NaN                   NaN
#
#   PYOtherExpensesAmt PYOtherRevenueAmt PYProgramServiceRevenueAmt  \
# 0                NaN               NaN                        NaN
#
#   PYRevenuesLessExpensesAmt PYSalariesCompEmpBnftPaidAmt PYTotalExpensesAmt  \
# 0                       NaN                          NaN                NaN
#
#   PYTotalProfFndrsngExpnsAmt PYTotalRevenueAmt PayrollTaxesGrp  \
# 0                        NaN               NaN             NaN
#
#   PensionPlanContributionsGrp PoliciesReferenceChaptersInd PrincipalOfficerNm  \
# 0                         NaN                          NaN                NaN
#
#   PriorPeriodAdjustmentsAmt ReconcilationRevenueExpnssAmt  \
# 0                       NaN                           NaN
#
#   RegularMonitoringEnfrcInd RelatedOrganizationsAmt  \
# 0                       NaN                     NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp SavingsAndTempCashInvstGrp  \
# 0                            NaN                        NaN
#
#   SpecialConditionDesc StatesWhereCopyOfReturnIsFldCd  \
# 0                  NaN                            NaN
#
#   TaxExemptBondLiabilitiesGrp TotReportableCompRltdOrgAmt TotalAssetsBOYAmt  \
# 0                         NaN                         NaN               NaN
#
#   TotalAssetsEOYAmt TotalAssetsGrp TotalCompGreaterThan150KInd  \
# 0               NaN            NaN                         NaN
#
#   TotalContributionsAmt TotalEmployeeCnt TotalFunctionalExpensesGrp  \
# 0                   NaN              NaN                        NaN
#
#   TotalGrossUBIAmt TotalLiabilitiesBOYAmt TotalLiabilitiesEOYAmt  \
# 0              NaN                    NaN                    NaN
#
#   TotalOtherCompensationAmt TotalProgramServiceRevenueAmt  \
# 0                       NaN                           NaN
#
#   TotalReportableCompFromOrgAmt TotalRevenueGrp TotalVolunteersCnt  \
# 0                           NaN             NaN                NaN
#
#   TypeOfOrganizationAssocInd TypeOfOrganizationCorpInd  \
# 0                        NaN                       NaN
#
#   TypeOfOrganizationOtherInd TypeOfOrganizationTrustInd  \
# 0                        NaN                        NaN
#
#   UnsecuredNotesLoansPayableGrp UponRequestInd VotingMembersGoverningBodyCnt  \
# 0                           NaN            NaN                           NaN
#
#   VotingMembersIndependentCnt WebsiteAddressTxt WhistleblowerPolicyInd  \
# 0                         NaN               NaN                    NaN
#
#   WrittenPolicyOrProcedureInd
# 0                         NaN

# %% [markdown]
# <br>39,729 990 filings are not in the database

# %%
#1587557 - len(dfo)
# Out:
# 39729

# %% [markdown]
# <br>70,092 duplicates were dropped
# <br>UPDATE: none dropped

# %% [markdown]
# ### Create *Fiscal Year* Variable

# %%
[c for c in df.columns.tolist() if 'Tax' in c]
# Out:
# ['TaxPeriod',
#  'PayrollTaxes',
#  'TaxExemptBondLiabilities',
#  'PayrollTaxesGrp',
#  'TaxExemptBondLiabilitiesGrp']

# %%
print(len(df[df['TaxPeriod'].notnull()]))
# Out:
# 1895015

# %%
print(len(df[df['TaxPeriod'].isnull()]))
# Out:
# 1

# %%
df['TaxPeriod'].value_counts().head()
# Out:
# 201712    138562
# 201812    136698
# 201612    131298
# 201512    124527
# 201412    115139
# Name: TaxPeriod, dtype: int64

# %%
df['TaxPeriod'].dtype
# Out:
# dtype('O')

# %%
df['fiscal_year'] = df['TaxPeriod'].str[:4]
df['fiscal_year'].value_counts()
# Out:
# 2017    251118
# 2018    250237
# 2016    240291
# 2015    228000
# 2014    210538
# 2013    190710
# 2012    170761
# 2011    139300
# 2019    113354
# 2010     98185
# 2020      2520
# 2108         1
# Name: fiscal_year, dtype: int64

# %%
years = pd.DataFrame(df['fiscal_year'].value_counts())
years.index.name = 'year'
years = years.reset_index()
years = years.sort_values('year')
years
# Out:
#     year  fiscal_year
# 9   2010        98185
# 7   2011       139300
# 6   2012       170761
# 5   2013       190710
# 4   2014       210538
# 3   2015       228000
# 2   2016       240291
# 0   2017       251118
# 1   2018       250237
# 8   2019       113354
# 10  2020         2520
# 11  2108            1

# %%
print("Number of columns:", len(df.columns))
print("Number of observations:", len(df))
df[:1]
# Out:
# Number of columns: 324
# Number of observations: 1895016
#                                            OrganizationName  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#               DLN TaxPeriod        EIN  \
# 0  93493313013011    201012  232705170
#
#                                                                                                                                                                                                                                                 ReturnHeader  \
# 0  {'@binaryAttachmentCount': '0', 'Timestamp': '2011-11-09T06:41:09-06:00', 'TaxPeriodEndDate': '2010-12-31', 'PreparerFirm': {'PreparerFirmBusinessName': {'BusinessNameLine1': 'CONCANNON MILLER & CO PC'}, 'PreparerFirmUSAddress': {'AddressLine1': ...
#
#   AddressChange NameOfPrincipalOfficerPerson GrossReceipts  \
# 0             X                MICHAEL ANTON       1473903
#
#   GroupReturnForAffiliates Organization501c3 WebSite  \
# 0                        0                 X     N/A
#
#   TypeOfOrganizationCorporation YearFormation StateLegalDomicile  \
# 0                             X          1992                 PA
#
#                                                                ActivityOrMissionDescription  \
# 0  MAKES GRANTS TO NON-PROFITS THAT DIRECTLY IMPROVE THE HEALTH AND WELL-BEING OF CHILDREN.
#
#   NbrVotingMembersGoverningBody NbrIndependentVotingMembers TotalNbrEmployees  \
# 0                            10                          10                 0
#
#   TotalNbrVolunteers TotalGrossUBI NetUnrelatedBusinessTxblIncome  \
# 0                  0             0                              0
#
#   ContributionsGrantsPriorYear ContributionsGrantsCurrentYear  \
# 0                      1044925                        1439340
#
#   ProgramServiceRevenuePriorYear ProgramServiceRevenueCY  \
# 0                              0                       0
#
#   InvestmentIncomePriorYear InvestmentIncomeCurrentYear OtherRevenuePriorYear  \
# 0                     30447                       33563                     0
#
#   OtherRevenueCurrentYear TotalRevenuePriorYear TotalRevenueCurrentYear  \
# 0                    1000               1075372                 1473903
#
#   GrantsAndSimilarAmntsPriorYear GrantsAndSimilarAmntsCY  \
# 0                         638637                  925000
#
#   BenefitsPaidToMembersPriorYear BenefitsPaidToMembersCY SalariesEtcPriorYear  \
# 0                              0                       0                    0
#
#   SalariesEtcCurrentYear TotalProfFundrsngExpPriorYear TotalProfFundrsngExpCY  \
# 0                      0                             0                      0
#
#   TotalFundrsngExpCurrentYear OtherExpensePriorYear OtherExpensesCurrentYear  \
# 0                      195892                243131                   459751
#
#   TotalExpensesPriorYear TotalExpensesCurrentYear  \
# 0                 881768                  1384751
#
#   RevenuesLessExpensesPriorYear RevenuesLessExpensesCY TotalAssetsBOY  \
# 0                        193604                  89152        1925215
#
#   TotalAssetsEOY TotalLiabilitiesBOY TotalLiabilitiesEOY  \
# 0        2440859              171810              450430
#
#   NetAssetsOrFundBalancesBOY NetAssetsOrFundBalancesEOY  \
# 0                    1753405                    1990429
#
#   ProfessionalFundraising FundraisingActivities Gaming  \
# 0                       0                     0      0
#
#   NbrVotingGoverningBodyMembers NumberIndependentVotingMembers  \
# 0                            10                             10
#
#   FamilyOrBusinessRelationship DelegationOfManagementDuties  \
# 0                            0                            0
#
#   ChangesToOrganizingDocs MaterialDiversionOrMisuse MembersOrStockholders  \
# 0                       0                         0                     0
#
#   ElectionOfBoardMembers DecisionsSubjectToApproval MinutesOfGoverningBody  \
# 0                      0                          0                      1
#
#   MinutesOfCommittees OfficerMailingAddress LocalChapters  \
# 0                   1                     0             0
#
#   Form990ProvidedToGoverningBody ConflictOfInterestPolicy  \
# 0                              1                        1
#
#   AnnualDisclosureCoveredPersons RegularMonitoringEnforcement  \
# 0                              1                            1
#
#   WhistleblowerPolicy DocumentRetentionPolicy CompensationProcessCEO  \
# 0                   0                       0                      0
#
#   CompensationProcessOther InvestmentInJointVenture  \
# 0                        0                        0
#
#   StatesWhereCopyOfReturnIsFiled UponRequest NoListedPersonsCompensated  \
# 0                   [PA, NJ, DE]           X                          X
#
#   TotalReportableCompFromOrg TotalReportableCompFrmRltdOrgs  \
# 0                          0                              0
#
#   TotalOtherCompensation NumberIndividualsGT100K FormersListed  \
# 0                      0                       0             0
#
#   TotalCompGT150K CompensationFromOtherSources NumberOfContractorsGT100K  \
# 0               0                            0                         0
#
#   AllOtherContributions TotalContributions TotalOtherRevenue  \
# 0               1439340            1439340              1000
#
#                                                                                                                               TotalRevenue  \
# 0  {'TotalRevenueColumn': '1473903', 'RelatedOrExemptFunctionIncome': '1000', 'UnrelatedBusinessRevenue': '0', 'ExclusionAmount': '33563'}
#
#                               FeesForServicesLegal  \
# 0  {'Total': '215', 'ManagementAndGeneral': '215'}
#
#                              FeesForServicesAccounting  \
# 0  {'Total': '21675', 'ManagementAndGeneral': '21675'}
#
#                                                                                          TotalFunctionalExpenses  \
# 0  {'Total': '1384751', 'ProgramServices': '1043744', 'ManagementAndGeneral': '145115', 'Fundraising': '195892'}
#
#         SavingsAndTempCashInvestments LandBuildingsEquipmentBasis  \
# 0  {'BOY': '332660', 'EOY': '270700'}                      256845
#
#   LandBldgEquipmentAccumDeprec                           TotalAssets  \
# 0                        86228  {'BOY': '1925215', 'EOY': '2440859'}
#
#                     OtherLiabilities FollowSFAS117  \
# 0  {'BOY': '51640', 'EOY': '240077'}             X
#
#   ReconcilationRevenueExpenses MethodOfAccountingAccrual  \
# 0                        89152                         X
#
#   AccountantCompileOrReview FSAudited AuditCommittee  \
# 0                         0         1              1
#
#   FederalGrantAuditRequired AllAffiliatesIncluded GroupExemptionNumber  \
# 0                         0                   NaN                  NaN
#
#   PoliciesReferenceChapters WrittenPolicyOrProcedure  \
# 0                       NaN                      NaN
#
#   TotalProgramServiceRevenue CompCurrentOfficersDirectors CompDisqualPersons  \
# 0                        NaN                          NaN                NaN
#
#   OtherSalariesAndWages PensionPlanContributions OtherEmployeeBenefits  \
# 0                   NaN                      NaN                   NaN
#
#   PayrollTaxes FeesForServicesManagement FeesForServicesLobbying  \
# 0          NaN                       NaN                     NaN
#
#   FeesForServicesProfFundraising FeesForServicesInvstMgmntFees  \
# 0                            NaN                           NaN
#
#   FeesForServicesOther CashNonInterestBearing MortNotesPyblSecuredInvestProp  \
# 0                  NaN                    NaN                            NaN
#
#   FederalGrantAuditPerformed LoansFromOfficersDirectors  \
# 0                        NaN                        NaN
#
#   MethodOfAccountingCash TaxExemptBondLiabilities OtherWebsite  \
# 0                    NaN                      NaN          NaN
#
#   FundraisingEvents CntrbtnsRprtdFundraisingEvents RelatedOrganizations  \
# 0               NaN                            NaN                  NaN
#
#   GrossIncomeFundraisingEvents FundraisingDirectExpenses FederatedCampaigns  \
# 0                          NaN                       NaN                NaN
#
#   GovernmentGrants MethodOfAccountingOther GrossSalesOfInventory  \
# 0              NaN                     NaN                   NaN
#
#   CostOfGoodsSold DoNotFollowSFAS117 RetainedEarningsEndowmentEtc  \
# 0             NaN                NaN                          NaN
#
#   InitialReturn MembershipDues GrossIncomeGaming GamingDirectExpenses  \
# 0           NaN            NaN               NaN                  NaN
#
#   NoncashContributions OwnWebsite UnsecuredNotesLoansPayable  \
# 0                  NaN        NaN                        NaN
#
#   TypeOfOrganizationOther Organization501c TypeOfOrganizationTrust  \
# 0                     NaN              NaN                     NaN
#
#   TypeOfOrganizationAssociation CountryLegalDomicile AmendedReturn  \
# 0                           NaN                  NaN           NaN
#
#   TypeOfOrgOtherDescription TerminatedReturn TerminationOrContraction  \
# 0                       NaN              NaN                      NaN
#
#   SpecialConditionDescription Organization4947a1  \
# 0                         NaN                NaN
#
#   ReconciliationUnrealizedInvest ReconcilationPriorAdjustment  \
# 0                            NaN                          NaN
#
#   ReconcilationDonatedServices ReconcilationInvestExpenses PrincipalOfficerNm  \
# 0                          NaN                         NaN                NaN
#
#   GrossReceiptsAmt GroupReturnForAffiliatesInd Organization501c3Ind  \
# 0              NaN                         NaN                  NaN
#
#   TypeOfOrganizationCorpInd FormationYr LegalDomicileStateCd  \
# 0                       NaN         NaN                  NaN
#
#   ActivityOrMissionDesc VotingMembersGoverningBodyCnt  \
# 0                   NaN                           NaN
#
#   VotingMembersIndependentCnt TotalEmployeeCnt TotalGrossUBIAmt  \
# 0                         NaN              NaN              NaN
#
#   CYContributionsGrantsAmt CYProgramServiceRevenueAmt CYInvestmentIncomeAmt  \
# 0                      NaN                        NaN                   NaN
#
#   CYOtherRevenueAmt CYTotalRevenueAmt CYGrantsAndSimilarPaidAmt  \
# 0               NaN               NaN                       NaN
#
#   CYBenefitsPaidToMembersAmt CYSalariesCompEmpBnftPaidAmt  \
# 0                        NaN                          NaN
#
#   CYTotalProfFndrsngExpnsAmt CYTotalFundraisingExpenseAmt CYOtherExpensesAmt  \
# 0                        NaN                          NaN                NaN
#
#   CYTotalExpensesAmt CYRevenuesLessExpensesAmt TotalAssetsBOYAmt  \
# 0                NaN                       NaN               NaN
#
#   TotalAssetsEOYAmt TotalLiabilitiesEOYAmt NetAssetsOrFundBalancesBOYAmt  \
# 0               NaN                    NaN                           NaN
#
#   NetAssetsOrFundBalancesEOYAmt ProfessionalFundraisingInd  \
# 0                           NaN                        NaN
#
#   FundraisingActivitiesInd GamingActivitiesInd GoverningBodyVotingMembersCnt  \
# 0                      NaN                 NaN                           NaN
#
#   IndependentVotingMemberCnt FamilyOrBusinessRlnInd DelegationOfMgmtDutiesInd  \
# 0                        NaN                    NaN                       NaN
#
#   ChangeToOrgDocumentsInd MaterialDiversionOrMisuseInd  \
# 0                     NaN                          NaN
#
#   MembersOrStockholdersInd ElectionOfBoardMembersInd  \
# 0                      NaN                       NaN
#
#   DecisionsSubjectToApprovaInd MinutesOfGoverningBodyInd  \
# 0                          NaN                       NaN
#
#   MinutesOfCommitteesInd OfficerMailingAddressInd LocalChaptersInd  \
# 0                    NaN                      NaN              NaN
#
#   Form990ProvidedToGvrnBodyInd ConflictOfInterestPolicyInd  \
# 0                          NaN                         NaN
#
#   WhistleblowerPolicyInd DocumentRetentionPolicyInd CompensationProcessCEOInd  \
# 0                    NaN                        NaN                       NaN
#
#   CompensationProcessOtherInd InvestmentInJointVentureInd  \
# 0                         NaN                         NaN
#
#   StatesWhereCopyOfReturnIsFldCd NoListedPersonsCompensatedInd  \
# 0                            NaN                           NaN
#
#   FormerOfcrEmployeesListedInd TotalCompGreaterThan150KInd  \
# 0                          NaN                         NaN
#
#   CompensationFromOtherSrcsInd MembershipDuesAmt FundraisingAmt  \
# 0                          NaN               NaN            NaN
#
#   AllOtherContributionsAmt TotalContributionsAmt OtherRevenueTotalAmt  \
# 0                      NaN                   NaN                  NaN
#
#   TotalRevenueGrp FeesForServicesAccountingGrp TotalFunctionalExpensesGrp  \
# 0             NaN                          NaN                        NaN
#
#   CashNonInterestBearingGrp TotalAssetsGrp OrgDoesNotFollowSFAS117Ind  \
# 0                       NaN            NaN                        NaN
#
#   RtnEarnEndowmentIncmOthFndsGrp ReconcilationRevenueExpnssAmt  \
# 0                            NaN                           NaN
#
#   MethodOfAccountingCashInd AccountantCompileOrReviewInd FSAuditedInd  \
# 0                       NaN                          NaN          NaN
#
#   FederalGrantAuditRequiredInd WebsiteAddressTxt TotalVolunteersCnt  \
# 0                          NaN               NaN                NaN
#
#   NetUnrelatedBusTxblIncmAmt PYContributionsGrantsAmt  \
# 0                        NaN                      NaN
#
#   PYProgramServiceRevenueAmt PYInvestmentIncomeAmt PYOtherRevenueAmt  \
# 0                        NaN                   NaN               NaN
#
#   PYTotalRevenueAmt PYGrantsAndSimilarPaidAmt PYBenefitsPaidToMembersAmt  \
# 0               NaN                       NaN                        NaN
#
#   PYSalariesCompEmpBnftPaidAmt PYTotalProfFndrsngExpnsAmt PYOtherExpensesAmt  \
# 0                          NaN                        NaN                NaN
#
#   PYTotalExpensesAmt PYRevenuesLessExpensesAmt TotalLiabilitiesBOYAmt  \
# 0                NaN                       NaN                    NaN
#
#   AnnualDisclosureCoveredPrsnInd RegularMonitoringEnfrcInd UponRequestInd  \
# 0                            NaN                       NaN            NaN
#
#   TotalReportableCompFromOrgAmt TotReportableCompRltdOrgAmt  \
# 0                           NaN                         NaN
#
#   TotalOtherCompensationAmt IndivRcvdGreaterThan100KCnt  \
# 0                       NaN                         NaN
#
#   CntrctRcvdGreaterThan100KCnt GovernmentGrantsAmt  \
# 0                          NaN                 NaN
#
#   TotalProgramServiceRevenueAmt FundraisingGrossIncomeAmt  \
# 0                           NaN                       NaN
#
#   ContriRptFundraisingEventAmt FundraisingDirectExpensesAmt  \
# 0                          NaN                          NaN
#
#   GrossSalesOfInventoryAmt CostOfGoodsSoldAmt CompCurrentOfcrDirectorsGrp  \
# 0                      NaN                NaN                         NaN
#
#   OtherSalariesAndWagesGrp PensionPlanContributionsGrp  \
# 0                      NaN                         NaN
#
#   OtherEmployeeBenefitsGrp PayrollTaxesGrp FeesForServicesOtherGrp  \
# 0                      NaN             NaN                     NaN
#
#   SavingsAndTempCashInvstGrp LandBldgEquipCostOrOtherBssAmt  \
# 0                        NaN                            NaN
#
#   LandBldgEquipAccumDeprecAmt MortgNotesPyblScrdInvstPropGrp  \
# 0                         NaN                            NaN
#
#   OtherLiabilitiesGrp OrganizationFollowsSFAS117Ind  \
# 0                 NaN                           NaN
#
#   NetUnrlzdGainsLossesInvstAmt AuditCommitteeInd AllAffiliatesIncludedInd  \
# 0                          NaN               NaN                      NaN
#
#   CompDisqualPersonsGrp FeesForServicesManagementGrp FeesForServicesLegalGrp  \
# 0                   NaN                          NaN                     NaN
#
#   FeesForServicesLobbyingGrp FeesForSrvcInvstMgmntFeesGrp  \
# 0                        NaN                          NaN
#
#   MethodOfAccountingAccrualInd NoncashContributionsAmt  \
# 0                          NaN                     NaN
#
#   TaxExemptBondLiabilitiesGrp LoansFromOfficersDirectorsGrp  \
# 0                         NaN                           NaN
#
#   UnsecuredNotesLoansPayableGrp PriorPeriodAdjustmentsAmt  \
# 0                           NaN                       NaN
#
#   FederalGrantAuditPerformedInd PoliciesReferenceChaptersInd OtherWebsiteInd  \
# 0                           NaN                          NaN             NaN
#
#   AddressChangeInd WrittenPolicyOrProcedureInd RelatedOrganizationsAmt  \
# 0              NaN                         NaN                     NaN
#
#   OwnWebsiteInd DonatedServicesAndUseFcltsAmt LegalDomicileCountryCd  \
# 0           NaN                           NaN                    NaN
#
#   TypeOfOrganizationTrustInd FinalReturnInd ContractTerminationInd  \
# 0                        NaN            NaN                    NaN
#
#   GroupExemptionNum FederatedCampaignsAmt TypeOfOrganizationOtherInd  \
# 0               NaN                   NaN                        NaN
#
#   OtherOrganizationDsc TypeOfOrganizationAssocInd InitialReturnInd  \
# 0                  NaN                        NaN              NaN
#
#   GamingGrossIncomeAmt GamingDirectExpensesAmt MethodOfAccountingOtherInd  \
# 0                  NaN                     NaN                        NaN
#
#   InvestmentExpenseAmt Organization501cInd Organization4947a1NotPFInd  \
# 0                  NaN                 NaN                        NaN
#
#   AmendedReturnInd SpecialConditionDesc fiscal_year
# 0              NaN                  NaN        2010

# %% [markdown]
# ### Initital Verifications - Check whether it contains all relevant columns

# %%
id_cols = ['DLN', 'EIN', 'URL', 'OrganizationName', 'ReturnHeader']

# %%
print(len(set(df.columns.tolist())) - len(set(id_cols)))
print(len(set(df.columns.tolist())) - len(set(mongo_cols)) - len(set(id_cols)))
# Out:
# 319
# -9

# %%
set(mongo_cols) - set(df.columns.tolist())
# Out:
# {'BuildTS',
#  'BusinessOfficerGrp',
#  'Filer',
#  'Officer',
#  'ReturnTs',
#  'TaxPeriodEndDate',
#  'TaxPeriodEndDt',
#  'TaxYear',
#  'TaxYr',
#  'Timestamp'}

# %%
set(df.columns.tolist()) - set(mongo_cols)
# Out:
# {'DLN', 'EIN', 'OrganizationName', 'ReturnHeader', 'URL', 'fiscal_year'}

# %%
len(df)
# Out:
# 1895016

# %%
len(df.columns)
# Out:
# 324

# %% [markdown]
# ### Save DF

# %%
pwd
# Out:
# 'C:\\Users\\Gregory\\IRS 990 Control Variables'

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %%
# %%time
df.to_pickle('all filings nov. 2020 - all control variables.pkl.gz', compression='gzip')
# Out:
# Wall time: 26min 25s
