# %% [markdown]
# # Overview
# This notebook should not be needed in future runs. If I've updated notebook 'A2', then the *ReturnHeader* columns will be parsed there.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from pandas import Series

# %%
print(pd.__version__)
# Out:
# 0.24.2

# %%
#http://pandas.pydata.org/pandas-docs/stable/options.html
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', 250)

# %% [markdown]
# #### Set working directory

# %%
#cd '/Users/gsaxton/Dropbox/990 e-file data'

# %%
pwd
# Out:
# 'C:\\Users\\Gregory'

# %%
cd "C:\\Users\\Gregory\\IRS 990 Control Variables\\"
# Out:
# C:\Users\Gregory\IRS 990 Control Variables

# %% [markdown]
# # Read in Concordance File
# We are going to read in two codebooks. First, there is the 'concordance' file. Specifically, before re-arranging and renaming variables, we will read in the relevant section from the *master concordance* file, and then use this file to identify the relevant 'compensation' variables. In a following notebook, we will be using the *new_variable_name* field as our variable name.

# %%
concordance = pd.read_excel('concordance_VERIFIED.xlsx')
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:2]
# Out:
# # of columns: 15
# # of observations: 378
#                                    xpath project     variable_name_new  \
# 0  /Return/ReturnHeader/TaxPeriodEndDate     NaN  F9_00_HD_TAX_PER_END
# 1    /Return/ReturnHeader/TaxPeriodEndDt     NaN  F9_00_HD_TAX_PER_END
#
#    # of Characters (newly named) variable name notes  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
#
#                        PARSING NOTES OTHER NOTES          description  \
# 0  Will be nested under ReturnHeader         NaN  Tax period end date
# 1  Will be nested under ReturnHeader         NaN  Tax period end date
#
#   location_code part data_type_xsd BINARIZE      MongoDB_Name sub_key  \
# 0        HEADER   HD      DateType      NaN  TaxPeriodEndDate     NaN
# 1        HEADER   HD      DateType      NaN    TaxPeriodEndDt     NaN
#
#   sub_sub_key
# 0         NaN
# 1         NaN

# %%
concordance
# Out:
#                                                            xpath project  \
# 0                          /Return/ReturnHeader/TaxPeriodEndDate     NaN
# 1                            /Return/ReturnHeader/TaxPeriodEndDt     NaN
# 2                                   /Return/ReturnHeader/TaxYear     NaN
# 3                                     /Return/ReturnHeader/TaxYr     NaN
# 4                                   /Return/ReturnHeader/BuildTS     NaN
# 5            /Return/ReturnHeader/BusinessOfficerGrp/SignatureDt     NaN
# 6                        /Return/ReturnHeader/Officer/DateSigned     NaN
# 7                                  /Return/ReturnHeader/ReturnTs     NaN
# 8                                 /Return/ReturnHeader/Timestamp     NaN
# 9                     /Return/ReturnHeader/Filer/USAddress/State     NaN
# 10      /Return/ReturnHeader/Filer/USAddress/StateAbbreviationCd     NaN
# 11                           /Return/ReturnData/IRS990/TaxPeriod     NaN
# 12                /Return/ReturnData/IRS990/SpecialConditionDesc     NaN
# 13         /Return/ReturnData/IRS990/SpecialConditionDescription     NaN
# 14                       /Return/ReturnData/IRS990/AddressChange     NaN
# 15                    /Return/ReturnData/IRS990/AddressChangeInd     NaN
# 16                       /Return/ReturnData/IRS990/AmendedReturn     NaN
# 17                    /Return/ReturnData/IRS990/AmendedReturnInd     NaN
# 18                      /Return/ReturnData/IRS990/FinalReturnInd     NaN
# 19                    /Return/ReturnData/IRS990/TerminatedReturn     NaN
# 20                       /Return/ReturnData/IRS990/InitialReturn     NaN
# 21                    /Return/ReturnData/IRS990/InitialReturnInd     NaN
# 22        /Return/ReturnData/IRS990/NameOfPrincipalOfficerPerson     NaN
# 23                  /Return/ReturnData/IRS990/PrincipalOfficerNm     NaN
# 24                       /Return/ReturnData/IRS990/GrossReceipts     NaN
# 25                    /Return/ReturnData/IRS990/GrossReceiptsAmt     NaN
# 26            /Return/ReturnData/IRS990/GroupReturnForAffiliates     NaN
# 27         /Return/ReturnData/IRS990/GroupReturnForAffiliatesInd     NaN
# 28               /Return/ReturnData/IRS990/AllAffiliatesIncluded     NaN
# 29            /Return/ReturnData/IRS990/AllAffiliatesIncludedInd     NaN
# ..                                                           ...     ...
# 348                         /Return/ReturnData/IRS990/OwnWebsite   PERKS
# 349                      /Return/ReturnData/IRS990/OwnWebsiteInd   PERKS
# 350                       /Return/ReturnData/IRS990/TotalRevenue   PERKS
# 351                    /Return/ReturnData/IRS990/TotalRevenueGrp   PERKS
# 352         /Return/ReturnData/IRS990/TotalProgramServiceRevenue   PERKS
# 353      /Return/ReturnData/IRS990/TotalProgramServiceRevenueAmt   PERKS
# 354                        /Return/ReturnData/IRS990/TotalAssets   PERKS
# 355                     /Return/ReturnData/IRS990/TotalAssetsGrp   PERKS
# 356           /Return/ReturnData/IRS990/TaxExemptBondLiabilities   PERKS
# 357        /Return/ReturnData/IRS990/TaxExemptBondLiabilitiesGrp   PERKS
# 358         /Return/ReturnData/IRS990/LoansFromOfficersDirectors   PERKS
# 359      /Return/ReturnData/IRS990/LoansFromOfficersDirectorsGrp   PERKS
# 360     /Return/ReturnData/IRS990/MortgNotesPyblScrdInvstPropGrp   PERKS
# 361     /Return/ReturnData/IRS990/MortNotesPyblSecuredInvestProp   PERKS
# 362      /Return/ReturnData/IRS990/UnsecuredNotesLoansPayableGrp   PERKS
# 363         /Return/ReturnData/IRS990/UnsecuredNotesLoansPayable   PERKS
# 364      /Return/ReturnData/IRS990/UnsecuredNotesLoansPayableGrp   PERKS
# 365         /Return/ReturnData/IRS990/UnsecuredNotesLoansPayable   PERKS
# 366                   /Return/ReturnData/IRS990/OtherLiabilities   PERKS
# 367                /Return/ReturnData/IRS990/OtherLiabilitiesGrp   PERKS
# 368       /Return/ReturnData/IRS990/RetainedEarningsEndowmentEtc   PERKS
# 369     /Return/ReturnData/IRS990/RtnEarnEndowmentIncmOthFndsGrp   PERKS
# 370         /Return/ReturnData/IRS990/CashNonInterestBearing/BOY   PERKS
# 371   /Return/ReturnData/IRS990/CashNonInterestBearingGrp/BOYAmt   PERKS
# 372         /Return/ReturnData/IRS990/CashNonInterestBearing/EOY   PERKS
# 373   /Return/ReturnData/IRS990/CashNonInterestBearingGrp/EOYAmt   PERKS
# 374  /Return/ReturnData/IRS990/SavingsAndTempCashInvestments/BOY   PERKS
# 375  /Return/ReturnData/IRS990/SavingsAndTempCashInvstGrp/BOYAmt   PERKS
# 376  /Return/ReturnData/IRS990/SavingsAndTempCashInvestments/EOY   PERKS
# 377  /Return/ReturnData/IRS990/SavingsAndTempCashInvstGrp/EOYAmt   PERKS
#
#                     variable_name_new  # of Characters (newly named)  \
# 0                F9_00_HD_TAX_PER_END                            NaN
# 1                F9_00_HD_TAX_PER_END                            NaN
# 2                   F9_00_HD_TAX_YEAR                            NaN
# 3                   F9_00_HD_TAX_YEAR                            NaN
# 4           F9_00_HD_BUILD_TIME_STAMP                            NaN
# 5     F9_00_HD_SIGNING_OFFICER_SIGNTR                            NaN
# 6     F9_00_HD_SIGNING_OFFICER_SIGNTR                            NaN
# 7                 F9_00_HD_TIME_STAMP                            NaN
# 8                 F9_00_HD_TIME_STAMP                            NaN
# 9             F9_00_HD_FILER_STATE_US                            NaN
# 10            F9_00_HD_FILER_STATE_US                            NaN
# 11                          TaxPeriod                            9.0
# 12    F9_00_HD_SPECIAL_CONDITION_DESC                            NaN
# 13    F9_00_HD_SPECIAL_CONDITION_DESC                           31.0
# 14               F9_00_HD_ADDR_CHANGE                           20.0
# 15               F9_00_HD_ADDR_CHANGE                            NaN
# 16            F9_00_HD_AMENDED_RETURN                           23.0
# 17            F9_00_HD_AMENDED_RETURN                           23.0
# 18              F9_00_HD_FINAL_RETURN                            NaN
# 19              F9_00_HD_FINAL_RETURN                            NaN
# 20            F9_00_HD_INITIAL_RETURN                            NaN
# 21            F9_00_HD_INITIAL_RETURN                            NaN
# 22             F9_00_HD_PRIN_OFF_NAME                            NaN
# 23             F9_00_HD_PRIN_OFF_NAME                            NaN
# 24                F9_00_HD_GROSS_RCPT                            NaN
# 25                F9_00_HD_GROSS_RCPT                            NaN
# 26              F9_00_HD_GROUP_RETURN                            NaN
# 27              F9_00_HD_GROUP_RETURN                            NaN
# 28      F9_00_HD_INCLUDES_SUBORD_ORGS                            NaN
# 29      F9_00_HD_INCLUDES_SUBORD_ORGS                            NaN
# ..                                ...                            ...
# 348   F9_06_PC_FORM_AVAIL_OWN_WEBSITE                           31.0
# 349   F9_06_PC_FORM_AVAIL_OWN_WEBSITE                           31.0
# 350            F9_08_PC_TOTAL_REVENUE                           22.0
# 351            F9_08_PC_TOTAL_REVENUE                           22.0
# 352   F9_08_PC_PROGRAM_SVCE_REV_TOTAL                           31.0
# 353   F9_08_PC_PROGRAM_SVCE_REV_TOTAL                           31.0
# 354         F9_10_PZ_TOTAL_ASSETS_EOY                           25.0
# 355         F9_10_PZ_TOTAL_ASSETS_EOY                           25.0
# 356     F9_10_PC_BOND_LIABILITIES_EOY                           29.0
# 357     F9_10_PC_BOND_LIABILITIES_EOY                           29.0
# 358  F9_10_PC_LOANS_FROM_OFFICERS_EOY                           32.0
# 359  F9_10_PC_LOANS_FROM_OFFICERS_EOY                           32.0
# 360    F9_10_PC_SECURED_MORTGAGES_EOY                           30.0
# 361    F9_10_PC_SECURED_MORTGAGES_EOY                           30.0
# 362      F9_10_PC_UNSECURED_NOTES_EOY                           28.0
# 363      F9_10_PC_UNSECURED_NOTES_EOY                           28.0
# 364      F9_10_PC_UNSECURED_NOTES_BOY                           28.0
# 365      F9_10_PC_UNSECURED_NOTES_BOY                           28.0
# 366    F9_10_PC_OTHER_LIABILITIES_EOY                           30.0
# 367    F9_10_PC_OTHER_LIABILITIES_EOY                           30.0
# 368  F9_10_PC_RET_EARNINGS_ENDWMT_EOY                           32.0
# 369  F9_10_PC_RET_EARNINGS_ENDWMT_EOY                           32.0
# 370    F9_10_PC_CASH_NON_INTEREST_BOY                           30.0
# 371    F9_10_PC_CASH_NON_INTEREST_BOY                           30.0
# 372    F9_10_PC_CASH_NON_INTEREST_EOY                           30.0
# 373    F9_10_PC_CASH_NON_INTEREST_EOY                           30.0
# 374  F9_10_PC_SAVINGS_TEMP_INVEST_BOY                           32.0
# 375  F9_10_PC_SAVINGS_TEMP_INVEST_BOY                           32.0
# 376  F9_10_PC_SAVINGS_TEMP_INVEST_EOY                           32.0
# 377  F9_10_PC_SAVINGS_TEMP_INVEST_EOY                           32.0
#
#                                               variable name notes  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# 5                                                             NaN
# 6                                                             NaN
# 7                                                             NaN
# 8                                                             NaN
# 9                                                             NaN
# 10                                                            NaN
# 11                                  variable_name_new value added
# 12                                                            NaN
# 13                                                            NaN
# 14                                                            NaN
# 15                                                            NaN
# 16   Fixed misspelled variable_name_new: F9_00_HD_AMMENDED_RETURN
# 17   Fixed misspelled variable_name_new: F9_00_HD_AMMENDED_RETURN
# 18                                                            NaN
# 19                                                            NaN
# 20                                                            NaN
# 21                                                            NaN
# 22                                                            NaN
# 23                                                            NaN
# 24                                                            NaN
# 25                                                            NaN
# 26                                                            NaN
# 27                                                            NaN
# 28                                                            NaN
# 29                                                            NaN
# ..                                                            ...
# 348                                 variable_name_new value added
# 349                                 variable_name_new value added
# 350                                 variable_name_new value added
# 351                                 variable_name_new value added
# 352                                 variable_name_new value added
# 353                                 variable_name_new value added
# 354                                 variable_name_new value added
# 355                                 variable_name_new value added
# 356                                 variable_name_new value added
# 357                                 variable_name_new value added
# 358                                 variable_name_new value added
# 359                                 variable_name_new value added
# 360                                 variable_name_new value added
# 361                                 variable_name_new value added
# 362                                 variable_name_new value added
# 363                                 variable_name_new value added
# 364                                 variable_name_new value added
# 365                                 variable_name_new value added
# 366                                 variable_name_new value added
# 367                                 variable_name_new value added
# 368                                 variable_name_new value added
# 369                                 variable_name_new value added
# 370                                 variable_name_new value added
# 371                                 variable_name_new value added
# 372                                 variable_name_new value added
# 373                                 variable_name_new value added
# 374                                 variable_name_new value added
# 375                                 variable_name_new value added
# 376                                 variable_name_new value added
# 377                                 variable_name_new value added
#
#                                                                                             PARSING NOTES  \
# 0                                                                       Will be nested under ReturnHeader
# 1                                                                       Will be nested under ReturnHeader
# 2                                                                       Will be nested under ReturnHeader
# 3                                                                       Will be nested under ReturnHeader
# 4                                                                       Will be nested under ReturnHeader
# 5                                                                       Will be nested under ReturnHeader
# 6                                                                       Will be nested under ReturnHeader
# 7                                                                       Will be nested under ReturnHeader
# 8                                                                       Will be nested under ReturnHeader
# 9                                                                       Will be nested under ReturnHeader
# 10                                                                      Will be nested under ReturnHeader
# 11                                                                                                    NaN
# 12                                                                                                    NaN
# 13                                                                                                    NaN
# 14                                                                                                    NaN
# 15                                                                                                    NaN
# 16                                                                                                    NaN
# 17                                                                                                    NaN
# 18                                                                                                    NaN
# 19                                                                                                    NaN
# 20                                                                                                    NaN
# 21                                                                                                    NaN
# 22                                                                                                    NaN
# 23                                                                                                    NaN
# 24                                                                                                    NaN
# 25                                                                                                    NaN
# 26                                                                                                    NaN
# 27                                                                                                    NaN
# 28                                                                                                    NaN
# 29                                                                                                    NaN
# ..                                                                                                    ...
# 348                                                                                                   NaN
# 349                                                                                                   NaN
# 350                                                                                                   NaN
# 351                                                                                                   NaN
# 352                                                                                                   NaN
# 353                                                                                                   NaN
# 354                                                                                                   NaN
# 355                                                                                                   NaN
# 356                                                                                                   NaN
# 357                                                                                                   NaN
# 358                                                                                                   NaN
# 359                                                                                                   NaN
# 360                                                                                                   NaN
# 361                                                                                                   NaN
# 362                                                                                                   NaN
# 363                                                                                                   NaN
# 364                                                                                                   NaN
# 365                                                                                                   NaN
# 366                                                                                                   NaN
# 367                                                                                                   NaN
# 368                                                                                                   NaN
# 369                                                                                                   NaN
# 370  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
# 371  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
# 372  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
# 373  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
# 374  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
# 375  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
# 376  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
# 377  sub key --> need to parse dictionary; thus custom MongoDB_Name; multiple variables from MongoDB_Name
#
#                                              OTHER NOTES  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11   This appears to be the month of tax period end date
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ..                                                   ...
# 348                                                  NaN
# 349                                                  NaN
# 350                                                  NaN
# 351                                                  NaN
# 352                                                  NaN
# 353                                                  NaN
# 354                                                  NaN
# 355                                                  NaN
# 356                                                  NaN
# 357                                                  NaN
# 358                                                  NaN
# 359                                                  NaN
# 360                                                  NaN
# 361                                                  NaN
# 362                       NOT IN MASTER CONCORDANCE FILE
# 363                       NOT IN MASTER CONCORDANCE FILE
# 364                       NOT IN MASTER CONCORDANCE FILE
# 365                       NOT IN MASTER CONCORDANCE FILE
# 366                                                  NaN
# 367                                                  NaN
# 368                                                  NaN
# 369                                                  NaN
# 370                                                  NaN
# 371                                                  NaN
# 372                                                  NaN
# 373                                                  NaN
# 374                                                  NaN
# 375                                                  NaN
# 376                                                  NaN
# 377                                                  NaN
#
#                                                     description  \
# 0                                           Tax period end date
# 1                                           Tax period end date
# 2                                                      Tax year
# 3                                                      Tax year
# 4                         Build time stamp - IRS internal field
# 5                           Date of Signing Officer's Signature
# 6                           Date of Signing Officer's Signature
# 7                 The date and time when the return was created
# 8                 The date and time when the return was created
# 9                     Address of Filing Organization (US State)
# 10                    Address of Filing Organization (US State)
# 11                                                          NaN
# 12                                Special condition description
# 13                                Special condition description
# 14                    Indicates this form has an address change
# 15                    Indicates this form has an address change
# 16                     Inidcates this form is an amended return
# 17                     Inidcates this form is an amended return
# 18                        Inidcates this form is a final return
# 19                        Inidcates this form is a final return
# 20                     Inidcates this form is an initial return
# 21                     Inidcates this form is an initial return
# 22                           Name of Principal Officer (Person)
# 23                           Name of Principal Officer (Person)
# 24                                      Gross Receipts (Header)
# 25                                      Gross Receipts (Header)
# 26       Indicates this form is a group return for subordinates
# 27       Indicates this form is a group return for subordinates
# 28   Indicates this form includes all subordinate organizations
# 29   Indicates this form includes all subordinate organizations
# ..                                                          ...
# 348                               Form available on own website
# 349                               Form available on own website
# 350                                               Total revenue
# 351                                               Total revenue
# 352                      Program service revenue group, line 2G
# 353                      Program service revenue group, line 2G
# 354                                   Total assets, end of year
# 355                                   Total assets, end of year
# 356                    Tax-exempt bond liabilities, end of year
# 357                    Tax-exempt bond liabilities, end of year
# 358      Loans and other receivables from officers, end of year
# 359      Loans and other receivables from officers, end of year
# 360            Secured mortgages and notes payable, end of year
# 361            Secured mortgages and notes payable, end of year
# 362                           Unsecured notes and loans payable
# 363                           Unsecured notes and loans payable
# 364                           Unsecured notes and loans payable
# 365                           Unsecured notes and loans payable
# 366                              Other liabilities, end of year
# 367                              Other liabilities, end of year
# 368                 Retained earnings or endowment, end of year
# 369                 Retained earnings or endowment, end of year
# 370               Cash, non-interest-bearing, beginning of year
# 371               Cash, non-interest-bearing, beginning of year
# 372                     Cash, non-interest-bearing, end of year
# 373                     Cash, non-interest-bearing, end of year
# 374   Savings and temporary cash investments, beginning of year
# 375   Savings and temporary cash investments, beginning of year
# 376         Savings and temporary cash investments, end of year
# 377         Savings and temporary cash investments, end of year
#
#                            location_code     part   data_type_xsd  BINARIZE  \
# 0                                 HEADER       HD        DateType       NaN
# 1                                 HEADER       HD        DateType       NaN
# 2                                 HEADER       HD        YearType       NaN
# 3                                 HEADER       HD        YearType       NaN
# 4                                 HEADER  PART-00             NaN       NaN
# 5                                 HEADER  PART-00        DateType       NaN
# 6                                 HEADER  PART-00        DateType       NaN
# 7                                 HEADER  PART-00   TimestampType       NaN
# 8                                 HEADER  PART-00   TimestampType       NaN
# 9                                 HEADER  PART-00       StateType       NaN
# 10                                HEADER  PART-00       StateType       NaN
# 11                                   NaN      NaN             NaN       NaN
# 12                       F990-PC-PART-00  PART-00        TextType       NaN
# 13                       F990-PC-PART-00  PART-00        TextType       NaN
# 14             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 15             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 16             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 17             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 18             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 19             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 20             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 21             F990-PC-PART-00-SECTION-B  PART-00    CheckboxType  binarize
# 22             F990-PC-PART-00-SECTION-F  PART-00  PersonNameType       NaN
# 23             F990-PC-PART-00-SECTION-F  PART-00  PersonNameType       NaN
# 24             F990-PC-PART-00-SECTION-G  PART-00  USAmountNNType       NaN
# 25             F990-PC-PART-00-SECTION-G  PART-00  USAmountNNType       NaN
# 26            F990-PC-PART-00-SECTION-HA  PART-00     BooleanType  binarize
# 27            F990-PC-PART-00-SECTION-HA  PART-00     BooleanType  binarize
# 28            F990-PC-PART-00-SECTION-HB  PART-00     BooleanType  binarize
# 29            F990-PC-PART-00-SECTION-HB  PART-00     BooleanType  binarize
# ..                                   ...      ...             ...       ...
# 348  F990-PC-PART-06-SECTION-C-LINE-18-1  PART-06    CheckboxType  binarize
# 349  F990-PC-PART-06-SECTION-C-LINE-18-1  PART-06    CheckboxType  binarize
# 350        F990-PC-PART-08-LINE-12-COL-A  PART-08    USAmountType       NaN
# 351        F990-PC-PART-08-LINE-12-COL-A  PART-08    USAmountType       NaN
# 352            F990-PC-PART-08-LINE-02-G  PART-08    USAmountType       NaN
# 353            F990-PC-PART-08-LINE-02-G  PART-08    USAmountType       NaN
# 354          F990-PC-PART-10-LINE-16-EOY  PART-10    USAmountType       NaN
# 355          F990-PC-PART-10-LINE-16-EOY  PART-10    USAmountType       NaN
# 356          F990-PC-PART-10-LINE-20-EOY  PART-10  USAmountNNType       NaN
# 357          F990-PC-PART-10-LINE-20-EOY  PART-10    USAmountType       NaN
# 358          F990-PC-PART-10-LINE-22-EOY  PART-10    USAmountType       NaN
# 359          F990-PC-PART-10-LINE-22-EOY  PART-10    USAmountType       NaN
# 360          F990-PC-PART-10-LINE-23-EOY  PART-10    USAmountType       NaN
# 361          F990-PC-PART-10-LINE-23-EOY  PART-10    USAmountType       NaN
# 362              F990-PC-PART-10-LINE-24  PART-10    USAmountType       NaN
# 363              F990-PC-PART-10-LINE-24  PART-10    USAmountType       NaN
# 364              F990-PC-PART-10-LINE-24  PART-10    USAmountType       NaN
# 365              F990-PC-PART-10-LINE-24  PART-10    USAmountType       NaN
# 366          F990-PC-PART-10-LINE-25-EOY  PART-10    USAmountType       NaN
# 367          F990-PC-PART-10-LINE-25-EOY  PART-10    USAmountType       NaN
# 368          F990-PC-PART-10-LINE-32-EOY  PART-10    USAmountType       NaN
# 369          F990-PC-PART-10-LINE-32-EOY  PART-10    USAmountType       NaN
# 370          F990-PC-PART-10-LINE-01-BOY  PART-10  USAmountNNType       NaN
# 371          F990-PC-PART-10-LINE-01-BOY  PART-10    USAmountType       NaN
# 372          F990-PC-PART-10-LINE-01-EOY  PART-10    USAmountType       NaN
# 373          F990-PC-PART-10-LINE-01-EOY  PART-10    USAmountType       NaN
# 374          F990-PC-PART-10-LINE-02-BOY  PART-10  USAmountNNType       NaN
# 375          F990-PC-PART-10-LINE-02-BOY  PART-10    USAmountType       NaN
# 376          F990-PC-PART-10-LINE-02-EOY  PART-10    USAmountType       NaN
# 377          F990-PC-PART-10-LINE-02-EOY  PART-10    USAmountType       NaN
#
#                        MongoDB_Name                sub_key  \
# 0                  TaxPeriodEndDate                    NaN
# 1                    TaxPeriodEndDt                    NaN
# 2                           TaxYear                    NaN
# 3                             TaxYr                    NaN
# 4                           BuildTS                    NaN
# 5                BusinessOfficerGrp            SignatureDt
# 6                           Officer             DateSigned
# 7                          ReturnTs                    NaN
# 8                         Timestamp                    NaN
# 9                             Filer              USAddress
# 10                            Filer              USAddress
# 11                        TaxPeriod                    NaN
# 12             SpecialConditionDesc                    NaN
# 13      SpecialConditionDescription                    NaN
# 14                    AddressChange                    NaN
# 15                 AddressChangeInd                    NaN
# 16                    AmendedReturn                    NaN
# 17                 AmendedReturnInd                    NaN
# 18                   FinalReturnInd                    NaN
# 19                 TerminatedReturn                    NaN
# 20                    InitialReturn                    NaN
# 21                 InitialReturnInd                    NaN
# 22     NameOfPrincipalOfficerPerson                    NaN
# 23               PrincipalOfficerNm                    NaN
# 24                    GrossReceipts                    NaN
# 25                 GrossReceiptsAmt                    NaN
# 26         GroupReturnForAffiliates                    NaN
# 27      GroupReturnForAffiliatesInd                    NaN
# 28            AllAffiliatesIncluded                    NaN
# 29         AllAffiliatesIncludedInd                    NaN
# ..                              ...                    ...
# 348                      OwnWebsite                    NaN
# 349                   OwnWebsiteInd                    NaN
# 350                    TotalRevenue     TotalRevenueColumn
# 351                 TotalRevenueGrp  TotalRevenueColumnAmt
# 352      TotalProgramServiceRevenue                    NaN
# 353   TotalProgramServiceRevenueAmt                    NaN
# 354                     TotalAssets                    EOY
# 355                  TotalAssetsGrp                 EOYAmt
# 356        TaxExemptBondLiabilities                    EOY
# 357     TaxExemptBondLiabilitiesGrp                 EOYAmt
# 358      LoansFromOfficersDirectors                 EOYAmt
# 359   LoansFromOfficersDirectorsGrp                 EOYAmt
# 360  MortgNotesPyblScrdInvstPropGrp                 EOYAmt
# 361  MortNotesPyblSecuredInvestProp                    EOY
# 362   UnsecuredNotesLoansPayableGrp                 EOYAmt
# 363      UnsecuredNotesLoansPayable                    EOY
# 364   UnsecuredNotesLoansPayableGrp                 BOYAmt
# 365      UnsecuredNotesLoansPayable                    BOY
# 366                OtherLiabilities                    EOY
# 367             OtherLiabilitiesGrp                 EOYAmt
# 368    RetainedEarningsEndowmentEtc                    EOY
# 369  RtnEarnEndowmentIncmOthFndsGrp                 EOYAmt
# 370          CashNonInterestBearing                    BOY
# 371       CashNonInterestBearingGrp                 BOYAmt
# 372          CashNonInterestBearing                    EOY
# 373       CashNonInterestBearingGrp                 EOYAmt
# 374   SavingsAndTempCashInvestments                    BOY
# 375      SavingsAndTempCashInvstGrp                 BOYAmt
# 376   SavingsAndTempCashInvestments                    EOY
# 377      SavingsAndTempCashInvstGrp                 EOYAmt
#
#              sub_sub_key
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                  State
# 10   StateAbbreviationCd
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# ..                   ...
# 348                  NaN
# 349                  NaN
# 350                  NaN
# 351                  NaN
# 352                  NaN
# 353                  NaN
# 354                  NaN
# 355                  NaN
# 356                  NaN
# 357                  NaN
# 358                  NaN
# 359                  NaN
# 360                  NaN
# 361                  NaN
# 362                  NaN
# 363                  NaN
# 364                  NaN
# 365                  NaN
# 366                  NaN
# 367                  NaN
# 368                  NaN
# 369                  NaN
# 370                  NaN
# 371                  NaN
# 372                  NaN
# 373                  NaN
# 374                  NaN
# 375                  NaN
# 376                  NaN
# 377                  NaN
#
# [378 rows x 15 columns]

# %%
concordance = concordance[concordance['xpath'].str.contains('ReturnHeader')]
print('# of columns:', len(concordance.columns))
print('# of observations:', len(concordance))
concordance[:1]
# Out:
# # of columns: 15
# # of observations: 11
#                                    xpath project     variable_name_new  \
# 0  /Return/ReturnHeader/TaxPeriodEndDate     NaN  F9_00_HD_TAX_PER_END
#
#    # of Characters (newly named) variable name notes  \
# 0                            NaN                 NaN
#
#                        PARSING NOTES OTHER NOTES          description  \
# 0  Will be nested under ReturnHeader         NaN  Tax period end date
#
#   location_code part data_type_xsd BINARIZE      MongoDB_Name sub_key  \
# 0        HEADER   HD      DateType      NaN  TaxPeriodEndDate     NaN
#
#   sub_sub_key
# 0         NaN

# %% [markdown]
# # Read 990 DB into PANDAS
# - In previous round there were 1,547,828 observations; now there are 1,727,056 observations
# - I also switched to using the *.pkl* file

# %%
df = pd.read_pickle('all filings feb. 2020 - select ReturnHeader variables.pkl')
print('# of columns:', len(df.columns))
print('# of observations:', len(df))
df[:2]
# Out:
# # of columns: 15
# # of observations: 1727056
#               DLN        EIN  \
# 0  93493313013011  232705170
# 1  93493313013111  581805618
#
#                                            OrganizationName TaxPeriod  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC    201012
# 1        TORRINGTON VOA ELDERLY HOUSING INC BELL PARK TOWER    201106
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
# 1  https://s3.amazonaws.com/irs-form-990/201113139349301311_public.xml
#
#                    Timestamp TaxPeriodEndDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31
# 1  2011-11-09T07:32:06-08:00       2011-06-30
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
# 1  {'EIN': '581805618', 'Name': {'BusinessNameLine1': 'TORRINGTON VOA ELDERLY HOUSING INC', 'BusinessNameLine2': 'BELL PARK TOWER'}, 'NameControl': 'TORR', 'Phone': '7033415000', 'USAddress': {'AddressLine1': '1660 DUKE STREET', 'City': 'ALEXANDRIA'...
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
# 1                                         {'Name': 'THOMAS D TURNBULL', 'Title': 'ASST. SEC/TREAS', 'DateSigned': '2011-11-09'}
#
#   TaxYear               BuildTS ReturnTs TaxPeriodEndDt BusinessOfficerGrp  \
# 0    2010  2016-02-24 21:20:13Z      NaN            NaN                NaN
# 1    2010  2016-02-24 21:20:13Z      NaN            NaN                NaN
#
#   TaxYr
# 0   NaN
# 1   NaN

# %% [markdown]
# ### Collapse

# %%
def agg_funcs(x):
    names = {
        #'name': x['variable_name_new'].head(1).values[0],
        'original_names':  list(set(x['MongoDB_Name'].tolist())),
        'data_type_xsd': x['data_type_xsd'].head(1).values[0]
        }
    #THE FOLLOWING SHORTCUT WORKS BUT CHANGES THE ORDER OF THE COLUMNS
    #return pd.Series(names, index = list(names.keys()))
    return pd.Series(names, index=['original_names', 'data_type_xsd'])
new_variables_df = concordance[:].groupby(['variable_name_new']).apply(agg_funcs)
new_variables_df = new_variables_df.reset_index()
print('# of variables:', len(new_variables_df))
new_variables_df[:5]
# Out:
# # of variables: 6
#                  variable_name_new                      original_names  \
# 0        F9_00_HD_BUILD_TIME_STAMP                           [BuildTS]
# 1          F9_00_HD_FILER_STATE_US                             [Filer]
# 2  F9_00_HD_SIGNING_OFFICER_SIGNTR       [BusinessOfficerGrp, Officer]
# 3             F9_00_HD_TAX_PER_END  [TaxPeriodEndDt, TaxPeriodEndDate]
# 4                F9_00_HD_TAX_YEAR                    [TaxYr, TaxYear]
#
#   data_type_xsd
# 0           NaN
# 1     StateType
# 2      DateType
# 3      DateType
# 4      YearType

# %%
new_variables_df['len'] = new_variables_df['original_names'].apply(lambda x: len(x))
print(new_variables_df['len'].value_counts(), '\n')
new_variables_df
# Out:
# 2    4
# 1    2
# Name: len, dtype: int64
#                  variable_name_new                      original_names  \
# 0        F9_00_HD_BUILD_TIME_STAMP                           [BuildTS]
# 1          F9_00_HD_FILER_STATE_US                             [Filer]
# 2  F9_00_HD_SIGNING_OFFICER_SIGNTR       [BusinessOfficerGrp, Officer]
# 3             F9_00_HD_TAX_PER_END  [TaxPeriodEndDt, TaxPeriodEndDate]
# 4                F9_00_HD_TAX_YEAR                    [TaxYr, TaxYear]
# 5              F9_00_HD_TIME_STAMP               [ReturnTs, Timestamp]
#
#    data_type_xsd  len
# 0            NaN    1
# 1      StateType    1
# 2       DateType    2
# 3       DateType    2
# 4       YearType    2
# 5  TimestampType    2

# %% [markdown]
# ### Handle variables with only 1 original name
# NOTE:
# - Per *IRS 990 e-File Data -- Control Variables (4) -- Fees-for-Services Variables  - Extract from MongoDB and Process -- Part I (Python 3.6).ipynb*, it looks like there is no *FeesForServicesProfFundraisingGrp*
#     - Instead, as seen in the concordance file, *FeesForServicesProfFundraising* has both a 'Total' and a 'TotalAmt' key, which suggests this is the only key that did not change names

# %%
new_variables_df[new_variables_df['len']!=2]
# Out:
#            variable_name_new original_names data_type_xsd  len
# 0  F9_00_HD_BUILD_TIME_STAMP      [BuildTS]           NaN    1
# 1    F9_00_HD_FILER_STATE_US        [Filer]     StateType    1

# %% [markdown]
# #### Rename *F9_00_HD_BUILD_TIME_STAMP*

# %%
df.rename(columns = {'BuildTS':'F9_00_HD_BUILD_TIME_STAMP'}, inplace = True)
df['F9_00_HD_BUILD_TIME_STAMP'].describe()
# Out:
# count                  1727056
# unique                      12
# top       2017-02-10 21:41:12Z
# freq                    304553
# Name: F9_00_HD_BUILD_TIME_STAMP, dtype: object

# %%
df['F9_00_HD_BUILD_TIME_STAMP'].value_counts().head()
# Out:
# 2017-02-10 21:41:12Z    304553
# 2016-02-24 21:20:13Z    299019
# 2019-02-21 02:37:17Z    230149
# 2015-11-30 17:44:51Z    199014
# 2016-02-25 16:41:14Z    170329
# Name: F9_00_HD_BUILD_TIME_STAMP, dtype: int64

# %%
#df = df.drop('fiscal_year', 1)

# %% [markdown]
# <br>Drop the two variables from *new_variables_df*

# %%
#print(len(new_variables_df))
#new_variables_df = new_variables_df[~new_variables_df['variable_name_new'].isin(['F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR'])]
print(len(new_variables_df))
# Out:
# 6

# %% [markdown]
# ##### Save DF

# %%
#import timeit
#start_time = timeit.default_timer()
#df.to_pickle('all filings - with 185 newly named control variables.pkl')
#elapsed = timeit.default_timer() - start_time
#print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  3.988038138333339

# %% [markdown]
# # Combine all columns where *len*==2

# %% [markdown]
# ### Define Function to combine columns
# In Python we can thus create a series of functions that can be used as shortcuts. First we'll create a function called 'combine' that will combine two variables. It takes as *inputs* four things: our dataset/dataframe (*df*), the name we'd like for our new variable (*newvar*), the name of the first variable to combine (*var1*), and the name of the second variable to combine (*var2*).

# %%
def combine(df, newvar, var1, var2):
    df[newvar] = np.where(df[var1].notnull(), df[var1], df[var2])
    #print(df[newvar].value_counts().head(), '\n')
    #print('# of missing observations:', len(df[df[newvar].isnull()]))
    #print('# of valid observations:', len(df[df[newvar].notnull()]), '\n')  
    #return df.sample(5)[[newvar, var1, var2, 'DLN']] 
    #print(df[[newvar, var1, var2, 'ObjectId']][:5], '\n\n\n')

# %% [markdown]
# #### Do initial check to ensure that no row has values in both columns

# %%
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    #print(row['variable_name_new'])
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    print('\t\t', len(df[df[row['original_names'][0]].notnull()]))
    print('\t\t', len(df[df[row['original_names'][1]].notnull()]))
    #print(len(df[(df[row['original_names'][0]].isnull()) & (df[row['original_names'][1]].isnull())]), '\n\n')      
    print('OK IF ZERO:', len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n\n')
# Out:
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# 		 1231533
# 		 495523
# OK IF ZERO: 0
#
#
# F9_00_HD_TAX_PER_END TaxPeriodEndDt TaxPeriodEndDate
# 		 1231533
# 		 495523
# OK IF ZERO: 0
#
#
# F9_00_HD_TAX_YEAR TaxYr TaxYear
# 		 1231533
# 		 495523
# OK IF ZERO: 0
#
#
# F9_00_HD_TIME_STAMP ReturnTs Timestamp
# 		 1231533
# 		 495523
# OK IF ZERO: 0

# %% [markdown]
# ### Combine

# %%
combo_fails = []
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    try:
        combine(df, row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    except:
        print('\n\n\n\n\n***********issue with variable: ', row['variable_name_new'])
        combo_fails.append(row['variable_name_new'])

print(combo_fails)
# Out:
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# F9_00_HD_TAX_PER_END TaxPeriodEndDt TaxPeriodEndDate
# F9_00_HD_TAX_YEAR TaxYr TaxYear
# F9_00_HD_TIME_STAMP ReturnTs Timestamp
# []

# %%
df.sample(5)
# Out:
#                  DLN        EIN           OrganizationName TaxPeriod  \
# 4283  93493050006434  941550842    STANFORD SETTLEMENT INC    201306
# 6994  93493233004339  383414580   GRAND RAPIDS RED PROJECT    201812
# 7809  93493250004347  920177969  COOK INLET LENDING CENTER    201612
# 1284  93493240005365  264338279               PROJECT SOLE    201412
# 3870  93493130015299  541478133             COLLINS CENTER    201806
#
#                                                                       URL  \
# 4283  https://s3.amazonaws.com/irs-form-990/201430509349300643_public.xml
# 6994  https://s3.amazonaws.com/irs-form-990/201932339349300433_public.xml
# 7809  https://s3.amazonaws.com/irs-form-990/201742509349300434_public.xml
# 1284  https://s3.amazonaws.com/irs-form-990/201512409349300536_public.xml
# 3870  https://s3.amazonaws.com/irs-form-990/201941309349301529_public.xml
#
#                       Timestamp TaxPeriodEndDate  \
# 4283  2014-02-19T17:31:19-06:00       2013-06-30
# 6994                        NaN              NaN
# 7809                        NaN              NaN
# 1284                        NaN              NaN
# 3870                        NaN              NaN
#
#                                                                                                                                                                                                                                                           Filer  \
# 4283         {'EIN': '941550842', 'Name': {'BusinessNameLine1': 'STANFORD SETTLEMENT INC'}, 'NameControl': 'STAN', 'Phone': '9169271303', 'USAddress': {'AddressLine1': '450 WEST EL CAMINO AVE', 'City': 'SACRAMENTO', 'State': 'CA', 'ZIPCode': '958332299'}}
# 6994  {'EIN': '383414580', 'BusinessName': {'BusinessNameLine1Txt': 'The Grand Rapids Red Project'}, 'BusinessNameControlTxt': 'GRAN', 'USAddress': {'AddressLine1Txt': '401 Hall Street SE', 'CityNm': 'Grand Rapids', 'StateAbbreviationCd': 'MI', 'ZIPCd'...
# 7809  {'EIN': '920177969', 'BusinessName': {'BusinessNameLine1Txt': 'COOK INLET LENDING CENTER'}, 'BusinessNameControlTxt': 'COOK', 'PhoneNum': '9077933000', 'USAddress': {'AddressLine1Txt': '3510 SPENARD ROAD NO 201', 'CityNm': 'ANCHORAGE', 'StateAbbr...
# 1284  {'EIN': '264338279', 'BusinessName': {'BusinessNameLine1Txt': 'PROJECT SOLE'}, 'BusinessNameControlTxt': 'PROJ', 'PhoneNum': '2148462042', 'USAddress': {'AddressLine1Txt': '1705 KELLY BLVD', 'CityNm': 'CARROLLTON', 'StateAbbreviationCd': 'TX', 'Z...
# 3870  {'EIN': '541478133', 'BusinessName': {'BusinessNameLine1Txt': 'THE COLLINS CENTER'}, 'BusinessNameControlTxt': 'COLL', 'PhoneNum': '5404326430', 'USAddress': {'AddressLine1Txt': '217 S LIBERTY STREET NO 205', 'CityNm': 'HARRISONBURG', 'StateAbbre...
#
#                                                                                                                                                 Officer  \
# 4283  {'Name': 'SISTER JEANNE FELION', 'Title': 'EXECUTIVE DIRECTOR', 'Phone': '9169271303', 'DateSigned': '2013-11-30', 'AuthorizeThirdParty': 'true'}
# 6994                                                                                                                                                NaN
# 7809                                                                                                                                                NaN
# 1284                                                                                                                                                NaN
# 3870                                                                                                                                                NaN
#
#      TaxYear F9_00_HD_BUILD_TIME_STAMP                   ReturnTs  \
# 4283    2012      2015-11-30 17:44:51Z                        NaN
# 6994     NaN      2019-02-21 02:37:17Z  2019-08-20T15:50:26-04:00
# 7809     NaN      2017-02-10 21:41:12Z  2017-09-07T12:54:29-05:00
# 1284     NaN      2016-03-07 17:11:31Z  2015-08-28T17:04:18-05:00
# 3870     NaN      2019-02-21 02:37:17Z  2019-05-10T07:17:15-05:00
#
#      TaxPeriodEndDt  \
# 4283            NaN
# 6994     2018-12-31
# 7809     2016-12-31
# 1284     2014-12-31
# 3870     2018-06-30
#
#                                                                                                                                                      BusinessOfficerGrp  \
# 4283                                                                                                                                                                NaN
# 6994    {'PersonNm': 'Stephen Alsum', 'PersonTitleTxt': 'Executive Direc', 'PhoneNum': '6164569063', 'SignatureDt': '2019-08-20', 'DiscussWithPaidPreparerInd': 'true'}
# 7809            {'PersonNm': 'JOE DUBLER', 'PersonTitleTxt': 'VP OF FINANCE', 'PhoneNum': '9077933000', 'SignatureDt': '2017-07-26', 'DiscussWithPaidPreparerInd': '1'}
# 1284           {'PersonNm': 'ZACH STEVENS', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '2148462042', 'SignatureDt': '2015-08-28', 'DiscussWithPaidPreparerInd': 'true'}
# 3870  {'PersonNm': 'MARIA SIMONETTI', 'PersonTitleTxt': 'EXECUTIVE DIRECTOR', 'PhoneNum': '5404326430', 'SignatureDt': '2019-05-09', 'DiscussWithPaidPreparerInd': '1'}
#
#      TaxYr  \
# 4283   NaN
# 6994  2018
# 7809  2016
# 1284  2014
# 3870  2017
#
#                                                                                                                                         F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 4283                  {'Name': 'SISTER JEANNE FELION', 'Title': 'EXECUTIVE DIRECTOR', 'Phone': '9169271303', 'DateSigned': '2013-11-30', 'AuthorizeThirdParty': 'true'}
# 6994    {'PersonNm': 'Stephen Alsum', 'PersonTitleTxt': 'Executive Direc', 'PhoneNum': '6164569063', 'SignatureDt': '2019-08-20', 'DiscussWithPaidPreparerInd': 'true'}
# 7809            {'PersonNm': 'JOE DUBLER', 'PersonTitleTxt': 'VP OF FINANCE', 'PhoneNum': '9077933000', 'SignatureDt': '2017-07-26', 'DiscussWithPaidPreparerInd': '1'}
# 1284           {'PersonNm': 'ZACH STEVENS', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '2148462042', 'SignatureDt': '2015-08-28', 'DiscussWithPaidPreparerInd': 'true'}
# 3870  {'PersonNm': 'MARIA SIMONETTI', 'PersonTitleTxt': 'EXECUTIVE DIRECTOR', 'PhoneNum': '5404326430', 'SignatureDt': '2019-05-09', 'DiscussWithPaidPreparerInd': '1'}
#
#             F9_00_HD_TIME_STAMP  \
# 4283  2014-02-19T17:31:19-06:00
# 6994  2019-08-20T15:50:26-04:00
# 7809  2017-09-07T12:54:29-05:00
# 1284  2015-08-28T17:04:18-05:00
# 3870  2019-05-10T07:17:15-05:00
#
#                                                                                                                                   F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE  \
# 4283                  {'Name': 'SISTER JEANNE FELION', 'Title': 'EXECUTIVE DIRECTOR', 'Phone': '9169271303', 'DateSigned': '2013-11-30', 'AuthorizeThirdParty': 'true'}
# 6994    {'PersonNm': 'Stephen Alsum', 'PersonTitleTxt': 'Executive Direc', 'PhoneNum': '6164569063', 'SignatureDt': '2019-08-20', 'DiscussWithPaidPreparerInd': 'true'}
# 7809            {'PersonNm': 'JOE DUBLER', 'PersonTitleTxt': 'VP OF FINANCE', 'PhoneNum': '9077933000', 'SignatureDt': '2017-07-26', 'DiscussWithPaidPreparerInd': '1'}
# 1284           {'PersonNm': 'ZACH STEVENS', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '2148462042', 'SignatureDt': '2015-08-28', 'DiscussWithPaidPreparerInd': 'true'}
# 3870  {'PersonNm': 'MARIA SIMONETTI', 'PersonTitleTxt': 'EXECUTIVE DIRECTOR', 'PhoneNum': '5404326430', 'SignatureDt': '2019-05-09', 'DiscussWithPaidPreparerInd': '1'}
#
#      F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR
# 4283           2013-06-30              2012
# 6994           2018-12-31              2018
# 7809           2016-12-31              2016
# 1284           2014-12-31              2014
# 3870           2018-06-30              2017

# %% [markdown]
# #### Save DF

# %%
import timeit
start_time = timeit.default_timer()
df.to_pickle('all filings feb. 2020 - select ReturnHeader variables.pkl')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.3671854616666678

# %% [markdown]
# ### *BusinessOfficerGrp*

# %%
def func(x, key1, key2):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    elif key2 in x.keys():
        return x[key2]
    else:
        return np.nan

# %%
concordance[concordance['sub_key'].notnull()]
# Out:
#                                                        xpath project  \
# 5        /Return/ReturnHeader/BusinessOfficerGrp/SignatureDt     NaN
# 6                    /Return/ReturnHeader/Officer/DateSigned     NaN
# 9                 /Return/ReturnHeader/Filer/USAddress/State     NaN
# 10  /Return/ReturnHeader/Filer/USAddress/StateAbbreviationCd     NaN
#
#                   variable_name_new  # of Characters (newly named)  \
# 5   F9_00_HD_SIGNING_OFFICER_SIGNTR                            NaN
# 6   F9_00_HD_SIGNING_OFFICER_SIGNTR                            NaN
# 9           F9_00_HD_FILER_STATE_US                            NaN
# 10          F9_00_HD_FILER_STATE_US                            NaN
#
#    variable name notes                      PARSING NOTES OTHER NOTES  \
# 5                  NaN  Will be nested under ReturnHeader         NaN
# 6                  NaN  Will be nested under ReturnHeader         NaN
# 9                  NaN  Will be nested under ReturnHeader         NaN
# 10                 NaN  Will be nested under ReturnHeader         NaN
#
#                                   description location_code     part  \
# 5         Date of Signing Officer's Signature        HEADER  PART-00
# 6         Date of Signing Officer's Signature        HEADER  PART-00
# 9   Address of Filing Organization (US State)        HEADER  PART-00
# 10  Address of Filing Organization (US State)        HEADER  PART-00
#
#    data_type_xsd BINARIZE        MongoDB_Name      sub_key  \
# 5       DateType      NaN  BusinessOfficerGrp  SignatureDt
# 6       DateType      NaN             Officer   DateSigned
# 9      StateType      NaN               Filer    USAddress
# 10     StateType      NaN               Filer    USAddress
#
#             sub_sub_key
# 5                   NaN
# 6                   NaN
# 9                 State
# 10  StateAbbreviationCd

# %%
df[:1]
# Out:
#               DLN        EIN  \
# 0  93493313013011  232705170
#
#                                            OrganizationName TaxPeriod  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC    201012
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#                    Timestamp TaxPeriodEndDate  \
# 0  2011-11-09T06:41:09-06:00       2010-12-31
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
#
#                                                                                                                         Officer  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   TaxYear F9_00_HD_BUILD_TIME_STAMP ReturnTs TaxPeriodEndDt  \
# 0    2010      2016-02-24 21:20:13Z      NaN            NaN
#
#   BusinessOfficerGrp TaxYr  \
# 0                NaN   NaN
#
#                                                                                                 F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#          F9_00_HD_TIME_STAMP  \
# 0  2011-11-09T06:41:09-06:00
#
#                                                                                           F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR
# 0           2010-12-31              2010

# %%
df['F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE'] = df['F9_00_HD_SIGNING_OFFICER_SIGNTR']

# %%
import timeit
start_time = timeit.default_timer()
df['F9_00_HD_SIGNING_OFFICER_SIGNTR'] = df['F9_00_HD_SIGNING_OFFICER_SIGNTR'][:].apply(func, key1='SignatureDt', key2='DateSigned')
#df['F9_09_PC_FEES_FOR_SVCE_MGMT_TOT2'] = df['ReturnHeader'].astype('float')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.18038617166666882

# %%
df[['EIN', 'F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE', 'F9_00_HD_SIGNING_OFFICER_SIGNTR']].sample(5)
# Out:
#             EIN  \
# 6162  570115330
# 5852  840504202
# 3297  481055202
# 8410  760351808
# 9081  741541774
#
#                                                                                                                                     F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE  \
# 6162  {'PersonNm': 'PAMELA L CHRISTOPHER', 'PersonTitleTxt': 'PRESIDENT & CEO', 'PhoneNum': '8642263454', 'SignatureDt': '2017-11-07', 'DiscussWithPaidPreparerInd': '1'}
# 5852              {'PersonNm': 'Debbie Bresina', 'PersonTitleTxt': 'President', 'PhoneNum': '3034251606', 'SignatureDt': '2017-11-28', 'DiscussWithPaidPreparerInd': '1'}
# 3297     {'PersonNm': 'JEANNIE BLANCK-GRIFFITH', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '7852724735', 'SignatureDt': '2014-07-11', 'DiscussWithPaidPreparerInd': '1'}
# 8410               {'PersonNm': 'JOHN BURNS', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '7134616533', 'SignatureDt': '2015-04-30', 'DiscussWithPaidPreparerInd': 'true'}
# 9081                               {'Name': 'ROBERT LUCIO', 'Title': 'EXECUTIVE DIRECTOR', 'Phone': '8303034376', 'DateSigned': '2012-08-08', 'AuthorizeThirdParty': '1'}
#
#                                                                                                                                           F9_00_HD_SIGNING_OFFICER_SIGNTR
# 6162  {'PersonNm': 'PAMELA L CHRISTOPHER', 'PersonTitleTxt': 'PRESIDENT & CEO', 'PhoneNum': '8642263454', 'SignatureDt': '2017-11-07', 'DiscussWithPaidPreparerInd': '1'}
# 5852              {'PersonNm': 'Debbie Bresina', 'PersonTitleTxt': 'President', 'PhoneNum': '3034251606', 'SignatureDt': '2017-11-28', 'DiscussWithPaidPreparerInd': '1'}
# 3297     {'PersonNm': 'JEANNIE BLANCK-GRIFFITH', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '7852724735', 'SignatureDt': '2014-07-11', 'DiscussWithPaidPreparerInd': '1'}
# 8410               {'PersonNm': 'JOHN BURNS', 'PersonTitleTxt': 'PRESIDENT', 'PhoneNum': '7134616533', 'SignatureDt': '2015-04-30', 'DiscussWithPaidPreparerInd': 'true'}
# 9081                               {'Name': 'ROBERT LUCIO', 'Title': 'EXECUTIVE DIRECTOR', 'Phone': '8303034376', 'DateSigned': '2012-08-08', 'AuthorizeThirdParty': '1'}

# %% [markdown]
# ### *F9_00_HD_FILER_STATE_US*

# %%
df[['Filer']].sample(2)
# Out:
#                                                                                                                                                                                                                                                           Filer
# 3927  {'EIN': '560623935', 'BusinessName': {'BusinessNameLine1Txt': 'CHARLOTTE COUNTRY DAY SCHOOL'}, 'BusinessNameControlTxt': 'CHAR', 'PhoneNum': '7049434500', 'USAddress': {'AddressLine1Txt': '1440 CARMEL ROAD', 'CityNm': 'CHARLOTTE', 'StateAbbreviat...
# 8632  {'EIN': '042978701', 'BusinessName': {'BusinessNameLine1Txt': 'MEDFIELD COALITION FOR PUBLIC EDUCATION', 'BusinessNameLine2Txt': 'INC'}, 'BusinessNameControlTxt': 'MEDF', 'PhoneNum': '5083591986', 'USAddress': {'AddressLine1Txt': 'C/O ADRIENNE BR...

# %%
def func_onekey(x, key1):
    if pd.isnull(x):
        return np.nan
    #else: 
    #    mydict = ast.literal_eval(x)
    elif key1 in x.keys():
        return x[key1]
    else:
        return np.nan

# %%
import timeit
start_time = timeit.default_timer()
df['USAddress'] = df['Filer'][:].apply(func_onekey, key1='USAddress')
#df['F9_09_PC_FEES_FOR_SVCE_MGMT_TOT2'] = df['ReturnHeader'].astype('float')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.19576037666666554

# %%
df[['EIN', 'Filer', 'USAddress']].sample(5)
# Out:
#             EIN  \
# 9633  621512543
# 8403  203970774
# 5970  382320469
# 4811  953457097
# 8169  202743344
#
#                                                                                                                                                                                                                                                           Filer  \
# 9633      {'EIN': '621512543', 'Name': {'BusinessNameLine1': 'SOUTH MEMPHIS ALLIANCE INCORPORATED'}, 'NameControl': 'SOUT', 'Phone': '9017749586', 'USAddress': {'AddressLine1': '1048 S BELLEVUE BLVD', 'City': 'MEMPHIS', 'State': 'TN', 'ZIPCode': '38106'}}
# 8403  {'EIN': '203970774', 'BusinessName': {'BusinessNameLine1': 'JERRY AND PAULA BAKER FOUNDATION', 'BusinessNameLine2': 'INC'}, 'BusinessNameControlTxt': 'JERR', 'PhoneNum': '2099627916', 'USAddress': {'AddressLine1': '12930 BOITANO COURT', 'City': '...
# 5970  {'EIN': '382320469', 'BusinessName': {'BusinessNameLine1Txt': 'MICHIGAN SCIENCE TEACHERS', 'BusinessNameLine2Txt': 'ASSOCIATION'}, 'BusinessNameControlTxt': 'MICH', 'PhoneNum': '7349730433', 'USAddress': {'AddressLine1Txt': '1390 EISENHOWER PLACE...
# 4811  {'EIN': '953457097', 'BusinessName': {'BusinessNameLine1Txt': 'ST NICHOLAS CEDARS MANOR INC', 'BusinessNameLine2Txt': 'C/O SK MANAGEMENT COMPANY LLC'}, 'BusinessNameControlTxt': 'STNI', 'PhoneNum': '3239302300', 'USAddress': {'AddressLine1Txt': '...
# 8169  {'EIN': '202743344', 'BusinessName': {'BusinessNameLine1': 'FOUNDATION FOR AFFORDABLE RENTAL HOUSING'}, 'BusinessNameControlTxt': 'FOUN', 'PhoneNum': '7704331711', 'USAddress': {'AddressLine1': '3330 CUMBERLAND BLVD SUITE 900', 'City': 'ATLANTA',...
#
#                                                                                                                  USAddress
# 9633                        {'AddressLine1': '1048 S BELLEVUE BLVD', 'City': 'MEMPHIS', 'State': 'TN', 'ZIPCode': '38106'}
# 8403                       {'AddressLine1': '12930 BOITANO COURT', 'City': 'GROVELAND', 'State': 'CA', 'ZIPCode': '95321'}
# 5970    {'AddressLine1Txt': '1390 EISENHOWER PLACE', 'CityNm': 'ANN ARBOR', 'StateAbbreviationCd': 'MI', 'ZIPCd': '48108'}
# 4811  {'AddressLine1Txt': '15910 VENTURA BLVD NO 1400', 'CityNm': 'ENCINO', 'StateAbbreviationCd': 'CA', 'ZIPCd': '91436'}
# 8169              {'AddressLine1': '3330 CUMBERLAND BLVD SUITE 900', 'City': 'ATLANTA', 'State': 'GA', 'ZIPCode': '30339'}

# %%
import timeit
start_time = timeit.default_timer()
df['F9_00_HD_FILER_STATE_US'] = df['USAddress'][:].apply(func, key1='State', key2='StateAbbreviationCd')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.1970622583333314

# %%
df[['EIN', 'Filer', 'USAddress', 'F9_00_HD_FILER_STATE_US']].sample(5)
# Out:
#             EIN  \
# 2946  710820020
# 6507  956095644
# 2809  132701075
# 6180  237409712
# 4880  233011941
#
#                                                                                                                                                                                                                                                           Filer  \
# 2946  {'EIN': '710820020', 'BusinessName': {'BusinessNameLine1Txt': 'JOYCORPS PROJECT'}, 'BusinessNameControlTxt': 'JOYC', 'PhoneNum': '4794426211', 'USAddress': {'AddressLine1Txt': 'PO BOX 8696', 'CityNm': 'FAYETTEVILLE', 'StateAbbreviationCd': 'AR', ...
# 6507            {'EIN': '956095644', 'Name': {'BusinessNameLine1': 'YOUTH TENNIS SAN DIEGO'}, 'NameControl': 'YOUT', 'Phone': '6192219000', 'USAddress': {'AddressLine1': '4490 WEST POINT LOMA BLVD', 'City': 'SAN DIEGO', 'State': 'CA', 'ZIPCode': '92107'}}
# 2809  {'EIN': '132701075', 'BusinessName': {'BusinessNameLine1Txt': 'DENTON GREEN HOUSING COMPANY INC'}, 'BusinessNameControlTxt': 'DENT', 'USAddress': {'AddressLine1Txt': '500 DENTON AVENUE', 'CityNm': 'GARDEN CITY PARK', 'StateAbbreviationCd': 'NY', ...
# 6180          {'EIN': '237409712', 'Name': {'BusinessNameLine1': 'THE SONGWRITERS GUILD FOUNDATION'}, 'NameControl': 'SONG', 'Phone': '6157429945', 'USAddress': {'AddressLine1': '5120 VIRGINIA WAY', 'City': 'BRENTWOOD', 'State': 'TN', 'ZIPCode': '37027'}}
# 4880  {'EIN': '233011941', 'Name': {'BusinessNameLine1': 'THE CENTER FOR LOSS AND BEREAVEMENT'}, 'NameControl': 'CENT', 'Phone': '6102224110', 'USAddress': {'AddressLine1': '3847 Skippack Pike', 'AddressLine2': 'PO Box 1299', 'City': 'Skippack', 'State...
#
#                                                                                                                          USAddress  \
# 2946                   {'AddressLine1Txt': 'PO BOX 8696', 'CityNm': 'FAYETTEVILLE', 'StateAbbreviationCd': 'AR', 'ZIPCd': '72703'}
# 6507                         {'AddressLine1': '4490 WEST POINT LOMA BLVD', 'City': 'SAN DIEGO', 'State': 'CA', 'ZIPCode': '92107'}
# 2809         {'AddressLine1Txt': '500 DENTON AVENUE', 'CityNm': 'GARDEN CITY PARK', 'StateAbbreviationCd': 'NY', 'ZIPCd': '11040'}
# 6180                                 {'AddressLine1': '5120 VIRGINIA WAY', 'City': 'BRENTWOOD', 'State': 'TN', 'ZIPCode': '37027'}
# 4880  {'AddressLine1': '3847 Skippack Pike', 'AddressLine2': 'PO Box 1299', 'City': 'Skippack', 'State': 'PA', 'ZIPCode': '19474'}
#
#      F9_00_HD_FILER_STATE_US
# 2946                      AR
# 6507                      CA
# 2809                      NY
# 6180                      TN
# 4880                      PA

# %% [markdown]
# #### Save DF

# %%
import timeit
start_time = timeit.default_timer()
df.to_pickle('all filings feb. 2020 - select ReturnHeader variables.pkl')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.7587211866666659

# %% [markdown]
# ### Check that total number of values in new variable equal sum of prior 2 variables

# %%
for index, row in new_variables_df[new_variables_df['len']==2][:].iterrows():
    #print(row['variable_name_new'])
    print(row['variable_name_new'], row['original_names'][0], row['original_names'][1])
    print(len(df[df[row['original_names'][0]].notnull()]) + len(df[df[row['original_names'][1]].notnull()]))    
    print(len(df[df[row['variable_name_new']].notnull()]), '\n')
    #print(len(df[(df[row['original_names'][0]].notnull()) & (df[row['original_names'][1]].notnull())]), '\n')
# Out:
# F9_00_HD_SIGNING_OFFICER_SIGNTR BusinessOfficerGrp Officer
# 1727056
# 1727056
#
# F9_00_HD_TAX_PER_END TaxPeriodEndDt TaxPeriodEndDate
# 1727056
# 1727056
#
# F9_00_HD_TAX_YEAR TaxYr TaxYear
# 1727056
# 1727056
#
# F9_00_HD_TIME_STAMP ReturnTs Timestamp
# 1727056
# 1727056

# %% [markdown]
# <br><br>
# From the above we are fine with deleting the 138 variables related to the 69 above variables in *variable_name_new*

# %% [markdown]
# ### Inspect the Combined and Original Variables
# Here I'm showing one variable

# %%
df[['F9_00_HD_TAX_YEAR', 'TaxYr', 'TaxYear']].sample(5)
# Out:
#      F9_00_HD_TAX_YEAR TaxYr TaxYear
# 5404              2017  2017     NaN
# 6923              2015  2015     NaN
# 7807              2017  2017     NaN
# 1830              2011   NaN    2011
# 8602              2010   NaN    2010

# %% [markdown]
# ### Drop variables

# %%
new_variables_df['original_names'].tolist()
# Out:
# [['BuildTS'],
#  ['Filer'],
#  ['BusinessOfficerGrp', 'Officer'],
#  ['TaxPeriodEndDt', 'TaxPeriodEndDate'],
#  ['TaxYr', 'TaxYear'],
#  ['ReturnTs', 'Timestamp']]

# %%
new_variables_df[new_variables_df['len']!=2]['original_names'].tolist()
# Out:
# [['BuildTS'], ['Filer']]

# %%
new_variables_df[new_variables_df['len']==2]['original_names'].tolist()
# Out:
# [['BusinessOfficerGrp', 'Officer'],
#  ['TaxPeriodEndDt', 'TaxPeriodEndDate'],
#  ['TaxYr', 'TaxYear'],
#  ['ReturnTs', 'Timestamp']]

# %%
flat_list = [item for sublist in new_variables_df[new_variables_df['len']==2]['original_names'].tolist() for item in sublist]
print(len(flat_list))
print(flat_list[:])
# Out:
# 8
# ['BusinessOfficerGrp', 'Officer', 'TaxPeriodEndDt', 'TaxPeriodEndDate', 'TaxYr', 'TaxYear', 'ReturnTs', 'Timestamp']

# %% [markdown]
# <br> Flatten a list of lists: https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-list-of-lists

# %%
print(len([c for c in df.columns.tolist() if c not in flat_list]))
print([c for c in df.columns.tolist() if c not in flat_list])
# Out:
# 14
# ['DLN', 'EIN', 'OrganizationName', 'TaxPeriod', 'URL', 'Filer', 'F9_00_HD_BUILD_TIME_STAMP', 'F9_00_HD_SIGNING_OFFICER_SIGNTR', 'F9_00_HD_TIME_STAMP', 'F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE', 'F9_00_HD_TAX_PER_END', 'F9_00_HD_TAX_YEAR', 'USAddress', 'F9_00_HD_FILER_STATE_US']

# %%
print(len(new_variables_df['variable_name_new'].tolist()))
# Out:
# 6

# %%
set([c for c in df.columns.tolist() if c not in flat_list]) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'DLN',
#  'EIN',
#  'F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE',
#  'Filer',
#  'OrganizationName',
#  'TaxPeriod',
#  'URL',
#  'USAddress'}

# %% [markdown]
# <br>The following block drops 310 columns

# %%
print(len(df.columns))
df = df[[c for c in df.columns.tolist() if c not in flat_list]]
print(len(df.columns))
df[:1]
# Out:
# 14
# 14
#               DLN        EIN  \
# 0  93493313013011  232705170
#
#                                            OrganizationName TaxPeriod  \
# 0  RONALD MCDONALD HOUSE CHARITIES- PHILADELPHIA REGION INC    201012
#
#                                                                    URL  \
# 0  https://s3.amazonaws.com/irs-form-990/201113139349301301_public.xml
#
#                                                                                                                                                                                                                                                        Filer  \
# 0  {'EIN': '232705170', 'Name': {'BusinessNameLine1': 'RONALD MCDONALD HOUSE CHARITIES-', 'BusinessNameLine2': 'PHILADELPHIA REGION INC'}, 'NameControl': 'RONA', 'Phone': '8565826843', 'USAddress': {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300...
#
#   F9_00_HD_BUILD_TIME_STAMP  \
# 0      2016-02-24 21:20:13Z
#
#                                                                                                 F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#          F9_00_HD_TIME_STAMP  \
# 0  2011-11-09T06:41:09-06:00
#
#                                                                                           F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE  \
# 0  {'Name': 'ROBERT TRAA', 'Title': 'TREASURER', 'Phone': '8565826843', 'DateSigned': '2011-11-04', 'AuthorizeThirdParty': '1'}
#
#   F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR  \
# 0           2010-12-31              2010
#
#                                                                                                        USAddress  \
# 0  {'AddressLine1': '1525 VALLEY CENTER PARKWAY NO 300', 'City': 'BETHLEHEM', 'State': 'PA', 'ZIPCode': '18017'}
#
#   F9_00_HD_FILER_STATE_US
# 0                      PA

# %%
df = df.drop('F9_00_HD_SIGNING_OFFICER_SIGNTR__SAFE', 1)
df = df.drop('Filer', 1)
df = df.drop('USAddress', 1)

# %% [markdown]
# ##### Verify

# %%
print(len(df.columns.tolist()))
# Out:
# 11

# %%
set(df.columns.tolist()) - set(new_variables_df['variable_name_new'].tolist())
# Out:
# {'DLN', 'EIN', 'OrganizationName', 'TaxPeriod', 'URL'}

# %%
set(new_variables_df['variable_name_new'].tolist()) - set(df.columns.tolist())
# Out:
# set()

# %%
df.sample(5)
# Out:
#                  DLN        EIN  \
# 8828  93493209009012  382872584
# 7095  93493139007046  010793507
# 3757  93493135047543  232455915
# 4462  93493193011596  061427077
# 9085  93493113006016  252120984
#
#                                            OrganizationName TaxPeriod  \
# 8828                    SUBSTANCE ABUSE PREVENTION SERVICES    201109
# 7095                     SOUTH CAROLINA COMMUNITY LOAN FUND    201512
# 3757                                    ACADEMIC ASSETS INC    201206
# 4462                          YOUNG MARINERS FOUNDATION INC    201508
# 9085  FEDERATION OF PITTSBURGH DIOCESAN TEACHERS LOCAL 2400    201512
#
#                                                                       URL  \
# 8828  https://s3.amazonaws.com/irs-form-990/201212099349300901_public.xml
# 7095  https://s3.amazonaws.com/irs-form-990/201641399349300704_public.xml
# 3757  https://s3.amazonaws.com/irs-form-990/201341359349304754_public.xml
# 4462  https://s3.amazonaws.com/irs-form-990/201641939349301159_public.xml
# 9085  https://s3.amazonaws.com/irs-form-990/201611139349300601_public.xml
#
#      F9_00_HD_BUILD_TIME_STAMP F9_00_HD_SIGNING_OFFICER_SIGNTR  \
# 8828      2016-02-24 21:20:13Z                      2012-07-23
# 7095      2016-09-27 15:27:22Z                      2016-05-16
# 3757      2016-02-24 21:20:13Z                      2013-05-15
# 4462      2016-09-27 15:27:22Z                      2016-07-11
# 9085      2016-09-27 15:27:22Z                      2016-04-22
#
#             F9_00_HD_TIME_STAMP F9_00_HD_TAX_PER_END F9_00_HD_TAX_YEAR  \
# 8828  2012-07-27T15:58:56-05:00           2011-09-30              2010
# 7095  2016-05-16T00:00:00-05:00           2015-12-31              2015
# 3757  2013-05-15T11:55:10-05:00           2012-06-30              2011
# 4462  2016-07-11T15:42:04-05:00           2015-08-31              2014
# 9085  2016-04-22T08:06:31-05:00           2015-12-31              2015
#
#      F9_00_HD_FILER_STATE_US
# 8828                      MI
# 7095                      SC
# 3757                      PA
# 4462                      CT
# 9085                      PA

# %% [markdown]
# ##### Save DF

# %%
import timeit
start_time = timeit.default_timer()
df.to_pickle('all filings feb. 2020 - select ReturnHeader variables.pkl')
elapsed = timeit.default_timer() - start_time
print('# of minutes: ', elapsed/60)
# Out:
# # of minutes:  0.19093227166666413
